# %% [markdown]
# # Create context-specific models using proteomic data
# ## Setup
# ### Import packages

# %%
from pathlib import Path

import gurobipy as gp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import sympy
from cobra.flux_analysis import find_blocked_reactions
from rbc_gem_utils import (COBRA_CONFIGURATION, PROCESSED_PATH, ROOT_PATH,
                           read_cobra_model, show_versions, write_cobra_model)
from rbc_gem_utils.analysis.overlay import (ComplexDilution, ProteinDilution,
                                            add_relaxation_budget,
                                            load_overlay_model,
                                            update_slack_value)
from rbc_gem_utils.util import AVOGADRO_NUMBER, DEFAULT_DRY_MASS_PER_CELL
from sklearn.metrics import r2_score

gp.setParam("OutputFlag", 0)
gp.setParam("LogToConsole", 0)

# Show versions of notebook
show_versions()
# Out:
# Set parameter Username
#
# Package Information
# -------------------
# rbc-gem-utils 0.0.1
#
# Dependency Information
# ----------------------
# beautifulsoup4                       4.12.3
# bio                                 missing
# cobra                                0.29.1
# depinfo                               2.2.0
# gurobipy                             11.0.3
# matplotlib                           3.10.0
# matplotlib-venn                       1.1.1
# memote                               0.17.0
# networkx                              3.4.2
# notebook                              7.3.2
# openpyxl                              3.1.5
# pandas                                2.2.3
# pre-commit                            4.1.0
# rbc-gem-utils[database,network,vis] missing
# requests                             2.32.3
# scipy                                1.15.1
# seaborn                              0.13.2
#
# Build Tools Information
# -----------------------
# pip          24.2
# setuptools 75.1.0
# wheel      0.44.0
#
# Platform Information
# --------------------
# Windows 11-AMD64
# CPython   3.12.8

# %% [markdown]
# ### Define configuration
# #### COBRA Configuration

# %%
COBRA_CONFIGURATION.solver = "gurobi"
COBRA_CONFIGURATION.bounds = (-1e8, 1e8)
COBRA_CONFIGURATION
# Out:
# solver: gurobi
# tolerance: 1e-07
# lower_bound: -100000000.0
# upper_bound: 100000000.0
# processes: 127
# cache_directory: C:\Users\Alicia Key\AppData\Local\opencobra\cobrapy\Cache
# max_cache_size: 104857600
# cache_expiration: None

# %% [markdown]
# ## Load RBC-GEM model

# %%
# model_id = "RBC3P"

# data_path = Path(f"{ROOT_PATH}/data/analysis/OVERLAY").resolve()
# results_path = Path(f"{ROOT_PATH}{PROCESSED_PATH}/{model_id}/OVERLAY")
# results_path.mkdir(exist_ok=True, parents=True)

# imagetype = "svg"
# transparent = True
# save_figures = True
# overwrite = True

# dataset_name = "RBComics"
# pcmodel_dirpath = Path(f"{data_path}/{model_id}")
# dataset_path = Path(f"{results_path}/{dataset_name}")
# dataset_models_dirpath = Path(f"{dataset_path}/pcmodels")

# sample_prefix, time_prefix = ("S", "D")
# # Integers are easier to work with for time points
# timepoints = [10, 23, 42]

# model = read_cobra_model(filename=f"{pcmodel_dirpath}/{model_id}.xml")
# pcmodel = load_overlay_model(filename=f"{pcmodel_dirpath}/{model_id}_PC.xml")

# pcmodel

# model_id = "RBC3P"
model_id = "RBC3P_expanded"

data_path = Path("../../../../data/analysis/OVERLAY").resolve()
root_path = Path("../../../..").resolve()
results_path = root_path / "data" / "processed" / model_id / "OVERLAY"
results_path.mkdir(exist_ok=True, parents=True)

imagetype = "svg"
transparent = True
save_figures = True
overwrite = True

dataset_name = "RBComics"
pcmodel_dirpath = data_path / model_id
dataset_path = results_path / dataset_name
dataset_models_dirpath = dataset_path / "pcmodels"

sample_prefix, time_prefix = ("S", "D")
# Integers are easier to work with for time points
timepoints = [10, 23, 42]

model_filename = pcmodel_dirpath / f"{model_id}.xml"
model = read_cobra_model(filename=model_filename)
pcmodel_filename = pcmodel_dirpath / f"{model_id}_PC.xml"
pcmodel = load_overlay_model(filename=pcmodel_filename)

pcmodel
# Out:
# <Model RBC3P_PC at 0x1c2f90cffe0>

# %% [markdown]
# ## Load RBC Proteomics

# %%
# Ensure index corresponds to sample IDs and columns are proteins IDs
df_copy_number_samples_filename = data_path / dataset_name / "Proteomics_CopyNumbers.tsv"
df_copy_number_samples = pd.read_csv(
    df_copy_number_samples_filename, sep="\t", index_col=0
)
sample_ids = df_copy_number_samples.index
df_copy_number_samples
# Out:
#                 P69905        P68871        P02042        P02008  \
# S1_D10    1.254607e+08  6.751875e+07  1.684139e+08  3.409157e+07
# S2_D10    1.622846e+08  3.248112e+07  2.455682e+08  6.281825e+07
# S3_D10    1.408849e+08  9.282055e+07  2.866462e+08  3.096045e+07
# S4_D10    1.533373e+08  9.428727e+07  2.796149e+08  4.492695e+07
# S5_D10    1.451599e+08  7.885271e+07  2.064930e+08  5.865059e+07
# ...                ...           ...           ...           ...
# S612_D42  1.479013e+08  9.034572e+07  1.777762e+08  5.760717e+07
# S613_D42  1.502160e+08  1.017134e+08  1.650392e+08  7.026294e+07
# S614_D42  1.367636e+08  7.392661e+07  1.359617e+08  5.370047e+07
# S615_D42  1.452709e+08  8.787838e+07  1.717963e+08  5.531884e+07
# S616_D42  1.508962e+08  9.040845e+07  1.687312e+08  5.736702e+07
#
#                 P02730        P30043        P32119        P02768  \
# S1_D10    4.582424e+06  1.956960e+07  7.461828e+06  4.729611e+06
# S2_D10    5.497925e+06  2.819367e+07  1.184191e+07  3.586910e+06
# S3_D10    4.302025e+06  1.713969e+07  8.752663e+06  2.807233e+06
# S4_D10    3.875573e+06  2.500399e+07  8.190457e+06  3.354456e+06
# S5_D10    6.774951e+06  2.690653e+07  1.633960e+07  3.973826e+06
# ...                ...           ...           ...           ...
# S612_D42  6.396855e+06  2.158214e+07  1.311621e+07  4.412278e+06
# S613_D42  6.076268e+06  2.803835e+07  1.344956e+07  3.119734e+06
# S614_D42  5.640477e+06  2.786735e+07  1.309307e+07  1.950198e+06
# S615_D42  6.005166e+06  2.895227e+07  1.179158e+07  2.199533e+06
# S616_D42  6.505993e+06  2.793557e+07  1.335286e+07  2.895548e+06
#
#                 Q92902        P04040  ...  Q9Y3E7        Q9Y4Y9       Q9Y508  \
# S1_D10    3.697239e+06  3.742403e+06  ...     0.0      0.000000     0.000000
# S2_D10    2.223799e+06  2.496767e+06  ...     0.0      0.000000  9634.822452
# S3_D10    1.635281e+07  8.260527e+05  ...     0.0      0.000000     0.000000
# S4_D10    1.123342e+06  3.666083e+06  ...     0.0      0.000000     0.000000
# S5_D10    2.859506e+06  4.664673e+06  ...     0.0  27830.662335     0.000000
# ...                ...           ...  ...     ...           ...          ...
# S612_D42  2.390702e+06  4.028351e+06  ...     0.0      0.000000     0.000000
# S613_D42  2.704957e+06  4.309456e+06  ...     0.0      0.000000     0.000000
# S614_D42  3.363896e+06  3.664767e+06  ...     0.0      0.000000     0.000000
# S615_D42  1.464653e+06  4.171225e+06  ...     0.0      0.000000     0.000000
# S616_D42  1.462335e+06  3.358596e+06  ...     0.0      0.000000     0.000000
#
#                Q9Y587       Q9Y5B8  Q9Y5P4        Q9Y5Y2       Q9Y666  \
# S1_D10       0.000000  7378.473625     0.0      0.000000     0.000000
# S2_D10    5263.615637   805.935440     0.0      0.000000  4567.509290
# S3_D10       0.000000     0.000000     0.0      0.000000  2406.122450
# S4_D10       0.000000     0.000000     0.0      0.000000     0.000000
# S5_D10       0.000000     0.000000     0.0      0.000000     0.000000
# ...               ...          ...     ...           ...          ...
# S612_D42     0.000000     0.000000     0.0  14528.761376  3442.080339
# S613_D42     0.000000     0.000000     0.0      0.000000     0.000000
# S614_D42     0.000000     0.000000     0.0  15479.120703  4372.160364
# S615_D42     0.000000     0.000000     0.0      0.000000     0.000000
# S616_D42     0.000000     0.000000     0.0  23856.349951     0.000000
#
#                Q9Y6B7         Q9Y6M4
# S1_D10    1088.451504       0.000000
# S2_D10       0.000000       0.000000
# S3_D10       0.000000       0.000000
# S4_D10    1195.145799       0.000000
# S5_D10       0.000000       0.000000
# ...               ...            ...
# S612_D42     0.000000  211244.957057
# S613_D42     0.000000       0.000000
# S614_D42     0.000000    5809.848633
# S615_D42     0.000000       0.000000
# S616_D42     0.000000  330688.105916
#
# [1848 rows x 1827 columns]

# %%
def get_sample_from_id(model_id, sample_prefix=""):
    sample = model_id.rsplit("_", 2)[-2]
    try:
        return int(sample.replace(sample_prefix, ""))
    except ValueError:
        return sample


def get_time_from_id(model_id, time_prefix=""):
    time = model_id.rsplit("_", 2)[-1]
    try:
        return int(time.replace(time_prefix, ""))
    except ValueError:
        return time

# %% [markdown]
# ### Get data subsets using operations on data

# %%
operations = [
    "mean",
    "median",
    # "min",
    # "max",
]
percentiles = [
    # 0.00, # Minimum
    # 0.10,
    # 0.20, # Quintile 1
    # 0.25, # Quartile 1
    # 0.30,
    # 0.40, # Quintile 2
    # 0.50, # Median, Quartile 2,
    # 0.60, # Quintile 3
    # 0.70,
    # 0.75, # Quartile 3
    # 0.80, # Quintile 4
    # 0.90,
    # 1.00, # Maximum, Quintile 5
]


if operations or percentiles:
    df_operations = []
    for time in timepoints:
        df_time = df_copy_number_samples.loc[
            [
                x
                for x in df_copy_number_samples.index
                if get_time_from_id(x, time_prefix) == time
            ]
        ].T
        df_op = pd.concat(
            [getattr(df_time, op.lower())(axis=1) for op in operations], axis=1
        )
        df_op.columns = [f"{op.capitalize()}_{time_prefix}{time}" for op in operations]
        df_operations += [df_op]
        if percentiles:
            df_op = pd.concat(
                [df_time.quantile(percent, axis=1) for percent in percentiles], axis=1
            )
            df_op.columns = [
                f"Percentile{int(round(percent * 100, 0))}_{time_prefix}{time}"
                for percent in percentiles
            ]
            df_operations += [df_op]
    df_operations = pd.concat(df_operations, axis=1)
    operation_ids = df_operations.columns
    df_copy_number_all = pd.concat((df_copy_number_samples.T, df_operations), axis=1).T
else:
    df_copy_number_all = df_copy_number_samples.T
    operation_ids = []
df_copy_number_all
# Out:
#                   P69905        P68871        P02042        P02008  \
# S1_D10      1.254607e+08  6.751875e+07  1.684139e+08  3.409157e+07
# S2_D10      1.622846e+08  3.248112e+07  2.455682e+08  6.281825e+07
# S3_D10      1.408849e+08  9.282055e+07  2.866462e+08  3.096045e+07
# S4_D10      1.533373e+08  9.428727e+07  2.796149e+08  4.492695e+07
# S5_D10      1.451599e+08  7.885271e+07  2.064930e+08  5.865059e+07
# ...                  ...           ...           ...           ...
# Median_D10  1.284522e+08  7.688185e+07  1.857545e+08  5.736548e+07
# Mean_D23    1.302204e+08  7.752765e+07  1.823978e+08  5.432346e+07
# Median_D23  1.296389e+08  7.714224e+07  1.820727e+08  5.597670e+07
# Mean_D42    1.303787e+08  7.906095e+07  1.837488e+08  5.559319e+07
# Median_D42  1.292425e+08  7.898725e+07  1.818945e+08  5.758715e+07
#
#                   P02730        P30043        P32119        P02768  \
# S1_D10      4.582424e+06  1.956960e+07  7.461828e+06  4.729611e+06
# S2_D10      5.497925e+06  2.819367e+07  1.184191e+07  3.586910e+06
# S3_D10      4.302025e+06  1.713969e+07  8.752663e+06  2.807233e+06
# S4_D10      3.875573e+06  2.500399e+07  8.190457e+06  3.354456e+06
# S5_D10      6.774951e+06  2.690653e+07  1.633960e+07  3.973826e+06
# ...                  ...           ...           ...           ...
# Median_D10  6.005098e+06  2.377645e+07  1.446120e+07  4.096275e+06
# Mean_D23    6.132440e+06  2.397774e+07  1.456396e+07  4.352813e+06
# Median_D23  6.063446e+06  2.407633e+07  1.467926e+07  4.294531e+06
# Mean_D42    6.128426e+06  2.366743e+07  1.468774e+07  4.274537e+06
# Median_D42  6.101236e+06  2.385596e+07  1.472559e+07  4.139741e+06
#
#                   Q92902        P04040  ...       Q9Y3E7        Q9Y4Y9  \
# S1_D10      3.697239e+06  3.742403e+06  ...     0.000000      0.000000
# S2_D10      2.223799e+06  2.496767e+06  ...     0.000000      0.000000
# S3_D10      1.635281e+07  8.260527e+05  ...     0.000000      0.000000
# S4_D10      1.123342e+06  3.666083e+06  ...     0.000000      0.000000
# S5_D10      2.859506e+06  4.664673e+06  ...     0.000000  27830.662335
# ...                  ...           ...  ...          ...           ...
# Median_D10  3.255035e+06  3.927278e+06  ...     0.000000      0.000000
# Mean_D23    3.369690e+06  4.035905e+06  ...  7305.738347   7519.400845
# Median_D23  3.122707e+06  4.045507e+06  ...     0.000000      0.000000
# Mean_D42    3.465648e+06  4.026779e+06  ...  6759.163035   7153.770726
# Median_D42  3.247272e+06  4.072650e+06  ...     0.000000      0.000000
#
#                  Q9Y508       Q9Y587       Q9Y5B8      Q9Y5P4       Q9Y5Y2  \
# S1_D10         0.000000     0.000000  7378.473625    0.000000     0.000000
# S2_D10      9634.822452  5263.615637   805.935440    0.000000     0.000000
# S3_D10         0.000000     0.000000     0.000000    0.000000     0.000000
# S4_D10         0.000000     0.000000     0.000000    0.000000     0.000000
# S5_D10         0.000000     0.000000     0.000000    0.000000     0.000000
# ...                 ...          ...          ...         ...          ...
# Median_D10     0.000000     0.000000     0.000000    0.000000     0.000000
# Mean_D23    3002.879818  3112.450644  2462.756244  383.923288  8859.738472
# Median_D23     0.000000     0.000000     0.000000    0.000000     0.000000
# Mean_D42    2592.430167  2252.168514  2036.105208  411.562739  6677.485580
# Median_D42     0.000000     0.000000     0.000000    0.000000     0.000000
#
#                  Q9Y666       Q9Y6B7        Q9Y6M4
# S1_D10         0.000000  1088.451504      0.000000
# S2_D10      4567.509290     0.000000      0.000000
# S3_D10      2406.122450     0.000000      0.000000
# S4_D10         0.000000  1195.145799      0.000000
# S5_D10         0.000000     0.000000      0.000000
# ...                 ...          ...           ...
# Median_D10     0.000000     0.000000      0.000000
# Mean_D23     226.333657   317.493351  26127.128644
# Median_D23     0.000000     0.000000      0.000000
# Mean_D42     215.658003   281.011732  30923.648721
# Median_D42     0.000000     0.000000      0.000000
#
# [1854 rows x 1827 columns]

# %% [markdown]
# ## Integrate proteomics with model
# ### Convert copy numbers to mg / gDW

# %%
df_protein_data = pd.read_csv(
    f"{data_path}/{dataset_name}/{dataset_name}_protein_data.tsv",
    sep="\t",
    index_col="Entry",
)
df_uniprot_to_mw = df_protein_data["Mass"] / 1000  # g/mol --> # kg / mol

df_mg_prot_per_gDW = (
    df_copy_number_all  # protein copies / cell
    * (1 / DEFAULT_DRY_MASS_PER_CELL)  # cell / pgDW
    * (1e12 / 1)  # pgDW / gDW
    * (1 / AVOGADRO_NUMBER)  # mol / protein copies
    * (df_uniprot_to_mw)  # kg / mol
    * (1e6 / 1)  # mg / kg
).copy()
df_mg_prot_per_gDW
# Out:
#                 P69905     P68871      P02042     P02008     P02730  \
# S1_D10      105.957851  59.788534  149.663564  29.507223  25.818843
# S2_D10      137.057505  28.762364  218.227945  54.370974  30.977066
# S3_D10      118.984330  82.193540  254.732482  26.797142  24.238983
# S4_D10      129.501028  83.492334  248.484024  38.885552  21.836219
# S5_D10      122.594800  69.824876  183.503129  50.763743  38.172241
# ...                ...        ...         ...        ...        ...
# Median_D10  108.484363  68.079656  165.073523  49.651448  33.834643
# Mean_D23    109.977619  68.651522  162.090554  47.018489  34.552125
# Median_D23  109.486564  68.310233  161.801687  48.449421  34.163395
# Mean_D42    110.111346  70.009273  163.291184  48.117479  34.529511
# Median_D42  109.151747  69.944008  161.643340  49.843311  34.376315
#
#                P30043     P32119     P02768     Q92902     P04040  ...  \
# S1_D10      23.959362   9.041875  18.159596  16.226867  12.378269  ...
# S2_D10      34.517950  14.349439  13.772135   9.760067   8.258238  ...
# S3_D10      20.984383  10.606046  10.778522  71.771113   2.732229  ...
# S4_D10      30.612770   9.924792  12.879614   4.930253  12.125835  ...
# S5_D10      32.942075  19.799519  15.257717  12.550130  15.428745  ...
# ...               ...        ...        ...        ...        ...  ...
# Median_D10  29.109870  17.523372  15.727869  14.286073  12.989758  ...
# Mean_D23    29.356315  17.647893  16.712859  14.789286  13.349048  ...
# Median_D23  29.477020  17.787602  16.489081  13.705296  13.380806  ...
# Mean_D42    28.976400  17.797882  16.412313  15.210435  13.318863  ...
# Median_D42  29.207215  17.843742  15.894759  14.252000  13.470583  ...
#
#               Q9Y3E7    Q9Y4Y9    Q9Y508    Q9Y587    Q9Y5B8    Q9Y5P4  \
# S1_D10      0.000000  0.000000  0.000000  0.000000  0.017354  0.000000
# S2_D10      0.000000  0.000000  0.013703  0.004954  0.001896  0.000000
# S3_D10      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# S4_D10      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# S5_D10      0.000000  0.015308  0.000000  0.000000  0.000000  0.000000
# ...              ...       ...       ...       ...       ...       ...
# Median_D10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Mean_D23    0.010139  0.004136  0.004271  0.002930  0.005792  0.001505
# Median_D23  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Mean_D42    0.009381  0.003935  0.003687  0.002120  0.004789  0.001614
# Median_D42  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#               Q9Y5Y2    Q9Y666    Q9Y6B7    Q9Y6M4
# S1_D10      0.000000  0.000000  0.005016  0.000000
# S2_D10      0.000000  0.030112  0.000000  0.000000
# S3_D10      0.000000  0.015863  0.000000  0.000000
# S4_D10      0.000000  0.000000  0.005508  0.000000
# S5_D10      0.000000  0.000000  0.000000  0.000000
# ...              ...       ...       ...       ...
# Median_D10  0.000000  0.000000  0.000000  0.000000
# Mean_D23    0.014136  0.001492  0.001463  0.074317
# Median_D23  0.000000  0.000000  0.000000  0.000000
# Mean_D42    0.010654  0.001422  0.001295  0.087961
# Median_D42  0.000000  0.000000  0.000000  0.000000
#
# [1854 rows x 1827 columns]

# %% [markdown]
# ### Scale measurements for proteome budget
# Note that this step will help ensure its theoretically possible for a perfect fit
#
# TODO: Change budget for the whole model. Could be personalized to the CBC hemoglobin measurements in the future. ANy protein not in hb_proteins dictionary goes to low abundance proteome. Scaling issues should be addressed by modifying the proteome_budget_value.

# %%
proteome_budget_value = 50
hemoglobin_budget_value = 950
total_budget_value = None

# %%
# Split into hemoglobin and low abundance proteomes
hb_proteins = {
    # Model Gene: UniProt ID
    "HBA": "P69905",
    "HBB": "P68871",
    "HBD": "P02042",
    "HBM": "Q6B0K9",
    "HBE1": "P02100",
    "HBG1": "P69891",
    "HBG2": "P69892",
    "HBQ1": "P09105",
    "HBZ": "P02008",
}
df_mg_prot_per_gDW_hb = df_mg_prot_per_gDW.loc[:, list(hb_proteins.values())]
df_mg_prot_per_gDW_la = df_mg_prot_per_gDW.loc[
    :, [x for x in df_mg_prot_per_gDW.columns if not x in list(hb_proteins.values())]
]

PBDL_proteome_budget = pcmodel.reactions.get_by_id("PBDL_proteome_budget")
PBDL_hemoglobin_budget = pcmodel.reactions.get_by_id("PBDL_hemoglobin_budget")
PBDL_total_budget = pcmodel.reactions.get_by_id("PBDL_total_budget")

if proteome_budget_value is None:
    proteome_budget_value = PBDL_proteome_budget.upper_bound
if hemoglobin_budget_value is None:
    hemoglobin_budget_value = PBDL_hemoglobin_budget.upper_bound
if total_budget_value is None:
    total_budget_value = PBDL_total_budget.upper_bound

assert total_budget_value >= (proteome_budget_value + hemoglobin_budget_value)

PBDL_proteome_budget.upper_bound = proteome_budget_value
PBDL_hemoglobin_budget.upper_bound = hemoglobin_budget_value
PBDL_total_budget.upper_bound = total_budget_value

# Scale values for low abundance proteome
budget_value = proteome_budget_value
df_mg_prot_per_gDW_la = (
    budget_value * (df_mg_prot_per_gDW_la.T / df_mg_prot_per_gDW_la.sum(axis=1)).T
)
print(f"Low abundance budget:\t{budget_value}\t(={budget_value * 100 / 1000}%)")

# Scale values for hemoglobin proteome
budget_value = hemoglobin_budget_value
df_mg_prot_per_gDW_hb = (
    budget_value * (df_mg_prot_per_gDW_hb.T / df_mg_prot_per_gDW_hb.sum(axis=1)).T
)
print(f"Hemoglobin budget:\t{budget_value}\t(={budget_value * 100 / 1000}%)")

budget_value = total_budget_value - sum(
    [proteome_budget_value, hemoglobin_budget_value]
)
print(f"Remaining budget:\t{budget_value}\t(={budget_value * 100 / 1000}%)")


# Combine dataframes back into one
df_mg_prot_per_gDW_normalized = pd.concat(
    (df_mg_prot_per_gDW_hb, df_mg_prot_per_gDW_la), axis=1
)
df_mg_prot_per_gDW_normalized.sum(axis=1)
# Out:
# Low abundance budget:	50	(=5.0%)
# Hemoglobin budget:	950	(=95.0%)
# Remaining budget:	0.0	(=0.0%)
# S1_D10        1000.0
# S2_D10        1000.0
# S3_D10        1000.0
# S4_D10        1000.0
# S5_D10        1000.0
#                ...
# Median_D10    1000.0
# Mean_D23      1000.0
# Median_D23    1000.0
# Mean_D42      1000.0
# Median_D42    1000.0
# Length: 1854, dtype: float64

# %% [markdown]
# ### Convert mg / gDW to nmol / gDW

# %%
df_nmol_prot_per_gDW = (
    df_mg_prot_per_gDW_normalized  # mg / gDW
    * (1 / df_uniprot_to_mw)  # mol / kg --> mmol / g --> umol / mg
    * (1e3 / 1)  # nmol / umol
).loc[:, df_mg_prot_per_gDW_normalized.columns]
df_nmol_prot_per_gDW = df_nmol_prot_per_gDW.T
df_nmol_prot_per_gDW
# Out:
#               S1_D10        S2_D10        S3_D10        S4_D10        S5_D10  \
# P69905  18075.456265  19105.243829  14631.076044  15795.176173  17661.151783
# P68871   9727.605483   3823.897600   9639.535334   9712.471978   9593.764725
# P02042  24263.838621  28909.955711  29768.580366  28802.953963  25123.361602
# Q6B0K9      1.099138      2.590875      1.391985      0.533154      1.488096
# P02100     22.727215      4.572540     40.030657      7.151495      1.010539
# ...              ...           ...           ...           ...           ...
# Q9Y5P4      0.000000      0.000000      0.000000      0.000000      0.000000
# Q9Y5Y2      0.000000      0.000000      0.000000      0.000000      0.000000
# Q9Y666      0.000000      0.025974      0.013674      0.000000      0.000000
# Q9Y6B7      0.006719      0.000000      0.000000      0.007583      0.000000
# Q9Y6M4      0.000000      0.000000      0.000000      0.000000      0.000000
#
#               S6_D10        S7_D10        S8_D10        S9_D10       S10_D10  \
# P69905  14369.457430  16482.836004  17024.362893  18247.365578  13824.557293
# P68871   9616.806176   9343.460129  10447.359061   9235.087988  11520.337791
# P02042  27530.494873  26710.237232  26080.913045  23484.891677  31112.255681
# Q6B0K9      2.893080      1.571854      0.650999      2.112306      1.093055
# P02100      7.195636      4.952831     22.739866     10.241859      0.000000
# ...              ...           ...           ...           ...           ...
# Q9Y5P4      0.000000      0.000000      0.000000      0.000000      0.000000
# Q9Y5Y2      0.000000      0.000000      0.221546      0.056889      0.324932
# Q9Y666      0.000000      0.000000      0.000000      0.000000      0.006972
# Q9Y6B7      0.000000      0.000000      0.006187      0.000000      0.000000
# Q9Y6M4      0.000000      0.028856      0.025749      0.000000      0.373526
#
#         ...      S613_D42      S614_D42      S615_D42      S616_D42  \
# P69905  ...  18344.370208  20262.437710  18716.059561  19264.958518
# P68871  ...  12421.232692  10952.717581  11321.864768  11542.469619
# P02042  ...  20154.572117  20143.627236  22133.485184  21541.956347
# Q6B0K9  ...      0.904652      0.639794      0.342624      0.912871
# P02100  ...      1.065640      2.262286    257.491334      1.929639
# ...     ...           ...           ...           ...           ...
# Q9Y5P4  ...      0.000000      0.000000      0.000000      0.000000
# Q9Y5Y2  ...      0.000000      0.096251      0.000000      0.129936
# Q9Y666  ...      0.000000      0.027187      0.000000      0.000000
# Q9Y6B7  ...      0.000000      0.000000      0.000000      0.000000
# Q9Y6M4  ...      0.000000      0.036126      0.000000      1.801121
#
#             Mean_D10    Median_D10      Mean_D23    Median_D23      Mean_D42  \
# P69905  16944.867231  16924.927324  17225.911342  17224.795418  17080.277399
# P68871  10270.881971  10129.988121  10255.574196  10249.694718  10357.390088
# P02042  24319.157589  24475.095067  24128.087747  24191.544202  24072.039600
# Q6B0K9      2.189801      1.376492      2.279456      1.439005      2.761238
# P02100     27.420626      6.425119     24.510769      5.923681     22.998424
# ...              ...           ...           ...           ...           ...
# Q9Y5P4      0.001745      0.000000      0.001989      0.000000      0.002148
# Q9Y5Y2      0.037245      0.000000      0.045901      0.000000      0.034848
# Q9Y666      0.001064      0.000000      0.001173      0.000000      0.001125
# Q9Y6B7      0.001418      0.000000      0.001645      0.000000      0.001467
# Q9Y6M4      0.135355      0.000000      0.135360      0.000000      0.161381
#
#           Median_D42
# P69905  17059.903775
# P68871  10426.254469
# P02042  24009.936113
# Q6B0K9      1.795620
# P02100      6.226073
# ...              ...
# Q9Y5P4      0.000000
# Q9Y5Y2      0.000000
# Q9Y666      0.000000
# Q9Y6B7      0.000000
# Q9Y6M4      0.000000
#
# [1827 rows x 1854 columns]

# %% [markdown]
# ## Create DataFrame for protein dilution reactions

# %%
df_model_protein_dilutions = pd.concat(
    (
        pd.Series(
            {g.annotation.get("uniprot"): g.id for g in model.genes}, name="genes"
        ),
        pd.Series(
            {
                protdl.annotation.get("uniprot"): protdl.id
                for protdl in pcmodel.reactions.query(
                    lambda x: isinstance(x, ProteinDilution)
                )
            },
            name="PROTDL",
        ),
    ),
    axis=1,
)
df_model_protein_dilutions.index.name = "uniprot"
df_model_protein_dilutions = df_model_protein_dilutions[
    df_model_protein_dilutions["genes"].isin(model.genes.list_attr("id"))
].sort_values("PROTDL")
df_model_protein_dilutions
# Out:
#            genes                     PROTDL
# uniprot
# P00813       ADA      PROTDL_protein_ADA_pc
# P55263       ADK      PROTDL_protein_ADK_pc
# P00568       AK1      PROTDL_protein_AK1_pc
# P04075     ALDOA    PROTDL_protein_ALDOA_pc
# P05062     ALDOB    PROTDL_protein_ALDOB_pc
# ...          ...                        ...
# Q9BVC6   TMEM109  PROTDL_protein_TMEM109_pc
# P60174      TPI1     PROTDL_protein_TPI1_pc
# Q9Y210     TRPC6    PROTDL_protein_TRPC6_pc
# Q9Y5S1     TRPV2    PROTDL_protein_TRPV2_pc
# P21796     VDAC1    PROTDL_protein_VDAC1_pc
#
# [103 rows x 2 columns]

# %% [markdown]
# ## Organize samples

# %%
df_samples = df_nmol_prot_per_gDW.copy()

# Best to sort by donor, if sample fails solving at any point, only need to redo the n_timepoints associated with sample.
sort_samples_by_donor = True
merge_key = "uniprot"
run_computations = True

# Use this line of code to determine which samples are used.
# Useful for picking up where notebook may have prematurely stopped.
# Set as 0 or less to use all samples
start_from_sample_id = 0
# Set as 0 or less to use only operation samples
# end_on_sample_id = 0
# Set as length of samples to use all samples
end_on_sample_id = len(df_samples)

# Use this line of code to determine which time points are used.
# Comment out to keep all original points defined in samples
timepoints = [10, 23, 42]
df_samples.index.name = merge_key
# Filter out time points
df_samples = df_samples.loc[
    :, [x for x in df_samples.columns if get_time_from_id(x, time_prefix) in timepoints]
]
# Filter out irrelevant samples
df_samples = pd.concat(
    (
        df_samples.loc[
            :,
            [
                x
                for x in sample_ids
                if start_from_sample_id
                <= get_sample_from_id(x, sample_prefix)
                <= end_on_sample_id
            ],
        ],
        df_samples.loc[:, [x for x in df_samples.columns if x in operation_ids]],
    ),
    axis=1,
)

if sort_samples_by_donor:
    df_samples = pd.concat(
        (
            df_samples.loc[
                :,
                sorted(
                    [x for x in df_samples.columns if x not in operation_ids],
                    key=lambda x: (
                        get_sample_from_id(x, sample_prefix),
                        get_time_from_id(x, time_prefix),
                    ),
                ),
            ],
            df_samples.loc[
                :,
                sorted(
                    [x for x in df_samples.columns if x in operation_ids],
                    key=lambda x: get_time_from_id(x, time_prefix),
                ),
            ],
        ),
        axis=1,
    )
else:
    df_samples = pd.concat(
        [
            pd.concat(
                (
                    df_samples.loc[
                        :,
                        sorted(
                            [
                                x
                                for x in df_samples.columns
                                if get_time_from_id(x, time_prefix) == time
                                and x not in operation_ids
                            ],
                            key=lambda x: get_sample_from_id(x, sample_prefix),
                        ),
                    ],
                    df_samples.loc[
                        :,
                        sorted(
                            [
                                x
                                for x in df_samples.columns
                                if get_time_from_id(x, time_prefix) == time
                                and x in operation_ids
                            ],
                        ),
                    ],
                ),
                axis=1,
            )
            for time in timepoints
        ],
        axis=1,
    )

# %% [markdown]
# ### Map samples to model

# %%
df_model = (
    df_model_protein_dilutions[["PROTDL"]]
    .merge(df_samples, left_index=True, right_index=True, how="left")
    .set_index("PROTDL")
    .sort_index()
)
no_experimental_measurements = [
    protein_dilution
    for protein_dilution, has_measurement in df_model.isna().all(axis=1).items()
    if has_measurement
]
print(
    f"Model proteins mapped to measurements: {len(df_model) - len(no_experimental_measurements)}"
)
print(f"Model proteins without measurements: {len(no_experimental_measurements)}")
df_model.dropna()
# Out:
# Model proteins mapped to measurements: 70
# Model proteins without measurements: 33
#                               S1_D10     S1_D23     S1_D42     S2_D10  \
# PROTDL
# PROTDL_protein_ADA_pc       0.073243   0.046350   0.091500   0.042135
# PROTDL_protein_ADK_pc       0.240040   0.254656   0.239002   0.324909
# PROTDL_protein_AK1_pc       7.568948   7.928522   7.473081   2.524183
# PROTDL_protein_ALDOA_pc     4.819084   4.610360   4.372591   5.374049
# PROTDL_protein_ALDOC_pc     1.292366   0.905062   1.082157   1.135920
# ...                              ...        ...        ...        ...
# PROTDL_protein_SLC43A3_pc   0.178285   0.108298   0.126072   0.057068
# PROTDL_protein_SOD1_pc      7.845346  26.502806  25.860621  15.012097
# PROTDL_protein_TALDO1_pc    2.060527   2.501260   2.576616   3.319535
# PROTDL_protein_TKT_pc       1.838035   1.493491   1.796938   1.688892
# PROTDL_protein_TPI1_pc     11.984722  14.657240  15.615947  16.027962
#
#                               S2_D23     S2_D42     S3_D10     S3_D23  \
# PROTDL
# PROTDL_protein_ADA_pc       0.044426   0.094702   0.033637   0.056042
# PROTDL_protein_ADK_pc       0.336365   0.329428   0.318621   0.341961
# PROTDL_protein_AK1_pc       6.102872   5.622176   2.524359   6.941116
# PROTDL_protein_ALDOA_pc     4.412209   4.286170   1.578919   4.382671
# PROTDL_protein_ALDOC_pc     0.885298   1.130149   0.903914   0.842881
# ...                              ...        ...        ...        ...
# PROTDL_protein_SLC43A3_pc   0.116582   0.000000   0.052182   0.162198
# PROTDL_protein_SOD1_pc     21.263476  22.344631   5.470446  23.463451
# PROTDL_protein_TALDO1_pc    2.386749   1.696120   2.294042   2.502276
# PROTDL_protein_TKT_pc       1.474261   1.771547   1.428526   1.624082
# PROTDL_protein_TPI1_pc     16.197319  14.744943  11.078788  13.967948
#
#                               S3_D42     S4_D10  ...   S615_D42   S616_D10  \
# PROTDL                                           ...
# PROTDL_protein_ADA_pc       0.082634   0.094200  ...   0.063444   0.070988
# PROTDL_protein_ADK_pc       0.356493   0.267661  ...   0.302170   0.277635
# PROTDL_protein_AK1_pc       6.087617   5.501008  ...   5.659571   3.851172
# PROTDL_protein_ALDOA_pc     4.561871   2.352644  ...   5.433200   5.182936
# PROTDL_protein_ALDOC_pc     1.230527   1.464564  ...   0.959450   0.859790
# ...                              ...        ...  ...        ...        ...
# PROTDL_protein_SLC43A3_pc   0.125654   0.290168  ...   0.075787   0.041508
# PROTDL_protein_SOD1_pc     23.258044   9.731906  ...  22.696008  20.182201
# PROTDL_protein_TALDO1_pc    1.241529   3.198628  ...   2.703993   1.904916
# PROTDL_protein_TKT_pc       2.037096   1.651252  ...   1.641625   1.440329
# PROTDL_protein_TPI1_pc     13.683168  11.997996  ...  12.461216   9.512615
#
#                             S616_D23   S616_D42   Mean_D10  Median_D10  \
# PROTDL
# PROTDL_protein_ADA_pc       0.066368   0.061732   0.078038    0.075310
# PROTDL_protein_ADK_pc       0.302770   0.293763   0.244831    0.250188
# PROTDL_protein_AK1_pc       3.527104   5.233947   4.588580    4.810617
# PROTDL_protein_ALDOA_pc     4.679183   4.771119   3.808248    4.113842
# PROTDL_protein_ALDOC_pc     0.731789   0.750137   0.787056    0.792026
# ...                              ...        ...        ...         ...
# PROTDL_protein_SLC43A3_pc   0.080027   0.102099   0.080248    0.078066
# PROTDL_protein_SOD1_pc     17.902988  18.988467  21.032843   22.037914
# PROTDL_protein_TALDO1_pc    2.208876   1.950643   1.908677    2.004746
# PROTDL_protein_TKT_pc       1.337149   1.336175   1.516615    1.587827
# PROTDL_protein_TPI1_pc     12.182260  12.216177  10.321212   10.940839
#
#                             Mean_D23  Median_D23   Mean_D42  Median_D42
# PROTDL
# PROTDL_protein_ADA_pc       0.076221    0.071785   0.077958    0.074667
# PROTDL_protein_ADK_pc       0.243873    0.249586   0.247522    0.260031
# PROTDL_protein_AK1_pc       4.783073    4.970557   4.609725    4.744058
# PROTDL_protein_ALDOA_pc     3.869536    4.162229   3.809724    4.023530
# PROTDL_protein_ALDOC_pc     0.795414    0.779492   0.794160    0.788460
# ...                              ...         ...        ...         ...
# PROTDL_protein_SLC43A3_pc   0.080387    0.080430   0.081709    0.080569
# PROTDL_protein_SOD1_pc     21.488945   22.749851  21.287384   22.356476
# PROTDL_protein_TALDO1_pc    1.895988    2.017241   1.904133    1.979078
# PROTDL_protein_TKT_pc       1.505157    1.584232   1.517659    1.577608
# PROTDL_protein_TPI1_pc     10.413977   10.928935  10.292269   10.781061
#
# [70 rows x 1854 columns]

# %% [markdown]
# ## TODO: Put pie chart cells in here (divide by 10 to get to percentage. I could be around 0.5%, this is the summation of proteins being mapped to the model.)

# %% [markdown]
# ### Reduce model using maximum values from proteomics
# Create a reduced model using the maximum value measured of each protein across all data samples. By finding the reactions that always remain blocked prior to analysis, the computation time may be reduced.
# Also ensure that proteins not found in the dataset don't significantly sway results,
#
# Note: May be problematic if proteins essential for catalysis are not measured. Keep protein bounds unchanged to remove only normal blocked reactions.

# %%
remove_blocked_reactions = False

if remove_blocked_reactions:
    pcmodel_blocked = pcmodel.copy()
    df = df_model.max(axis=1)
    for protein_dilution, bound in df.items():
        protein_dilution = pcmodel_blocked.reactions.get_by_id(protein_dilution)
        # if not np.isnan(bound):
        #     protein_dilution.bounds = (0, bound)
        # else:
        #     protein_dilution.bounds = (0, 0)
    blocked = find_blocked_reactions(pcmodel_blocked)
    pcmodel.remove_reactions(blocked, remove_orphans=True)

for objective_reaction in ["NaKt"]:
    objective_reaction = pcmodel.reactions.get_by_id(objective_reaction)
    pcmodel.objective = objective_reaction.flux_expression
    print(pcmodel.slim_optimize())

pcmodel
# Out:
# 17.49253822318117
# <Model RBC3P_PC at 0x1c2f90cffe0>

# %% [markdown]
# ## Create QP model for each sample

# %%
def solve_qp(pcmodel, df):
    x = []  # Variables
    c = []  # Data * Weights
    F = []  # Weights

    for protdl, (data_value, weight) in df.iterrows():
        protdl = pcmodel.reactions.get_by_id(protdl)
        x.append(protdl.flux_expression)
        c.append(weight * data_value)
        F.append(weight)

    x = sympy.Matrix(x)
    c = sympy.Matrix(c)
    F = sympy.DiagMatrix(sympy.Matrix(F))
    # # QP Objective must be in form of 0.5 * x.T * F * x - c.T * x
    objective = 0.5 * x.T * F * x - c.T * x
    pcmodel.objective = objective[0]
    pcmodel.objective_direction = "min"
    pcmodel.tolerance = 1e-9

    qp_sol = pcmodel.optimize()
    return qp_sol


def solve_qp_for_samples(pcmodel, df_samples, df_weights=None, verbose=False):
    qp_solutions_dict = {}
    for sample_id, data_series in df_samples.items():
        # Get protein values
        data_series.name = "Data"
        if df_weights is None:
            data_weights = 1 / data_series.replace(0, 1)
            data_weights = data_weights / data_weights.mean()
        else:
            data_weights = df_weights.loc[:, sample_id]
        # Get protein weights
        data_weights.name = "Weights"

        # Map to model, currently model mapping DataFrame generated outside scope of function
        df_model_data_weights = (
            df_model_protein_dilutions[["PROTDL"]]
            .merge(data_series, left_index=True, right_index=True, how="left")
            .merge(data_weights, left_index=True, right_index=True, how="left")
            .set_index("PROTDL")
            .sort_index()
        )

        df = df_model_data_weights.loc[:, [data_series.name, data_weights.name]].dropna(
            axis=0, how="all"
        )

        with pcmodel:
            qp_sol = solve_qp(pcmodel, df)

        df_qp_sol = qp_sol.fluxes.loc[
            pcmodel.reactions.query(lambda x: isinstance(x, ProteinDilution)).list_attr(
                "id"
            )
        ]
        df_qp_sol = (
            pd.concat((df_model_data_weights, df_qp_sol), axis=1).dropna().sort_index()
        )
        # data_weights = df_qp_sol.loc[:, "Weights"]

        df_qp_sol = df_qp_sol.rename(
            {"Data": "Measured Proteome", "fluxes": "Best-Fitted Proteome"}, axis=1
        )
        df_qp_sol = df_qp_sol.loc[:, ["Measured Proteome", "Best-Fitted Proteome"]]

        r2 = r2_score(
            df_qp_sol.iloc[:, 0].values,
            df_qp_sol.iloc[:, 1].values,
            multioutput="uniform_average",
        )
        qp_solutions_dict[sample_id] = (df_qp_sol, r2, qp_sol.objective_value)
        if verbose:
            # Recall that the objective is designed to try to minimize fitting error via maximizing R2, so 1 is a possibility
            print(
                "R^2 (objective) value for Sample '{}': {:.9f} ({:.5f})".format(
                    sample_id, r2, qp_sol.objective_value
                )
            )
        # TODO catch bad fits

    return qp_solutions_dict

# %% [markdown]
# ### Set weightings for QP problem

# %%
# Ensure data is provided as (Protein IDs x Sample IDs)
# Use original measurements for weights
df_weights = df_copy_number_all.T.loc[:, df_samples.columns]
df_weights = 1 / df_weights.replace(0, 1)
df_weights /= df_weights.mean()

# %%
# proteome_path = Path(f"{dataset_path}/proteome")
proteome_path = dataset_path / "proteome"
print(proteome_path)

if run_computations:
    qp_solutions_dict = solve_qp_for_samples(
        pcmodel, df_samples, df_weights=df_weights, verbose=True
    )
    df_measured = {}
    df_best_fit = {}
    df_r2_objective = {}
    for sample_id, (df_qp_sol, r2, objective_value) in qp_solutions_dict.items():
        df_measured[sample_id] = df_qp_sol["Measured Proteome"].to_dict()
        df_best_fit[sample_id] = df_qp_sol["Best-Fitted Proteome"].to_dict()
        df_r2_objective[sample_id] = {"R2": r2, "Objective": objective_value}

    df_measured = pd.DataFrame.from_dict(df_measured, orient="columns")
    # df_measured.to_csv(f"{proteome_path}/proteome_measured.tsv", sep="\t", index=True)
    df_measured.to_csv(proteome_path / "proteome_measured.tsv", sep="\t", index=True)

    df_best_fit = pd.DataFrame.from_dict(df_best_fit, orient="columns")
    # df_best_fit.to_csv(f"{proteome_path}/proteome_best_fit.tsv", sep="\t", index=True)
    df_best_fit.to_csv(proteome_path / "proteome_best_fit.tsv", sep="\t", index=True)

    df_r2_objective = pd.DataFrame.from_dict(df_r2_objective, orient="columns")
    df_r2_objective.to_csv(
        proteome_path / "proteome_r2_objective.tsv", sep="\t", index=True
    )
else:
    df_measured = pd.read_csv(
        proteome_path / "proteome_measured.tsv", sep="\t", index_col=0
    )
    df_best_fit = pd.read_csv(
        proteome_path / "proteome_best_fit.tsv", sep="\t", index_col=0
    )
    df_r2_objective = pd.read_csv(
        proteome_path / "proteome_r2_objective.tsv", sep="\t", index_col=0
    )

    qp_solutions_dict = {}
    for sample_id in list(sample_ids) + list(operation_ids):
        if not sample_id.replace(f"{pcmodel.id}_", "") in df_samples.columns:
            continue
        df_qp_sol = pd.concat(
            (
                df_measured.loc[:, sample_id],
                df_best_fit.loc[:, sample_id],
            ),
            axis=1,
        )
        df_qp_sol.columns = ["Measured Proteome", "Best-Fitted Proteome"]
        r2, objective_value = df_r2_objective.loc[:, sample_id].values
        qp_solutions_dict[sample_id] = (df_qp_sol, r2, objective_value)
print(f"Number of QP solutions: {len(qp_solutions_dict)}")
# Out:
# D:\Projects\RBC-GEM-akey7\data\processed\RBC3P\OVERLAY\RBComics\proteome
# R^2 (objective) value for Sample 'S1_D10': 0.999999997 (-18.29085)
# R^2 (objective) value for Sample 'S1_D23': 0.999999996 (-53.58104)
# R^2 (objective) value for Sample 'S1_D42': 0.999999995 (-21.30392)
# R^2 (objective) value for Sample 'S2_D10': 0.999999994 (-17.14804)
# R^2 (objective) value for Sample 'S2_D23': 0.999999996 (-19.58606)
# R^2 (objective) value for Sample 'S2_D42': 0.999999996 (-18.13095)
# R^2 (objective) value for Sample 'S3_D10': 0.999999996 (-11.37943)
# R^2 (objective) value for Sample 'S3_D23': 0.999999997 (-37.89252)
# R^2 (objective) value for Sample 'S3_D42': 0.999999996 (-13.32929)
# R^2 (objective) value for Sample 'S4_D10': 0.999999996 (-12.78942)
# R^2 (objective) value for Sample 'S4_D23': 0.999999996 (-14.93195)
# R^2 (objective) value for Sample 'S4_D42': 0.999999996 (-41.72834)
# R^2 (objective) value for Sample 'S5_D10': 0.999999996 (-19.97868)
# R^2 (objective) value for Sample 'S5_D23': 0.999999996 (-19.19998)
# R^2 (objective) value for Sample 'S5_D42': 0.999999996 (-19.71846)
# R^2 (objective) value for Sample 'S6_D10': 0.999999996 (-14.85983)
# R^2 (objective) value for Sample 'S6_D23': 0.999999996 (-39.65731)
# R^2 (objective) value for Sample 'S6_D42': 0.999999996 (-21.20554)
# R^2 (objective) value for Sample 'S7_D10': 0.999999996 (-22.03270)
# R^2 (objective) value for Sample 'S7_D23': 0.999999996 (-20.41204)
# R^2 (objective) value for Sample 'S7_D42': 0.999999996 (-20.59545)
# R^2 (objective) value for Sample 'S8_D10': 0.999999996 (-21.63287)
# R^2 (objective) value for Sample 'S8_D23': 0.999999996 (-17.85218)
# R^2 (objective) value for Sample 'S8_D42': 0.999999996 (-21.17362)
# R^2 (objective) value for Sample 'S9_D10': 0.999999996 (-19.72443)
# R^2 (objective) value for Sample 'S9_D23': 0.999999996 (-20.59285)
# R^2 (objective) value for Sample 'S9_D42': 0.999999996 (-20.27832)
# R^2 (objective) value for Sample 'S10_D10': 0.999999996 (-36.58313)
# R^2 (objective) value for Sample 'S10_D23': 0.999999996 (-16.44129)
# R^2 (objective) value for Sample 'S10_D42': 0.999999996 (-21.57548)
# R^2 (objective) value for Sample 'S11_D10': 0.999999996 (-15.82804)
# R^2 (objective) value for Sample 'S11_D23': 0.999999996 (-14.95990)
# R^2 (objective) value for Sample 'S11_D42': 0.999999996 (-22.58498)
# R^2 (objective) value for Sample 'S12_D10': 0.999999996 (-22.68572)
# R^2 (objective) value for Sample 'S12_D23': 0.999999996 (-26.59834)
# R^2 (objective) value for Sample 'S12_D42': 0.999999996 (-24.54179)
# R^2 (objective) value for Sample 'S13_D10': 0.999999997 (-22.11911)
# R^2 (objective) value for Sample 'S13_D23': 0.999999996 (-23.07645)
# R^2 (objective) value for Sample 'S13_D42': 0.999999996 (-24.34253)
# R^2 (objective) value for Sample 'S14_D10': 0.999999996 (-21.21507)
# R^2 (objective) value for Sample 'S14_D23': 0.999999996 (-23.47672)
# R^2 (objective) value for Sample 'S14_D42': 0.999999996 (-23.53348)
# R^2 (objective) value for Sample 'S15_D10': 0.999999996 (-30.77050)
# R^2 (objective) value for Sample 'S15_D23': 0.999999996 (-25.17363)
# R^2 (objective) value for Sample 'S15_D42': 0.999999996 (-32.03572)
# R^2 (objective) value for Sample 'S16_D10': 0.999999997 (-25.81578)
# R^2 (objective) value for Sample 'S16_D23': 0.999999996 (-23.68257)
# R^2 (objective) value for Sample 'S16_D42': 0.999999997 (-14.74793)
# R^2 (objective) value for Sample 'S17_D10': 0.999999996 (-24.23346)
# R^2 (objective) value for Sample 'S17_D23': 0.999999996 (-37.53247)
# R^2 (objective) value for Sample 'S17_D42': 0.999999995 (-17.21371)
# R^2 (objective) value for Sample 'S18_D10': 0.999999996 (-15.77797)
# R^2 (objective) value for Sample 'S18_D23': 0.999999996 (-33.75552)
# R^2 (objective) value for Sample 'S18_D42': 0.999999996 (-18.26205)
# R^2 (objective) value for Sample 'S19_D10': 0.999999997 (-12.85458)
# R^2 (objective) value for Sample 'S19_D23': 0.999999996 (-24.82058)
# R^2 (objective) value for Sample 'S19_D42': 0.999999996 (-19.60731)
# R^2 (objective) value for Sample 'S20_D10': 0.999999996 (-25.89924)
# R^2 (objective) value for Sample 'S20_D23': 0.999999996 (-25.32591)
# R^2 (objective) value for Sample 'S20_D42': 0.999999997 (-39.68992)
# R^2 (objective) value for Sample 'S21_D10': 0.999999995 (-9.96255)
# R^2 (objective) value for Sample 'S21_D23': 0.999999996 (-15.55537)
# R^2 (objective) value for Sample 'S21_D42': 0.999999996 (-21.78426)
# R^2 (objective) value for Sample 'S22_D10': 0.999999997 (-18.31835)
# R^2 (objective) value for Sample 'S22_D23': 0.999999996 (-40.56857)
# R^2 (objective) value for Sample 'S22_D42': 0.999999997 (-18.42843)
# R^2 (objective) value for Sample 'S23_D10': 0.999999996 (-27.91958)
# R^2 (objective) value for Sample 'S23_D23': 0.999999995 (-12.73178)
# R^2 (objective) value for Sample 'S23_D42': 0.999999997 (-38.19520)
# R^2 (objective) value for Sample 'S24_D10': 0.999999996 (-20.30212)
# R^2 (objective) value for Sample 'S24_D23': 0.999999997 (-22.75618)
# R^2 (objective) value for Sample 'S24_D42': 0.999999996 (-21.37700)
# R^2 (objective) value for Sample 'S25_D10': 0.999999997 (-20.26105)
# R^2 (objective) value for Sample 'S25_D23': 0.999999996 (-24.41651)
# R^2 (objective) value for Sample 'S25_D42': 0.999999997 (-39.15874)
# R^2 (objective) value for Sample 'S26_D10': 0.999999997 (-17.89381)
# R^2 (objective) value for Sample 'S26_D23': 0.999999996 (-16.27086)
# R^2 (objective) value for Sample 'S26_D42': 0.999999996 (-20.55557)
# R^2 (objective) value for Sample 'S27_D10': 0.999999996 (-15.25882)
# R^2 (objective) value for Sample 'S27_D23': 0.999999996 (-37.81973)
# R^2 (objective) value for Sample 'S27_D42': 0.999999996 (-19.96778)
# R^2 (objective) value for Sample 'S28_D10': 0.999999996 (-16.19037)
# R^2 (objective) value for Sample 'S28_D23': 0.999999996 (-29.60550)
# R^2 (objective) value for Sample 'S28_D42': 0.999999996 (-16.99665)
# R^2 (objective) value for Sample 'S29_D10': 0.999999996 (-26.94625)
# R^2 (objective) value for Sample 'S29_D23': 0.999999997 (-34.57693)
# R^2 (objective) value for Sample 'S29_D42': 0.999999996 (-54.73314)
# R^2 (objective) value for Sample 'S30_D10': 0.999999997 (-25.41515)
# R^2 (objective) value for Sample 'S30_D23': 0.999999996 (-30.21459)
# R^2 (objective) value for Sample 'S30_D42': 0.999999997 (-27.45498)
# R^2 (objective) value for Sample 'S31_D10': 0.999999996 (-22.50290)
# R^2 (objective) value for Sample 'S31_D23': 0.999999997 (-22.18692)
# R^2 (objective) value for Sample 'S31_D42': 0.999999996 (-25.12932)
# R^2 (objective) value for Sample 'S32_D10': 0.999999996 (-23.53734)
# R^2 (objective) value for Sample 'S32_D23': 0.999999996 (-21.94493)
# R^2 (objective) value for Sample 'S32_D42': 0.999999997 (-20.20938)
# R^2 (objective) value for Sample 'S33_D10': 0.999999996 (-18.07287)
# R^2 (objective) value for Sample 'S33_D23': 0.999999997 (-17.67028)
# R^2 (objective) value for Sample 'S33_D42': 0.999999997 (-15.49719)
# R^2 (objective) value for Sample 'S34_D10': 0.999999997 (-28.33966)
# R^2 (objective) value for Sample 'S34_D23': 0.999999996 (-23.51706)
# R^2 (objective) value for Sample 'S34_D42': 0.999999998 (-31.82901)
# R^2 (objective) value for Sample 'S35_D10': 0.999999997 (-21.07255)
# R^2 (objective) value for Sample 'S35_D23': 0.999999997 (-23.66705)
# R^2 (objective) value for Sample 'S35_D42': 0.999999996 (-24.84235)
# R^2 (objective) value for Sample 'S36_D10': 0.999999996 (-27.42800)
# R^2 (objective) value for Sample 'S36_D23': 0.999999997 (-15.72176)
# R^2 (objective) value for Sample 'S36_D42': 0.999999996 (-19.08657)
# R^2 (objective) value for Sample 'S37_D10': 0.999999997 (-17.97341)
# R^2 (objective) value for Sample 'S37_D23': 0.999999996 (-20.66885)
# R^2 (objective) value for Sample 'S37_D42': 0.999999996 (-20.43956)
# R^2 (objective) value for Sample 'S38_D10': 0.999999997 (-29.12466)
# R^2 (objective) value for Sample 'S38_D23': 0.999999996 (-44.47770)
# R^2 (objective) value for Sample 'S38_D42': 0.999999998 (-32.78514)
# R^2 (objective) value for Sample 'S39_D10': 0.999999997 (-20.12677)
# R^2 (objective) value for Sample 'S39_D23': 0.999999997 (-18.62970)
# R^2 (objective) value for Sample 'S39_D42': 0.999999996 (-22.63809)
# R^2 (objective) value for Sample 'S40_D10': 0.999999996 (-17.73359)
# R^2 (objective) value for Sample 'S40_D23': 0.999999997 (-19.39241)
# R^2 (objective) value for Sample 'S40_D42': 0.999999996 (-17.17616)
# R^2 (objective) value for Sample 'S41_D10': 0.999999997 (-22.53649)
# R^2 (objective) value for Sample 'S41_D23': 0.999999997 (-22.92073)
# R^2 (objective) value for Sample 'S41_D42': 0.999999998 (-29.46336)
# R^2 (objective) value for Sample 'S42_D10': 0.999999997 (-24.27008)
# R^2 (objective) value for Sample 'S42_D23': 0.999999997 (-24.09369)
# R^2 (objective) value for Sample 'S42_D42': 0.999999996 (-23.03421)
# R^2 (objective) value for Sample 'S43_D10': 0.999999997 (-25.33410)
# R^2 (objective) value for Sample 'S43_D23': 0.999999997 (-20.80280)
# R^2 (objective) value for Sample 'S43_D42': 0.999999996 (-19.48955)
# R^2 (objective) value for Sample 'S44_D10': 0.999999997 (-30.72231)
# R^2 (objective) value for Sample 'S44_D23': 0.999999997 (-24.95877)
# R^2 (objective) value for Sample 'S44_D42': 0.999999997 (-24.00258)
# R^2 (objective) value for Sample 'S45_D10': 0.999999997 (-25.42240)
# R^2 (objective) value for Sample 'S45_D23': 0.999999997 (-18.99410)
# R^2 (objective) value for Sample 'S45_D42': 0.999999997 (-25.60740)
# R^2 (objective) value for Sample 'S46_D10': 0.999999997 (-26.43571)
# R^2 (objective) value for Sample 'S46_D23': 0.999999997 (-24.26972)
# R^2 (objective) value for Sample 'S46_D42': 0.999999997 (-28.01288)
# R^2 (objective) value for Sample 'S47_D10': 0.999999997 (-19.35789)
# R^2 (objective) value for Sample 'S47_D23': 0.999999996 (-19.75803)
# R^2 (objective) value for Sample 'S47_D42': 0.999999997 (-17.67178)
# R^2 (objective) value for Sample 'S48_D10': 0.999999997 (-22.11080)
# R^2 (objective) value for Sample 'S48_D23': 0.999999997 (-21.14254)
# R^2 (objective) value for Sample 'S48_D42': 0.999999996 (-17.38436)
# R^2 (objective) value for Sample 'S49_D10': 0.999999997 (-45.75471)
# R^2 (objective) value for Sample 'S49_D23': 0.999999997 (-24.28288)
# R^2 (objective) value for Sample 'S49_D42': 0.999999997 (-29.11434)
# R^2 (objective) value for Sample 'S50_D10': 0.999999996 (-41.74136)
# R^2 (objective) value for Sample 'S50_D23': 0.999999996 (-32.24784)
# R^2 (objective) value for Sample 'S50_D42': 0.999999997 (-33.65626)
# R^2 (objective) value for Sample 'S51_D10': 0.999999997 (-34.15013)
# R^2 (objective) value for Sample 'S51_D23': 0.999999997 (-27.84266)
# R^2 (objective) value for Sample 'S51_D42': 0.999999997 (-27.02357)
# R^2 (objective) value for Sample 'S52_D10': 0.999999997 (-19.42411)
# R^2 (objective) value for Sample 'S52_D23': 0.999999997 (-18.15625)
# R^2 (objective) value for Sample 'S52_D42': 0.999999997 (-12.41065)
# R^2 (objective) value for Sample 'S53_D10': 0.999999997 (-17.26651)
# R^2 (objective) value for Sample 'S53_D23': 0.999999997 (-17.59299)
# R^2 (objective) value for Sample 'S53_D42': 0.999999996 (-20.72623)
# R^2 (objective) value for Sample 'S54_D10': 0.999999997 (-31.63820)
# R^2 (objective) value for Sample 'S54_D23': 0.999999997 (-23.43967)
# R^2 (objective) value for Sample 'S54_D42': 0.999999996 (-24.68431)
# R^2 (objective) value for Sample 'S55_D10': 0.999999997 (-20.84369)
# R^2 (objective) value for Sample 'S55_D23': 0.999999997 (-23.55626)
# R^2 (objective) value for Sample 'S55_D42': 0.999999997 (-22.00446)
# R^2 (objective) value for Sample 'S56_D10': 0.999999996 (-22.23211)
# R^2 (objective) value for Sample 'S56_D23': 0.999999997 (-18.30863)
# R^2 (objective) value for Sample 'S56_D42': 0.999999997 (-15.14652)
# R^2 (objective) value for Sample 'S57_D10': 0.999999996 (-19.30707)
# R^2 (objective) value for Sample 'S57_D23': 0.999999997 (-15.59102)
# R^2 (objective) value for Sample 'S57_D42': 0.999999997 (-13.22544)
# R^2 (objective) value for Sample 'S58_D10': 0.999999997 (-11.44681)
# R^2 (objective) value for Sample 'S58_D23': 0.999999996 (-9.90136)
# R^2 (objective) value for Sample 'S58_D42': 0.999999996 (-14.57409)
# R^2 (objective) value for Sample 'S59_D10': 0.999999996 (-23.90039)
# R^2 (objective) value for Sample 'S59_D23': 0.999999997 (-16.84224)
# R^2 (objective) value for Sample 'S59_D42': 0.999999997 (-15.29368)
# R^2 (objective) value for Sample 'S60_D10': 0.999999994 (-9.35910)
# R^2 (objective) value for Sample 'S60_D23': 0.999999996 (-12.26682)
# R^2 (objective) value for Sample 'S60_D42': 0.999999995 (-20.71203)
# R^2 (objective) value for Sample 'S61_D10': 0.999999996 (-12.15708)
# R^2 (objective) value for Sample 'S61_D23': 0.999999996 (-14.03095)
# R^2 (objective) value for Sample 'S61_D42': 0.999999997 (-14.53809)
# R^2 (objective) value for Sample 'S62_D10': 0.999999996 (-12.24264)
# R^2 (objective) value for Sample 'S62_D23': 0.999999996 (-31.36325)
# R^2 (objective) value for Sample 'S62_D42': 0.999999997 (-13.75988)
# R^2 (objective) value for Sample 'S63_D10': 0.999999996 (-12.59259)
# R^2 (objective) value for Sample 'S63_D23': 0.999999996 (-14.59924)
# R^2 (objective) value for Sample 'S63_D42': 0.999999996 (-11.08903)
# R^2 (objective) value for Sample 'S64_D10': 0.999999997 (-19.39082)
# R^2 (objective) value for Sample 'S64_D23': 0.999999996 (-14.85804)
# R^2 (objective) value for Sample 'S64_D42': 0.999999997 (-15.66430)
# R^2 (objective) value for Sample 'S65_D10': 0.999999996 (-15.39918)
# R^2 (objective) value for Sample 'S65_D23': 0.999999997 (-21.40114)
# R^2 (objective) value for Sample 'S65_D42': 0.999999997 (-18.36610)
# R^2 (objective) value for Sample 'S66_D10': 0.999999997 (-13.97028)
# R^2 (objective) value for Sample 'S66_D23': 0.999999997 (-35.66208)
# R^2 (objective) value for Sample 'S66_D42': 0.999999997 (-12.03665)
# R^2 (objective) value for Sample 'S67_D10': 0.999999997 (-29.23436)
# R^2 (objective) value for Sample 'S67_D23': 0.999999997 (-16.67241)
# R^2 (objective) value for Sample 'S67_D42': 0.999999997 (-13.56362)
# R^2 (objective) value for Sample 'S68_D10': 0.999999997 (-13.56150)
# R^2 (objective) value for Sample 'S68_D23': 0.999999996 (-15.22040)
# R^2 (objective) value for Sample 'S68_D42': 0.999999997 (-11.08937)
# R^2 (objective) value for Sample 'S69_D10': 0.999999996 (-13.04272)
# R^2 (objective) value for Sample 'S69_D23': 0.999999997 (-18.84882)
# R^2 (objective) value for Sample 'S69_D42': 0.999999997 (-17.94055)
# R^2 (objective) value for Sample 'S70_D10': 0.999999997 (-17.45410)
# R^2 (objective) value for Sample 'S70_D23': 0.999999996 (-29.41199)
# R^2 (objective) value for Sample 'S70_D42': 0.999999996 (-18.37046)
# R^2 (objective) value for Sample 'S71_D10': 0.999999997 (-15.36803)
# R^2 (objective) value for Sample 'S71_D23': 0.999999998 (-15.40561)
# R^2 (objective) value for Sample 'S71_D42': 0.999999997 (-12.10185)
# R^2 (objective) value for Sample 'S72_D10': 0.999999996 (-14.15410)
# R^2 (objective) value for Sample 'S72_D23': 0.999999996 (-14.53682)
# R^2 (objective) value for Sample 'S72_D42': 0.999999996 (-13.99700)
# R^2 (objective) value for Sample 'S73_D10': 0.999999996 (-12.25590)
# R^2 (objective) value for Sample 'S73_D23': 0.999999996 (-12.45700)
# R^2 (objective) value for Sample 'S73_D42': 0.999999997 (-12.63442)
# R^2 (objective) value for Sample 'S74_D10': 0.999999997 (-9.51506)
# R^2 (objective) value for Sample 'S74_D23': 0.999999997 (-18.10681)
# R^2 (objective) value for Sample 'S74_D42': 0.999999997 (-17.31595)
# R^2 (objective) value for Sample 'S75_D10': 0.999999997 (-12.10698)
# R^2 (objective) value for Sample 'S75_D23': 0.999999996 (-27.38108)
# R^2 (objective) value for Sample 'S75_D42': 0.999999996 (-12.54023)
# R^2 (objective) value for Sample 'S76_D10': 0.999999995 (-17.78374)
# R^2 (objective) value for Sample 'S76_D23': 0.999999996 (-15.32145)
# R^2 (objective) value for Sample 'S76_D42': 0.999999997 (-20.21791)
# R^2 (objective) value for Sample 'S77_D10': 0.999999997 (-14.77269)
# R^2 (objective) value for Sample 'S77_D23': 0.999999997 (-18.60154)
# R^2 (objective) value for Sample 'S77_D42': 0.999999997 (-18.94534)
# R^2 (objective) value for Sample 'S78_D10': 0.999999997 (-10.98204)
# R^2 (objective) value for Sample 'S78_D23': 0.999999998 (-18.23255)
# R^2 (objective) value for Sample 'S78_D42': 0.999999996 (-15.15006)
# R^2 (objective) value for Sample 'S79_D10': 0.999999996 (-16.60404)
# R^2 (objective) value for Sample 'S79_D23': 0.999999996 (-18.97065)
# R^2 (objective) value for Sample 'S79_D42': 0.999999997 (-16.51061)
# R^2 (objective) value for Sample 'S80_D10': 0.999999996 (-24.10046)
# R^2 (objective) value for Sample 'S80_D23': 0.999999997 (-13.89651)
# R^2 (objective) value for Sample 'S80_D42': 0.999999996 (-51.57933)
# R^2 (objective) value for Sample 'S81_D10': 0.999999996 (-14.88636)
# R^2 (objective) value for Sample 'S81_D23': 0.999999997 (-20.79149)
# R^2 (objective) value for Sample 'S81_D42': 0.999999996 (-19.54604)
# R^2 (objective) value for Sample 'S82_D10': 0.999999996 (-14.45740)
# R^2 (objective) value for Sample 'S82_D23': 0.999999996 (-35.20344)
# R^2 (objective) value for Sample 'S82_D42': 0.999999996 (-11.92985)
# R^2 (objective) value for Sample 'S83_D10': 0.999999996 (-16.89995)
# R^2 (objective) value for Sample 'S83_D23': 0.999999997 (-15.66747)
# R^2 (objective) value for Sample 'S83_D42': 0.999999997 (-44.51464)
# R^2 (objective) value for Sample 'S84_D10': 0.999999997 (-17.84588)
# R^2 (objective) value for Sample 'S84_D23': 0.999999994 (-14.07154)
# R^2 (objective) value for Sample 'S84_D42': 0.999999995 (-16.15950)
# R^2 (objective) value for Sample 'S85_D10': 0.999999996 (-11.58246)
# R^2 (objective) value for Sample 'S85_D23': 0.999999996 (-15.38937)
# R^2 (objective) value for Sample 'S85_D42': 0.999999995 (-14.89386)
# R^2 (objective) value for Sample 'S86_D10': 0.999999996 (-21.33197)
# R^2 (objective) value for Sample 'S86_D23': 0.999999996 (-18.63481)
# R^2 (objective) value for Sample 'S86_D42': 0.999999996 (-17.19059)
# R^2 (objective) value for Sample 'S87_D10': 0.999999996 (-13.53295)
# R^2 (objective) value for Sample 'S87_D23': 0.999999997 (-14.49585)
# R^2 (objective) value for Sample 'S87_D42': 0.999999996 (-18.42788)
# R^2 (objective) value for Sample 'S88_D10': 0.999999996 (-14.42964)
# R^2 (objective) value for Sample 'S88_D23': 0.999999996 (-15.68693)
# R^2 (objective) value for Sample 'S88_D42': 0.999999996 (-16.40464)
# R^2 (objective) value for Sample 'S89_D10': 0.999999996 (-16.40346)
# R^2 (objective) value for Sample 'S89_D23': 0.999999996 (-13.49493)
# R^2 (objective) value for Sample 'S89_D42': 0.999999997 (-22.25626)
# R^2 (objective) value for Sample 'S90_D10': 0.999999996 (-17.16028)
# R^2 (objective) value for Sample 'S90_D23': 0.999999997 (-16.34095)
# R^2 (objective) value for Sample 'S90_D42': 0.999999997 (-19.87722)
# R^2 (objective) value for Sample 'S91_D10': 0.999999997 (-19.63440)
# R^2 (objective) value for Sample 'S91_D23': 0.999999996 (-22.84817)
# R^2 (objective) value for Sample 'S91_D42': 0.999999997 (-24.59043)
# R^2 (objective) value for Sample 'S92_D10': 0.999999996 (-20.47082)
# R^2 (objective) value for Sample 'S92_D23': 0.999999996 (-24.97228)
# R^2 (objective) value for Sample 'S92_D42': 0.999999996 (-22.83791)
# R^2 (objective) value for Sample 'S93_D10': 0.999999996 (-15.41557)
# R^2 (objective) value for Sample 'S93_D23': 0.999999997 (-11.00547)
# R^2 (objective) value for Sample 'S93_D42': 0.999999997 (-17.93860)
# R^2 (objective) value for Sample 'S94_D10': 0.999999996 (-25.42107)
# R^2 (objective) value for Sample 'S94_D23': 0.999999996 (-21.67690)
# R^2 (objective) value for Sample 'S94_D42': 0.999999996 (-21.67960)
# R^2 (objective) value for Sample 'S95_D10': 0.999999996 (-20.64167)
# R^2 (objective) value for Sample 'S95_D23': 0.999999997 (-22.66888)
# R^2 (objective) value for Sample 'S95_D42': 0.999999997 (-23.19563)
# R^2 (objective) value for Sample 'S96_D10': 0.999999996 (-19.37877)
# R^2 (objective) value for Sample 'S96_D23': 0.999999996 (-26.48886)
# R^2 (objective) value for Sample 'S96_D42': 0.999999996 (-15.73177)
# R^2 (objective) value for Sample 'S97_D10': 0.999999996 (-15.98647)
# R^2 (objective) value for Sample 'S97_D23': 0.999999996 (-18.95470)
# R^2 (objective) value for Sample 'S97_D42': 0.999999997 (-18.88816)
# R^2 (objective) value for Sample 'S98_D10': 0.999999997 (-23.11833)
# R^2 (objective) value for Sample 'S98_D23': 0.999999996 (-15.71416)
# R^2 (objective) value for Sample 'S98_D42': 0.999999996 (-18.54687)
# R^2 (objective) value for Sample 'S99_D10': 0.999999997 (-18.80939)
# R^2 (objective) value for Sample 'S99_D23': 0.999999996 (-19.22621)
# R^2 (objective) value for Sample 'S99_D42': 0.999999996 (-18.05631)
# R^2 (objective) value for Sample 'S100_D10': 0.999999997 (-17.38406)
# R^2 (objective) value for Sample 'S100_D23': 0.999999996 (-22.67788)
# R^2 (objective) value for Sample 'S100_D42': 0.999999996 (-18.73443)
# R^2 (objective) value for Sample 'S101_D10': 0.999999997 (-19.21369)
# R^2 (objective) value for Sample 'S101_D23': 0.999999996 (-21.06672)
# R^2 (objective) value for Sample 'S101_D42': 0.999999997 (-16.48675)
# R^2 (objective) value for Sample 'S102_D10': 0.999999997 (-28.88103)
# R^2 (objective) value for Sample 'S102_D23': 0.999999996 (-30.58726)
# R^2 (objective) value for Sample 'S102_D42': 0.999999996 (-29.12906)
# R^2 (objective) value for Sample 'S103_D10': 0.999999996 (-25.74493)
# R^2 (objective) value for Sample 'S103_D23': 0.999999996 (-29.25856)
# R^2 (objective) value for Sample 'S103_D42': 0.999999996 (-27.83625)
# R^2 (objective) value for Sample 'S104_D10': 0.999999996 (-23.19956)
# R^2 (objective) value for Sample 'S104_D23': 0.999999996 (-22.08725)
# R^2 (objective) value for Sample 'S104_D42': 0.999999996 (-21.32798)
# R^2 (objective) value for Sample 'S105_D10': 0.999999996 (-18.45515)
# R^2 (objective) value for Sample 'S105_D23': 0.999999996 (-15.26262)
# R^2 (objective) value for Sample 'S105_D42': 0.999999996 (-17.95985)
# R^2 (objective) value for Sample 'S106_D10': 0.999999996 (-15.34641)
# R^2 (objective) value for Sample 'S106_D23': 0.999999997 (-17.70377)
# R^2 (objective) value for Sample 'S106_D42': 0.999999997 (-16.39875)
# R^2 (objective) value for Sample 'S107_D10': 0.999999996 (-18.24894)
# R^2 (objective) value for Sample 'S107_D23': 0.999999996 (-16.97149)
# R^2 (objective) value for Sample 'S107_D42': 0.999999996 (-21.87192)
# R^2 (objective) value for Sample 'S108_D10': 0.999999996 (-22.83286)
# R^2 (objective) value for Sample 'S108_D23': 0.999999997 (-27.66817)
# R^2 (objective) value for Sample 'S108_D42': 0.999999996 (-25.64870)
# R^2 (objective) value for Sample 'S109_D10': 0.999999997 (-11.23838)
# R^2 (objective) value for Sample 'S109_D23': 0.999999996 (-22.41498)
# R^2 (objective) value for Sample 'S109_D42': 0.999999997 (-16.08378)
# R^2 (objective) value for Sample 'S110_D10': 0.999999997 (-19.16595)
# R^2 (objective) value for Sample 'S110_D23': 0.999999996 (-16.51361)
# R^2 (objective) value for Sample 'S110_D42': 0.999999997 (-16.30332)
# R^2 (objective) value for Sample 'S111_D10': 0.999999996 (-18.96035)
# R^2 (objective) value for Sample 'S111_D23': 0.999999997 (-19.04852)
# R^2 (objective) value for Sample 'S111_D42': 0.999999997 (-24.06212)
# R^2 (objective) value for Sample 'S112_D10': 0.999999997 (-19.86423)
# R^2 (objective) value for Sample 'S112_D23': 0.999999996 (-21.55154)
# R^2 (objective) value for Sample 'S112_D42': 0.999999997 (-15.91082)
# R^2 (objective) value for Sample 'S113_D10': 0.999999996 (-24.08280)
# R^2 (objective) value for Sample 'S113_D23': 0.999999996 (-19.75188)
# R^2 (objective) value for Sample 'S113_D42': 0.999999997 (-13.41396)
# R^2 (objective) value for Sample 'S114_D10': 0.999999997 (-13.28940)
# R^2 (objective) value for Sample 'S114_D23': 0.999999997 (-19.18278)
# R^2 (objective) value for Sample 'S114_D42': 0.999999997 (-14.06597)
# R^2 (objective) value for Sample 'S115_D10': 0.999999996 (-33.63803)
# R^2 (objective) value for Sample 'S115_D23': 0.999999997 (-15.22514)
# R^2 (objective) value for Sample 'S115_D42': 0.999999996 (-16.95415)
# R^2 (objective) value for Sample 'S116_D10': 0.999999996 (-17.13667)
# R^2 (objective) value for Sample 'S116_D23': 0.999999997 (-13.14869)
# R^2 (objective) value for Sample 'S116_D42': 0.999999997 (-33.27058)
# R^2 (objective) value for Sample 'S117_D10': 0.999999996 (-15.95856)
# R^2 (objective) value for Sample 'S117_D23': 0.999999997 (-43.23293)
# R^2 (objective) value for Sample 'S117_D42': 0.999999997 (-20.28503)
# R^2 (objective) value for Sample 'S118_D10': 0.999999996 (-10.93836)
# R^2 (objective) value for Sample 'S118_D23': 0.999999996 (-23.65996)
# R^2 (objective) value for Sample 'S118_D42': 0.999999997 (-10.84261)
# R^2 (objective) value for Sample 'S119_D10': 0.999999996 (-30.82887)
# R^2 (objective) value for Sample 'S119_D23': 0.999999997 (-20.07200)
# R^2 (objective) value for Sample 'S119_D42': 0.999999996 (-17.75981)
# R^2 (objective) value for Sample 'S120_D10': 0.999999997 (-22.21229)
# R^2 (objective) value for Sample 'S120_D23': 0.999999997 (-21.86386)
# R^2 (objective) value for Sample 'S120_D42': 0.999999997 (-19.35965)
# R^2 (objective) value for Sample 'S121_D10': 0.999999996 (-20.30730)
# R^2 (objective) value for Sample 'S121_D23': 0.999999997 (-18.33385)
# R^2 (objective) value for Sample 'S121_D42': 0.999999997 (-22.76567)
# R^2 (objective) value for Sample 'S122_D10': 0.999999997 (-19.98608)
# R^2 (objective) value for Sample 'S122_D23': 0.999999997 (-19.50877)
# R^2 (objective) value for Sample 'S122_D42': 0.999999997 (-28.34057)
# R^2 (objective) value for Sample 'S123_D10': 0.999999997 (-25.27232)
# R^2 (objective) value for Sample 'S123_D23': 0.999999996 (-21.97066)
# R^2 (objective) value for Sample 'S123_D42': 0.999999997 (-22.47493)
# R^2 (objective) value for Sample 'S124_D10': 0.999999996 (-15.76347)
# R^2 (objective) value for Sample 'S124_D23': 0.999999996 (-16.33179)
# R^2 (objective) value for Sample 'S124_D42': 0.999999996 (-15.66399)
# R^2 (objective) value for Sample 'S125_D10': 0.999999996 (-19.96537)
# R^2 (objective) value for Sample 'S125_D23': 0.999999996 (-19.78775)
# R^2 (objective) value for Sample 'S125_D42': 0.999999997 (-16.09086)
# R^2 (objective) value for Sample 'S126_D10': 0.999999997 (-20.45089)
# R^2 (objective) value for Sample 'S126_D23': 0.999999996 (-28.41764)
# R^2 (objective) value for Sample 'S126_D42': 0.999999997 (-21.75586)
# R^2 (objective) value for Sample 'S127_D10': 0.999999997 (-13.59747)
# R^2 (objective) value for Sample 'S127_D23': 0.999999997 (-14.34037)
# R^2 (objective) value for Sample 'S127_D42': 0.999999997 (-13.92077)
# R^2 (objective) value for Sample 'S128_D10': 0.999999996 (-22.78850)
# R^2 (objective) value for Sample 'S128_D23': 0.999999997 (-20.01687)
# R^2 (objective) value for Sample 'S128_D42': 0.999999996 (-19.69453)
# R^2 (objective) value for Sample 'S129_D10': 0.999999997 (-20.36252)
# R^2 (objective) value for Sample 'S129_D23': 0.999999997 (-18.45344)
# R^2 (objective) value for Sample 'S129_D42': 0.999999997 (-17.01720)
# R^2 (objective) value for Sample 'S130_D10': 0.999999998 (-25.59639)
# R^2 (objective) value for Sample 'S130_D23': 0.999999997 (-34.16130)
# R^2 (objective) value for Sample 'S130_D42': 0.999999997 (-20.93243)
# R^2 (objective) value for Sample 'S131_D10': 0.999999997 (-19.66668)
# R^2 (objective) value for Sample 'S131_D23': 0.999999997 (-19.86431)
# R^2 (objective) value for Sample 'S131_D42': 0.999999998 (-21.15765)
# R^2 (objective) value for Sample 'S132_D10': 0.999999998 (-16.77817)
# R^2 (objective) value for Sample 'S132_D23': 0.999999996 (-11.12946)
# R^2 (objective) value for Sample 'S132_D42': 0.999999997 (-30.29566)
# R^2 (objective) value for Sample 'S133_D10': 0.999999997 (-14.78228)
# R^2 (objective) value for Sample 'S133_D23': 0.999999996 (-38.57435)
# R^2 (objective) value for Sample 'S133_D42': 0.999999996 (-16.31703)
# R^2 (objective) value for Sample 'S134_D10': 0.999999997 (-20.89767)
# R^2 (objective) value for Sample 'S134_D23': 0.999999998 (-18.19678)
# R^2 (objective) value for Sample 'S134_D42': 0.999999996 (-23.37970)
# R^2 (objective) value for Sample 'S135_D10': 0.999999996 (-15.43296)
# R^2 (objective) value for Sample 'S135_D23': 0.999999997 (-17.05449)
# R^2 (objective) value for Sample 'S135_D42': 0.999999997 (-15.00215)
# R^2 (objective) value for Sample 'S136_D10': 0.999999997 (-18.62526)
# R^2 (objective) value for Sample 'S136_D23': 0.999999997 (-20.01671)
# R^2 (objective) value for Sample 'S136_D42': 0.999999997 (-19.57182)
# R^2 (objective) value for Sample 'S137_D10': 0.999999996 (-16.03979)
# R^2 (objective) value for Sample 'S137_D23': 0.999999997 (-15.17840)
# R^2 (objective) value for Sample 'S137_D42': 0.999999997 (-15.30625)
# R^2 (objective) value for Sample 'S138_D10': 0.999999996 (-16.53550)
# R^2 (objective) value for Sample 'S138_D23': 0.999999997 (-17.99433)
# R^2 (objective) value for Sample 'S138_D42': 0.999999997 (-20.45040)
# R^2 (objective) value for Sample 'S139_D10': 0.999999997 (-20.29708)
# R^2 (objective) value for Sample 'S139_D23': 0.999999996 (-31.40076)
# R^2 (objective) value for Sample 'S139_D42': 0.999999998 (-14.41350)
# R^2 (objective) value for Sample 'S140_D10': 0.999999998 (-17.88404)
# R^2 (objective) value for Sample 'S140_D23': 0.999999996 (-18.36110)
# R^2 (objective) value for Sample 'S140_D42': 0.999999996 (-18.59417)
# R^2 (objective) value for Sample 'S141_D10': 0.999999997 (-12.18231)
# R^2 (objective) value for Sample 'S141_D23': 0.999999997 (-34.57449)
# R^2 (objective) value for Sample 'S141_D42': 0.999999997 (-19.65932)
# R^2 (objective) value for Sample 'S142_D10': 0.999999998 (-16.60850)
# R^2 (objective) value for Sample 'S142_D23': 0.999999997 (-14.39618)
# R^2 (objective) value for Sample 'S142_D42': 0.999999997 (-16.50808)
# R^2 (objective) value for Sample 'S143_D10': 0.999999998 (-16.99127)
# R^2 (objective) value for Sample 'S143_D23': 0.999999996 (-22.77219)
# R^2 (objective) value for Sample 'S143_D42': 0.999999996 (-15.46949)
# R^2 (objective) value for Sample 'S144_D10': 0.999999996 (-19.27492)
# R^2 (objective) value for Sample 'S144_D23': 0.999999997 (-18.43406)
# R^2 (objective) value for Sample 'S144_D42': 0.999999997 (-30.92498)
# R^2 (objective) value for Sample 'S145_D10': 0.999999996 (-19.51539)
# R^2 (objective) value for Sample 'S145_D23': 0.999999997 (-25.32500)
# R^2 (objective) value for Sample 'S145_D42': 0.999999996 (-27.17953)
# R^2 (objective) value for Sample 'S146_D10': 0.999999997 (-24.52053)
# R^2 (objective) value for Sample 'S146_D23': 0.999999996 (-20.66094)
# R^2 (objective) value for Sample 'S146_D42': 0.999999997 (-17.22485)
# R^2 (objective) value for Sample 'S147_D10': 0.999999997 (-24.01253)
# R^2 (objective) value for Sample 'S147_D23': 0.999999996 (-21.14814)
# R^2 (objective) value for Sample 'S147_D42': 0.999999996 (-21.03155)
# R^2 (objective) value for Sample 'S148_D10': 0.999999997 (-19.84434)
# R^2 (objective) value for Sample 'S148_D23': 0.999999998 (-20.37683)
# R^2 (objective) value for Sample 'S148_D42': 0.999999998 (-20.08594)
# R^2 (objective) value for Sample 'S149_D10': 0.999999996 (-16.32536)
# R^2 (objective) value for Sample 'S149_D23': 0.999999997 (-19.18026)
# R^2 (objective) value for Sample 'S149_D42': 0.999999997 (-19.26115)
# R^2 (objective) value for Sample 'S150_D10': 0.999999996 (-16.62632)
# R^2 (objective) value for Sample 'S150_D23': 0.999999997 (-17.62699)
# R^2 (objective) value for Sample 'S150_D42': 0.999999997 (-16.87028)
# R^2 (objective) value for Sample 'S151_D10': 0.999999997 (-24.58104)
# R^2 (objective) value for Sample 'S151_D23': 0.999999997 (-21.85587)
# R^2 (objective) value for Sample 'S151_D42': 0.999999996 (-17.35167)
# R^2 (objective) value for Sample 'S152_D10': 0.999999996 (-23.76442)
# R^2 (objective) value for Sample 'S152_D23': 0.999999996 (-40.89731)
# R^2 (objective) value for Sample 'S152_D42': 0.999999998 (-20.40603)
# R^2 (objective) value for Sample 'S153_D10': 0.999999997 (-22.72470)
# R^2 (objective) value for Sample 'S153_D23': 0.999999996 (-26.66562)
# R^2 (objective) value for Sample 'S153_D42': 0.999999996 (-20.08020)
# R^2 (objective) value for Sample 'S154_D10': 0.999999997 (-16.00980)
# R^2 (objective) value for Sample 'S154_D23': 0.999999997 (-27.03195)
# R^2 (objective) value for Sample 'S154_D42': 0.999999996 (-15.32116)
# R^2 (objective) value for Sample 'S155_D10': 0.999999996 (-22.79122)
# R^2 (objective) value for Sample 'S155_D23': 0.999999996 (-37.49502)
# R^2 (objective) value for Sample 'S155_D42': 0.999999997 (-16.58718)
# R^2 (objective) value for Sample 'S156_D10': 0.999999996 (-20.95934)
# R^2 (objective) value for Sample 'S156_D23': 0.999999997 (-31.05431)
# R^2 (objective) value for Sample 'S156_D42': 0.999999996 (-14.82000)
# R^2 (objective) value for Sample 'S157_D10': 0.999999997 (-19.98103)
# R^2 (objective) value for Sample 'S157_D23': 0.999999997 (-20.45325)
# R^2 (objective) value for Sample 'S157_D42': 0.999999997 (-19.47610)
# R^2 (objective) value for Sample 'S158_D10': 0.999999997 (-20.87719)
# R^2 (objective) value for Sample 'S158_D23': 0.999999997 (-19.82734)
# R^2 (objective) value for Sample 'S158_D42': 0.999999997 (-18.43678)
# R^2 (objective) value for Sample 'S159_D10': 0.999999997 (-16.25935)
# R^2 (objective) value for Sample 'S159_D23': 0.999999996 (-22.14912)
# R^2 (objective) value for Sample 'S159_D42': 0.999999996 (-22.33886)
# R^2 (objective) value for Sample 'S160_D10': 0.999999996 (-25.51790)
# R^2 (objective) value for Sample 'S160_D23': 0.999999996 (-37.88582)
# R^2 (objective) value for Sample 'S160_D42': 0.999999997 (-20.12281)
# R^2 (objective) value for Sample 'S161_D10': 0.999999996 (-16.61877)
# R^2 (objective) value for Sample 'S161_D23': 0.999999996 (-14.43481)
# R^2 (objective) value for Sample 'S161_D42': 0.999999997 (-18.40223)
# R^2 (objective) value for Sample 'S162_D10': 0.999999998 (-15.06339)
# R^2 (objective) value for Sample 'S162_D23': 0.999999996 (-33.34707)
# R^2 (objective) value for Sample 'S162_D42': 0.999999996 (-17.65113)
# R^2 (objective) value for Sample 'S163_D10': 0.999999996 (-20.84740)
# R^2 (objective) value for Sample 'S163_D23': 0.999999997 (-22.48875)
# R^2 (objective) value for Sample 'S163_D42': 0.999999997 (-22.31440)
# R^2 (objective) value for Sample 'S164_D10': 0.999999997 (-25.39237)
# R^2 (objective) value for Sample 'S164_D23': 0.999999997 (-27.84148)
# R^2 (objective) value for Sample 'S164_D42': 0.999999997 (-25.97894)
# R^2 (objective) value for Sample 'S165_D10': 0.999999997 (-21.44964)
# R^2 (objective) value for Sample 'S165_D23': 0.999999996 (-19.27996)
# R^2 (objective) value for Sample 'S165_D42': 0.999999997 (-20.11144)
# R^2 (objective) value for Sample 'S166_D10': 0.999999997 (-26.09598)
# R^2 (objective) value for Sample 'S166_D23': 0.999999996 (-21.74906)
# R^2 (objective) value for Sample 'S166_D42': 0.999999997 (-21.66461)
# R^2 (objective) value for Sample 'S167_D10': 0.999999997 (-12.01250)
# R^2 (objective) value for Sample 'S167_D23': 0.999999997 (-9.87411)
# R^2 (objective) value for Sample 'S167_D42': 0.999999996 (-15.95627)
# R^2 (objective) value for Sample 'S168_D10': 0.999999996 (-43.17433)
# R^2 (objective) value for Sample 'S168_D23': 0.999999996 (-19.17669)
# R^2 (objective) value for Sample 'S168_D42': 0.999999997 (-13.55372)
# R^2 (objective) value for Sample 'S169_D10': 0.999999996 (-18.49647)
# R^2 (objective) value for Sample 'S169_D23': 0.999999996 (-20.72196)
# R^2 (objective) value for Sample 'S169_D42': 0.999999996 (-12.86089)
# R^2 (objective) value for Sample 'S170_D10': 0.999999997 (-24.39847)
# R^2 (objective) value for Sample 'S170_D23': 0.999999997 (-24.03923)
# R^2 (objective) value for Sample 'S170_D42': 0.999999997 (-20.04363)
# R^2 (objective) value for Sample 'S171_D10': 0.999999997 (-11.64978)
# R^2 (objective) value for Sample 'S171_D23': 0.999999996 (-24.58507)
# R^2 (objective) value for Sample 'S171_D42': 0.999999997 (-20.57793)
# R^2 (objective) value for Sample 'S172_D10': 0.999999996 (-25.30812)
# R^2 (objective) value for Sample 'S172_D23': 0.999999996 (-31.56956)
# R^2 (objective) value for Sample 'S172_D42': 0.999999996 (-39.82123)
# R^2 (objective) value for Sample 'S173_D10': 0.999999996 (-23.09609)
# R^2 (objective) value for Sample 'S173_D23': 0.999999996 (-21.68668)
# R^2 (objective) value for Sample 'S173_D42': 0.999999996 (-24.86923)
# R^2 (objective) value for Sample 'S174_D10': 0.999999996 (-21.03945)
# R^2 (objective) value for Sample 'S174_D23': 0.999999997 (-15.15386)
# R^2 (objective) value for Sample 'S174_D42': 0.999999996 (-8.02640)
# R^2 (objective) value for Sample 'S175_D10': 0.999999997 (-29.60062)
# R^2 (objective) value for Sample 'S175_D23': 0.999999996 (-20.97057)
# R^2 (objective) value for Sample 'S175_D42': 0.999999996 (-24.28401)
# R^2 (objective) value for Sample 'S176_D10': 0.999999996 (-32.45812)
# R^2 (objective) value for Sample 'S176_D23': 0.999999996 (-29.03328)
# R^2 (objective) value for Sample 'S176_D42': 0.999999996 (-36.23780)
# R^2 (objective) value for Sample 'S177_D10': 0.999999996 (-23.58050)
# R^2 (objective) value for Sample 'S177_D23': 0.999999997 (-23.83437)
# R^2 (objective) value for Sample 'S177_D42': 0.999999997 (-27.79176)
# R^2 (objective) value for Sample 'S178_D10': 0.999999997 (-26.16753)
# R^2 (objective) value for Sample 'S178_D23': 0.999999997 (-21.99376)
# R^2 (objective) value for Sample 'S178_D42': 0.999999997 (-14.00820)
# R^2 (objective) value for Sample 'S179_D10': 0.999999997 (-19.59172)
# R^2 (objective) value for Sample 'S179_D23': 0.999999996 (-17.22116)
# R^2 (objective) value for Sample 'S179_D42': 0.999999997 (-34.25108)
# R^2 (objective) value for Sample 'S180_D10': 0.999999996 (-13.86804)
# R^2 (objective) value for Sample 'S180_D23': 0.999999996 (-20.39248)
# R^2 (objective) value for Sample 'S180_D42': 0.999999996 (-23.02880)
# R^2 (objective) value for Sample 'S181_D10': 0.999999996 (-32.28302)
# R^2 (objective) value for Sample 'S181_D23': 0.999999996 (-30.95894)
# R^2 (objective) value for Sample 'S181_D42': 0.999999996 (-35.49016)
# R^2 (objective) value for Sample 'S182_D10': 0.999999996 (-12.80132)
# R^2 (objective) value for Sample 'S182_D23': 0.999999996 (-25.02175)
# R^2 (objective) value for Sample 'S182_D42': 0.999999996 (-37.48998)
# R^2 (objective) value for Sample 'S183_D10': 0.999999996 (-20.83174)
# R^2 (objective) value for Sample 'S183_D23': 0.999999996 (-19.45749)
# R^2 (objective) value for Sample 'S183_D42': 0.999999996 (-21.87316)
# R^2 (objective) value for Sample 'S184_D10': 0.999999996 (-28.46285)
# R^2 (objective) value for Sample 'S184_D23': 0.999999997 (-24.58077)
# R^2 (objective) value for Sample 'S184_D42': 0.999999996 (-28.92356)
# R^2 (objective) value for Sample 'S185_D10': 0.999999996 (-37.84851)
# R^2 (objective) value for Sample 'S185_D23': 0.999999996 (-38.54458)
# R^2 (objective) value for Sample 'S185_D42': 0.999999996 (-35.34976)
# R^2 (objective) value for Sample 'S186_D10': 0.999999997 (-21.05482)
# R^2 (objective) value for Sample 'S186_D23': 0.999999996 (-22.16057)
# R^2 (objective) value for Sample 'S186_D42': 0.999999997 (-19.26351)
# R^2 (objective) value for Sample 'S187_D10': 0.999999997 (-23.88156)
# R^2 (objective) value for Sample 'S187_D23': 0.999999996 (-30.59224)
# R^2 (objective) value for Sample 'S187_D42': 0.999999997 (-18.30406)
# R^2 (objective) value for Sample 'S188_D10': 0.999999996 (-22.27677)
# R^2 (objective) value for Sample 'S188_D23': 0.999999996 (-32.52932)
# R^2 (objective) value for Sample 'S188_D42': 0.999999996 (-19.63776)
# R^2 (objective) value for Sample 'S189_D10': 0.999999996 (-33.01634)
# R^2 (objective) value for Sample 'S189_D23': 0.999999996 (-32.33745)
# R^2 (objective) value for Sample 'S189_D42': 0.999999996 (-32.65028)
# R^2 (objective) value for Sample 'S190_D10': 0.999999996 (-22.13206)
# R^2 (objective) value for Sample 'S190_D23': 0.999999996 (-32.73001)
# R^2 (objective) value for Sample 'S190_D42': 0.999999996 (-32.96480)
# R^2 (objective) value for Sample 'S191_D10': 0.999999996 (-26.90757)
# R^2 (objective) value for Sample 'S191_D23': 0.999999996 (-28.96413)
# R^2 (objective) value for Sample 'S191_D42': 0.999999996 (-30.08932)
# R^2 (objective) value for Sample 'S192_D10': 0.999999996 (-27.72057)
# R^2 (objective) value for Sample 'S192_D23': 0.999999996 (-24.66272)
# R^2 (objective) value for Sample 'S192_D42': 0.999999996 (-20.46305)
# R^2 (objective) value for Sample 'S193_D10': 0.999999997 (-35.72693)
# R^2 (objective) value for Sample 'S193_D23': 0.999999996 (-33.69021)
# R^2 (objective) value for Sample 'S193_D42': 0.999999996 (-32.78968)
# R^2 (objective) value for Sample 'S194_D10': 0.999999996 (-30.77429)
# R^2 (objective) value for Sample 'S194_D23': 0.999999997 (-22.72636)
# R^2 (objective) value for Sample 'S194_D42': 0.999999996 (-23.15098)
# R^2 (objective) value for Sample 'S195_D10': 0.999999996 (-19.44241)
# R^2 (objective) value for Sample 'S195_D23': 0.999999996 (-23.90932)
# R^2 (objective) value for Sample 'S195_D42': 0.999999997 (-23.62717)
# R^2 (objective) value for Sample 'S196_D10': 0.999999996 (-38.87433)
# R^2 (objective) value for Sample 'S196_D23': 0.999999996 (-34.14895)
# R^2 (objective) value for Sample 'S196_D42': 0.999999996 (-34.48961)
# R^2 (objective) value for Sample 'S197_D10': 0.999999997 (-26.55428)
# R^2 (objective) value for Sample 'S197_D23': 0.999999997 (-31.12045)
# R^2 (objective) value for Sample 'S197_D42': 0.999999996 (-31.67532)
# R^2 (objective) value for Sample 'S198_D10': 0.999999996 (-18.80373)
# R^2 (objective) value for Sample 'S198_D23': 0.999999997 (-42.21095)
# R^2 (objective) value for Sample 'S198_D42': 0.999999997 (-27.48305)
# R^2 (objective) value for Sample 'S199_D10': 0.999999995 (-26.34627)
# R^2 (objective) value for Sample 'S199_D23': 0.999999996 (-26.78562)
# R^2 (objective) value for Sample 'S199_D42': 0.999999996 (-28.74196)
# R^2 (objective) value for Sample 'S200_D10': 0.999999996 (-20.26043)
# R^2 (objective) value for Sample 'S200_D23': 0.999999996 (-37.56022)
# R^2 (objective) value for Sample 'S200_D42': 0.999999996 (-30.65377)
# R^2 (objective) value for Sample 'S201_D10': 0.999999996 (-22.34254)
# R^2 (objective) value for Sample 'S201_D23': 0.999999996 (-24.84437)
# R^2 (objective) value for Sample 'S201_D42': 0.999999997 (-22.24491)
# R^2 (objective) value for Sample 'S202_D10': 0.999999996 (-22.61953)
# R^2 (objective) value for Sample 'S202_D23': 0.999999996 (-23.68567)
# R^2 (objective) value for Sample 'S202_D42': 0.999999997 (-21.99583)
# R^2 (objective) value for Sample 'S203_D10': 0.999999997 (-32.48097)
# R^2 (objective) value for Sample 'S203_D23': 0.999999997 (-32.47273)
# R^2 (objective) value for Sample 'S203_D42': 0.999999997 (-33.18920)
# R^2 (objective) value for Sample 'S204_D10': 0.999999997 (-23.79265)
# R^2 (objective) value for Sample 'S204_D23': 0.999999997 (-28.03068)
# R^2 (objective) value for Sample 'S204_D42': 0.999999997 (-29.66170)
# R^2 (objective) value for Sample 'S205_D10': 0.999999996 (-29.91702)
# R^2 (objective) value for Sample 'S205_D23': 0.999999996 (-25.97291)
# R^2 (objective) value for Sample 'S205_D42': 0.999999996 (-29.04651)
# R^2 (objective) value for Sample 'S206_D10': 0.999999996 (-34.89764)
# R^2 (objective) value for Sample 'S206_D23': 0.999999996 (-32.16735)
# R^2 (objective) value for Sample 'S206_D42': 0.999999997 (-33.01696)
# R^2 (objective) value for Sample 'S207_D10': 0.999999996 (-23.49017)
# R^2 (objective) value for Sample 'S207_D23': 0.999999997 (-23.09619)
# R^2 (objective) value for Sample 'S207_D42': 0.999999996 (-14.89026)
# R^2 (objective) value for Sample 'S208_D10': 0.999999996 (-32.72214)
# R^2 (objective) value for Sample 'S208_D23': 0.999999996 (-29.26137)
# R^2 (objective) value for Sample 'S208_D42': 0.999999996 (-25.92034)
# R^2 (objective) value for Sample 'S209_D10': 0.999999997 (-26.71542)
# R^2 (objective) value for Sample 'S209_D23': 0.999999996 (-23.11521)
# R^2 (objective) value for Sample 'S209_D42': 0.999999996 (-20.78608)
# R^2 (objective) value for Sample 'S210_D10': 0.999999996 (-29.82258)
# R^2 (objective) value for Sample 'S210_D23': 0.999999996 (-30.21202)
# R^2 (objective) value for Sample 'S210_D42': 0.999999996 (-27.43247)
# R^2 (objective) value for Sample 'S211_D10': 0.999999997 (-22.52515)
# R^2 (objective) value for Sample 'S211_D23': 0.999999997 (-21.76263)
# R^2 (objective) value for Sample 'S211_D42': 0.999999997 (-25.33034)
# R^2 (objective) value for Sample 'S212_D10': 0.999999996 (-23.01158)
# R^2 (objective) value for Sample 'S212_D23': 0.999999996 (-21.20229)
# R^2 (objective) value for Sample 'S212_D42': 0.999999997 (-26.68052)
# R^2 (objective) value for Sample 'S213_D10': 0.999999997 (-33.18946)
# R^2 (objective) value for Sample 'S213_D23': 0.999999997 (-23.95641)
# R^2 (objective) value for Sample 'S213_D42': 0.999999996 (-22.27960)
# R^2 (objective) value for Sample 'S214_D10': 0.999999997 (-26.42873)
# R^2 (objective) value for Sample 'S214_D23': 0.999999997 (-24.29211)
# R^2 (objective) value for Sample 'S214_D42': 0.999999997 (-28.39029)
# R^2 (objective) value for Sample 'S215_D10': 0.999999997 (-27.41494)
# R^2 (objective) value for Sample 'S215_D23': 0.999999996 (-22.55282)
# R^2 (objective) value for Sample 'S215_D42': 0.999999997 (-34.75801)
# R^2 (objective) value for Sample 'S216_D10': 0.999999996 (-28.22205)
# R^2 (objective) value for Sample 'S216_D23': 0.999999996 (-28.52052)
# R^2 (objective) value for Sample 'S216_D42': 0.999999996 (-28.11846)
# R^2 (objective) value for Sample 'S217_D10': 0.999999996 (-21.69689)
# R^2 (objective) value for Sample 'S217_D23': 0.999999996 (-36.33754)
# R^2 (objective) value for Sample 'S217_D42': 0.999999996 (-33.56042)
# R^2 (objective) value for Sample 'S218_D10': 0.999999996 (-42.30319)
# R^2 (objective) value for Sample 'S218_D23': 0.999999996 (-45.52568)
# R^2 (objective) value for Sample 'S218_D42': 0.999999996 (-43.55590)
# R^2 (objective) value for Sample 'S219_D10': 0.999999996 (-22.47044)
# R^2 (objective) value for Sample 'S219_D23': 0.999999996 (-25.75430)
# R^2 (objective) value for Sample 'S219_D42': 0.999999996 (-30.20446)
# R^2 (objective) value for Sample 'S220_D10': 0.999999996 (-28.29691)
# R^2 (objective) value for Sample 'S220_D23': 0.999999996 (-26.36895)
# R^2 (objective) value for Sample 'S220_D42': 0.999999996 (-26.29766)
# R^2 (objective) value for Sample 'S221_D10': 0.999999996 (-28.93154)
# R^2 (objective) value for Sample 'S221_D23': 0.999999996 (-24.00123)
# R^2 (objective) value for Sample 'S221_D42': 0.999999996 (-24.53169)
# R^2 (objective) value for Sample 'S222_D10': 0.999999996 (-24.31612)
# R^2 (objective) value for Sample 'S222_D23': 0.999999996 (-28.24226)
# R^2 (objective) value for Sample 'S222_D42': 0.999999996 (-30.03931)
# R^2 (objective) value for Sample 'S223_D10': 0.999999996 (-33.49633)
# R^2 (objective) value for Sample 'S223_D23': 0.999999997 (-17.64595)
# R^2 (objective) value for Sample 'S223_D42': 0.999999997 (-23.09337)
# R^2 (objective) value for Sample 'S224_D10': 0.999999996 (-18.31195)
# R^2 (objective) value for Sample 'S224_D23': 0.999999996 (-35.12189)
# R^2 (objective) value for Sample 'S224_D42': 0.999999996 (-27.83015)
# R^2 (objective) value for Sample 'S225_D10': 0.999999997 (-23.02082)
# R^2 (objective) value for Sample 'S225_D23': 0.999999996 (-25.25928)
# R^2 (objective) value for Sample 'S225_D42': 0.999999996 (-23.39740)
# R^2 (objective) value for Sample 'S226_D10': 0.999999996 (-31.57572)
# R^2 (objective) value for Sample 'S226_D23': 0.999999997 (-36.34556)
# R^2 (objective) value for Sample 'S226_D42': 0.999999997 (-31.70682)
# R^2 (objective) value for Sample 'S227_D10': 0.999999996 (-36.22068)
# R^2 (objective) value for Sample 'S227_D23': 0.999999996 (-21.35243)
# R^2 (objective) value for Sample 'S227_D42': 0.999999997 (-21.11612)
# R^2 (objective) value for Sample 'S228_D10': 0.999999997 (-23.79313)
# R^2 (objective) value for Sample 'S228_D23': 0.999999997 (-14.96881)
# R^2 (objective) value for Sample 'S228_D42': 0.999999996 (-19.34178)
# R^2 (objective) value for Sample 'S229_D10': 0.999999997 (-46.74675)
# R^2 (objective) value for Sample 'S229_D23': 0.999999998 (-24.89807)
# R^2 (objective) value for Sample 'S229_D42': 0.999999996 (-19.06492)
# R^2 (objective) value for Sample 'S230_D10': 0.999999996 (-20.00968)
# R^2 (objective) value for Sample 'S230_D23': 0.999999996 (-19.36442)
# R^2 (objective) value for Sample 'S230_D42': 0.999999997 (-21.91524)
# R^2 (objective) value for Sample 'S231_D10': 0.999999998 (-30.73245)
# R^2 (objective) value for Sample 'S231_D23': 0.999999997 (-28.16050)
# R^2 (objective) value for Sample 'S231_D42': 0.999999997 (-26.66508)
# R^2 (objective) value for Sample 'S232_D10': 0.999999996 (-19.07416)
# R^2 (objective) value for Sample 'S232_D23': 0.999999997 (-17.87986)
# R^2 (objective) value for Sample 'S232_D42': 0.999999998 (-21.05462)
# R^2 (objective) value for Sample 'S233_D10': 0.999999997 (-15.77850)
# R^2 (objective) value for Sample 'S233_D23': 0.999999997 (-14.47527)
# R^2 (objective) value for Sample 'S233_D42': 0.999999994 (-11.10553)
# ...
# R^2 (objective) value for Sample 'S542_D10': 0.999999996 (-13.18458)
# R^2 (objective) value for Sample 'S542_D23': 0.999999995 (-31.99409)
# R^2 (objective) value for Sample 'S542_D42': 0.999999996 (-11.28980)
# R^2 (objective) value for Sample 'S543_D10': 0.999999997 (-20.34646)
# R^2 (objective) value for Sample 'S543_D23': 0.999999996 (-43.89709)
# R^2 (objective) value for Sample 'S543_D42': 0.999999997 (-16.74984)
# R^2 (objective) value for Sample 'S544_D10': 0.999999996 (-17.34848)
# R^2 (objective) value for Sample 'S544_D23': 0.999999997 (-17.96948)
# R^2 (objective) value for Sample 'S544_D42': 0.999999997 (-13.76061)
# R^2 (objective) value for Sample 'S545_D10': 0.999999996 (-11.32685)
# R^2 (objective) value for Sample 'S545_D23': 0.999999997 (-12.88955)
# R^2 (objective) value for Sample 'S545_D42': 0.999999996 (-14.20644)
# R^2 (objective) value for Sample 'S546_D10': 0.999999995 (-15.46836)
# R^2 (objective) value for Sample 'S546_D23': 0.999999996 (-13.64761)
# R^2 (objective) value for Sample 'S546_D42': 0.999999996 (-18.51764)
# R^2 (objective) value for Sample 'S547_D10': 0.999999996 (-23.16076)
# R^2 (objective) value for Sample 'S547_D23': 0.999999996 (-22.22180)
# R^2 (objective) value for Sample 'S547_D42': 0.999999997 (-18.19893)
# R^2 (objective) value for Sample 'S548_D10': 0.999999996 (-10.46855)
# R^2 (objective) value for Sample 'S548_D23': 0.999999996 (-12.94344)
# R^2 (objective) value for Sample 'S548_D42': 0.999999996 (-12.68978)
# R^2 (objective) value for Sample 'S549_D10': 0.999999995 (-40.13553)
# R^2 (objective) value for Sample 'S549_D23': 0.999999996 (-17.60679)
# R^2 (objective) value for Sample 'S549_D42': 0.999999995 (-17.41244)
# R^2 (objective) value for Sample 'S550_D10': 0.999999996 (-15.07837)
# R^2 (objective) value for Sample 'S550_D23': 0.999999996 (-13.80998)
# R^2 (objective) value for Sample 'S550_D42': 0.999999996 (-9.58441)
# R^2 (objective) value for Sample 'S551_D10': 0.999999997 (-10.99356)
# R^2 (objective) value for Sample 'S551_D23': 0.999999996 (-15.27511)
# R^2 (objective) value for Sample 'S551_D42': 0.999999996 (-13.50784)
# R^2 (objective) value for Sample 'S552_D10': 0.999999996 (-13.44899)
# R^2 (objective) value for Sample 'S552_D23': 0.999999996 (-12.20975)
# R^2 (objective) value for Sample 'S552_D42': 0.999999996 (-12.97736)
# R^2 (objective) value for Sample 'S553_D10': 0.999999996 (-14.16896)
# R^2 (objective) value for Sample 'S553_D23': 0.999999995 (-14.84255)
# R^2 (objective) value for Sample 'S553_D42': 0.999999996 (-16.20532)
# R^2 (objective) value for Sample 'S554_D10': 0.999999996 (-15.40578)
# R^2 (objective) value for Sample 'S554_D23': 0.999999996 (-13.86609)
# R^2 (objective) value for Sample 'S554_D42': 0.999999996 (-13.77518)
# R^2 (objective) value for Sample 'S555_D10': 0.999999996 (-10.74855)
# R^2 (objective) value for Sample 'S555_D23': 0.999999995 (-49.90016)
# R^2 (objective) value for Sample 'S555_D42': 0.999999996 (-12.75052)
# R^2 (objective) value for Sample 'S556_D10': 0.999999996 (-14.70978)
# R^2 (objective) value for Sample 'S556_D23': 0.999999996 (-15.91543)
# R^2 (objective) value for Sample 'S556_D42': 0.999999995 (-16.01421)
# R^2 (objective) value for Sample 'S557_D10': 0.999999996 (-13.77591)
# R^2 (objective) value for Sample 'S557_D23': 0.999999996 (-16.76031)
# R^2 (objective) value for Sample 'S557_D42': 0.999999996 (-16.68791)
# R^2 (objective) value for Sample 'S558_D10': 0.999999996 (-16.40340)
# R^2 (objective) value for Sample 'S558_D23': 0.999999995 (-17.42409)
# R^2 (objective) value for Sample 'S558_D42': 0.999999996 (-19.24448)
# R^2 (objective) value for Sample 'S559_D10': 0.999999996 (-10.53378)
# R^2 (objective) value for Sample 'S559_D23': 0.999999996 (-10.68002)
# R^2 (objective) value for Sample 'S559_D42': 0.999999996 (-11.34161)
# R^2 (objective) value for Sample 'S560_D10': 0.999999996 (-11.95318)
# R^2 (objective) value for Sample 'S560_D23': 0.999999996 (-10.76295)
# R^2 (objective) value for Sample 'S560_D42': 0.999999995 (-9.44095)
# R^2 (objective) value for Sample 'S561_D10': 0.999999996 (-13.48110)
# R^2 (objective) value for Sample 'S561_D23': 0.999999996 (-13.50406)
# R^2 (objective) value for Sample 'S561_D42': 0.999999996 (-14.34712)
# R^2 (objective) value for Sample 'S562_D10': 0.999999996 (-17.15858)
# R^2 (objective) value for Sample 'S562_D23': 0.999999996 (-16.49312)
# R^2 (objective) value for Sample 'S562_D42': 0.999999996 (-15.24942)
# R^2 (objective) value for Sample 'S563_D10': 0.999999996 (-15.40171)
# R^2 (objective) value for Sample 'S563_D23': 0.999999995 (-37.38042)
# R^2 (objective) value for Sample 'S563_D42': 0.999999997 (-15.85332)
# R^2 (objective) value for Sample 'S564_D10': 0.999999996 (-20.55302)
# R^2 (objective) value for Sample 'S564_D23': 0.999999997 (-20.46143)
# R^2 (objective) value for Sample 'S564_D42': 0.999999995 (-17.94799)
# R^2 (objective) value for Sample 'S565_D10': 0.999999996 (-17.88712)
# R^2 (objective) value for Sample 'S565_D23': 0.999999996 (-17.57706)
# R^2 (objective) value for Sample 'S565_D42': 0.999999996 (-16.96070)
# R^2 (objective) value for Sample 'S566_D10': 0.999999996 (-16.61370)
# R^2 (objective) value for Sample 'S566_D23': 0.999999997 (-14.42445)
# R^2 (objective) value for Sample 'S566_D42': 0.999999996 (-18.74903)
# R^2 (objective) value for Sample 'S567_D10': 0.999999996 (-15.45757)
# R^2 (objective) value for Sample 'S567_D23': 0.999999997 (-14.97720)
# R^2 (objective) value for Sample 'S567_D42': 0.999999996 (-14.22153)
# R^2 (objective) value for Sample 'S568_D10': 0.999999996 (-17.02668)
# R^2 (objective) value for Sample 'S568_D23': 0.999999997 (-10.81766)
# R^2 (objective) value for Sample 'S568_D42': 0.999999997 (-30.77665)
# R^2 (objective) value for Sample 'S569_D10': 0.999999997 (-11.76236)
# R^2 (objective) value for Sample 'S569_D23': 0.999999995 (-35.74387)
# R^2 (objective) value for Sample 'S569_D42': 0.999999996 (-14.73813)
# R^2 (objective) value for Sample 'S570_D10': 0.999999996 (-19.02642)
# R^2 (objective) value for Sample 'S570_D23': 0.999999996 (-19.73725)
# R^2 (objective) value for Sample 'S570_D42': 0.999999996 (-15.11306)
# R^2 (objective) value for Sample 'S571_D10': 0.999999996 (-15.60228)
# R^2 (objective) value for Sample 'S571_D23': 0.999999997 (-17.22512)
# R^2 (objective) value for Sample 'S571_D42': 0.999999997 (-15.56263)
# R^2 (objective) value for Sample 'S572_D10': 0.999999996 (-18.61643)
# R^2 (objective) value for Sample 'S572_D23': 0.999999996 (-23.84538)
# R^2 (objective) value for Sample 'S572_D42': 0.999999996 (-19.87130)
# R^2 (objective) value for Sample 'S573_D10': 0.999999996 (-21.88216)
# R^2 (objective) value for Sample 'S573_D23': 0.999999996 (-17.71379)
# R^2 (objective) value for Sample 'S573_D42': 0.999999996 (-20.32490)
# R^2 (objective) value for Sample 'S574_D10': 0.999999996 (-25.53315)
# R^2 (objective) value for Sample 'S574_D23': 0.999999996 (-25.85510)
# R^2 (objective) value for Sample 'S574_D42': 0.999999997 (-26.32918)
# R^2 (objective) value for Sample 'S575_D10': 0.999999996 (-21.52514)
# R^2 (objective) value for Sample 'S575_D23': 0.999999996 (-24.73453)
# R^2 (objective) value for Sample 'S575_D42': 0.999999996 (-18.26815)
# R^2 (objective) value for Sample 'S576_D10': 0.999999996 (-13.14200)
# R^2 (objective) value for Sample 'S576_D23': 0.999999997 (-17.62641)
# R^2 (objective) value for Sample 'S576_D42': 0.999999996 (-17.39282)
# R^2 (objective) value for Sample 'S577_D10': 0.999999996 (-21.51523)
# R^2 (objective) value for Sample 'S577_D23': 0.999999996 (-19.42505)
# R^2 (objective) value for Sample 'S577_D42': 0.999999996 (-25.91741)
# R^2 (objective) value for Sample 'S578_D10': 0.999999996 (-20.97655)
# R^2 (objective) value for Sample 'S578_D23': 0.999999996 (-19.79549)
# R^2 (objective) value for Sample 'S578_D42': 0.999999995 (-26.90656)
# R^2 (objective) value for Sample 'S579_D10': 0.999999996 (-14.58706)
# R^2 (objective) value for Sample 'S579_D23': 0.999999996 (-17.48054)
# R^2 (objective) value for Sample 'S579_D42': 0.999999996 (-14.19314)
# R^2 (objective) value for Sample 'S580_D10': 0.999999996 (-14.09792)
# R^2 (objective) value for Sample 'S580_D23': 0.999999996 (-13.47494)
# R^2 (objective) value for Sample 'S580_D42': 0.999999996 (-16.99344)
# R^2 (objective) value for Sample 'S581_D10': 0.999999996 (-19.70988)
# R^2 (objective) value for Sample 'S581_D23': 0.999999996 (-18.59600)
# R^2 (objective) value for Sample 'S581_D42': 0.999999996 (-19.06446)
# R^2 (objective) value for Sample 'S582_D10': 0.999999996 (-28.27759)
# R^2 (objective) value for Sample 'S582_D23': 0.999999995 (-28.42882)
# R^2 (objective) value for Sample 'S582_D42': 0.999999996 (-29.92410)
# R^2 (objective) value for Sample 'S583_D10': 0.999999997 (-18.32067)
# R^2 (objective) value for Sample 'S583_D23': 0.999999996 (-16.68821)
# R^2 (objective) value for Sample 'S583_D42': 0.999999996 (-13.53733)
# R^2 (objective) value for Sample 'S584_D10': 0.999999996 (-22.14740)
# R^2 (objective) value for Sample 'S584_D23': 0.999999996 (-29.82883)
# R^2 (objective) value for Sample 'S584_D42': 0.999999996 (-24.85812)
# R^2 (objective) value for Sample 'S585_D10': 0.999999996 (-17.36132)
# R^2 (objective) value for Sample 'S585_D23': 0.999999996 (-16.57917)
# R^2 (objective) value for Sample 'S585_D42': 0.999999997 (-16.40756)
# R^2 (objective) value for Sample 'S586_D10': 0.999999995 (-25.44238)
# R^2 (objective) value for Sample 'S586_D23': 0.999999996 (-19.90338)
# R^2 (objective) value for Sample 'S586_D42': 0.999999996 (-21.28420)
# R^2 (objective) value for Sample 'S587_D10': 0.999999996 (-13.04448)
# R^2 (objective) value for Sample 'S587_D23': 0.999999996 (-17.09914)
# R^2 (objective) value for Sample 'S587_D42': 0.999999996 (-13.97409)
# R^2 (objective) value for Sample 'S588_D10': 0.999999996 (-18.26070)
# R^2 (objective) value for Sample 'S588_D23': 0.999999996 (-14.70667)
# R^2 (objective) value for Sample 'S588_D42': 0.999999997 (-19.08145)
# R^2 (objective) value for Sample 'S589_D10': 0.999999996 (-19.99151)
# R^2 (objective) value for Sample 'S589_D23': 0.999999996 (-21.32734)
# R^2 (objective) value for Sample 'S589_D42': 0.999999996 (-25.36961)
# R^2 (objective) value for Sample 'S590_D10': 0.999999996 (-10.30309)
# R^2 (objective) value for Sample 'S590_D23': 0.999999996 (-28.28629)
# R^2 (objective) value for Sample 'S590_D42': 0.999999997 (-15.62571)
# R^2 (objective) value for Sample 'S591_D10': 0.999999996 (-16.34031)
# R^2 (objective) value for Sample 'S591_D23': 0.999999996 (-17.77438)
# R^2 (objective) value for Sample 'S591_D42': 0.999999996 (-18.21135)
# R^2 (objective) value for Sample 'S592_D10': 0.999999996 (-21.36408)
# R^2 (objective) value for Sample 'S592_D23': 0.999999996 (-22.80854)
# R^2 (objective) value for Sample 'S592_D42': 0.999999996 (-19.49761)
# R^2 (objective) value for Sample 'S593_D10': 0.999999995 (-21.44896)
# R^2 (objective) value for Sample 'S593_D23': 0.999999995 (-17.37939)
# R^2 (objective) value for Sample 'S593_D42': 0.999999995 (-17.75667)
# R^2 (objective) value for Sample 'S594_D10': 0.999999996 (-11.78264)
# R^2 (objective) value for Sample 'S594_D23': 0.999999996 (-13.37571)
# R^2 (objective) value for Sample 'S594_D42': 0.999999996 (-10.47030)
# R^2 (objective) value for Sample 'S595_D10': 0.999999996 (-17.09092)
# R^2 (objective) value for Sample 'S595_D23': 0.999999995 (-32.57382)
# R^2 (objective) value for Sample 'S595_D42': 0.999999996 (-12.76386)
# R^2 (objective) value for Sample 'S596_D10': 0.999999995 (-33.60795)
# R^2 (objective) value for Sample 'S596_D23': 0.999999996 (-13.05433)
# R^2 (objective) value for Sample 'S596_D42': 0.999999995 (-38.10805)
# R^2 (objective) value for Sample 'S597_D10': 0.999999996 (-11.67825)
# R^2 (objective) value for Sample 'S597_D23': 0.999999997 (-14.64114)
# R^2 (objective) value for Sample 'S597_D42': 0.999999997 (-12.71600)
# R^2 (objective) value for Sample 'S598_D10': 0.999999996 (-16.20141)
# R^2 (objective) value for Sample 'S598_D23': 0.999999996 (-15.16346)
# R^2 (objective) value for Sample 'S598_D42': 0.999999996 (-17.76341)
# R^2 (objective) value for Sample 'S599_D10': 0.999999996 (-36.52301)
# R^2 (objective) value for Sample 'S599_D23': 0.999999996 (-13.35652)
# R^2 (objective) value for Sample 'S599_D42': 0.999999996 (-39.34526)
# R^2 (objective) value for Sample 'S600_D10': 0.999999996 (-12.56243)
# R^2 (objective) value for Sample 'S600_D23': 0.999999996 (-37.90577)
# R^2 (objective) value for Sample 'S600_D42': 0.999999996 (-12.13732)
# R^2 (objective) value for Sample 'S601_D10': 0.999999995 (-36.68877)
# R^2 (objective) value for Sample 'S601_D23': 0.999999997 (-10.79631)
# R^2 (objective) value for Sample 'S601_D42': 0.999999996 (-18.76546)
# R^2 (objective) value for Sample 'S602_D10': 0.999999996 (-16.06042)
# R^2 (objective) value for Sample 'S602_D23': 0.999999996 (-21.39540)
# R^2 (objective) value for Sample 'S602_D42': 0.999999997 (-19.57313)
# R^2 (objective) value for Sample 'S603_D10': 0.999999996 (-17.90750)
# R^2 (objective) value for Sample 'S603_D23': 0.999999996 (-17.40940)
# R^2 (objective) value for Sample 'S603_D42': 0.999999996 (-18.21974)
# R^2 (objective) value for Sample 'S604_D10': 0.999999996 (-18.26446)
# R^2 (objective) value for Sample 'S604_D23': 0.999999995 (-30.06379)
# R^2 (objective) value for Sample 'S604_D42': 0.999999996 (-12.03490)
# R^2 (objective) value for Sample 'S605_D10': 0.999999996 (-18.98809)
# R^2 (objective) value for Sample 'S605_D23': 0.999999996 (-21.24935)
# R^2 (objective) value for Sample 'S605_D42': 0.999999996 (-20.04725)
# R^2 (objective) value for Sample 'S606_D10': 0.999999996 (-35.09251)
# R^2 (objective) value for Sample 'S606_D23': 0.999999996 (-16.82149)
# R^2 (objective) value for Sample 'S606_D42': 0.999999996 (-26.47248)
# R^2 (objective) value for Sample 'S607_D10': 0.999999997 (-13.65283)
# R^2 (objective) value for Sample 'S607_D23': 0.999999996 (-18.19445)
# R^2 (objective) value for Sample 'S607_D42': 0.999999996 (-11.00266)
# R^2 (objective) value for Sample 'S608_D10': 0.999999996 (-18.16289)
# R^2 (objective) value for Sample 'S608_D23': 0.999999996 (-16.89843)
# R^2 (objective) value for Sample 'S608_D42': 0.999999997 (-12.20738)
# R^2 (objective) value for Sample 'S609_D10': 0.999999996 (-28.68352)
# R^2 (objective) value for Sample 'S609_D23': 0.999999996 (-13.24263)
# R^2 (objective) value for Sample 'S609_D42': 0.999999996 (-10.80483)
# R^2 (objective) value for Sample 'S610_D10': 0.999999996 (-13.29880)
# R^2 (objective) value for Sample 'S610_D23': 0.999999995 (-31.36069)
# R^2 (objective) value for Sample 'S610_D42': 0.999999996 (-21.42657)
# R^2 (objective) value for Sample 'S611_D10': 0.999999996 (-19.11575)
# R^2 (objective) value for Sample 'S611_D23': 0.999999996 (-17.85036)
# R^2 (objective) value for Sample 'S611_D42': 0.999999996 (-10.69488)
# R^2 (objective) value for Sample 'S612_D10': 0.999999996 (-29.60630)
# R^2 (objective) value for Sample 'S612_D23': 0.999999996 (-16.43737)
# R^2 (objective) value for Sample 'S612_D42': 0.999999996 (-15.70812)
# R^2 (objective) value for Sample 'S613_D10': 0.999999996 (-19.90685)
# R^2 (objective) value for Sample 'S613_D23': 0.999999996 (-21.26745)
# R^2 (objective) value for Sample 'S613_D42': 0.999999996 (-14.78992)
# R^2 (objective) value for Sample 'S614_D10': 0.999999996 (-17.63207)
# R^2 (objective) value for Sample 'S614_D23': 0.999999996 (-24.24687)
# R^2 (objective) value for Sample 'S614_D42': 0.999999996 (-22.95309)
# R^2 (objective) value for Sample 'S615_D10': 0.999999996 (-18.67827)
# R^2 (objective) value for Sample 'S615_D23': 0.999999996 (-21.49159)
# R^2 (objective) value for Sample 'S615_D42': 0.999999996 (-17.96336)
# R^2 (objective) value for Sample 'S616_D10': 0.999999996 (-14.00105)
# R^2 (objective) value for Sample 'S616_D23': 0.999999996 (-19.01177)
# R^2 (objective) value for Sample 'S616_D42': 0.999999996 (-18.37135)
# R^2 (objective) value for Sample 'Mean_D10': 0.999999996 (-5511.97228)
# R^2 (objective) value for Sample 'Median_D10': 0.999999996 (-19.21787)
# R^2 (objective) value for Sample 'Mean_D23': 0.999999996 (-5656.28770)
# R^2 (objective) value for Sample 'Median_D23': 0.999999996 (-19.85720)
# R^2 (objective) value for Sample 'Mean_D42': 0.999999996 (-3490.41039)
# R^2 (objective) value for Sample 'Median_D42': 0.999999996 (-19.05346)
# Number of QP solutions: 1854

# %% [markdown]
# ### Plot fitting for the mean and median samples

# %%
samples_to_plot = np.array(
    [
        # Best for 1 or 3 columns
        [x for x in operation_ids if "Mean" in x],
        [x for x in operation_ids if "Median" in x],
    ]
)

r2_text_loc = "lower right"

length = 4
nrows, ncols = samples_to_plot.shape
fig, axes = plt.subplots(
    nrows=nrows,
    ncols=ncols,
    figsize=(length * ncols, length * nrows),
    sharex=True,
    sharey=True,
)
sns.despine(fig)

for idx, (sample_id, ax) in enumerate(zip(samples_to_plot.flatten(), axes.flatten())):
    df_qp_sol, r2, objective_value = qp_solutions_dict[sample_id]
    xlabel, ylabel = df_qp_sol.columns

    ticks = np.geomspace(1e-6, 1e6, 5)
    perfect_fit_line = ax.plot(
        [0, ticks[-1]],
        [0, ticks[-1]],
        linestyle=":",
        color="black",
        linewidth=1,
        alpha=1,
    )

    df_zeros = df_qp_sol[(df_qp_sol.apply(lambda x: np.isclose(x, 0))).any(axis=1)]
    df_perfect = df_qp_sol[
        np.isclose(
            abs(df_qp_sol["Measured Proteome"] - df_qp_sol["Best-Fitted Proteome"]), 0
        )
    ]
    df_perfect = df_perfect[~df_perfect.index.isin(df_zeros.index)]

    df_altered = df_qp_sol[
        ~np.isclose(
            abs(df_qp_sol["Measured Proteome"] - df_qp_sol["Best-Fitted Proteome"]), 0
        )
    ]
    df_altered = df_altered[~df_altered.index.isin(df_zeros.index)]
    df_always_zero = df_zeros[(df_zeros == 0).all(axis=1)]
    df_zeros = df_zeros[~df_zeros.index.isin(df_always_zero.index)]
    df_from_zeros = df_zeros[np.isclose(df_zeros["Measured Proteome"], 0)]
    df_to_zeros = df_zeros[np.isclose(df_zeros["Best-Fitted Proteome"], 0)]

    handles = [
        ax.scatter(
            data=df_perfect.replace(0, ticks[0]),
            x=xlabel,
            y=ylabel,
            color="xkcd:blue",
            alpha=0.5,
            edgecolors="black",
            linewidths=1,
        ),
        ax.scatter(
            data=df_altered.replace(0, ticks[0]),
            x=xlabel,
            y=ylabel,
            color="xkcd:yellow",
            alpha=0.5,
            edgecolors="black",
            linewidths=1,
        ),
        ax.scatter(
            data=df_from_zeros.replace(0, ticks[0]),
            x=xlabel,
            y=ylabel,
            color="xkcd:green",
            alpha=0.5,
            edgecolors="black",
            linewidths=1,
        ),
        ax.scatter(
            data=df_to_zeros.replace(0, ticks[0]),
            x=xlabel,
            y=ylabel,
            color="xkcd:red",
            alpha=0.5,
            edgecolors="black",
            linewidths=1,
        ),
        ax.scatter(
            data=df_always_zero.replace(0, ticks[0]),
            x=xlabel,
            y=ylabel,
            color="xkcd:black",
            alpha=0.5,
            edgecolors="black",
            linewidths=1,
        ),
    ]
    labels = [
        f"Perfect fit",
        f"Adjusted expression",
        f"Unexpressed to expressed",
        f"Expressed to unexpressed",
        f"Never expressed",
    ]

    donor, day = sample_id.split("_")
    if not ("Mean" == donor or "Median" == donor):
        donor = donor.replace("S", "; Donor ")
    day = day.replace("D", "Day ")
    fancy_sample_id = " ".join((day, donor))

    ax.set_xscale("log")
    ax.set_yscale("log")

    fontdict = {"size": "xx-large"}
    if idx == len(samples_to_plot.flatten()) - np.ceil(ncols / 2):
        ax.set_xlabel(xlabel, fontdict=fontdict)
    fig.legend(
        handles=handles,
        labels=labels,
        loc="lower center",
        ncols=len(labels),
        frameon=False,
        fontsize="large",
        markerscale=2,
        bbox_to_anchor=(0.5, -0.05),
    )
    if idx % ncols == 0:
        ax.set_ylabel(ylabel, fontdict=fontdict)

    ax.set_xticks(ticks)
    ax.set_yticks(ticks)

    ax.xaxis.set_tick_params(labelsize="x-large")
    ax.yaxis.set_tick_params(labelsize="x-large")

    r2_format = " = {:.4f}"
    if r2_text_loc == "lower right":
        ax.text(
            0.95,
            0.1,
            r"$R^{2}$" + r2_format.format(r2) + ("\n{}".format(fancy_sample_id)),
            transform=ax.transAxes,
            color="black",
            fontsize="large",
            ha="right",
        )
    elif r2_text_loc == "upper left":
        ax.text(
            0.05,
            0.9,
            ("{}\n".format(fancy_sample_id)) + r"$R^{2}$" + r2_format.format(r2),
            transform=ax.transAxes,
            color="black",
            fontsize="large",
            ha="left",
        )
    else:
        pass
fig.tight_layout()
if save_figures:
    fig.savefig(
        f"{results_path}/QPfitting_{model_id}.{imagetype}",
        transparent=transparent,
        format=imagetype,
    )

# %% [markdown]
# ### Determine best value for slack variables

# %%
list_of_pcmodels = []
verbose = True
objective_rxns = ["NaKt"]

df_relaxation_filename = results_path / f"SlackPercentDeterminationData_{model_id}.tsv"

slack_min = 1e-5  # Slack %
slack_max = 1.5
if run_computations:
    for sample_id in operation_ids:
        df_qp_sol, r2, objective_value = qp_solutions_dict[sample_id]
        # Create a copy of the model
        pcmodel_sample = pcmodel.copy()
        pcmodel_sample.id = f"{pcmodel.id}_{sample_id}"
        for protdl in pcmodel_sample.reactions.query(
            lambda x: isinstance(x, ProteinDilution)
        ):
            if protdl.id in df_qp_sol.index:
                prot_bound = df_qp_sol.loc[protdl.id]["Best-Fitted Proteome"]
            else:
                prot_bound = 0
            protdl.bounds = (float(prot_bound), float(prot_bound))
        # Add the relaxation budget with slack = 0 first
        add_relaxation_budget(pcmodel_sample, 0, verbose)
        list_of_pcmodels += [pcmodel_sample]

    solutions = {
        pcmodel_sample.id: {
            "model": [],
            "slack": [],
            "objective": [],
            "relaxation": [],
            "_".join(objective_rxns): [],
        }
        for pcmodel_sample in list_of_pcmodels
    }
    slack_min = 1e-5
    slack_max = 1.5
    for slack_value in np.geomspace(slack_min, slack_max, 251):
        print(f"Updating slack variable to {100 * slack_value:.4f}%.")
        for pcmodel_sample in list_of_pcmodels:
            update_slack_value(pcmodel_sample, slack_value, verbose=False)
            relaxation_demand = pcmodel_sample.reactions.get_by_id(
                f"PBDL_relaxation_budget"
            )
            pcmodel_sample.objective = (
                sum(
                    [
                        r.flux_expression
                        for r in pcmodel_sample.reactions.get_by_any(objective_rxns)
                    ]
                )
                - relaxation_demand.flux_expression
            )
            pcmodel_sample.objective_direction = "max"
            sol = pcmodel_sample.optimize()
            obj_value = sol.objective_value
            if not obj_value or np.isnan(obj_value):
                continue
            else:
                demand = relaxation_demand.flux
                budget = relaxation_demand.upper_bound
            solutions[pcmodel_sample.id]["model"].append(pcmodel_sample.id)
            solutions[pcmodel_sample.id]["slack"].append(slack_value)
            solutions[pcmodel_sample.id]["objective"].append(obj_value)
            solutions[pcmodel_sample.id]["_".join(objective_rxns)].append(
                obj_value + demand
            )
            solutions[pcmodel_sample.id]["relaxation"].append(demand / budget)
    solutions = {
        pcmodel_sample: pd.DataFrame.from_dict(sol)
        for pcmodel_sample, sol in solutions.items()
    }

    df_relaxation = pd.concat(list(solutions.values()), axis=0)
    df_relaxation.to_csv(
        # f"{results_path}/SlackPercentDeterminationData_{model_id}.tsv",
        df_relaxation_filename,
        sep="\t",
        index=False,
    )
else:
    df_relaxation = pd.read_csv(
        df_relaxation_filename, sep="\t"
    )
    solutions = {
        mid: df_relaxation[df_relaxation["model"] == mid].drop("model", axis=1)
        for mid in df_relaxation["model"].unique()
    }
df_relaxation
# Out:
# Relaxation budget added to RBC3P_PC_Mean_D10, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC3P_PC_Median_D10, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC3P_PC_Mean_D23, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC3P_PC_Median_D23, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC3P_PC_Mean_D42, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC3P_PC_Median_D42, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Updating slack variable to 0.0010%.
# Updating slack variable to 0.0010%.
# d:\Anaconda3\envs\RBC-GEM-akey7\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Updating slack variable to 0.0011%.
# Updating slack variable to 0.0012%.
# Updating slack variable to 0.0012%.
# Updating slack variable to 0.0013%.
# Updating slack variable to 0.0013%.
# Updating slack variable to 0.0014%.
# Updating slack variable to 0.0015%.
# Updating slack variable to 0.0015%.
# Updating slack variable to 0.0016%.
# Updating slack variable to 0.0017%.
# Updating slack variable to 0.0018%.
# Updating slack variable to 0.0019%.
# Updating slack variable to 0.0019%.
# Updating slack variable to 0.0020%.
# Updating slack variable to 0.0021%.
# Updating slack variable to 0.0022%.
# Updating slack variable to 0.0024%.
# Updating slack variable to 0.0025%.
# Updating slack variable to 0.0026%.
# Updating slack variable to 0.0027%.
# Updating slack variable to 0.0029%.
# Updating slack variable to 0.0030%.
# Updating slack variable to 0.0031%.
# Updating slack variable to 0.0033%.
# Updating slack variable to 0.0035%.
# Updating slack variable to 0.0036%.
# Updating slack variable to 0.0038%.
# Updating slack variable to 0.0040%.
# Updating slack variable to 0.0042%.
# Updating slack variable to 0.0044%.
# Updating slack variable to 0.0046%.
# Updating slack variable to 0.0048%.
# Updating slack variable to 0.0051%.
# Updating slack variable to 0.0053%.
# Updating slack variable to 0.0056%.
# Updating slack variable to 0.0058%.
# Updating slack variable to 0.0061%.
# Updating slack variable to 0.0064%.
# Updating slack variable to 0.0067%.
# Updating slack variable to 0.0071%.
# Updating slack variable to 0.0074%.
# Updating slack variable to 0.0078%.
# Updating slack variable to 0.0081%.
# Updating slack variable to 0.0085%.
# Updating slack variable to 0.0090%.
# Updating slack variable to 0.0094%.
# Updating slack variable to 0.0099%.
# Updating slack variable to 0.0103%.
# Updating slack variable to 0.0108%.
# Updating slack variable to 0.0114%.
# Updating slack variable to 0.0119%.
# Updating slack variable to 0.0125%.
# Updating slack variable to 0.0131%.
# Updating slack variable to 0.0138%.
# Updating slack variable to 0.0144%.
# Updating slack variable to 0.0151%.
# Updating slack variable to 0.0159%.
# Updating slack variable to 0.0167%.
# Updating slack variable to 0.0175%.
# Updating slack variable to 0.0183%.
# Updating slack variable to 0.0192%.
# Updating slack variable to 0.0202%.
# Updating slack variable to 0.0211%.
# Updating slack variable to 0.0222%.
# Updating slack variable to 0.0233%.
# Updating slack variable to 0.0244%.
# Updating slack variable to 0.0256%.
# Updating slack variable to 0.0268%.
# Updating slack variable to 0.0281%.
# Updating slack variable to 0.0295%.
# Updating slack variable to 0.0310%.
# Updating slack variable to 0.0325%.
# Updating slack variable to 0.0341%.
# Updating slack variable to 0.0357%.
# Updating slack variable to 0.0375%.
# Updating slack variable to 0.0393%.
# Updating slack variable to 0.0412%.
# Updating slack variable to 0.0432%.
# Updating slack variable to 0.0453%.
# Updating slack variable to 0.0475%.
# Updating slack variable to 0.0499%.
# Updating slack variable to 0.0523%.
# Updating slack variable to 0.0548%.
# Updating slack variable to 0.0575%.
# Updating slack variable to 0.0603%.
# Updating slack variable to 0.0633%.
# Updating slack variable to 0.0664%.
# Updating slack variable to 0.0696%.
# Updating slack variable to 0.0730%.
# Updating slack variable to 0.0766%.
# Updating slack variable to 0.0803%.
# Updating slack variable to 0.0842%.
# Updating slack variable to 0.0884%.
# Updating slack variable to 0.0927%.
# Updating slack variable to 0.0972%.
# Updating slack variable to 0.1019%.
# Updating slack variable to 0.1069%.
# Updating slack variable to 0.1121%.
# Updating slack variable to 0.1176%.
# Updating slack variable to 0.1234%.
# Updating slack variable to 0.1294%.
# Updating slack variable to 0.1357%.
# Updating slack variable to 0.1423%.
# Updating slack variable to 0.1493%.
# Updating slack variable to 0.1566%.
# Updating slack variable to 0.1642%.
# Updating slack variable to 0.1722%.
# Updating slack variable to 0.1806%.
# Updating slack variable to 0.1894%.
# Updating slack variable to 0.1987%.
# Updating slack variable to 0.2084%.
# Updating slack variable to 0.2186%.
# Updating slack variable to 0.2292%.
# Updating slack variable to 0.2404%.
# Updating slack variable to 0.2522%.
# Updating slack variable to 0.2645%.
# Updating slack variable to 0.2774%.
# Updating slack variable to 0.2910%.
# Updating slack variable to 0.3052%.
# Updating slack variable to 0.3201%.
# Updating slack variable to 0.3357%.
# Updating slack variable to 0.3521%.
# Updating slack variable to 0.3693%.
# Updating slack variable to 0.3873%.
# Updating slack variable to 0.4062%.
# Updating slack variable to 0.4260%.
# Updating slack variable to 0.4468%.
# Updating slack variable to 0.4687%.
# Updating slack variable to 0.4915%.
# Updating slack variable to 0.5156%.
# Updating slack variable to 0.5407%.
# Updating slack variable to 0.5671%.
# Updating slack variable to 0.5948%.
# Updating slack variable to 0.6239%.
# Updating slack variable to 0.6543%.
# Updating slack variable to 0.6863%.
# Updating slack variable to 0.7198%.
# Updating slack variable to 0.7549%.
# Updating slack variable to 0.7918%.
# Updating slack variable to 0.8305%.
# Updating slack variable to 0.8710%.
# Updating slack variable to 0.9135%.
# Updating slack variable to 0.9581%.
# Updating slack variable to 1.0049%.
# Updating slack variable to 1.0540%.
# Updating slack variable to 1.1055%.
# Updating slack variable to 1.1594%.
# Updating slack variable to 1.2160%.
# Updating slack variable to 1.2754%.
# Updating slack variable to 1.3377%.
# Updating slack variable to 1.4030%.
# Updating slack variable to 1.4715%.
# Updating slack variable to 1.5434%.
# Updating slack variable to 1.6187%.
# Updating slack variable to 1.6978%.
# Updating slack variable to 1.7807%.
# Updating slack variable to 1.8676%.
# Updating slack variable to 1.9588%.
# Updating slack variable to 2.0545%.
# Updating slack variable to 2.1548%.
# Updating slack variable to 2.2600%.
# Updating slack variable to 2.3703%.
# Updating slack variable to 2.4861%.
# Updating slack variable to 2.6075%.
# Updating slack variable to 2.7348%.
# Updating slack variable to 2.8683%.
# Updating slack variable to 3.0084%.
# Updating slack variable to 3.1553%.
# Updating slack variable to 3.3093%.
# Updating slack variable to 3.4709%.
# Updating slack variable to 3.6404%.
# Updating slack variable to 3.8182%.
# Updating slack variable to 4.0046%.
# Updating slack variable to 4.2001%.
# Updating slack variable to 4.4052%.
# Updating slack variable to 4.6203%.
# Updating slack variable to 4.8459%.
# Updating slack variable to 5.0825%.
# Updating slack variable to 5.3307%.
# Updating slack variable to 5.5910%.
# Updating slack variable to 5.8640%.
# Updating slack variable to 6.1503%.
# Updating slack variable to 6.4506%.
# Updating slack variable to 6.7656%.
# Updating slack variable to 7.0960%.
# Updating slack variable to 7.4425%.
# Updating slack variable to 7.8059%.
# Updating slack variable to 8.1870%.
# Updating slack variable to 8.5868%.
# Updating slack variable to 9.0060%.
# Updating slack variable to 9.4458%.
# Updating slack variable to 9.9070%.
# Updating slack variable to 10.3907%.
# Updating slack variable to 10.8981%.
# Updating slack variable to 11.4302%.
# Updating slack variable to 11.9884%.
# Updating slack variable to 12.5737%.
# Updating slack variable to 13.1877%.
# Updating slack variable to 13.8316%.
# Updating slack variable to 14.5070%.
# Updating slack variable to 15.2153%.
# Updating slack variable to 15.9583%.
# Updating slack variable to 16.7375%.
# Updating slack variable to 17.5548%.
# Updating slack variable to 18.4119%.
# Updating slack variable to 19.3109%.
# Updating slack variable to 20.2539%.
# Updating slack variable to 21.2428%.
# Updating slack variable to 22.2801%.
# Updating slack variable to 23.3680%.
# Updating slack variable to 24.5090%.
# Updating slack variable to 25.7057%.
# Updating slack variable to 26.9609%.
# Updating slack variable to 28.2773%.
# Updating slack variable to 29.6581%.
# Updating slack variable to 31.1062%.
# Updating slack variable to 32.6251%.
# Updating slack variable to 34.2181%.
# Updating slack variable to 35.8889%.
# Updating slack variable to 37.6413%.
# Updating slack variable to 39.4793%.
# Updating slack variable to 41.4070%.
# Updating slack variable to 43.4288%.
# Updating slack variable to 45.5493%.
# Updating slack variable to 47.7734%.
# Updating slack variable to 50.1061%.
# Updating slack variable to 52.5527%.
# Updating slack variable to 55.1188%.
# Updating slack variable to 57.8101%.
# Updating slack variable to 60.6329%.
# Updating slack variable to 63.5935%.
# Updating slack variable to 66.6987%.
# Updating slack variable to 69.9554%.
# Updating slack variable to 73.3712%.
# Updating slack variable to 76.9538%.
# Updating slack variable to 80.7113%.
# Updating slack variable to 84.6523%.
# Updating slack variable to 88.7857%.
# Updating slack variable to 93.1210%.
# Updating slack variable to 97.6679%.
# Updating slack variable to 102.4369%.
# Updating slack variable to 107.4387%.
# Updating slack variable to 112.6847%.
# Updating slack variable to 118.1869%.
# Updating slack variable to 123.9578%.
# Updating slack variable to 130.0104%.
# Updating slack variable to 136.3586%.
# Updating slack variable to 143.0167%.
# Updating slack variable to 150.0000%.
#                    model     slack  objective  relaxation      NaKt
# 0      RBC3P_PC_Mean_D10  0.004062  -0.013580    0.021256  0.068835
# 1      RBC3P_PC_Mean_D10  0.004260  -0.013432    0.020230  0.068835
# 2      RBC3P_PC_Mean_D10  0.004468  -0.013334    0.019265  0.068835
# 3      RBC3P_PC_Mean_D10  0.004687  -0.013226    0.018344  0.068835
# 4      RBC3P_PC_Mean_D10  0.004915  -0.013108    0.017465  0.068835
# ..                   ...       ...        ...         ...       ...
# 119  RBC3P_PC_Median_D42  1.239578   0.014459    0.000047  0.070297
# 120  RBC3P_PC_Median_D42  1.300104   0.014459    0.000045  0.070297
# 121  RBC3P_PC_Median_D42  1.363586   0.014459    0.000043  0.070297
# 122  RBC3P_PC_Median_D42  1.430167   0.014459    0.000041  0.070297
# 123  RBC3P_PC_Median_D42  1.500000   0.014459    0.000039  0.070297
#
# [747 rows x 5 columns]

# %%
fig, axes = plt.subplots(
    3, 1, figsize=(4, 10), sharex=True, gridspec_kw=dict(hspace=0.05)
)
axes = axes.flatten()

# ax3d = fig.add_subplot(2, 2, 4, projection="3d")
sns.despine(fig)

handles = []
labels = []
chosen_slack_var = 0.03
colors = {
    "D10": "xkcd:green",
    "D23": "xkcd:gold",
    "D42": "xkcd:red",
}
linestyles = {
    "Mean": "-",
    "Median": "-.",
}
use_percents = True
for pcmodel_sample in list(solutions):
    donor, day = str(pcmodel_sample).split("_")[-2:]
    linestyle = linestyles.get(donor, ":")
    color = colors.get(day, "xkcd:light blue")
    if not ("Mean" == donor or "Median" == donor):
        donor = donor.replace("S", "; Donor ")
    day = day.replace("D", "Day ")
    fancy_sample_id = " ".join((day, donor))

    labels.append(fancy_sample_id)
    s_values = solutions[str(pcmodel_sample)]["slack"].values
    r_values = solutions[str(pcmodel_sample)]["relaxation"].values * (
        100 if use_percents else 1
    )
    o_values = solutions[str(pcmodel_sample)]["objective"].values
    rxn_values = solutions[str(pcmodel_sample)]["_".join(objective_rxns)].values

    zorder = 1
    lw = 2
    axes[0].plot(
        s_values,
        r_values,
        label=str(pcmodel_sample),
        color=color,
        linestyle=linestyle,
        linewidth=lw,
        zorder=zorder,
    )
    axes[1].plot(
        s_values,
        o_values,
        label=str(pcmodel_sample),
        color=color,
        linestyle=linestyle,
        linewidth=lw,
        zorder=zorder,
    )
    axes[2].plot(
        s_values,
        rxn_values,
        label=str(pcmodel_sample),
        color=color,
        linestyle=linestyle,
        linewidth=lw,
        zorder=zorder,
    )

    # index = list(s_values).index(s_values[s_values >= chosen_slack_var][0])
    # spt = s_values[index]
    # rpt = r_values[index]
    # opt = o_values[index]
    # rxnpt = rxn_values[index]
    # c = "black"
    # ls = ""
    # marker = "o"
    # markersize = 8
    # axes[0].plot(spt, rpt, color=c, linestyle=ls, marker=marker, markersize=markersize)
    # axes[1].plot(spt, opt, color=c, linestyle=ls, marker=marker, markersize=markersize)
    # axes[2].plot(spt, rxnpt, color=c, linestyle=ls, marker=marker, markersize=markersize)
    # ax3d.plot(spt, rpt, opt, color=c, linestyle=ls, marker=marker, markersize=markersize)
    # print(f"Elbow point for {pcmodel_sample}: ({spt:.5f}, {rpt:.5f}, {opt:.5f})")
fontdict = {"size": "x-large"}
axes[-1].set_xlabel(r"Slack variable $s$", fontdict=fontdict)

i = 0
zorder = 2
alpha = 0.7
limit_pad_sclar = 1.2
ymin, ymax = (-0.001 * (100 if use_percents else 1), max(r_values) * limit_pad_sclar)
smin = s_values[list(o_values).index(o_values[o_values <= 0][0])]
axes[i].vlines(chosen_slack_var, ymin=ymin, ymax=ymax, color="black", linestyle=":")
axes[i].vlines(
    smin, ymin=ymin, ymax=ymax, color="black", linestyle="-", zorder=zorder, alpha=alpha
)
axes[i].vlines(
    1, ymin=ymin, ymax=ymax, color="black", linestyle="-", zorder=zorder, alpha=alpha
)
axes[i].set_xlim(smin / 2, slack_max)
axes[i].set_ylim(ymin, ymax)
axes[i].set_xscale("log")
axes[i].annotate(
    rf"$s = {chosen_slack_var}$",
    xy=(chosen_slack_var, 0),
    xycoords="data",
    xytext=(5, 0),
    textcoords="offset points",
    ha="left",
    fontsize=fontdict["size"],
)
axes[i].annotate(
    rf"$s > 0$",
    xy=(smin, ymax),
    xycoords="data",
    xytext=(10, 5),
    textcoords="offset points",
    ha="center",
    fontsize=fontdict["size"],
)
axes[i].annotate(
    rf"$s \leq 1$",
    xy=(1, ymax),
    xycoords="data",
    xytext=(10, 5),
    textcoords="offset points",
    ha="center",
    fontsize=fontdict["size"],
)
axes[i].fill_between((smin / 2, smin), ymin, ymax, color="xkcd:light grey")
axes[i].annotate(
    "Infeasible",
    xy=(smin, (ymax + ymin) / 2),
    xycoords="data",
    rotation=90,
    xytext=(-10, 0),
    textcoords="offset points",
    va="center",
    ha="right",
    fontsize=fontdict["size"],
)


i += 1
ymin, ymax = (min(o_values) * limit_pad_sclar, max(o_values) * limit_pad_sclar)
axes[i].vlines(chosen_slack_var, ymin=ymin, ymax=ymax, color="black", linestyle=":")
axes[i].vlines(
    smin, ymin=ymin, ymax=ymax, color="black", linestyle="-", zorder=zorder, alpha=alpha
)
axes[i].vlines(
    1, ymin=ymin, ymax=ymax, color="black", linestyle="-", zorder=zorder, alpha=alpha
)
axes[i].set_xlim(smin / 2, slack_max)
axes[i].set_ylim(ymin, ymax)
axes[i].set_xscale("log")
# axes[i].annotate(rf'$s = {chosen_slack_var}$', xy=(chosen_slack_var, 0), xycoords='data', xytext=(5, 0), textcoords='offset points',  ha="left", fontsize=fontdict["size"])
# axes[i].annotate(rf'$s > 0$', xy=(smin, ymax), xycoords='data', xytext=(10, 5), textcoords='offset points', ha="center", fontsize=fontdict["size"])
# axes[i].annotate(rf'$s \leq 1$', xy=(1, ymax), xycoords='data', xytext=(10, 5), textcoords='offset points', ha="center", fontsize=fontdict["size"])
axes[i].fill_between((smin / 2, smin), ymin, ymax, color="xkcd:light grey")
axes[i].annotate(
    "Infeasible",
    xy=(smin, (ymax + ymin) / 2),
    xycoords="data",
    rotation=90,
    xytext=(-10, 0),
    textcoords="offset points",
    va="center",
    ha="right",
    fontsize=fontdict["size"],
)

i += 1

ymin, ymax = (0, max(rxn_values) * limit_pad_sclar)
axes[i].vlines(chosen_slack_var, ymin=ymin, ymax=ymax, color="black", linestyle=":")
axes[i].vlines(
    smin, ymin=ymin, ymax=ymax, color="black", linestyle="-", zorder=zorder, alpha=alpha
)
axes[i].vlines(
    1, ymin=ymin, ymax=ymax, color="black", linestyle="-", zorder=zorder, alpha=alpha
)
axes[i].set_xlim(smin / 2, slack_max)
axes[i].set_ylim(ymin, ymax)
axes[i].set_xscale("log")
# axes[i].annotate(rf'$s = {chosen_slack_var}$', xy=(chosen_slack_var, 0), xycoords='data', xytext=(5, 0), textcoords='offset points',  ha="left", fontsize=fontdict["size"])
# axes[i].annotate(rf'$s > 0$', xy=(smin, ymax), xycoords='data', xytext=(10, 5), textcoords='offset points', ha="center", fontsize=fontdict["size"])
# axes[i].annotate(rf'$s \leq 1$', xy=(1, ymax), xycoords='data', xytext=(10, 5), textcoords='offset points', ha="center", fontsize=fontdict["size"])
axes[i].fill_between((smin / 2, smin), ymin, ymax, color="xkcd:light grey")
axes[i].annotate(
    "Infeasible",
    xy=(smin, (ymax + ymin) / 2),
    xycoords="data",
    rotation=90,
    xytext=(-10, 0),
    textcoords="offset points",
    va="center",
    ha="right",
    fontsize=fontdict["size"],
)

handles, labels = axes[2].get_legend_handles_labels()
handles_labels = dict(zip(labels, handles))
handles_labels = {
    k: handles_labels[k] for k in sorted(handles_labels, key=get_time_from_id)
}
handles, labels = (list(handles_labels.values()), list(handles_labels.keys()))
labels = [
    "Day " + " ".join(l.replace(f"{pcmodel.id}_", "").split("_")[::-1])[1:]
    for l in labels
]
axes[2].legend(
    handles=handles,
    labels=labels,
    ncols=1,
    frameon=False,
    loc="upper center",
    fontsize="large",
    bbox_to_anchor=(0.6, 0.7),
)


axes[0].set_ylabel("Relaxation budget used (%)", fontdict=fontdict)
axes[1].set_ylabel("Objective value", fontdict=fontdict)
axes[2].set_ylabel("NaKt (mmol/gDW/hr)", fontdict=fontdict)

fig.align_labels()
if save_figures:
    fig.savefig(
        f"{results_path}/SlackPercentDetermination_{model_id}.{imagetype}",
        transparent=transparent,
        format=imagetype,
    )

# %% [markdown]
# ### Formulate models from QP solutions

# %%
list_of_relaxed_models = []
slack_value = chosen_slack_var  # Slack %
verbose = True

# In our experience, SBML/XML loads faster, but will take up to 4x more space uncompressed as compared to JSON
ftypes = {
    "xml"
    # "json",
}

model_values = {}
dataset_models_dirpath.mkdir(exist_ok=True, parents=True)
ftypes = set([ftypes]) if isinstance(ftypes, str) else set(ftypes)
for sample_id, (df_qp_sol, r2, objective_value) in qp_solutions_dict.items():
    # Create a copy of the model
    sample_id = f"{pcmodel.id}_{sample_id}"
    filenames = [
        Path(f"{dataset_models_dirpath}/{sample_id}.{ftype}") for ftype in ftypes
    ]
    if all([filename.exists() for filename in filenames]):
        print(f"Model already created for {sample_id}")
        continue
    pcmodel_sample = pcmodel.copy()
    pcmodel_sample.id = sample_id
    for protdl in pcmodel_sample.reactions.query(
        lambda x: isinstance(x, ProteinDilution)
    ):
        if protdl.id in df_qp_sol.index:
            prot_bound = df_qp_sol.loc[protdl.id]["Best-Fitted Proteome"]
        else:
            prot_bound = 0
        protdl.bounds = (float(prot_bound), float(prot_bound))
    # Add the relaxation budget
    add_relaxation_budget(pcmodel_sample, slack_value, verbose)
    # # Store model for later use
    # list_of_relaxed_models += [pcmodel_sample]
    for filename in filenames:
        # Might as well overwrite all files, especially if model needed to be regenerated anyways
        write_cobra_model(
            pcmodel_sample,
            filename=filename,
        )
# Out:
# Relaxation budget added to RBC3P_PC_S1_D10, extra 28.6437 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S1_D23, extra 28.6545 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S1_D42, extra 28.6671 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S2_D10, extra 28.6579 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S2_D23, extra 28.6510 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S2_D42, extra 28.6554 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S3_D10, extra 28.6212 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S3_D23, extra 28.6503 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S3_D42, extra 28.6574 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S4_D10, extra 28.6490 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S4_D23, extra 28.6519 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S4_D42, extra 28.6520 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S5_D10, extra 28.6640 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S5_D23, extra 28.6595 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S5_D42, extra 28.6592 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S6_D10, extra 28.6501 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S6_D23, extra 28.6392 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S6_D42, extra 28.6461 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S7_D10, extra 28.6686 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S7_D23, extra 28.6693 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S7_D42, extra 28.6534 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S8_D10, extra 28.6467 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S8_D23, extra 28.6609 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S8_D42, extra 28.6555 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S9_D10, extra 28.6572 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S9_D23, extra 28.6571 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S9_D42, extra 28.6576 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S10_D10, extra 28.6450 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S10_D23, extra 28.6311 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S10_D42, extra 28.6462 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S11_D10, extra 28.6572 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S11_D23, extra 28.6440 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S11_D42, extra 28.6598 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S12_D10, extra 28.6445 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S12_D23, extra 28.6365 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S12_D42, extra 28.6357 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S13_D10, extra 28.6493 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S13_D23, extra 28.6459 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S13_D42, extra 28.6507 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S14_D10, extra 28.6361 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S14_D23, extra 28.6456 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S14_D42, extra 28.6489 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S15_D10, extra 28.6558 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S15_D23, extra 28.6496 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S15_D42, extra 28.6584 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S16_D10, extra 28.6607 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S16_D23, extra 28.6666 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S16_D42, extra 28.6418 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S17_D10, extra 28.6443 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S17_D23, extra 28.6417 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S17_D42, extra 28.6318 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S18_D10, extra 28.6542 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S18_D23, extra 28.6603 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S18_D42, extra 28.6517 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S19_D10, extra 28.6323 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S19_D23, extra 28.6350 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S19_D42, extra 28.6388 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S20_D10, extra 28.6454 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S20_D23, extra 28.6493 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S20_D42, extra 28.6318 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S21_D10, extra 28.6316 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S21_D23, extra 28.6439 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S21_D42, extra 28.6365 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S22_D10, extra 28.6312 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S22_D23, extra 28.6374 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S22_D42, extra 28.6357 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S23_D10, extra 28.6475 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S23_D23, extra 28.6381 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S23_D42, extra 28.6510 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S24_D10, extra 28.6643 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S24_D23, extra 28.6690 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S24_D42, extra 28.6568 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S25_D10, extra 28.6160 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S25_D23, extra 28.6452 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S25_D42, extra 28.6520 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S26_D10, extra 28.6457 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S26_D23, extra 28.6394 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S26_D42, extra 28.6539 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S27_D10, extra 28.6489 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S27_D23, extra 28.6570 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S27_D42, extra 28.6480 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S28_D10, extra 28.6470 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S28_D23, extra 28.6621 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S28_D42, extra 28.6559 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S29_D10, extra 28.6387 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S29_D23, extra 28.6295 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S29_D42, extra 28.6367 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S30_D10, extra 28.6599 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S30_D23, extra 28.6495 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S30_D42, extra 28.6645 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S31_D10, extra 28.6494 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S31_D23, extra 28.6513 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S31_D42, extra 28.6402 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S32_D10, extra 28.6543 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S32_D23, extra 28.6451 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S32_D42, extra 28.6516 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S33_D10, extra 28.6460 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S33_D23, extra 28.6336 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S33_D42, extra 28.6400 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S34_D10, extra 28.6398 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S34_D23, extra 28.6366 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S34_D42, extra 28.6475 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S35_D10, extra 28.6435 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S35_D23, extra 28.6287 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S35_D42, extra 28.6309 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S36_D10, extra 28.6475 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S36_D23, extra 28.6534 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S36_D42, extra 28.6411 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S37_D10, extra 28.6406 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S37_D23, extra 28.6475 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S37_D42, extra 28.6531 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S38_D10, extra 28.6386 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S38_D23, extra 28.6335 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S38_D42, extra 28.6389 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S39_D10, extra 28.6623 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S39_D23, extra 28.6578 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S39_D42, extra 28.6573 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S40_D10, extra 28.6626 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S40_D23, extra 28.6506 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S40_D42, extra 28.6683 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S41_D10, extra 28.6573 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S41_D23, extra 28.6372 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S41_D42, extra 28.6419 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S42_D10, extra 28.6413 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S42_D23, extra 28.6370 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S42_D42, extra 28.6331 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S43_D10, extra 28.6584 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S43_D23, extra 28.6566 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S43_D42, extra 28.6545 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S44_D10, extra 28.6444 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S44_D23, extra 28.6468 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S44_D42, extra 28.6591 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S45_D10, extra 28.6489 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S45_D23, extra 28.6487 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S45_D42, extra 28.6437 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S46_D10, extra 28.6338 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S46_D23, extra 28.6393 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S46_D42, extra 28.6438 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S47_D10, extra 28.6636 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S47_D23, extra 28.6508 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S47_D42, extra 28.6477 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S48_D10, extra 28.6405 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S48_D23, extra 28.6387 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S48_D42, extra 28.6306 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S49_D10, extra 28.6483 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S49_D23, extra 28.6597 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S49_D42, extra 28.6440 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S50_D10, extra 28.6322 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S50_D23, extra 28.6313 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S50_D42, extra 28.6254 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S51_D10, extra 28.6443 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S51_D23, extra 28.6385 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S51_D42, extra 28.6486 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S52_D10, extra 28.6626 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S52_D23, extra 28.6509 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S52_D42, extra 28.6522 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S53_D10, extra 28.6435 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S53_D23, extra 28.6632 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S53_D42, extra 28.6446 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S54_D10, extra 28.6455 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S54_D23, extra 28.6454 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S54_D42, extra 28.6448 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S55_D10, extra 28.6481 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S55_D23, extra 28.6478 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S55_D42, extra 28.6369 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S56_D10, extra 28.6545 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S56_D23, extra 28.6602 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S56_D42, extra 28.6455 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S57_D10, extra 28.6490 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S57_D23, extra 28.6441 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S57_D42, extra 28.6391 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S58_D10, extra 28.6346 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S58_D23, extra 28.6416 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S58_D42, extra 28.6363 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S59_D10, extra 28.6377 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S59_D23, extra 28.6368 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S59_D42, extra 28.6400 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S60_D10, extra 28.6429 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S60_D23, extra 28.6408 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S60_D42, extra 28.6442 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S61_D10, extra 28.6391 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S61_D23, extra 28.6497 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S61_D42, extra 28.6414 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S62_D10, extra 28.6380 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S62_D23, extra 28.6451 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S62_D42, extra 28.6095 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S63_D10, extra 28.6447 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S63_D23, extra 28.6542 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S63_D42, extra 28.6567 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S64_D10, extra 28.6570 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S64_D23, extra 28.6557 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S64_D42, extra 28.6516 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S65_D10, extra 28.6338 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S65_D23, extra 28.6433 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S65_D42, extra 28.6469 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S66_D10, extra 28.6477 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S66_D23, extra 28.6549 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S66_D42, extra 28.6370 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S67_D10, extra 28.6351 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S67_D23, extra 28.6340 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S67_D42, extra 28.6277 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S68_D10, extra 28.6380 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S68_D23, extra 28.6385 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S68_D42, extra 28.6276 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S69_D10, extra 28.6512 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S69_D23, extra 28.6500 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S69_D42, extra 28.6467 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S70_D10, extra 28.6487 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S70_D23, extra 28.6515 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S70_D42, extra 28.6605 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S71_D10, extra 28.6484 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S71_D23, extra 28.6387 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S71_D42, extra 28.6390 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S72_D10, extra 28.6383 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S72_D23, extra 28.6345 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S72_D42, extra 28.6371 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S73_D10, extra 28.6463 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S73_D23, extra 28.6426 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S73_D42, extra 28.6383 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S74_D10, extra 28.6338 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S74_D23, extra 28.6372 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S74_D42, extra 28.6370 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S75_D10, extra 28.6480 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S75_D23, extra 28.6453 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S75_D42, extra 28.6397 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S76_D10, extra 28.6517 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S76_D23, extra 28.6527 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S76_D42, extra 28.6452 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S77_D10, extra 28.6487 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S77_D23, extra 28.6417 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S77_D42, extra 28.6382 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S78_D10, extra 28.6457 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S78_D23, extra 28.6418 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S78_D42, extra 28.6496 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S79_D10, extra 28.6411 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S79_D23, extra 28.6362 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S79_D42, extra 28.6326 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S80_D10, extra 28.6479 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S80_D23, extra 28.6199 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S80_D42, extra 28.6417 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S81_D10, extra 28.6414 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S81_D23, extra 28.6412 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S81_D42, extra 28.6348 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S82_D10, extra 28.6361 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S82_D23, extra 28.6404 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S82_D42, extra 28.6412 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S83_D10, extra 28.6499 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S83_D23, extra 28.6066 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S83_D42, extra 28.6421 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S84_D10, extra 28.6531 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S84_D23, extra 28.6624 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S84_D42, extra 28.6544 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S85_D10, extra 28.6440 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S85_D23, extra 28.6438 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S85_D42, extra 28.6449 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S86_D10, extra 28.6491 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S86_D23, extra 28.6491 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S86_D42, extra 28.6291 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S87_D10, extra 28.6439 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S87_D23, extra 28.6502 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S87_D42, extra 28.6497 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S88_D10, extra 28.6363 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S88_D23, extra 28.6326 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S88_D42, extra 28.6420 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S89_D10, extra 28.6480 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S89_D23, extra 28.6261 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S89_D42, extra 28.6447 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S90_D10, extra 28.6255 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S90_D23, extra 28.6432 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S90_D42, extra 28.6300 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S91_D10, extra 28.6368 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S91_D23, extra 28.6510 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S91_D42, extra 28.6420 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S92_D10, extra 28.6518 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S92_D23, extra 28.6531 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S92_D42, extra 28.6396 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S93_D10, extra 28.6505 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S93_D23, extra 28.6269 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S93_D42, extra 28.6537 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S94_D10, extra 28.6413 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S94_D23, extra 28.6348 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S94_D42, extra 28.6394 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S95_D10, extra 28.6376 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S95_D23, extra 28.6375 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S95_D42, extra 28.6382 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S96_D10, extra 28.6258 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S96_D23, extra 28.6352 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S96_D42, extra 28.6311 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S97_D10, extra 28.6131 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S97_D23, extra 28.6110 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S97_D42, extra 28.6231 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S98_D10, extra 28.6270 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S98_D23, extra 28.6271 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S98_D42, extra 28.6293 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S99_D10, extra 28.6532 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S99_D23, extra 28.6473 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S99_D42, extra 28.6555 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S100_D10, extra 28.6417 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S100_D23, extra 28.6298 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S100_D42, extra 28.6326 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S101_D10, extra 28.6476 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S101_D23, extra 28.6414 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S101_D42, extra 28.6399 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S102_D10, extra 28.6340 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S102_D23, extra 28.6347 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S102_D42, extra 28.6334 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S103_D10, extra 28.6456 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S103_D23, extra 28.6474 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S103_D42, extra 28.6575 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S104_D10, extra 28.6405 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S104_D23, extra 28.6416 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S104_D42, extra 28.6410 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S105_D10, extra 28.6418 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S105_D23, extra 28.6409 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S105_D42, extra 28.6427 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S106_D10, extra 28.6394 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S106_D23, extra 28.6579 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S106_D42, extra 28.6538 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S107_D10, extra 28.6499 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S107_D23, extra 28.6453 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S107_D42, extra 28.6496 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S108_D10, extra 28.6525 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S108_D23, extra 28.6406 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S108_D42, extra 28.6454 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S109_D10, extra 28.6560 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S109_D23, extra 28.6439 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S109_D42, extra 28.6455 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S110_D10, extra 28.6384 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S110_D23, extra 28.6457 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S110_D42, extra 28.6409 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S111_D10, extra 28.6394 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S111_D23, extra 28.6510 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S111_D42, extra 28.6558 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S112_D10, extra 28.6498 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S112_D23, extra 28.6446 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S112_D42, extra 28.6281 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S113_D10, extra 28.6343 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S113_D23, extra 28.6198 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S113_D42, extra 28.6423 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S114_D10, extra 28.6388 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S114_D23, extra 28.6405 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S114_D42, extra 28.6342 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S115_D10, extra 28.6351 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S115_D23, extra 28.6369 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S115_D42, extra 28.6414 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S116_D10, extra 28.6469 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S116_D23, extra 28.6405 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S116_D42, extra 28.6465 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S117_D10, extra 28.6364 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S117_D23, extra 28.6343 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S117_D42, extra 28.6338 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S118_D10, extra 28.6308 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S118_D23, extra 28.6428 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S118_D42, extra 28.6328 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S119_D10, extra 28.6432 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S119_D23, extra 28.6306 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S119_D42, extra 28.6356 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S120_D10, extra 28.6314 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S120_D23, extra 28.6273 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S120_D42, extra 28.6378 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S121_D10, extra 28.6236 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S121_D23, extra 28.6346 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S121_D42, extra 28.6170 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S122_D10, extra 28.6231 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S122_D23, extra 28.6278 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S122_D42, extra 28.6189 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S123_D10, extra 28.6417 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S123_D23, extra 28.6406 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S123_D42, extra 28.6421 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S124_D10, extra 28.6231 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S124_D23, extra 28.6378 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S124_D42, extra 28.6369 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S125_D10, extra 28.6456 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S125_D23, extra 28.6379 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S125_D42, extra 28.6307 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S126_D10, extra 28.6398 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S126_D23, extra 28.6387 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S126_D42, extra 28.6341 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S127_D10, extra 28.6368 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S127_D23, extra 28.6379 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S127_D42, extra 28.6252 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S128_D10, extra 28.6446 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S128_D23, extra 28.6344 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S128_D42, extra 28.6380 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S129_D10, extra 28.6364 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S129_D23, extra 28.6390 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S129_D42, extra 28.6483 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S130_D10, extra 28.6558 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S130_D23, extra 28.6602 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S130_D42, extra 28.6589 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S131_D10, extra 28.6321 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S131_D23, extra 28.6468 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S131_D42, extra 28.6414 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S132_D10, extra 28.6268 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S132_D23, extra 28.6254 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S132_D42, extra 28.6251 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S133_D10, extra 28.6204 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S133_D23, extra 28.6208 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S133_D42, extra 28.6227 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S134_D10, extra 28.6442 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S134_D23, extra 28.6447 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S134_D42, extra 28.6328 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S135_D10, extra 28.6481 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S135_D23, extra 28.6335 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S135_D42, extra 28.6369 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S136_D10, extra 28.6345 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S136_D23, extra 28.6403 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S136_D42, extra 28.6371 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S137_D10, extra 28.6271 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S137_D23, extra 28.6364 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S137_D42, extra 28.6363 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S138_D10, extra 28.6331 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S138_D23, extra 28.6288 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S138_D42, extra 28.6324 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S139_D10, extra 28.6394 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S139_D23, extra 28.6605 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S139_D42, extra 28.6366 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S140_D10, extra 28.6309 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S140_D23, extra 28.6380 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S140_D42, extra 28.6296 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S141_D10, extra 28.6488 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S141_D23, extra 28.6492 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S141_D42, extra 28.6455 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S142_D10, extra 28.6130 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S142_D23, extra 28.6216 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S142_D42, extra 28.6201 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S143_D10, extra 28.6337 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S143_D23, extra 28.6427 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S143_D42, extra 28.6472 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S144_D10, extra 28.6483 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S144_D23, extra 28.6448 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S144_D42, extra 28.6580 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S145_D10, extra 28.6268 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S145_D23, extra 28.6215 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S145_D42, extra 28.6285 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S146_D10, extra 28.6256 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S146_D23, extra 28.6343 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S146_D42, extra 28.6301 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S147_D10, extra 28.6511 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S147_D23, extra 28.6398 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S147_D42, extra 28.6407 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S148_D10, extra 28.6311 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S148_D23, extra 28.6239 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S148_D42, extra 28.6315 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S149_D10, extra 28.6492 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S149_D23, extra 28.6476 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S149_D42, extra 28.6452 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S150_D10, extra 28.6476 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S150_D23, extra 28.6429 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S150_D42, extra 28.6289 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S151_D10, extra 28.6587 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S151_D23, extra 28.6552 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S151_D42, extra 28.6443 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S152_D10, extra 28.6585 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S152_D23, extra 28.6549 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# ...
# Relaxation budget added to RBC3P_PC_S569_D10, extra 28.6277 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S569_D23, extra 28.6345 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S569_D42, extra 28.6325 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S570_D10, extra 28.6374 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S570_D23, extra 28.6331 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S570_D42, extra 28.6375 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S571_D10, extra 28.6400 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S571_D23, extra 28.6297 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S571_D42, extra 28.6331 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S572_D10, extra 28.6226 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S572_D23, extra 28.6217 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S572_D42, extra 28.6215 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S573_D10, extra 28.6176 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S573_D23, extra 28.6230 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S573_D42, extra 28.6164 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S574_D10, extra 28.6161 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S574_D23, extra 28.6223 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S574_D42, extra 28.6201 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S575_D10, extra 28.6171 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S575_D23, extra 28.6189 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S575_D42, extra 28.6278 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S576_D10, extra 28.6400 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S576_D23, extra 28.6275 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S576_D42, extra 28.6226 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S577_D10, extra 28.6455 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S577_D23, extra 28.6391 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S577_D42, extra 28.6169 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S578_D10, extra 28.6373 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S578_D23, extra 28.6314 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S578_D42, extra 28.6283 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S579_D10, extra 28.6213 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S579_D23, extra 28.6254 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S579_D42, extra 28.6199 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S580_D10, extra 28.6215 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S580_D23, extra 28.6249 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S580_D42, extra 28.6229 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S581_D10, extra 28.6272 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S581_D23, extra 28.6295 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S581_D42, extra 28.6297 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S582_D10, extra 28.6320 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S582_D23, extra 28.6237 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S582_D42, extra 28.6264 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S583_D10, extra 28.6121 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S583_D23, extra 28.6157 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S583_D42, extra 28.6174 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S584_D10, extra 28.6303 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S584_D23, extra 28.6332 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S584_D42, extra 28.6441 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S585_D10, extra 28.6335 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S585_D23, extra 28.6275 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S585_D42, extra 28.6333 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S586_D10, extra 28.6605 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S586_D23, extra 28.6609 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S586_D42, extra 28.6481 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S587_D10, extra 28.6326 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S587_D23, extra 28.6494 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S587_D42, extra 28.6427 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S588_D10, extra 28.6465 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S588_D23, extra 28.6439 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S588_D42, extra 28.6441 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S589_D10, extra 28.6369 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S589_D23, extra 28.6378 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S589_D42, extra 28.6343 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S590_D10, extra 28.6397 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S590_D23, extra 28.6384 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S590_D42, extra 28.6389 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S591_D10, extra 28.6398 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S591_D23, extra 28.6404 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S591_D42, extra 28.6428 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S592_D10, extra 28.6279 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S592_D23, extra 28.6205 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S592_D42, extra 28.6225 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S593_D10, extra 28.6484 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S593_D23, extra 28.6435 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S593_D42, extra 28.6429 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S594_D10, extra 28.6376 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S594_D23, extra 28.6383 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S594_D42, extra 28.6363 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S595_D10, extra 28.6347 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S595_D23, extra 28.6343 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S595_D42, extra 28.6334 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S596_D10, extra 28.6428 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S596_D23, extra 28.6544 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S596_D42, extra 28.6449 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S597_D10, extra 28.6383 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S597_D23, extra 28.6394 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S597_D42, extra 28.6386 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S598_D10, extra 28.6510 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S598_D23, extra 28.6495 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S598_D42, extra 28.6489 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S599_D10, extra 28.6371 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S599_D23, extra 28.6403 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S599_D42, extra 28.6389 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S600_D10, extra 28.6282 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S600_D23, extra 28.6332 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S600_D42, extra 28.6270 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S601_D10, extra 28.6377 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S601_D23, extra 28.6404 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S601_D42, extra 28.6434 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S602_D10, extra 28.6339 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S602_D23, extra 28.6427 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S602_D42, extra 28.6458 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S603_D10, extra 28.6301 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S603_D23, extra 28.6366 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S603_D42, extra 28.6313 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S604_D10, extra 28.6326 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S604_D23, extra 28.6356 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S604_D42, extra 28.6351 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S605_D10, extra 28.6274 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S605_D23, extra 28.6282 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S605_D42, extra 28.6283 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S606_D10, extra 28.6355 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S606_D23, extra 28.6341 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S606_D42, extra 28.6331 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S607_D10, extra 28.6412 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S607_D23, extra 28.6354 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S607_D42, extra 28.6279 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S608_D10, extra 28.6351 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S608_D23, extra 28.6398 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S608_D42, extra 28.6415 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S609_D10, extra 28.6146 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S609_D23, extra 28.6235 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S609_D42, extra 28.6278 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S610_D10, extra 28.6243 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S610_D23, extra 28.6206 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S610_D42, extra 28.6216 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S611_D10, extra 28.6268 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S611_D23, extra 28.6223 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S611_D42, extra 28.6312 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S612_D10, extra 28.6171 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S612_D23, extra 28.6159 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S612_D42, extra 28.6123 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S613_D10, extra 28.6353 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S613_D23, extra 28.6354 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S613_D42, extra 28.6382 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S614_D10, extra 28.6534 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S614_D23, extra 28.6453 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S614_D42, extra 28.6429 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S615_D10, extra 28.6443 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S615_D23, extra 28.6453 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S615_D42, extra 28.6470 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S616_D10, extra 28.6409 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S616_D23, extra 28.6383 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_S616_D42, extra 28.6410 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_Mean_D10, extra 28.6346 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_Median_D10, extra 28.6399 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_Mean_D23, extra 28.6351 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_Median_D23, extra 28.6397 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_Mean_D42, extra 28.6343 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC3P_PC_Median_D42, extra 28.6386 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
