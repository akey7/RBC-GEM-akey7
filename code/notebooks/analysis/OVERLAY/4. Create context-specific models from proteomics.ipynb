# %% [markdown]
# # Create context-specific models using proteomic data
# ## Setup
# ### Import packages

# %%
from pathlib import Path

import gurobipy as gp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import sympy
from cobra.flux_analysis import find_blocked_reactions
from rbc_gem_utils import (COBRA_CONFIGURATION, PROCESSED_PATH, ROOT_PATH,
                           read_cobra_model, show_versions, write_cobra_model)
from rbc_gem_utils.analysis.overlay import (ComplexDilution, ProteinDilution,
                                            add_relaxation_budget,
                                            load_overlay_model,
                                            update_slack_value)
from rbc_gem_utils.util import AVOGADRO_NUMBER, DEFAULT_DRY_MASS_PER_CELL
from sklearn.metrics import r2_score

gp.setParam("OutputFlag", 0)
gp.setParam("LogToConsole", 0)

# Show versions of notebook
show_versions()
# Out:
# Set parameter Username
#
# Package Information
# -------------------
# rbc-gem-utils 0.0.1
#
# Dependency Information
# ----------------------
# beautifulsoup4                       4.12.3
# bio                                 missing
# cobra                                0.29.1
# depinfo                               2.2.0
# gurobipy                             11.0.3
# matplotlib                           3.10.0
# matplotlib-venn                       1.1.1
# memote                               0.17.0
# networkx                              3.4.2
# notebook                              7.3.2
# openpyxl                              3.1.5
# pandas                                2.2.3
# pre-commit                            4.1.0
# rbc-gem-utils[database,network,vis] missing
# requests                             2.32.3
# scipy                                1.15.1
# seaborn                              0.13.2
#
# Build Tools Information
# -----------------------
# pip          24.2
# setuptools 75.1.0
# wheel      0.44.0
#
# Platform Information
# --------------------
# Windows 11-AMD64
# CPython   3.12.8

# %% [markdown]
# ### Define configuration
# #### COBRA Configuration

# %%
COBRA_CONFIGURATION.solver = "gurobi"
COBRA_CONFIGURATION.bounds = (-1e8, 1e8)
COBRA_CONFIGURATION
# Out:
# solver: gurobi
# tolerance: 1e-07
# lower_bound: -100000000.0
# upper_bound: 100000000.0
# processes: 127
# cache_directory: C:\Users\Alicia Key\AppData\Local\opencobra\cobrapy\Cache
# max_cache_size: 104857600
# cache_expiration: None

# %% [markdown]
# ## Load RBC-GEM model

# %%
model_id = "RBC3P"

data_path = Path("../../../../data/analysis/OVERLAY").resolve()
root_path = Path("../../../..").resolve()
results_path = root_path / "data" / "processed" / model_id / "OVERLAY"
results_path.mkdir(exist_ok=True, parents=True)

imagetype = "svg"
transparent = True
save_figures = True
overwrite = True

dataset_name = "RBComics"
pcmodel_dirpath = data_path / model_id
dataset_path = results_path / dataset_name
dataset_models_dirpath = dataset_path / "pcmodels"

sample_prefix, time_prefix = ("S", "D")
# Integers are easier to work with for time points
timepoints = [10, 23, 42]

model_filename = pcmodel_dirpath / f"{model_id}.xml"
model = read_cobra_model(filename=model_filename)
pcmodel_filename = pcmodel_dirpath / f"{model_id}_PC.xml"
pcmodel = load_overlay_model(filename=pcmodel_filename)

pcmodel
# Out:
# <Model RBC3P_PC at 0x218d2edb8c0>

# %% [markdown]
# ## Load RBC Proteomics

# %%
# Ensure index corresponds to sample IDs and columns are proteins IDs
df_copy_number_samples_filename = data_path / dataset_name / "Proteomics_CopyNumbers.tsv"
df_copy_number_samples = pd.read_csv(
    df_copy_number_samples_filename, sep="\t", index_col=0
)
sample_ids = df_copy_number_samples.index
df_copy_number_samples
# Out:
#                 P69905        P68871        P02042        P02008  \
# S1_D10    1.254607e+08  6.751875e+07  1.684139e+08  3.409157e+07
# S2_D10    1.622846e+08  3.248112e+07  2.455682e+08  6.281825e+07
# S3_D10    1.408849e+08  9.282055e+07  2.866462e+08  3.096045e+07
# S4_D10    1.533373e+08  9.428727e+07  2.796149e+08  4.492695e+07
# S5_D10    1.451599e+08  7.885271e+07  2.064930e+08  5.865059e+07
# ...                ...           ...           ...           ...
# S612_D42  1.479013e+08  9.034572e+07  1.777762e+08  5.760717e+07
# S613_D42  1.502160e+08  1.017134e+08  1.650392e+08  7.026294e+07
# S614_D42  1.367636e+08  7.392661e+07  1.359617e+08  5.370047e+07
# S615_D42  1.452709e+08  8.787838e+07  1.717963e+08  5.531884e+07
# S616_D42  1.508962e+08  9.040845e+07  1.687312e+08  5.736702e+07
#
#                 P02730        P30043        P32119        P02768  \
# S1_D10    4.582424e+06  1.956960e+07  7.461828e+06  4.729611e+06
# S2_D10    5.497925e+06  2.819367e+07  1.184191e+07  3.586910e+06
# S3_D10    4.302025e+06  1.713969e+07  8.752663e+06  2.807233e+06
# S4_D10    3.875573e+06  2.500399e+07  8.190457e+06  3.354456e+06
# S5_D10    6.774951e+06  2.690653e+07  1.633960e+07  3.973826e+06
# ...                ...           ...           ...           ...
# S612_D42  6.396855e+06  2.158214e+07  1.311621e+07  4.412278e+06
# S613_D42  6.076268e+06  2.803835e+07  1.344956e+07  3.119734e+06
# S614_D42  5.640477e+06  2.786735e+07  1.309307e+07  1.950198e+06
# S615_D42  6.005166e+06  2.895227e+07  1.179158e+07  2.199533e+06
# S616_D42  6.505993e+06  2.793557e+07  1.335286e+07  2.895548e+06
#
#                 Q92902        P04040  ...  Q9Y3E7        Q9Y4Y9       Q9Y508  \
# S1_D10    3.697239e+06  3.742403e+06  ...     0.0      0.000000     0.000000
# S2_D10    2.223799e+06  2.496767e+06  ...     0.0      0.000000  9634.822452
# S3_D10    1.635281e+07  8.260527e+05  ...     0.0      0.000000     0.000000
# S4_D10    1.123342e+06  3.666083e+06  ...     0.0      0.000000     0.000000
# S5_D10    2.859506e+06  4.664673e+06  ...     0.0  27830.662335     0.000000
# ...                ...           ...  ...     ...           ...          ...
# S612_D42  2.390702e+06  4.028351e+06  ...     0.0      0.000000     0.000000
# S613_D42  2.704957e+06  4.309456e+06  ...     0.0      0.000000     0.000000
# S614_D42  3.363896e+06  3.664767e+06  ...     0.0      0.000000     0.000000
# S615_D42  1.464653e+06  4.171225e+06  ...     0.0      0.000000     0.000000
# S616_D42  1.462335e+06  3.358596e+06  ...     0.0      0.000000     0.000000
#
#                Q9Y587       Q9Y5B8  Q9Y5P4        Q9Y5Y2       Q9Y666  \
# S1_D10       0.000000  7378.473625     0.0      0.000000     0.000000
# S2_D10    5263.615637   805.935440     0.0      0.000000  4567.509290
# S3_D10       0.000000     0.000000     0.0      0.000000  2406.122450
# S4_D10       0.000000     0.000000     0.0      0.000000     0.000000
# S5_D10       0.000000     0.000000     0.0      0.000000     0.000000
# ...               ...          ...     ...           ...          ...
# S612_D42     0.000000     0.000000     0.0  14528.761376  3442.080339
# S613_D42     0.000000     0.000000     0.0      0.000000     0.000000
# S614_D42     0.000000     0.000000     0.0  15479.120703  4372.160364
# S615_D42     0.000000     0.000000     0.0      0.000000     0.000000
# S616_D42     0.000000     0.000000     0.0  23856.349951     0.000000
#
#                Q9Y6B7         Q9Y6M4
# S1_D10    1088.451504       0.000000
# S2_D10       0.000000       0.000000
# S3_D10       0.000000       0.000000
# S4_D10    1195.145799       0.000000
# S5_D10       0.000000       0.000000
# ...               ...            ...
# S612_D42     0.000000  211244.957057
# S613_D42     0.000000       0.000000
# S614_D42     0.000000    5809.848633
# S615_D42     0.000000       0.000000
# S616_D42     0.000000  330688.105916
#
# [1848 rows x 1827 columns]

# %%
def get_sample_from_id(model_id, sample_prefix=""):
    sample = model_id.rsplit("_", 2)[-2]
    try:
        return int(sample.replace(sample_prefix, ""))
    except ValueError:
        return sample


def get_time_from_id(model_id, time_prefix=""):
    time = model_id.rsplit("_", 2)[-1]
    try:
        return int(time.replace(time_prefix, ""))
    except ValueError:
        return time

# %% [markdown]
# ### Get data subsets using operations on data

# %%
operations = [
    "mean",
    "median",
    # "min",
    # "max",
]
percentiles = [
    # 0.00, # Minimum
    # 0.10,
    # 0.20, # Quintile 1
    # 0.25, # Quartile 1
    # 0.30,
    # 0.40, # Quintile 2
    # 0.50, # Median, Quartile 2,
    # 0.60, # Quintile 3
    # 0.70,
    # 0.75, # Quartile 3
    # 0.80, # Quintile 4
    # 0.90,
    # 1.00, # Maximum, Quintile 5
]


if operations or percentiles:
    df_operations = []
    for time in timepoints:
        df_time = df_copy_number_samples.loc[
            [
                x
                for x in df_copy_number_samples.index
                if get_time_from_id(x, time_prefix) == time
            ]
        ].T
        df_op = pd.concat(
            [getattr(df_time, op.lower())(axis=1) for op in operations], axis=1
        )
        df_op.columns = [f"{op.capitalize()}_{time_prefix}{time}" for op in operations]
        df_operations += [df_op]
        if percentiles:
            df_op = pd.concat(
                [df_time.quantile(percent, axis=1) for percent in percentiles], axis=1
            )
            df_op.columns = [
                f"Percentile{int(round(percent * 100, 0))}_{time_prefix}{time}"
                for percent in percentiles
            ]
            df_operations += [df_op]
    df_operations = pd.concat(df_operations, axis=1)
    operation_ids = df_operations.columns
    df_copy_number_all = pd.concat((df_copy_number_samples.T, df_operations), axis=1).T
else:
    df_copy_number_all = df_copy_number_samples.T
    operation_ids = []
df_copy_number_all
# Out:
#                   P69905        P68871        P02042        P02008  \
# S1_D10      1.254607e+08  6.751875e+07  1.684139e+08  3.409157e+07
# S2_D10      1.622846e+08  3.248112e+07  2.455682e+08  6.281825e+07
# S3_D10      1.408849e+08  9.282055e+07  2.866462e+08  3.096045e+07
# S4_D10      1.533373e+08  9.428727e+07  2.796149e+08  4.492695e+07
# S5_D10      1.451599e+08  7.885271e+07  2.064930e+08  5.865059e+07
# ...                  ...           ...           ...           ...
# Median_D10  1.284522e+08  7.688185e+07  1.857545e+08  5.736548e+07
# Mean_D23    1.302204e+08  7.752765e+07  1.823978e+08  5.432346e+07
# Median_D23  1.296389e+08  7.714224e+07  1.820727e+08  5.597670e+07
# Mean_D42    1.303787e+08  7.906095e+07  1.837488e+08  5.559319e+07
# Median_D42  1.292425e+08  7.898725e+07  1.818945e+08  5.758715e+07
#
#                   P02730        P30043        P32119        P02768  \
# S1_D10      4.582424e+06  1.956960e+07  7.461828e+06  4.729611e+06
# S2_D10      5.497925e+06  2.819367e+07  1.184191e+07  3.586910e+06
# S3_D10      4.302025e+06  1.713969e+07  8.752663e+06  2.807233e+06
# S4_D10      3.875573e+06  2.500399e+07  8.190457e+06  3.354456e+06
# S5_D10      6.774951e+06  2.690653e+07  1.633960e+07  3.973826e+06
# ...                  ...           ...           ...           ...
# Median_D10  6.005098e+06  2.377645e+07  1.446120e+07  4.096275e+06
# Mean_D23    6.132440e+06  2.397774e+07  1.456396e+07  4.352813e+06
# Median_D23  6.063446e+06  2.407633e+07  1.467926e+07  4.294531e+06
# Mean_D42    6.128426e+06  2.366743e+07  1.468774e+07  4.274537e+06
# Median_D42  6.101236e+06  2.385596e+07  1.472559e+07  4.139741e+06
#
#                   Q92902        P04040  ...       Q9Y3E7        Q9Y4Y9  \
# S1_D10      3.697239e+06  3.742403e+06  ...     0.000000      0.000000
# S2_D10      2.223799e+06  2.496767e+06  ...     0.000000      0.000000
# S3_D10      1.635281e+07  8.260527e+05  ...     0.000000      0.000000
# S4_D10      1.123342e+06  3.666083e+06  ...     0.000000      0.000000
# S5_D10      2.859506e+06  4.664673e+06  ...     0.000000  27830.662335
# ...                  ...           ...  ...          ...           ...
# Median_D10  3.255035e+06  3.927278e+06  ...     0.000000      0.000000
# Mean_D23    3.369690e+06  4.035905e+06  ...  7305.738347   7519.400845
# Median_D23  3.122707e+06  4.045507e+06  ...     0.000000      0.000000
# Mean_D42    3.465648e+06  4.026779e+06  ...  6759.163035   7153.770726
# Median_D42  3.247272e+06  4.072650e+06  ...     0.000000      0.000000
#
#                  Q9Y508       Q9Y587       Q9Y5B8      Q9Y5P4       Q9Y5Y2  \
# S1_D10         0.000000     0.000000  7378.473625    0.000000     0.000000
# S2_D10      9634.822452  5263.615637   805.935440    0.000000     0.000000
# S3_D10         0.000000     0.000000     0.000000    0.000000     0.000000
# S4_D10         0.000000     0.000000     0.000000    0.000000     0.000000
# S5_D10         0.000000     0.000000     0.000000    0.000000     0.000000
# ...                 ...          ...          ...         ...          ...
# Median_D10     0.000000     0.000000     0.000000    0.000000     0.000000
# Mean_D23    3002.879818  3112.450644  2462.756244  383.923288  8859.738472
# Median_D23     0.000000     0.000000     0.000000    0.000000     0.000000
# Mean_D42    2592.430167  2252.168514  2036.105208  411.562739  6677.485580
# Median_D42     0.000000     0.000000     0.000000    0.000000     0.000000
#
#                  Q9Y666       Q9Y6B7        Q9Y6M4
# S1_D10         0.000000  1088.451504      0.000000
# S2_D10      4567.509290     0.000000      0.000000
# S3_D10      2406.122450     0.000000      0.000000
# S4_D10         0.000000  1195.145799      0.000000
# S5_D10         0.000000     0.000000      0.000000
# ...                 ...          ...           ...
# Median_D10     0.000000     0.000000      0.000000
# Mean_D23     226.333657   317.493351  26127.128644
# Median_D23     0.000000     0.000000      0.000000
# Mean_D42     215.658003   281.011732  30923.648721
# Median_D42     0.000000     0.000000      0.000000
#
# [1854 rows x 1827 columns]

# %% [markdown]
# ## Integrate proteomics with model
# ### Convert copy numbers to mg / gDW

# %%
df_protein_data = pd.read_csv(
    f"{data_path}/{dataset_name}/{dataset_name}_protein_data.tsv",
    sep="\t",
    index_col="Entry",
)
df_uniprot_to_mw = df_protein_data["Mass"] / 1000  # g/mol --> # kg / mol

df_mg_prot_per_gDW = (
    df_copy_number_all  # protein copies / cell
    * (1 / DEFAULT_DRY_MASS_PER_CELL)  # cell / pgDW
    * (1e12 / 1)  # pgDW / gDW
    * (1 / AVOGADRO_NUMBER)  # mol / protein copies
    * (df_uniprot_to_mw)  # kg / mol
    * (1e6 / 1)  # mg / kg
).copy()
df_mg_prot_per_gDW
# Out:
#                 P69905     P68871      P02042     P02008     P02730  \
# S1_D10      105.957851  59.788534  149.663564  29.507223  25.818843
# S2_D10      137.057505  28.762364  218.227945  54.370974  30.977066
# S3_D10      118.984330  82.193540  254.732482  26.797142  24.238983
# S4_D10      129.501028  83.492334  248.484024  38.885552  21.836219
# S5_D10      122.594800  69.824876  183.503129  50.763743  38.172241
# ...                ...        ...         ...        ...        ...
# Median_D10  108.484363  68.079656  165.073523  49.651448  33.834643
# Mean_D23    109.977619  68.651522  162.090554  47.018489  34.552125
# Median_D23  109.486564  68.310233  161.801687  48.449421  34.163395
# Mean_D42    110.111346  70.009273  163.291184  48.117479  34.529511
# Median_D42  109.151747  69.944008  161.643340  49.843311  34.376315
#
#                P30043     P32119     P02768     Q92902     P04040  ...  \
# S1_D10      23.959362   9.041875  18.159596  16.226867  12.378269  ...
# S2_D10      34.517950  14.349439  13.772135   9.760067   8.258238  ...
# S3_D10      20.984383  10.606046  10.778522  71.771113   2.732229  ...
# S4_D10      30.612770   9.924792  12.879614   4.930253  12.125835  ...
# S5_D10      32.942075  19.799519  15.257717  12.550130  15.428745  ...
# ...               ...        ...        ...        ...        ...  ...
# Median_D10  29.109870  17.523372  15.727869  14.286073  12.989758  ...
# Mean_D23    29.356315  17.647893  16.712859  14.789286  13.349048  ...
# Median_D23  29.477020  17.787602  16.489081  13.705296  13.380806  ...
# Mean_D42    28.976400  17.797882  16.412313  15.210435  13.318863  ...
# Median_D42  29.207215  17.843742  15.894759  14.252000  13.470583  ...
#
#               Q9Y3E7    Q9Y4Y9    Q9Y508    Q9Y587    Q9Y5B8    Q9Y5P4  \
# S1_D10      0.000000  0.000000  0.000000  0.000000  0.017354  0.000000
# S2_D10      0.000000  0.000000  0.013703  0.004954  0.001896  0.000000
# S3_D10      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# S4_D10      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# S5_D10      0.000000  0.015308  0.000000  0.000000  0.000000  0.000000
# ...              ...       ...       ...       ...       ...       ...
# Median_D10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Mean_D23    0.010139  0.004136  0.004271  0.002930  0.005792  0.001505
# Median_D23  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Mean_D42    0.009381  0.003935  0.003687  0.002120  0.004789  0.001614
# Median_D42  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#               Q9Y5Y2    Q9Y666    Q9Y6B7    Q9Y6M4
# S1_D10      0.000000  0.000000  0.005016  0.000000
# S2_D10      0.000000  0.030112  0.000000  0.000000
# S3_D10      0.000000  0.015863  0.000000  0.000000
# S4_D10      0.000000  0.000000  0.005508  0.000000
# S5_D10      0.000000  0.000000  0.000000  0.000000
# ...              ...       ...       ...       ...
# Median_D10  0.000000  0.000000  0.000000  0.000000
# Mean_D23    0.014136  0.001492  0.001463  0.074317
# Median_D23  0.000000  0.000000  0.000000  0.000000
# Mean_D42    0.010654  0.001422  0.001295  0.087961
# Median_D42  0.000000  0.000000  0.000000  0.000000
#
# [1854 rows x 1827 columns]

# %% [markdown]
# ### Scale measurements for proteome budget
# Note that this step will help ensure its theoretically possible for a perfect fit
#
# TODO: Change budget for the whole model. Could be personalized to the CBC hemoglobin measurements in the future. ANy protein not in hb_proteins dictionary goes to low abundance proteome. Scaling issues should be addressed by modifying the proteome_budget_value.

# %%
proteome_budget_value = 50
hemoglobin_budget_value = 950
total_budget_value = None

# %%
# Split into hemoglobin and low abundance proteomes
hb_proteins = {
    # Model Gene: UniProt ID
    "HBA": "P69905",
    "HBB": "P68871",
    "HBD": "P02042",
    "HBM": "Q6B0K9",
    "HBE1": "P02100",
    "HBG1": "P69891",
    "HBG2": "P69892",
    "HBQ1": "P09105",
    "HBZ": "P02008",
}
df_mg_prot_per_gDW_hb = df_mg_prot_per_gDW.loc[:, list(hb_proteins.values())]
df_mg_prot_per_gDW_la = df_mg_prot_per_gDW.loc[
    :, [x for x in df_mg_prot_per_gDW.columns if not x in list(hb_proteins.values())]
]

PBDL_proteome_budget = pcmodel.reactions.get_by_id("PBDL_proteome_budget")
PBDL_hemoglobin_budget = pcmodel.reactions.get_by_id("PBDL_hemoglobin_budget")
PBDL_total_budget = pcmodel.reactions.get_by_id("PBDL_total_budget")

if proteome_budget_value is None:
    proteome_budget_value = PBDL_proteome_budget.upper_bound
if hemoglobin_budget_value is None:
    hemoglobin_budget_value = PBDL_hemoglobin_budget.upper_bound
if total_budget_value is None:
    total_budget_value = PBDL_total_budget.upper_bound

assert total_budget_value >= (proteome_budget_value + hemoglobin_budget_value)

PBDL_proteome_budget.upper_bound = proteome_budget_value
PBDL_hemoglobin_budget.upper_bound = hemoglobin_budget_value
PBDL_total_budget.upper_bound = total_budget_value

# Scale values for low abundance proteome
budget_value = proteome_budget_value
df_mg_prot_per_gDW_la = (
    budget_value * (df_mg_prot_per_gDW_la.T / df_mg_prot_per_gDW_la.sum(axis=1)).T
)
print(f"Low abundance budget:\t{budget_value}\t(={budget_value * 100 / 1000}%)")

# Scale values for hemoglobin proteome
budget_value = hemoglobin_budget_value
df_mg_prot_per_gDW_hb = (
    budget_value * (df_mg_prot_per_gDW_hb.T / df_mg_prot_per_gDW_hb.sum(axis=1)).T
)
print(f"Hemoglobin budget:\t{budget_value}\t(={budget_value * 100 / 1000}%)")

budget_value = total_budget_value - sum(
    [proteome_budget_value, hemoglobin_budget_value]
)
print(f"Remaining budget:\t{budget_value}\t(={budget_value * 100 / 1000}%)")


# Combine dataframes back into one
df_mg_prot_per_gDW_normalized = pd.concat(
    (df_mg_prot_per_gDW_hb, df_mg_prot_per_gDW_la), axis=1
)
df_mg_prot_per_gDW_normalized.sum(axis=1)
# Out:
# Low abundance budget:	50	(=5.0%)
# Hemoglobin budget:	950	(=95.0%)
# Remaining budget:	0.0	(=0.0%)
# S1_D10        1000.0
# S2_D10        1000.0
# S3_D10        1000.0
# S4_D10        1000.0
# S5_D10        1000.0
#                ...
# Median_D10    1000.0
# Mean_D23      1000.0
# Median_D23    1000.0
# Mean_D42      1000.0
# Median_D42    1000.0
# Length: 1854, dtype: float64

# %% [markdown]
# ### Convert mg / gDW to nmol / gDW

# %%
df_nmol_prot_per_gDW = (
    df_mg_prot_per_gDW_normalized  # mg / gDW
    * (1 / df_uniprot_to_mw)  # mol / kg --> mmol / g --> umol / mg
    * (1e3 / 1)  # nmol / umol
).loc[:, df_mg_prot_per_gDW_normalized.columns]
df_nmol_prot_per_gDW = df_nmol_prot_per_gDW.T
df_nmol_prot_per_gDW
# Out:
#               S1_D10        S2_D10        S3_D10        S4_D10        S5_D10  \
# P69905  18075.456265  19105.243829  14631.076044  15795.176173  17661.151783
# P68871   9727.605483   3823.897600   9639.535334   9712.471978   9593.764725
# P02042  24263.838621  28909.955711  29768.580366  28802.953963  25123.361602
# Q6B0K9      1.099138      2.590875      1.391985      0.533154      1.488096
# P02100     22.727215      4.572540     40.030657      7.151495      1.010539
# ...              ...           ...           ...           ...           ...
# Q9Y5P4      0.000000      0.000000      0.000000      0.000000      0.000000
# Q9Y5Y2      0.000000      0.000000      0.000000      0.000000      0.000000
# Q9Y666      0.000000      0.025974      0.013674      0.000000      0.000000
# Q9Y6B7      0.006719      0.000000      0.000000      0.007583      0.000000
# Q9Y6M4      0.000000      0.000000      0.000000      0.000000      0.000000
#
#               S6_D10        S7_D10        S8_D10        S9_D10       S10_D10  \
# P69905  14369.457430  16482.836004  17024.362893  18247.365578  13824.557293
# P68871   9616.806176   9343.460129  10447.359061   9235.087988  11520.337791
# P02042  27530.494873  26710.237232  26080.913045  23484.891677  31112.255681
# Q6B0K9      2.893080      1.571854      0.650999      2.112306      1.093055
# P02100      7.195636      4.952831     22.739866     10.241859      0.000000
# ...              ...           ...           ...           ...           ...
# Q9Y5P4      0.000000      0.000000      0.000000      0.000000      0.000000
# Q9Y5Y2      0.000000      0.000000      0.221546      0.056889      0.324932
# Q9Y666      0.000000      0.000000      0.000000      0.000000      0.006972
# Q9Y6B7      0.000000      0.000000      0.006187      0.000000      0.000000
# Q9Y6M4      0.000000      0.028856      0.025749      0.000000      0.373526
#
#         ...      S613_D42      S614_D42      S615_D42      S616_D42  \
# P69905  ...  18344.370208  20262.437710  18716.059561  19264.958518
# P68871  ...  12421.232692  10952.717581  11321.864768  11542.469619
# P02042  ...  20154.572117  20143.627236  22133.485184  21541.956347
# Q6B0K9  ...      0.904652      0.639794      0.342624      0.912871
# P02100  ...      1.065640      2.262286    257.491334      1.929639
# ...     ...           ...           ...           ...           ...
# Q9Y5P4  ...      0.000000      0.000000      0.000000      0.000000
# Q9Y5Y2  ...      0.000000      0.096251      0.000000      0.129936
# Q9Y666  ...      0.000000      0.027187      0.000000      0.000000
# Q9Y6B7  ...      0.000000      0.000000      0.000000      0.000000
# Q9Y6M4  ...      0.000000      0.036126      0.000000      1.801121
#
#             Mean_D10    Median_D10      Mean_D23    Median_D23      Mean_D42  \
# P69905  16944.867231  16924.927324  17225.911342  17224.795418  17080.277399
# P68871  10270.881971  10129.988121  10255.574196  10249.694718  10357.390088
# P02042  24319.157589  24475.095067  24128.087747  24191.544202  24072.039600
# Q6B0K9      2.189801      1.376492      2.279456      1.439005      2.761238
# P02100     27.420626      6.425119     24.510769      5.923681     22.998424
# ...              ...           ...           ...           ...           ...
# Q9Y5P4      0.001745      0.000000      0.001989      0.000000      0.002148
# Q9Y5Y2      0.037245      0.000000      0.045901      0.000000      0.034848
# Q9Y666      0.001064      0.000000      0.001173      0.000000      0.001125
# Q9Y6B7      0.001418      0.000000      0.001645      0.000000      0.001467
# Q9Y6M4      0.135355      0.000000      0.135360      0.000000      0.161381
#
#           Median_D42
# P69905  17059.903775
# P68871  10426.254469
# P02042  24009.936113
# Q6B0K9      1.795620
# P02100      6.226073
# ...              ...
# Q9Y5P4      0.000000
# Q9Y5Y2      0.000000
# Q9Y666      0.000000
# Q9Y6B7      0.000000
# Q9Y6M4      0.000000
#
# [1827 rows x 1854 columns]

# %% [markdown]
# ## Create DataFrame for protein dilution reactions

# %%
df_model_protein_dilutions = pd.concat(
    (
        pd.Series(
            {g.annotation.get("uniprot"): g.id for g in model.genes}, name="genes"
        ),
        pd.Series(
            {
                protdl.annotation.get("uniprot"): protdl.id
                for protdl in pcmodel.reactions.query(
                    lambda x: isinstance(x, ProteinDilution)
                )
            },
            name="PROTDL",
        ),
    ),
    axis=1,
)
df_model_protein_dilutions.index.name = "uniprot"
df_model_protein_dilutions = df_model_protein_dilutions[
    df_model_protein_dilutions["genes"].isin(model.genes.list_attr("id"))
].sort_values("PROTDL")
df_model_protein_dilutions
# Out:
#            genes                     PROTDL
# uniprot
# O15439     ABCC4    PROTDL_protein_ABCC4_pc
# P00813       ADA      PROTDL_protein_ADA_pc
# P55263       ADK      PROTDL_protein_ADK_pc
# P00568       AK1      PROTDL_protein_AK1_pc
# P04075     ALDOA    PROTDL_protein_ALDOA_pc
# ...          ...                        ...
# Q9BVC6   TMEM109  PROTDL_protein_TMEM109_pc
# P60174      TPI1     PROTDL_protein_TPI1_pc
# Q9Y210     TRPC6    PROTDL_protein_TRPC6_pc
# Q9Y5S1     TRPV2    PROTDL_protein_TRPV2_pc
# P21796     VDAC1    PROTDL_protein_VDAC1_pc
#
# [107 rows x 2 columns]

# %% [markdown]
# ## Organize samples

# %%
df_samples = df_nmol_prot_per_gDW.copy()

# Best to sort by donor, if sample fails solving at any point, only need to redo the n_timepoints associated with sample.
sort_samples_by_donor = True
merge_key = "uniprot"
run_computations = True

# Use this line of code to determine which samples are used.
# Useful for picking up where notebook may have prematurely stopped.
# Set as 0 or less to use all samples
start_from_sample_id = 0
# Set as 0 or less to use only operation samples
# end_on_sample_id = 0
# Set as length of samples to use all samples
end_on_sample_id = len(df_samples)

# Use this line of code to determine which time points are used.
# Comment out to keep all original points defined in samples
timepoints = [10, 23, 42]
df_samples.index.name = merge_key
# Filter out time points
df_samples = df_samples.loc[
    :, [x for x in df_samples.columns if get_time_from_id(x, time_prefix) in timepoints]
]
# Filter out irrelevant samples
df_samples = pd.concat(
    (
        df_samples.loc[
            :,
            [
                x
                for x in sample_ids
                if start_from_sample_id
                <= get_sample_from_id(x, sample_prefix)
                <= end_on_sample_id
            ],
        ],
        df_samples.loc[:, [x for x in df_samples.columns if x in operation_ids]],
    ),
    axis=1,
)

if sort_samples_by_donor:
    df_samples = pd.concat(
        (
            df_samples.loc[
                :,
                sorted(
                    [x for x in df_samples.columns if x not in operation_ids],
                    key=lambda x: (
                        get_sample_from_id(x, sample_prefix),
                        get_time_from_id(x, time_prefix),
                    ),
                ),
            ],
            df_samples.loc[
                :,
                sorted(
                    [x for x in df_samples.columns if x in operation_ids],
                    key=lambda x: get_time_from_id(x, time_prefix),
                ),
            ],
        ),
        axis=1,
    )
else:
    df_samples = pd.concat(
        [
            pd.concat(
                (
                    df_samples.loc[
                        :,
                        sorted(
                            [
                                x
                                for x in df_samples.columns
                                if get_time_from_id(x, time_prefix) == time
                                and x not in operation_ids
                            ],
                            key=lambda x: get_sample_from_id(x, sample_prefix),
                        ),
                    ],
                    df_samples.loc[
                        :,
                        sorted(
                            [
                                x
                                for x in df_samples.columns
                                if get_time_from_id(x, time_prefix) == time
                                and x in operation_ids
                            ],
                        ),
                    ],
                ),
                axis=1,
            )
            for time in timepoints
        ],
        axis=1,
    )

# %% [markdown]
# ### Map samples to model

# %%
df_model = (
    df_model_protein_dilutions[["PROTDL"]]
    .merge(df_samples, left_index=True, right_index=True, how="left")
    .set_index("PROTDL")
    .sort_index()
)
no_experimental_measurements = [
    protein_dilution
    for protein_dilution, has_measurement in df_model.isna().all(axis=1).items()
    if has_measurement
]
print(
    f"Model proteins mapped to measurements: {len(df_model) - len(no_experimental_measurements)}"
)
print(f"Model proteins without measurements: {len(no_experimental_measurements)}")
df_model.dropna()
# Out:
# Model proteins mapped to measurements: 73
# Model proteins without measurements: 34
#                               S1_D10     S1_D23     S1_D42     S2_D10  \
# PROTDL
# PROTDL_protein_ABCC4_pc     0.060166   0.045654   0.051166   0.051378
# PROTDL_protein_ADA_pc       0.073243   0.046350   0.091500   0.042135
# PROTDL_protein_ADK_pc       0.240040   0.254656   0.239002   0.324909
# PROTDL_protein_AK1_pc       7.568948   7.928522   7.473081   2.524183
# PROTDL_protein_ALDOA_pc     4.819084   4.610360   4.372591   5.374049
# ...                              ...        ...        ...        ...
# PROTDL_protein_SLC43A3_pc   0.178285   0.108298   0.126072   0.057068
# PROTDL_protein_SOD1_pc      7.845346  26.502806  25.860621  15.012097
# PROTDL_protein_TALDO1_pc    2.060527   2.501260   2.576616   3.319535
# PROTDL_protein_TKT_pc       1.838035   1.493491   1.796938   1.688892
# PROTDL_protein_TPI1_pc     11.984722  14.657240  15.615947  16.027962
#
#                               S2_D23     S2_D42     S3_D10     S3_D23  \
# PROTDL
# PROTDL_protein_ABCC4_pc     0.048278   0.051962   0.039254   0.040554
# PROTDL_protein_ADA_pc       0.044426   0.094702   0.033637   0.056042
# PROTDL_protein_ADK_pc       0.336365   0.329428   0.318621   0.341961
# PROTDL_protein_AK1_pc       6.102872   5.622176   2.524359   6.941116
# PROTDL_protein_ALDOA_pc     4.412209   4.286170   1.578919   4.382671
# ...                              ...        ...        ...        ...
# PROTDL_protein_SLC43A3_pc   0.116582   0.000000   0.052182   0.162198
# PROTDL_protein_SOD1_pc     21.263476  22.344631   5.470446  23.463451
# PROTDL_protein_TALDO1_pc    2.386749   1.696120   2.294042   2.502276
# PROTDL_protein_TKT_pc       1.474261   1.771547   1.428526   1.624082
# PROTDL_protein_TPI1_pc     16.197319  14.744943  11.078788  13.967948
#
#                               S3_D42     S4_D10  ...   S615_D42   S616_D10  \
# PROTDL                                           ...
# PROTDL_protein_ABCC4_pc     0.063613   0.073125  ...   0.082699   0.054622
# PROTDL_protein_ADA_pc       0.082634   0.094200  ...   0.063444   0.070988
# PROTDL_protein_ADK_pc       0.356493   0.267661  ...   0.302170   0.277635
# PROTDL_protein_AK1_pc       6.087617   5.501008  ...   5.659571   3.851172
# PROTDL_protein_ALDOA_pc     4.561871   2.352644  ...   5.433200   5.182936
# ...                              ...        ...  ...        ...        ...
# PROTDL_protein_SLC43A3_pc   0.125654   0.290168  ...   0.075787   0.041508
# PROTDL_protein_SOD1_pc     23.258044   9.731906  ...  22.696008  20.182201
# PROTDL_protein_TALDO1_pc    1.241529   3.198628  ...   2.703993   1.904916
# PROTDL_protein_TKT_pc       2.037096   1.651252  ...   1.641625   1.440329
# PROTDL_protein_TPI1_pc     13.683168  11.997996  ...  12.461216   9.512615
#
#                             S616_D23   S616_D42   Mean_D10  Median_D10  \
# PROTDL
# PROTDL_protein_ABCC4_pc     0.044466   0.050581   0.053893    0.056559
# PROTDL_protein_ADA_pc       0.066368   0.061732   0.078038    0.075310
# PROTDL_protein_ADK_pc       0.302770   0.293763   0.244831    0.250188
# PROTDL_protein_AK1_pc       3.527104   5.233947   4.588580    4.810617
# PROTDL_protein_ALDOA_pc     4.679183   4.771119   3.808248    4.113842
# ...                              ...        ...        ...         ...
# PROTDL_protein_SLC43A3_pc   0.080027   0.102099   0.080248    0.078066
# PROTDL_protein_SOD1_pc     17.902988  18.988467  21.032843   22.037914
# PROTDL_protein_TALDO1_pc    2.208876   1.950643   1.908677    2.004746
# PROTDL_protein_TKT_pc       1.337149   1.336175   1.516615    1.587827
# PROTDL_protein_TPI1_pc     12.182260  12.216177  10.321212   10.940839
#
#                             Mean_D23  Median_D23   Mean_D42  Median_D42
# PROTDL
# PROTDL_protein_ABCC4_pc     0.053734    0.056261   0.053465    0.055874
# PROTDL_protein_ADA_pc       0.076221    0.071785   0.077958    0.074667
# PROTDL_protein_ADK_pc       0.243873    0.249586   0.247522    0.260031
# PROTDL_protein_AK1_pc       4.783073    4.970557   4.609725    4.744058
# PROTDL_protein_ALDOA_pc     3.869536    4.162229   3.809724    4.023530
# ...                              ...         ...        ...         ...
# PROTDL_protein_SLC43A3_pc   0.080387    0.080430   0.081709    0.080569
# PROTDL_protein_SOD1_pc     21.488945   22.749851  21.287384   22.356476
# PROTDL_protein_TALDO1_pc    1.895988    2.017241   1.904133    1.979078
# PROTDL_protein_TKT_pc       1.505157    1.584232   1.517659    1.577608
# PROTDL_protein_TPI1_pc     10.413977   10.928935  10.292269   10.781061
#
# [73 rows x 1854 columns]

# %% [markdown]
# ## TODO: Put pie chart cells in here (divide by 10 to get to percentage. I could be around 0.5%, this is the summation of proteins being mapped to the model.)

# %% [markdown]
# ### Reduce model using maximum values from proteomics
# Create a reduced model using the maximum value measured of each protein across all data samples. By finding the reactions that always remain blocked prior to analysis, the computation time may be reduced.
# Also ensure that proteins not found in the dataset don't significantly sway results,
#
# Note: May be problematic if proteins essential for catalysis are not measured. Keep protein bounds unchanged to remove only normal blocked reactions.

# %%
remove_blocked_reactions = False

if remove_blocked_reactions:
    pcmodel_blocked = pcmodel.copy()
    df = df_model.max(axis=1)
    for protein_dilution, bound in df.items():
        protein_dilution = pcmodel_blocked.reactions.get_by_id(protein_dilution)
        # if not np.isnan(bound):
        #     protein_dilution.bounds = (0, bound)
        # else:
        #     protein_dilution.bounds = (0, 0)
    blocked = find_blocked_reactions(pcmodel_blocked)
    pcmodel.remove_reactions(blocked, remove_orphans=True)

for objective_reaction in ["NaKt"]:
    objective_reaction = pcmodel.reactions.get_by_id(objective_reaction)
    pcmodel.objective = objective_reaction.flux_expression
    print(pcmodel.slim_optimize())

pcmodel
# Out:
# 17.33558202791764
# <Model RBC3P_PC at 0x218d2edb8c0>

# %% [markdown]
# ## Create QP model for each sample

# %%
def solve_qp(pcmodel, df):
    x = []  # Variables
    c = []  # Data * Weights
    F = []  # Weights

    for protdl, (data_value, weight) in df.iterrows():
        protdl = pcmodel.reactions.get_by_id(protdl)
        x.append(protdl.flux_expression)
        c.append(weight * data_value)
        F.append(weight)

    x = sympy.Matrix(x)
    c = sympy.Matrix(c)
    F = sympy.DiagMatrix(sympy.Matrix(F))
    # # QP Objective must be in form of 0.5 * x.T * F * x - c.T * x
    objective = 0.5 * x.T * F * x - c.T * x
    pcmodel.objective = objective[0]
    pcmodel.objective_direction = "min"
    pcmodel.tolerance = 1e-9

    qp_sol = pcmodel.optimize()
    return qp_sol


def solve_qp_for_samples(pcmodel, df_samples, df_weights=None, verbose=False):
    qp_solutions_dict = {}
    for sample_id, data_series in df_samples.items():
        # Get protein values
        data_series.name = "Data"
        if df_weights is None:
            data_weights = 1 / data_series.replace(0, 1)
            data_weights = data_weights / data_weights.mean()
        else:
            data_weights = df_weights.loc[:, sample_id]
        # Get protein weights
        data_weights.name = "Weights"

        # Map to model, currently model mapping DataFrame generated outside scope of function
        df_model_data_weights = (
            df_model_protein_dilutions[["PROTDL"]]
            .merge(data_series, left_index=True, right_index=True, how="left")
            .merge(data_weights, left_index=True, right_index=True, how="left")
            .set_index("PROTDL")
            .sort_index()
        )

        df = df_model_data_weights.loc[:, [data_series.name, data_weights.name]].dropna(
            axis=0, how="all"
        )

        with pcmodel:
            qp_sol = solve_qp(pcmodel, df)

        df_qp_sol = qp_sol.fluxes.loc[
            pcmodel.reactions.query(lambda x: isinstance(x, ProteinDilution)).list_attr(
                "id"
            )
        ]
        df_qp_sol = (
            pd.concat((df_model_data_weights, df_qp_sol), axis=1).dropna().sort_index()
        )
        # data_weights = df_qp_sol.loc[:, "Weights"]

        df_qp_sol = df_qp_sol.rename(
            {"Data": "Measured Proteome", "fluxes": "Best-Fitted Proteome"}, axis=1
        )
        df_qp_sol = df_qp_sol.loc[:, ["Measured Proteome", "Best-Fitted Proteome"]]

        r2 = r2_score(
            df_qp_sol.iloc[:, 0].values,
            df_qp_sol.iloc[:, 1].values,
            multioutput="uniform_average",
        )
        qp_solutions_dict[sample_id] = (df_qp_sol, r2, qp_sol.objective_value)
        if verbose:
            # Recall that the objective is designed to try to minimize fitting error via maximizing R2, so 1 is a possibility
            print(
                "R^2 (objective) value for Sample '{}': {:.9f} ({:.5f})".format(
                    sample_id, r2, qp_sol.objective_value
                )
            )
        # TODO catch bad fits

    return qp_solutions_dict

# %% [markdown]
# ### Set weightings for QP problem

# %%
# Ensure data is provided as (Protein IDs x Sample IDs)
# Use original measurements for weights
df_weights = df_copy_number_all.T.loc[:, df_samples.columns]
df_weights = 1 / df_weights.replace(0, 1)
df_weights /= df_weights.mean()

# %%
# proteome_path = Path(f"{dataset_path}/proteome")
proteome_path = dataset_path / "proteome"
print(proteome_path)

if run_computations:
    qp_solutions_dict = solve_qp_for_samples(
        pcmodel, df_samples, df_weights=df_weights, verbose=True
    )
    df_measured = {}
    df_best_fit = {}
    df_r2_objective = {}
    for sample_id, (df_qp_sol, r2, objective_value) in qp_solutions_dict.items():
        df_measured[sample_id] = df_qp_sol["Measured Proteome"].to_dict()
        df_best_fit[sample_id] = df_qp_sol["Best-Fitted Proteome"].to_dict()
        df_r2_objective[sample_id] = {"R2": r2, "Objective": objective_value}

    df_measured = pd.DataFrame.from_dict(df_measured, orient="columns")
    # df_measured.to_csv(f"{proteome_path}/proteome_measured.tsv", sep="\t", index=True)
    df_measured.to_csv(proteome_path / "proteome_measured.tsv", sep="\t", index=True)

    df_best_fit = pd.DataFrame.from_dict(df_best_fit, orient="columns")
    # df_best_fit.to_csv(f"{proteome_path}/proteome_best_fit.tsv", sep="\t", index=True)
    df_best_fit.to_csv(proteome_path / "proteome_best_fit.tsv", sep="\t", index=True)

    df_r2_objective = pd.DataFrame.from_dict(df_r2_objective, orient="columns")
    df_r2_objective.to_csv(
        proteome_path / "proteome_r2_objective.tsv", sep="\t", index=True
    )
else:
    df_measured = pd.read_csv(
        proteome_path / "proteome_measured.tsv", sep="\t", index_col=0
    )
    df_best_fit = pd.read_csv(
        proteome_path / "proteome_best_fit.tsv", sep="\t", index_col=0
    )
    df_r2_objective = pd.read_csv(
        proteome_path / "proteome_r2_objective.tsv", sep="\t", index_col=0
    )

    qp_solutions_dict = {}
    for sample_id in list(sample_ids) + list(operation_ids):
        if not sample_id.replace(f"{pcmodel.id}_", "") in df_samples.columns:
            continue
        df_qp_sol = pd.concat(
            (
                df_measured.loc[:, sample_id],
                df_best_fit.loc[:, sample_id],
            ),
            axis=1,
        )
        df_qp_sol.columns = ["Measured Proteome", "Best-Fitted Proteome"]
        r2, objective_value = df_r2_objective.loc[:, sample_id].values
        qp_solutions_dict[sample_id] = (df_qp_sol, r2, objective_value)
print(f"Number of QP solutions: {len(qp_solutions_dict)}")
# Out:
# D:\Projects\RBC-GEM-akey7\data\processed\RBC3P\OVERLAY\RBComics\proteome
# R^2 (objective) value for Sample 'S1_D10': 0.999999997 (-18.29252)
# R^2 (objective) value for Sample 'S1_D23': 0.999999996 (-53.58446)
# R^2 (objective) value for Sample 'S1_D42': 0.999999995 (-21.30633)
# R^2 (objective) value for Sample 'S2_D10': 0.999999994 (-17.15036)
# R^2 (objective) value for Sample 'S2_D23': 0.999999996 (-19.58863)
# R^2 (objective) value for Sample 'S2_D42': 0.999999996 (-18.13345)
# R^2 (objective) value for Sample 'S3_D10': 0.999999996 (-11.38054)
# R^2 (objective) value for Sample 'S3_D23': 0.999999997 (-37.89537)
# R^2 (objective) value for Sample 'S3_D42': 0.999999996 (-13.33130)
# R^2 (objective) value for Sample 'S4_D10': 0.999999996 (-12.79160)
# R^2 (objective) value for Sample 'S4_D23': 0.999999996 (-14.93397)
# R^2 (objective) value for Sample 'S4_D42': 0.999999996 (-41.73092)
# R^2 (objective) value for Sample 'S5_D10': 0.999999996 (-19.98077)
# R^2 (objective) value for Sample 'S5_D23': 0.999999996 (-19.20184)
# R^2 (objective) value for Sample 'S5_D42': 0.999999996 (-19.72049)
# R^2 (objective) value for Sample 'S6_D10': 0.999999996 (-14.86216)
# R^2 (objective) value for Sample 'S6_D23': 0.999999996 (-39.66011)
# R^2 (objective) value for Sample 'S6_D42': 0.999999996 (-21.20791)
# R^2 (objective) value for Sample 'S7_D10': 0.999999996 (-22.03528)
# R^2 (objective) value for Sample 'S7_D23': 0.999999996 (-20.41476)
# R^2 (objective) value for Sample 'S7_D42': 0.999999996 (-20.59759)
# R^2 (objective) value for Sample 'S8_D10': 0.999999996 (-21.63565)
# R^2 (objective) value for Sample 'S8_D23': 0.999999996 (-17.85491)
# R^2 (objective) value for Sample 'S8_D42': 0.999999996 (-21.17611)
# R^2 (objective) value for Sample 'S9_D10': 0.999999996 (-19.72676)
# R^2 (objective) value for Sample 'S9_D23': 0.999999996 (-20.59541)
# R^2 (objective) value for Sample 'S9_D42': 0.999999996 (-20.28065)
# R^2 (objective) value for Sample 'S10_D10': 0.999999996 (-36.58585)
# R^2 (objective) value for Sample 'S10_D23': 0.999999996 (-16.44353)
# R^2 (objective) value for Sample 'S10_D42': 0.999999996 (-21.57738)
# R^2 (objective) value for Sample 'S11_D10': 0.999999996 (-15.83025)
# R^2 (objective) value for Sample 'S11_D23': 0.999999996 (-14.96228)
# R^2 (objective) value for Sample 'S11_D42': 0.999999996 (-22.58744)
# R^2 (objective) value for Sample 'S12_D10': 0.999999996 (-22.68804)
# R^2 (objective) value for Sample 'S12_D23': 0.999999996 (-26.60098)
# R^2 (objective) value for Sample 'S12_D42': 0.999999996 (-24.54393)
# R^2 (objective) value for Sample 'S13_D10': 0.999999997 (-22.12133)
# R^2 (objective) value for Sample 'S13_D23': 0.999999996 (-23.07871)
# R^2 (objective) value for Sample 'S13_D42': 0.999999996 (-24.34487)
# R^2 (objective) value for Sample 'S14_D10': 0.999999996 (-21.21754)
# R^2 (objective) value for Sample 'S14_D23': 0.999999996 (-23.47908)
# R^2 (objective) value for Sample 'S14_D42': 0.999999996 (-23.53588)
# R^2 (objective) value for Sample 'S15_D10': 0.999999996 (-30.77365)
# R^2 (objective) value for Sample 'S15_D23': 0.999999996 (-25.17591)
# R^2 (objective) value for Sample 'S15_D42': 0.999999996 (-32.03887)
# R^2 (objective) value for Sample 'S16_D10': 0.999999997 (-25.81795)
# R^2 (objective) value for Sample 'S16_D23': 0.999999997 (-23.68555)
# R^2 (objective) value for Sample 'S16_D42': 0.999999997 (-14.74990)
# R^2 (objective) value for Sample 'S17_D10': 0.999999996 (-24.23618)
# R^2 (objective) value for Sample 'S17_D23': 0.999999996 (-37.53526)
# R^2 (objective) value for Sample 'S17_D42': 0.999999995 (-17.21594)
# R^2 (objective) value for Sample 'S18_D10': 0.999999996 (-15.77991)
# R^2 (objective) value for Sample 'S18_D23': 0.999999996 (-33.75844)
# R^2 (objective) value for Sample 'S18_D42': 0.999999996 (-18.26414)
# R^2 (objective) value for Sample 'S19_D10': 0.999999997 (-12.85614)
# R^2 (objective) value for Sample 'S19_D23': 0.999999996 (-24.82303)
# R^2 (objective) value for Sample 'S19_D42': 0.999999996 (-19.60957)
# R^2 (objective) value for Sample 'S20_D10': 0.999999996 (-25.90294)
# R^2 (objective) value for Sample 'S20_D23': 0.999999996 (-25.32969)
# R^2 (objective) value for Sample 'S20_D42': 0.999999997 (-39.69330)
# R^2 (objective) value for Sample 'S21_D10': 0.999999995 (-9.96416)
# R^2 (objective) value for Sample 'S21_D23': 0.999999996 (-15.55725)
# R^2 (objective) value for Sample 'S21_D42': 0.999999996 (-21.78648)
# R^2 (objective) value for Sample 'S22_D10': 0.999999997 (-18.32052)
# R^2 (objective) value for Sample 'S22_D23': 0.999999996 (-40.57195)
# R^2 (objective) value for Sample 'S22_D42': 0.999999997 (-18.43113)
# R^2 (objective) value for Sample 'S23_D10': 0.999999996 (-27.92165)
# R^2 (objective) value for Sample 'S23_D23': 0.999999995 (-12.73333)
# R^2 (objective) value for Sample 'S23_D42': 0.999999997 (-38.19764)
# R^2 (objective) value for Sample 'S24_D10': 0.999999996 (-20.30498)
# R^2 (objective) value for Sample 'S24_D23': 0.999999997 (-22.75904)
# R^2 (objective) value for Sample 'S24_D42': 0.999999996 (-21.37914)
# R^2 (objective) value for Sample 'S25_D10': 0.999999997 (-20.26359)
# R^2 (objective) value for Sample 'S25_D23': 0.999999996 (-24.41947)
# R^2 (objective) value for Sample 'S25_D42': 0.999999997 (-39.16201)
# R^2 (objective) value for Sample 'S26_D10': 0.999999997 (-17.89601)
# R^2 (objective) value for Sample 'S26_D23': 0.999999996 (-16.27324)
# R^2 (objective) value for Sample 'S26_D42': 0.999999996 (-20.55810)
# R^2 (objective) value for Sample 'S27_D10': 0.999999996 (-15.26119)
# R^2 (objective) value for Sample 'S27_D23': 0.999999996 (-37.82277)
# R^2 (objective) value for Sample 'S27_D42': 0.999999996 (-19.97030)
# R^2 (objective) value for Sample 'S28_D10': 0.999999996 (-16.19231)
# R^2 (objective) value for Sample 'S28_D23': 0.999999996 (-29.60800)
# R^2 (objective) value for Sample 'S28_D42': 0.999999996 (-16.99858)
# R^2 (objective) value for Sample 'S29_D10': 0.999999996 (-26.94831)
# R^2 (objective) value for Sample 'S29_D23': 0.999999997 (-34.57877)
# R^2 (objective) value for Sample 'S29_D42': 0.999999996 (-54.73568)
# R^2 (objective) value for Sample 'S30_D10': 0.999999997 (-25.41713)
# R^2 (objective) value for Sample 'S30_D23': 0.999999996 (-30.21654)
# R^2 (objective) value for Sample 'S30_D42': 0.999999997 (-27.45714)
# R^2 (objective) value for Sample 'S31_D10': 0.999999996 (-22.50509)
# R^2 (objective) value for Sample 'S31_D23': 0.999999997 (-22.18872)
# R^2 (objective) value for Sample 'S31_D42': 0.999999996 (-25.13152)
# R^2 (objective) value for Sample 'S32_D10': 0.999999996 (-23.53944)
# R^2 (objective) value for Sample 'S32_D23': 0.999999996 (-21.94708)
# R^2 (objective) value for Sample 'S32_D42': 0.999999997 (-20.21121)
# R^2 (objective) value for Sample 'S33_D10': 0.999999996 (-18.07458)
# R^2 (objective) value for Sample 'S33_D23': 0.999999997 (-17.67177)
# R^2 (objective) value for Sample 'S33_D42': 0.999999997 (-15.49826)
# R^2 (objective) value for Sample 'S34_D10': 0.999999997 (-28.34145)
# R^2 (objective) value for Sample 'S34_D23': 0.999999996 (-23.51883)
# R^2 (objective) value for Sample 'S34_D42': 0.999999998 (-31.83078)
# R^2 (objective) value for Sample 'S35_D10': 0.999999997 (-21.07420)
# R^2 (objective) value for Sample 'S35_D23': 0.999999997 (-23.66857)
# R^2 (objective) value for Sample 'S35_D42': 0.999999996 (-24.84414)
# R^2 (objective) value for Sample 'S36_D10': 0.999999996 (-27.43012)
# R^2 (objective) value for Sample 'S36_D23': 0.999999997 (-15.72327)
# R^2 (objective) value for Sample 'S36_D42': 0.999999996 (-19.08807)
# R^2 (objective) value for Sample 'S37_D10': 0.999999997 (-17.97478)
# R^2 (objective) value for Sample 'S37_D23': 0.999999996 (-20.67059)
# R^2 (objective) value for Sample 'S37_D42': 0.999999996 (-20.44127)
# R^2 (objective) value for Sample 'S38_D10': 0.999999997 (-29.12638)
# R^2 (objective) value for Sample 'S38_D23': 0.999999996 (-44.48021)
# R^2 (objective) value for Sample 'S38_D42': 0.999999998 (-32.78683)
# R^2 (objective) value for Sample 'S39_D10': 0.999999997 (-20.12889)
# R^2 (objective) value for Sample 'S39_D23': 0.999999997 (-18.63165)
# R^2 (objective) value for Sample 'S39_D42': 0.999999996 (-22.64020)
# R^2 (objective) value for Sample 'S40_D10': 0.999999996 (-17.73539)
# R^2 (objective) value for Sample 'S40_D23': 0.999999997 (-19.39413)
# R^2 (objective) value for Sample 'S40_D42': 0.999999996 (-17.17817)
# R^2 (objective) value for Sample 'S41_D10': 0.999999997 (-22.53877)
# R^2 (objective) value for Sample 'S41_D23': 0.999999997 (-22.92298)
# R^2 (objective) value for Sample 'S41_D42': 0.999999998 (-29.46509)
# R^2 (objective) value for Sample 'S42_D10': 0.999999997 (-24.27199)
# R^2 (objective) value for Sample 'S42_D23': 0.999999997 (-24.09569)
# R^2 (objective) value for Sample 'S42_D42': 0.999999996 (-23.03590)
# R^2 (objective) value for Sample 'S43_D10': 0.999999997 (-25.33610)
# R^2 (objective) value for Sample 'S43_D23': 0.999999997 (-20.80456)
# R^2 (objective) value for Sample 'S43_D42': 0.999999996 (-19.49122)
# R^2 (objective) value for Sample 'S44_D10': 0.999999997 (-30.72429)
# R^2 (objective) value for Sample 'S44_D23': 0.999999997 (-24.96086)
# R^2 (objective) value for Sample 'S44_D42': 0.999999997 (-24.00468)
# R^2 (objective) value for Sample 'S45_D10': 0.999999997 (-25.42422)
# R^2 (objective) value for Sample 'S45_D23': 0.999999997 (-18.99594)
# R^2 (objective) value for Sample 'S45_D42': 0.999999997 (-25.60954)
# R^2 (objective) value for Sample 'S46_D10': 0.999999997 (-26.43764)
# R^2 (objective) value for Sample 'S46_D23': 0.999999997 (-24.27161)
# R^2 (objective) value for Sample 'S46_D42': 0.999999997 (-28.01563)
# R^2 (objective) value for Sample 'S47_D10': 0.999999997 (-19.36023)
# R^2 (objective) value for Sample 'S47_D23': 0.999999996 (-19.76028)
# R^2 (objective) value for Sample 'S47_D42': 0.999999997 (-17.67369)
# R^2 (objective) value for Sample 'S48_D10': 0.999999997 (-22.11253)
# R^2 (objective) value for Sample 'S48_D23': 0.999999997 (-21.14392)
# R^2 (objective) value for Sample 'S48_D42': 0.999999996 (-17.38568)
# R^2 (objective) value for Sample 'S49_D10': 0.999999997 (-45.75624)
# R^2 (objective) value for Sample 'S49_D23': 0.999999997 (-24.28458)
# R^2 (objective) value for Sample 'S49_D42': 0.999999997 (-29.11594)
# R^2 (objective) value for Sample 'S50_D10': 0.999999996 (-41.74371)
# R^2 (objective) value for Sample 'S50_D23': 0.999999996 (-32.24963)
# R^2 (objective) value for Sample 'S50_D42': 0.999999997 (-33.65812)
# R^2 (objective) value for Sample 'S51_D10': 0.999999997 (-34.15302)
# R^2 (objective) value for Sample 'S51_D23': 0.999999997 (-27.84508)
# R^2 (objective) value for Sample 'S51_D42': 0.999999997 (-27.02583)
# R^2 (objective) value for Sample 'S52_D10': 0.999999997 (-19.42599)
# R^2 (objective) value for Sample 'S52_D23': 0.999999997 (-18.15778)
# R^2 (objective) value for Sample 'S52_D42': 0.999999997 (-12.41191)
# R^2 (objective) value for Sample 'S53_D10': 0.999999997 (-17.26805)
# R^2 (objective) value for Sample 'S53_D23': 0.999999997 (-17.59479)
# R^2 (objective) value for Sample 'S53_D42': 0.999999996 (-20.72823)
# R^2 (objective) value for Sample 'S54_D10': 0.999999997 (-31.63999)
# R^2 (objective) value for Sample 'S54_D23': 0.999999997 (-23.44178)
# R^2 (objective) value for Sample 'S54_D42': 0.999999996 (-24.68647)
# R^2 (objective) value for Sample 'S55_D10': 0.999999997 (-20.84543)
# R^2 (objective) value for Sample 'S55_D23': 0.999999997 (-23.55846)
# R^2 (objective) value for Sample 'S55_D42': 0.999999997 (-22.00629)
# R^2 (objective) value for Sample 'S56_D10': 0.999999996 (-22.23418)
# R^2 (objective) value for Sample 'S56_D23': 0.999999997 (-18.31039)
# R^2 (objective) value for Sample 'S56_D42': 0.999999997 (-15.14827)
# R^2 (objective) value for Sample 'S57_D10': 0.999999996 (-19.30867)
# R^2 (objective) value for Sample 'S57_D23': 0.999999997 (-15.59254)
# R^2 (objective) value for Sample 'S57_D42': 0.999999997 (-13.22668)
# R^2 (objective) value for Sample 'S58_D10': 0.999999997 (-11.44794)
# R^2 (objective) value for Sample 'S58_D23': 0.999999996 (-9.90262)
# R^2 (objective) value for Sample 'S58_D42': 0.999999996 (-14.57556)
# R^2 (objective) value for Sample 'S59_D10': 0.999999996 (-23.90202)
# R^2 (objective) value for Sample 'S59_D23': 0.999999997 (-16.84381)
# R^2 (objective) value for Sample 'S59_D42': 0.999999997 (-15.29538)
# R^2 (objective) value for Sample 'S60_D10': 0.999999994 (-9.36025)
# R^2 (objective) value for Sample 'S60_D23': 0.999999996 (-12.26823)
# R^2 (objective) value for Sample 'S60_D42': 0.999999995 (-20.71371)
# R^2 (objective) value for Sample 'S61_D10': 0.999999996 (-12.15894)
# R^2 (objective) value for Sample 'S61_D23': 0.999999996 (-14.03265)
# R^2 (objective) value for Sample 'S61_D42': 0.999999997 (-14.53941)
# R^2 (objective) value for Sample 'S62_D10': 0.999999996 (-12.24379)
# R^2 (objective) value for Sample 'S62_D23': 0.999999996 (-31.36538)
# R^2 (objective) value for Sample 'S62_D42': 0.999999997 (-13.76115)
# R^2 (objective) value for Sample 'S63_D10': 0.999999996 (-12.59393)
# R^2 (objective) value for Sample 'S63_D23': 0.999999996 (-14.60078)
# R^2 (objective) value for Sample 'S63_D42': 0.999999996 (-11.09065)
# R^2 (objective) value for Sample 'S64_D10': 0.999999997 (-19.39287)
# R^2 (objective) value for Sample 'S64_D23': 0.999999996 (-14.85973)
# R^2 (objective) value for Sample 'S64_D42': 0.999999997 (-15.66598)
# R^2 (objective) value for Sample 'S65_D10': 0.999999996 (-15.40062)
# R^2 (objective) value for Sample 'S65_D23': 0.999999997 (-21.40294)
# R^2 (objective) value for Sample 'S65_D42': 0.999999997 (-18.36763)
# R^2 (objective) value for Sample 'S66_D10': 0.999999997 (-13.97163)
# R^2 (objective) value for Sample 'S66_D23': 0.999999997 (-35.66416)
# R^2 (objective) value for Sample 'S66_D42': 0.999999997 (-12.03755)
# R^2 (objective) value for Sample 'S67_D10': 0.999999997 (-29.23623)
# R^2 (objective) value for Sample 'S67_D23': 0.999999997 (-16.67390)
# R^2 (objective) value for Sample 'S67_D42': 0.999999997 (-13.56486)
# R^2 (objective) value for Sample 'S68_D10': 0.999999997 (-13.56290)
# R^2 (objective) value for Sample 'S68_D23': 0.999999996 (-15.22194)
# R^2 (objective) value for Sample 'S68_D42': 0.999999997 (-11.09044)
# R^2 (objective) value for Sample 'S69_D10': 0.999999996 (-13.04454)
# R^2 (objective) value for Sample 'S69_D23': 0.999999997 (-18.85076)
# R^2 (objective) value for Sample 'S69_D42': 0.999999997 (-17.94243)
# R^2 (objective) value for Sample 'S70_D10': 0.999999997 (-17.45584)
# R^2 (objective) value for Sample 'S70_D23': 0.999999996 (-29.41395)
# R^2 (objective) value for Sample 'S70_D42': 0.999999997 (-18.37210)
# R^2 (objective) value for Sample 'S71_D10': 0.999999997 (-15.37003)
# R^2 (objective) value for Sample 'S71_D23': 0.999999998 (-15.40733)
# R^2 (objective) value for Sample 'S71_D42': 0.999999997 (-12.10330)
# R^2 (objective) value for Sample 'S72_D10': 0.999999996 (-14.15548)
# R^2 (objective) value for Sample 'S72_D23': 0.999999996 (-14.53818)
# R^2 (objective) value for Sample 'S72_D42': 0.999999996 (-13.99826)
# R^2 (objective) value for Sample 'S73_D10': 0.999999996 (-12.25698)
# R^2 (objective) value for Sample 'S73_D23': 0.999999996 (-12.45859)
# R^2 (objective) value for Sample 'S73_D42': 0.999999997 (-12.63568)
# R^2 (objective) value for Sample 'S74_D10': 0.999999997 (-9.51651)
# R^2 (objective) value for Sample 'S74_D23': 0.999999997 (-18.10842)
# R^2 (objective) value for Sample 'S74_D42': 0.999999997 (-17.31747)
# R^2 (objective) value for Sample 'S75_D10': 0.999999997 (-12.10832)
# R^2 (objective) value for Sample 'S75_D23': 0.999999996 (-27.38321)
# R^2 (objective) value for Sample 'S75_D42': 0.999999996 (-12.54148)
# R^2 (objective) value for Sample 'S76_D10': 0.999999995 (-17.78547)
# R^2 (objective) value for Sample 'S76_D23': 0.999999996 (-15.32319)
# R^2 (objective) value for Sample 'S76_D42': 0.999999997 (-20.21962)
# R^2 (objective) value for Sample 'S77_D10': 0.999999997 (-14.77389)
# R^2 (objective) value for Sample 'S77_D23': 0.999999997 (-18.60337)
# R^2 (objective) value for Sample 'S77_D42': 0.999999997 (-18.94676)
# R^2 (objective) value for Sample 'S78_D10': 0.999999997 (-10.98333)
# R^2 (objective) value for Sample 'S78_D23': 0.999999998 (-18.23387)
# R^2 (objective) value for Sample 'S78_D42': 0.999999996 (-15.15190)
# R^2 (objective) value for Sample 'S79_D10': 0.999999996 (-16.60550)
# R^2 (objective) value for Sample 'S79_D23': 0.999999996 (-18.97198)
# R^2 (objective) value for Sample 'S79_D42': 0.999999997 (-16.51199)
# R^2 (objective) value for Sample 'S80_D10': 0.999999996 (-24.10259)
# R^2 (objective) value for Sample 'S80_D23': 0.999999997 (-13.89776)
# R^2 (objective) value for Sample 'S80_D42': 0.999999996 (-51.58156)
# R^2 (objective) value for Sample 'S81_D10': 0.999999996 (-14.88809)
# R^2 (objective) value for Sample 'S81_D23': 0.999999997 (-20.79338)
# R^2 (objective) value for Sample 'S81_D42': 0.999999996 (-19.54792)
# R^2 (objective) value for Sample 'S82_D10': 0.999999996 (-14.45882)
# R^2 (objective) value for Sample 'S82_D23': 0.999999996 (-35.20464)
# R^2 (objective) value for Sample 'S82_D42': 0.999999996 (-11.93097)
# R^2 (objective) value for Sample 'S83_D10': 0.999999996 (-16.90126)
# R^2 (objective) value for Sample 'S83_D23': 0.999999997 (-15.66858)
# R^2 (objective) value for Sample 'S83_D42': 0.999999997 (-44.51641)
# R^2 (objective) value for Sample 'S84_D10': 0.999999997 (-17.84721)
# R^2 (objective) value for Sample 'S84_D23': 0.999999994 (-14.07315)
# R^2 (objective) value for Sample 'S84_D42': 0.999999995 (-16.16128)
# R^2 (objective) value for Sample 'S85_D10': 0.999999996 (-11.58375)
# R^2 (objective) value for Sample 'S85_D23': 0.999999996 (-15.39056)
# R^2 (objective) value for Sample 'S85_D42': 0.999999995 (-14.89536)
# R^2 (objective) value for Sample 'S86_D10': 0.999999996 (-21.33330)
# R^2 (objective) value for Sample 'S86_D23': 0.999999996 (-18.63619)
# R^2 (objective) value for Sample 'S86_D42': 0.999999996 (-17.19220)
# R^2 (objective) value for Sample 'S87_D10': 0.999999996 (-13.53428)
# R^2 (objective) value for Sample 'S87_D23': 0.999999997 (-14.49767)
# R^2 (objective) value for Sample 'S87_D42': 0.999999996 (-18.42997)
# R^2 (objective) value for Sample 'S88_D10': 0.999999996 (-14.43132)
# R^2 (objective) value for Sample 'S88_D23': 0.999999996 (-15.68855)
# R^2 (objective) value for Sample 'S88_D42': 0.999999996 (-16.40668)
# R^2 (objective) value for Sample 'S89_D10': 0.999999996 (-16.40505)
# R^2 (objective) value for Sample 'S89_D23': 0.999999996 (-13.49617)
# R^2 (objective) value for Sample 'S89_D42': 0.999999997 (-22.25760)
# R^2 (objective) value for Sample 'S90_D10': 0.999999996 (-17.16142)
# R^2 (objective) value for Sample 'S90_D23': 0.999999997 (-16.34265)
# R^2 (objective) value for Sample 'S90_D42': 0.999999997 (-19.87851)
# R^2 (objective) value for Sample 'S91_D10': 0.999999997 (-19.63601)
# R^2 (objective) value for Sample 'S91_D23': 0.999999996 (-22.85069)
# R^2 (objective) value for Sample 'S91_D42': 0.999999997 (-24.59215)
# R^2 (objective) value for Sample 'S92_D10': 0.999999996 (-20.47295)
# R^2 (objective) value for Sample 'S92_D23': 0.999999996 (-24.97467)
# R^2 (objective) value for Sample 'S92_D42': 0.999999996 (-22.84038)
# R^2 (objective) value for Sample 'S93_D10': 0.999999996 (-15.41782)
# R^2 (objective) value for Sample 'S93_D23': 0.999999997 (-11.00674)
# R^2 (objective) value for Sample 'S93_D42': 0.999999997 (-17.94049)
# R^2 (objective) value for Sample 'S94_D10': 0.999999996 (-25.42347)
# R^2 (objective) value for Sample 'S94_D23': 0.999999996 (-21.67856)
# R^2 (objective) value for Sample 'S94_D42': 0.999999996 (-21.68190)
# R^2 (objective) value for Sample 'S95_D10': 0.999999996 (-20.64355)
# R^2 (objective) value for Sample 'S95_D23': 0.999999997 (-22.67094)
# R^2 (objective) value for Sample 'S95_D42': 0.999999997 (-23.19738)
# R^2 (objective) value for Sample 'S96_D10': 0.999999996 (-19.38003)
# R^2 (objective) value for Sample 'S96_D23': 0.999999996 (-26.49124)
# R^2 (objective) value for Sample 'S96_D42': 0.999999996 (-15.73388)
# R^2 (objective) value for Sample 'S97_D10': 0.999999996 (-15.98829)
# R^2 (objective) value for Sample 'S97_D23': 0.999999996 (-18.95596)
# R^2 (objective) value for Sample 'S97_D42': 0.999999997 (-18.88988)
# R^2 (objective) value for Sample 'S98_D10': 0.999999997 (-23.11972)
# R^2 (objective) value for Sample 'S98_D23': 0.999999996 (-15.71577)
# R^2 (objective) value for Sample 'S98_D42': 0.999999996 (-18.54847)
# R^2 (objective) value for Sample 'S99_D10': 0.999999997 (-18.81050)
# R^2 (objective) value for Sample 'S99_D23': 0.999999996 (-19.22722)
# R^2 (objective) value for Sample 'S99_D42': 0.999999996 (-18.05789)
# R^2 (objective) value for Sample 'S100_D10': 0.999999997 (-17.38541)
# R^2 (objective) value for Sample 'S100_D23': 0.999999996 (-22.67989)
# R^2 (objective) value for Sample 'S100_D42': 0.999999996 (-18.73617)
# R^2 (objective) value for Sample 'S101_D10': 0.999999997 (-19.21535)
# R^2 (objective) value for Sample 'S101_D23': 0.999999996 (-21.06878)
# R^2 (objective) value for Sample 'S101_D42': 0.999999997 (-16.48828)
# R^2 (objective) value for Sample 'S102_D10': 0.999999997 (-28.88318)
# R^2 (objective) value for Sample 'S102_D23': 0.999999996 (-30.58986)
# R^2 (objective) value for Sample 'S102_D42': 0.999999996 (-29.13132)
# R^2 (objective) value for Sample 'S103_D10': 0.999999996 (-25.74778)
# R^2 (objective) value for Sample 'S103_D23': 0.999999996 (-29.26092)
# R^2 (objective) value for Sample 'S103_D42': 0.999999996 (-27.83877)
# R^2 (objective) value for Sample 'S104_D10': 0.999999996 (-23.20076)
# R^2 (objective) value for Sample 'S104_D23': 0.999999996 (-22.08914)
# R^2 (objective) value for Sample 'S104_D42': 0.999999996 (-21.32987)
# R^2 (objective) value for Sample 'S105_D10': 0.999999996 (-18.45681)
# R^2 (objective) value for Sample 'S105_D23': 0.999999996 (-15.26400)
# R^2 (objective) value for Sample 'S105_D42': 0.999999996 (-17.96185)
# R^2 (objective) value for Sample 'S106_D10': 0.999999996 (-15.34779)
# R^2 (objective) value for Sample 'S106_D23': 0.999999997 (-17.70504)
# R^2 (objective) value for Sample 'S106_D42': 0.999999997 (-16.40061)
# R^2 (objective) value for Sample 'S107_D10': 0.999999996 (-18.25094)
# R^2 (objective) value for Sample 'S107_D23': 0.999999996 (-16.97349)
# R^2 (objective) value for Sample 'S107_D42': 0.999999996 (-21.87412)
# R^2 (objective) value for Sample 'S108_D10': 0.999999996 (-22.83513)
# R^2 (objective) value for Sample 'S108_D23': 0.999999997 (-27.67027)
# R^2 (objective) value for Sample 'S108_D42': 0.999999996 (-25.65134)
# R^2 (objective) value for Sample 'S109_D10': 0.999999997 (-11.24004)
# R^2 (objective) value for Sample 'S109_D23': 0.999999996 (-22.41677)
# R^2 (objective) value for Sample 'S109_D42': 0.999999997 (-16.08524)
# R^2 (objective) value for Sample 'S110_D10': 0.999999997 (-19.16796)
# R^2 (objective) value for Sample 'S110_D23': 0.999999996 (-16.51556)
# R^2 (objective) value for Sample 'S110_D42': 0.999999997 (-16.30521)
# R^2 (objective) value for Sample 'S111_D10': 0.999999996 (-18.96234)
# R^2 (objective) value for Sample 'S111_D23': 0.999999997 (-19.05071)
# R^2 (objective) value for Sample 'S111_D42': 0.999999997 (-24.06434)
# R^2 (objective) value for Sample 'S112_D10': 0.999999997 (-19.86557)
# R^2 (objective) value for Sample 'S112_D23': 0.999999996 (-21.55298)
# R^2 (objective) value for Sample 'S112_D42': 0.999999997 (-15.91181)
# R^2 (objective) value for Sample 'S113_D10': 0.999999996 (-24.08409)
# R^2 (objective) value for Sample 'S113_D23': 0.999999996 (-19.75350)
# R^2 (objective) value for Sample 'S113_D42': 0.999999997 (-13.41525)
# R^2 (objective) value for Sample 'S114_D10': 0.999999997 (-13.29062)
# R^2 (objective) value for Sample 'S114_D23': 0.999999997 (-19.18464)
# R^2 (objective) value for Sample 'S114_D42': 0.999999997 (-14.06713)
# R^2 (objective) value for Sample 'S115_D10': 0.999999996 (-33.64014)
# R^2 (objective) value for Sample 'S115_D23': 0.999999997 (-15.22684)
# R^2 (objective) value for Sample 'S115_D42': 0.999999996 (-16.95611)
# R^2 (objective) value for Sample 'S116_D10': 0.999999996 (-17.13905)
# R^2 (objective) value for Sample 'S116_D23': 0.999999997 (-13.15021)
# R^2 (objective) value for Sample 'S116_D42': 0.999999997 (-33.27291)
# R^2 (objective) value for Sample 'S117_D10': 0.999999996 (-15.96042)
# R^2 (objective) value for Sample 'S117_D23': 0.999999997 (-43.23513)
# R^2 (objective) value for Sample 'S117_D42': 0.999999997 (-20.28694)
# R^2 (objective) value for Sample 'S118_D10': 0.999999996 (-10.93950)
# R^2 (objective) value for Sample 'S118_D23': 0.999999996 (-23.66167)
# R^2 (objective) value for Sample 'S118_D42': 0.999999997 (-10.84398)
# R^2 (objective) value for Sample 'S119_D10': 0.999999996 (-30.83125)
# R^2 (objective) value for Sample 'S119_D23': 0.999999997 (-20.07386)
# R^2 (objective) value for Sample 'S119_D42': 0.999999996 (-17.76172)
# R^2 (objective) value for Sample 'S120_D10': 0.999999997 (-22.21508)
# R^2 (objective) value for Sample 'S120_D23': 0.999999997 (-21.86627)
# R^2 (objective) value for Sample 'S120_D42': 0.999999997 (-19.36242)
# R^2 (objective) value for Sample 'S121_D10': 0.999999996 (-20.30904)
# R^2 (objective) value for Sample 'S121_D23': 0.999999997 (-18.33563)
# R^2 (objective) value for Sample 'S121_D42': 0.999999997 (-22.76702)
# R^2 (objective) value for Sample 'S122_D10': 0.999999997 (-19.98754)
# R^2 (objective) value for Sample 'S122_D23': 0.999999997 (-19.51052)
# R^2 (objective) value for Sample 'S122_D42': 0.999999997 (-28.34235)
# R^2 (objective) value for Sample 'S123_D10': 0.999999997 (-25.27466)
# R^2 (objective) value for Sample 'S123_D23': 0.999999996 (-21.97298)
# R^2 (objective) value for Sample 'S123_D42': 0.999999997 (-22.47685)
# R^2 (objective) value for Sample 'S124_D10': 0.999999996 (-15.76476)
# R^2 (objective) value for Sample 'S124_D23': 0.999999996 (-16.33353)
# R^2 (objective) value for Sample 'S124_D42': 0.999999996 (-15.66561)
# R^2 (objective) value for Sample 'S125_D10': 0.999999996 (-19.96791)
# R^2 (objective) value for Sample 'S125_D23': 0.999999996 (-19.78994)
# R^2 (objective) value for Sample 'S125_D42': 0.999999997 (-16.09261)
# R^2 (objective) value for Sample 'S126_D10': 0.999999997 (-20.45241)
# R^2 (objective) value for Sample 'S126_D23': 0.999999996 (-28.41987)
# R^2 (objective) value for Sample 'S126_D42': 0.999999997 (-21.75769)
# R^2 (objective) value for Sample 'S127_D10': 0.999999997 (-13.59909)
# R^2 (objective) value for Sample 'S127_D23': 0.999999997 (-14.34221)
# R^2 (objective) value for Sample 'S127_D42': 0.999999997 (-13.92228)
# R^2 (objective) value for Sample 'S128_D10': 0.999999996 (-22.79148)
# R^2 (objective) value for Sample 'S128_D23': 0.999999997 (-20.01915)
# R^2 (objective) value for Sample 'S128_D42': 0.999999996 (-19.69730)
# R^2 (objective) value for Sample 'S129_D10': 0.999999997 (-20.36482)
# R^2 (objective) value for Sample 'S129_D23': 0.999999997 (-18.45568)
# R^2 (objective) value for Sample 'S129_D42': 0.999999997 (-17.01927)
# R^2 (objective) value for Sample 'S130_D10': 0.999999998 (-25.59850)
# R^2 (objective) value for Sample 'S130_D23': 0.999999997 (-34.16405)
# R^2 (objective) value for Sample 'S130_D42': 0.999999997 (-20.93493)
# R^2 (objective) value for Sample 'S131_D10': 0.999999997 (-19.66892)
# R^2 (objective) value for Sample 'S131_D23': 0.999999997 (-19.86625)
# R^2 (objective) value for Sample 'S131_D42': 0.999999998 (-21.15935)
# R^2 (objective) value for Sample 'S132_D10': 0.999999998 (-16.77952)
# R^2 (objective) value for Sample 'S132_D23': 0.999999996 (-11.13080)
# R^2 (objective) value for Sample 'S132_D42': 0.999999997 (-30.29745)
# R^2 (objective) value for Sample 'S133_D10': 0.999999997 (-14.78322)
# R^2 (objective) value for Sample 'S133_D23': 0.999999996 (-38.57586)
# R^2 (objective) value for Sample 'S133_D42': 0.999999996 (-16.31840)
# R^2 (objective) value for Sample 'S134_D10': 0.999999997 (-20.89962)
# R^2 (objective) value for Sample 'S134_D23': 0.999999998 (-18.19853)
# R^2 (objective) value for Sample 'S134_D42': 0.999999996 (-23.38161)
# R^2 (objective) value for Sample 'S135_D10': 0.999999997 (-15.43477)
# R^2 (objective) value for Sample 'S135_D23': 0.999999997 (-17.05604)
# R^2 (objective) value for Sample 'S135_D42': 0.999999997 (-15.00377)
# R^2 (objective) value for Sample 'S136_D10': 0.999999997 (-18.62737)
# R^2 (objective) value for Sample 'S136_D23': 0.999999997 (-20.01888)
# R^2 (objective) value for Sample 'S136_D42': 0.999999997 (-19.57388)
# R^2 (objective) value for Sample 'S137_D10': 0.999999996 (-16.04154)
# R^2 (objective) value for Sample 'S137_D23': 0.999999997 (-15.18032)
# R^2 (objective) value for Sample 'S137_D42': 0.999999997 (-15.30803)
# R^2 (objective) value for Sample 'S138_D10': 0.999999996 (-16.53710)
# R^2 (objective) value for Sample 'S138_D23': 0.999999997 (-17.99595)
# R^2 (objective) value for Sample 'S138_D42': 0.999999997 (-20.45217)
# R^2 (objective) value for Sample 'S139_D10': 0.999999997 (-20.29894)
# R^2 (objective) value for Sample 'S139_D23': 0.999999996 (-31.40332)
# R^2 (objective) value for Sample 'S139_D42': 0.999999998 (-14.41496)
# R^2 (objective) value for Sample 'S140_D10': 0.999999998 (-17.88565)
# R^2 (objective) value for Sample 'S140_D23': 0.999999996 (-18.36302)
# R^2 (objective) value for Sample 'S140_D42': 0.999999996 (-18.59585)
# R^2 (objective) value for Sample 'S141_D10': 0.999999997 (-12.18425)
# R^2 (objective) value for Sample 'S141_D23': 0.999999997 (-34.57694)
# R^2 (objective) value for Sample 'S141_D42': 0.999999997 (-19.66125)
# R^2 (objective) value for Sample 'S142_D10': 0.999999998 (-16.60961)
# R^2 (objective) value for Sample 'S142_D23': 0.999999997 (-14.39721)
# R^2 (objective) value for Sample 'S142_D42': 0.999999997 (-16.50946)
# R^2 (objective) value for Sample 'S143_D10': 0.999999998 (-16.99251)
# R^2 (objective) value for Sample 'S143_D23': 0.999999996 (-22.77363)
# R^2 (objective) value for Sample 'S143_D42': 0.999999996 (-15.47125)
# R^2 (objective) value for Sample 'S144_D10': 0.999999996 (-19.27700)
# R^2 (objective) value for Sample 'S144_D23': 0.999999997 (-18.43586)
# R^2 (objective) value for Sample 'S144_D42': 0.999999997 (-30.92704)
# R^2 (objective) value for Sample 'S145_D10': 0.999999996 (-19.51699)
# R^2 (objective) value for Sample 'S145_D23': 0.999999997 (-25.32628)
# R^2 (objective) value for Sample 'S145_D42': 0.999999996 (-27.18132)
# R^2 (objective) value for Sample 'S146_D10': 0.999999997 (-24.52216)
# R^2 (objective) value for Sample 'S146_D23': 0.999999996 (-20.66272)
# R^2 (objective) value for Sample 'S146_D42': 0.999999997 (-17.22608)
# R^2 (objective) value for Sample 'S147_D10': 0.999999997 (-24.01486)
# R^2 (objective) value for Sample 'S147_D23': 0.999999996 (-21.15038)
# R^2 (objective) value for Sample 'S147_D42': 0.999999996 (-21.03379)
# R^2 (objective) value for Sample 'S148_D10': 0.999999997 (-19.84594)
# R^2 (objective) value for Sample 'S148_D23': 0.999999998 (-20.37825)
# R^2 (objective) value for Sample 'S148_D42': 0.999999998 (-20.08761)
# R^2 (objective) value for Sample 'S149_D10': 0.999999997 (-16.32733)
# R^2 (objective) value for Sample 'S149_D23': 0.999999997 (-19.18230)
# R^2 (objective) value for Sample 'S149_D42': 0.999999997 (-19.26309)
# R^2 (objective) value for Sample 'S150_D10': 0.999999996 (-16.62836)
# R^2 (objective) value for Sample 'S150_D23': 0.999999997 (-17.62874)
# R^2 (objective) value for Sample 'S150_D42': 0.999999997 (-16.87159)
# R^2 (objective) value for Sample 'S151_D10': 0.999999997 (-24.58349)
# R^2 (objective) value for Sample 'S151_D23': 0.999999997 (-21.85798)
# R^2 (objective) value for Sample 'S151_D42': 0.999999996 (-17.35404)
# R^2 (objective) value for Sample 'S152_D10': 0.999999996 (-23.76692)
# R^2 (objective) value for Sample 'S152_D23': 0.999999996 (-40.89982)
# R^2 (objective) value for Sample 'S152_D42': 0.999999998 (-20.40789)
# R^2 (objective) value for Sample 'S153_D10': 0.999999997 (-22.72622)
# R^2 (objective) value for Sample 'S153_D23': 0.999999996 (-26.66761)
# R^2 (objective) value for Sample 'S153_D42': 0.999999996 (-20.08163)
# R^2 (objective) value for Sample 'S154_D10': 0.999999997 (-16.01140)
# R^2 (objective) value for Sample 'S154_D23': 0.999999997 (-27.03389)
# R^2 (objective) value for Sample 'S154_D42': 0.999999996 (-15.32270)
# R^2 (objective) value for Sample 'S155_D10': 0.999999996 (-22.79323)
# R^2 (objective) value for Sample 'S155_D23': 0.999999996 (-37.49711)
# R^2 (objective) value for Sample 'S155_D42': 0.999999997 (-16.58890)
# R^2 (objective) value for Sample 'S156_D10': 0.999999996 (-20.96183)
# R^2 (objective) value for Sample 'S156_D23': 0.999999997 (-31.05673)
# R^2 (objective) value for Sample 'S156_D42': 0.999999996 (-14.82180)
# R^2 (objective) value for Sample 'S157_D10': 0.999999997 (-19.98290)
# R^2 (objective) value for Sample 'S157_D23': 0.999999997 (-20.45526)
# R^2 (objective) value for Sample 'S157_D42': 0.999999997 (-19.47789)
# R^2 (objective) value for Sample 'S158_D10': 0.999999997 (-20.87985)
# R^2 (objective) value for Sample 'S158_D23': 0.999999997 (-19.82980)
# R^2 (objective) value for Sample 'S158_D42': 0.999999997 (-18.43893)
# R^2 (objective) value for Sample 'S159_D10': 0.999999997 (-16.26155)
# R^2 (objective) value for Sample 'S159_D23': 0.999999996 (-22.15141)
# R^2 (objective) value for Sample 'S159_D42': 0.999999996 (-22.34100)
# R^2 (objective) value for Sample 'S160_D10': 0.999999996 (-25.52053)
# R^2 (objective) value for Sample 'S160_D23': 0.999999996 (-37.88848)
# R^2 (objective) value for Sample 'S160_D42': 0.999999997 (-20.12460)
# R^2 (objective) value for Sample 'S161_D10': 0.999999996 (-16.61994)
# R^2 (objective) value for Sample 'S161_D23': 0.999999996 (-14.43580)
# R^2 (objective) value for Sample 'S161_D42': 0.999999997 (-18.40323)
# R^2 (objective) value for Sample 'S162_D10': 0.999999998 (-15.06454)
# R^2 (objective) value for Sample 'S162_D23': 0.999999996 (-33.34912)
# R^2 (objective) value for Sample 'S162_D42': 0.999999996 (-17.65270)
# R^2 (objective) value for Sample 'S163_D10': 0.999999996 (-20.84900)
# R^2 (objective) value for Sample 'S163_D23': 0.999999997 (-22.49000)
# R^2 (objective) value for Sample 'S163_D42': 0.999999997 (-22.31597)
# R^2 (objective) value for Sample 'S164_D10': 0.999999997 (-25.39414)
# R^2 (objective) value for Sample 'S164_D23': 0.999999997 (-27.84327)
# R^2 (objective) value for Sample 'S164_D42': 0.999999997 (-25.98072)
# R^2 (objective) value for Sample 'S165_D10': 0.999999997 (-21.45086)
# R^2 (objective) value for Sample 'S165_D23': 0.999999996 (-19.28150)
# R^2 (objective) value for Sample 'S165_D42': 0.999999997 (-20.11252)
# R^2 (objective) value for Sample 'S166_D10': 0.999999997 (-26.09763)
# R^2 (objective) value for Sample 'S166_D23': 0.999999996 (-21.75099)
# R^2 (objective) value for Sample 'S166_D42': 0.999999997 (-21.66648)
# R^2 (objective) value for Sample 'S167_D10': 0.999999997 (-12.01403)
# R^2 (objective) value for Sample 'S167_D23': 0.999999997 (-9.87523)
# R^2 (objective) value for Sample 'S167_D42': 0.999999996 (-15.95785)
# R^2 (objective) value for Sample 'S168_D10': 0.999999996 (-43.17647)
# R^2 (objective) value for Sample 'S168_D23': 0.999999996 (-19.17830)
# R^2 (objective) value for Sample 'S168_D42': 0.999999997 (-13.55472)
# R^2 (objective) value for Sample 'S169_D10': 0.999999996 (-18.49813)
# R^2 (objective) value for Sample 'S169_D23': 0.999999996 (-20.72389)
# R^2 (objective) value for Sample 'S169_D42': 0.999999996 (-12.86211)
# R^2 (objective) value for Sample 'S170_D10': 0.999999997 (-24.40051)
# R^2 (objective) value for Sample 'S170_D23': 0.999999997 (-24.04157)
# R^2 (objective) value for Sample 'S170_D42': 0.999999997 (-20.04579)
# R^2 (objective) value for Sample 'S171_D10': 0.999999997 (-11.65072)
# R^2 (objective) value for Sample 'S171_D23': 0.999999996 (-24.58693)
# R^2 (objective) value for Sample 'S171_D42': 0.999999997 (-20.57968)
# R^2 (objective) value for Sample 'S172_D10': 0.999999996 (-25.31011)
# R^2 (objective) value for Sample 'S172_D23': 0.999999996 (-31.57204)
# R^2 (objective) value for Sample 'S172_D42': 0.999999996 (-39.82413)
# R^2 (objective) value for Sample 'S173_D10': 0.999999996 (-23.09820)
# R^2 (objective) value for Sample 'S173_D23': 0.999999996 (-21.68888)
# R^2 (objective) value for Sample 'S173_D42': 0.999999996 (-24.87144)
# R^2 (objective) value for Sample 'S174_D10': 0.999999996 (-21.04190)
# R^2 (objective) value for Sample 'S174_D23': 0.999999997 (-15.15534)
# R^2 (objective) value for Sample 'S174_D42': 0.999999996 (-8.02764)
# R^2 (objective) value for Sample 'S175_D10': 0.999999997 (-29.60229)
# R^2 (objective) value for Sample 'S175_D23': 0.999999996 (-20.97239)
# R^2 (objective) value for Sample 'S175_D42': 0.999999996 (-24.28590)
# R^2 (objective) value for Sample 'S176_D10': 0.999999996 (-32.46063)
# R^2 (objective) value for Sample 'S176_D23': 0.999999996 (-29.03566)
# R^2 (objective) value for Sample 'S176_D42': 0.999999996 (-36.24041)
# R^2 (objective) value for Sample 'S177_D10': 0.999999996 (-23.58298)
# R^2 (objective) value for Sample 'S177_D23': 0.999999997 (-23.83668)
# R^2 (objective) value for Sample 'S177_D42': 0.999999997 (-27.79437)
# R^2 (objective) value for Sample 'S178_D10': 0.999999997 (-26.16979)
# R^2 (objective) value for Sample 'S178_D23': 0.999999997 (-21.99611)
# R^2 (objective) value for Sample 'S178_D42': 0.999999997 (-14.00967)
# R^2 (objective) value for Sample 'S179_D10': 0.999999997 (-19.59349)
# R^2 (objective) value for Sample 'S179_D23': 0.999999996 (-17.22284)
# R^2 (objective) value for Sample 'S179_D42': 0.999999997 (-34.25334)
# R^2 (objective) value for Sample 'S180_D10': 0.999999996 (-13.86929)
# R^2 (objective) value for Sample 'S180_D23': 0.999999996 (-20.39412)
# R^2 (objective) value for Sample 'S180_D42': 0.999999996 (-23.03042)
# R^2 (objective) value for Sample 'S181_D10': 0.999999996 (-32.28568)
# R^2 (objective) value for Sample 'S181_D23': 0.999999996 (-30.96148)
# R^2 (objective) value for Sample 'S181_D42': 0.999999996 (-35.49303)
# R^2 (objective) value for Sample 'S182_D10': 0.999999996 (-12.80279)
# R^2 (objective) value for Sample 'S182_D23': 0.999999996 (-25.02307)
# R^2 (objective) value for Sample 'S182_D42': 0.999999996 (-37.49200)
# R^2 (objective) value for Sample 'S183_D10': 0.999999996 (-20.83331)
# R^2 (objective) value for Sample 'S183_D23': 0.999999996 (-19.45936)
# R^2 (objective) value for Sample 'S183_D42': 0.999999996 (-21.87488)
# R^2 (objective) value for Sample 'S184_D10': 0.999999996 (-28.46530)
# R^2 (objective) value for Sample 'S184_D23': 0.999999997 (-24.58288)
# R^2 (objective) value for Sample 'S184_D42': 0.999999996 (-28.92634)
# R^2 (objective) value for Sample 'S185_D10': 0.999999996 (-37.85126)
# R^2 (objective) value for Sample 'S185_D23': 0.999999996 (-38.54735)
# R^2 (objective) value for Sample 'S185_D42': 0.999999996 (-35.35241)
# R^2 (objective) value for Sample 'S186_D10': 0.999999997 (-21.05664)
# R^2 (objective) value for Sample 'S186_D23': 0.999999996 (-22.16236)
# R^2 (objective) value for Sample 'S186_D42': 0.999999997 (-19.26490)
# R^2 (objective) value for Sample 'S187_D10': 0.999999997 (-23.88386)
# R^2 (objective) value for Sample 'S187_D23': 0.999999996 (-30.59468)
# R^2 (objective) value for Sample 'S187_D42': 0.999999997 (-18.30596)
# R^2 (objective) value for Sample 'S188_D10': 0.999999996 (-22.27845)
# R^2 (objective) value for Sample 'S188_D23': 0.999999996 (-32.53103)
# R^2 (objective) value for Sample 'S188_D42': 0.999999996 (-19.63915)
# R^2 (objective) value for Sample 'S189_D10': 0.999999996 (-33.01878)
# R^2 (objective) value for Sample 'S189_D23': 0.999999996 (-32.33983)
# R^2 (objective) value for Sample 'S189_D42': 0.999999996 (-32.65274)
# R^2 (objective) value for Sample 'S190_D10': 0.999999996 (-22.13346)
# R^2 (objective) value for Sample 'S190_D23': 0.999999996 (-32.73200)
# R^2 (objective) value for Sample 'S190_D42': 0.999999996 (-32.96680)
# R^2 (objective) value for Sample 'S191_D10': 0.999999996 (-26.90912)
# R^2 (objective) value for Sample 'S191_D23': 0.999999996 (-28.96594)
# R^2 (objective) value for Sample 'S191_D42': 0.999999996 (-30.09143)
# R^2 (objective) value for Sample 'S192_D10': 0.999999996 (-27.72287)
# R^2 (objective) value for Sample 'S192_D23': 0.999999996 (-24.66493)
# R^2 (objective) value for Sample 'S192_D42': 0.999999996 (-20.46514)
# R^2 (objective) value for Sample 'S193_D10': 0.999999997 (-35.72886)
# R^2 (objective) value for Sample 'S193_D23': 0.999999996 (-33.69247)
# R^2 (objective) value for Sample 'S193_D42': 0.999999996 (-32.79182)
# R^2 (objective) value for Sample 'S194_D10': 0.999999996 (-30.77609)
# R^2 (objective) value for Sample 'S194_D23': 0.999999997 (-22.72814)
# R^2 (objective) value for Sample 'S194_D42': 0.999999996 (-23.15281)
# R^2 (objective) value for Sample 'S195_D10': 0.999999996 (-19.44420)
# R^2 (objective) value for Sample 'S195_D23': 0.999999996 (-23.91107)
# R^2 (objective) value for Sample 'S195_D42': 0.999999997 (-23.62915)
# R^2 (objective) value for Sample 'S196_D10': 0.999999996 (-38.87668)
# R^2 (objective) value for Sample 'S196_D23': 0.999999996 (-34.15103)
# R^2 (objective) value for Sample 'S196_D42': 0.999999996 (-34.49201)
# R^2 (objective) value for Sample 'S197_D10': 0.999999997 (-26.55624)
# R^2 (objective) value for Sample 'S197_D23': 0.999999997 (-31.12228)
# R^2 (objective) value for Sample 'S197_D42': 0.999999996 (-31.67768)
# R^2 (objective) value for Sample 'S198_D10': 0.999999996 (-18.80555)
# R^2 (objective) value for Sample 'S198_D23': 0.999999997 (-42.21352)
# R^2 (objective) value for Sample 'S198_D42': 0.999999997 (-27.48549)
# R^2 (objective) value for Sample 'S199_D10': 0.999999995 (-26.34726)
# R^2 (objective) value for Sample 'S199_D23': 0.999999996 (-26.78615)
# R^2 (objective) value for Sample 'S199_D42': 0.999999996 (-28.74399)
# R^2 (objective) value for Sample 'S200_D10': 0.999999996 (-20.26215)
# R^2 (objective) value for Sample 'S200_D23': 0.999999996 (-37.56195)
# R^2 (objective) value for Sample 'S200_D42': 0.999999996 (-30.65591)
# R^2 (objective) value for Sample 'S201_D10': 0.999999996 (-22.34431)
# R^2 (objective) value for Sample 'S201_D23': 0.999999996 (-24.84597)
# R^2 (objective) value for Sample 'S201_D42': 0.999999997 (-22.24661)
# R^2 (objective) value for Sample 'S202_D10': 0.999999996 (-22.62087)
# R^2 (objective) value for Sample 'S202_D23': 0.999999996 (-23.68632)
# R^2 (objective) value for Sample 'S202_D42': 0.999999997 (-21.99619)
# R^2 (objective) value for Sample 'S203_D10': 0.999999997 (-32.48320)
# R^2 (objective) value for Sample 'S203_D23': 0.999999997 (-32.47475)
# R^2 (objective) value for Sample 'S203_D42': 0.999999997 (-33.19154)
# R^2 (objective) value for Sample 'S204_D10': 0.999999997 (-23.79425)
# R^2 (objective) value for Sample 'S204_D23': 0.999999997 (-28.03236)
# R^2 (objective) value for Sample 'S204_D42': 0.999999997 (-29.66379)
# R^2 (objective) value for Sample 'S205_D10': 0.999999996 (-29.91918)
# R^2 (objective) value for Sample 'S205_D23': 0.999999996 (-25.97493)
# R^2 (objective) value for Sample 'S205_D42': 0.999999996 (-29.04838)
# R^2 (objective) value for Sample 'S206_D10': 0.999999996 (-34.89984)
# R^2 (objective) value for Sample 'S206_D23': 0.999999996 (-32.16927)
# R^2 (objective) value for Sample 'S206_D42': 0.999999997 (-33.01866)
# R^2 (objective) value for Sample 'S207_D10': 0.999999996 (-23.49175)
# R^2 (objective) value for Sample 'S207_D23': 0.999999997 (-23.09771)
# R^2 (objective) value for Sample 'S207_D42': 0.999999996 (-14.89177)
# R^2 (objective) value for Sample 'S208_D10': 0.999999996 (-32.72348)
# R^2 (objective) value for Sample 'S208_D23': 0.999999996 (-29.26308)
# R^2 (objective) value for Sample 'S208_D42': 0.999999996 (-25.92150)
# R^2 (objective) value for Sample 'S209_D10': 0.999999997 (-26.71693)
# R^2 (objective) value for Sample 'S209_D23': 0.999999996 (-23.11679)
# R^2 (objective) value for Sample 'S209_D42': 0.999999996 (-20.78749)
# R^2 (objective) value for Sample 'S210_D10': 0.999999996 (-29.82438)
# R^2 (objective) value for Sample 'S210_D23': 0.999999996 (-30.21397)
# R^2 (objective) value for Sample 'S210_D42': 0.999999996 (-27.43400)
# R^2 (objective) value for Sample 'S211_D10': 0.999999997 (-22.52719)
# R^2 (objective) value for Sample 'S211_D23': 0.999999997 (-21.76466)
# R^2 (objective) value for Sample 'S211_D42': 0.999999997 (-25.33239)
# R^2 (objective) value for Sample 'S212_D10': 0.999999996 (-23.01367)
# R^2 (objective) value for Sample 'S212_D23': 0.999999996 (-21.20416)
# R^2 (objective) value for Sample 'S212_D42': 0.999999997 (-26.68259)
# R^2 (objective) value for Sample 'S213_D10': 0.999999997 (-33.19163)
# R^2 (objective) value for Sample 'S213_D23': 0.999999997 (-23.95900)
# R^2 (objective) value for Sample 'S213_D42': 0.999999996 (-22.28205)
# R^2 (objective) value for Sample 'S214_D10': 0.999999997 (-26.43109)
# R^2 (objective) value for Sample 'S214_D23': 0.999999997 (-24.29459)
# R^2 (objective) value for Sample 'S214_D42': 0.999999997 (-28.39272)
# R^2 (objective) value for Sample 'S215_D10': 0.999999997 (-27.41697)
# R^2 (objective) value for Sample 'S215_D23': 0.999999996 (-22.55495)
# R^2 (objective) value for Sample 'S215_D42': 0.999999997 (-34.76069)
# R^2 (objective) value for Sample 'S216_D10': 0.999999996 (-28.22417)
# R^2 (objective) value for Sample 'S216_D23': 0.999999996 (-28.52268)
# R^2 (objective) value for Sample 'S216_D42': 0.999999996 (-28.12057)
# R^2 (objective) value for Sample 'S217_D10': 0.999999996 (-21.69899)
# R^2 (objective) value for Sample 'S217_D23': 0.999999996 (-36.33951)
# R^2 (objective) value for Sample 'S217_D42': 0.999999996 (-33.56293)
# R^2 (objective) value for Sample 'S218_D10': 0.999999996 (-42.30563)
# R^2 (objective) value for Sample 'S218_D23': 0.999999996 (-45.52796)
# R^2 (objective) value for Sample 'S218_D42': 0.999999996 (-43.55769)
# R^2 (objective) value for Sample 'S219_D10': 0.999999997 (-22.47207)
# R^2 (objective) value for Sample 'S219_D23': 0.999999996 (-25.75632)
# R^2 (objective) value for Sample 'S219_D42': 0.999999996 (-30.20679)
# R^2 (objective) value for Sample 'S220_D10': 0.999999996 (-28.29846)
# R^2 (objective) value for Sample 'S220_D23': 0.999999996 (-26.37023)
# R^2 (objective) value for Sample 'S220_D42': 0.999999996 (-26.29944)
# R^2 (objective) value for Sample 'S221_D10': 0.999999996 (-28.93288)
# R^2 (objective) value for Sample 'S221_D23': 0.999999996 (-24.00310)
# R^2 (objective) value for Sample 'S221_D42': 0.999999996 (-24.53353)
# R^2 (objective) value for Sample 'S222_D10': 0.999999996 (-24.31766)
# R^2 (objective) value for Sample 'S222_D23': 0.999999996 (-28.24379)
# R^2 (objective) value for Sample 'S222_D42': 0.999999996 (-30.04070)
# R^2 (objective) value for Sample 'S223_D10': 0.999999996 (-33.49818)
# R^2 (objective) value for Sample 'S223_D23': 0.999999997 (-17.64732)
# R^2 (objective) value for Sample 'S223_D42': 0.999999997 (-23.09538)
# R^2 (objective) value for Sample 'S224_D10': 0.999999996 (-18.31385)
# R^2 (objective) value for Sample 'S224_D23': 0.999999996 (-35.12375)
# R^2 (objective) value for Sample 'S224_D42': 0.999999996 (-27.83212)
# R^2 (objective) value for Sample 'S225_D10': 0.999999997 (-23.02249)
# R^2 (objective) value for Sample 'S225_D23': 0.999999996 (-25.26151)
# R^2 (objective) value for Sample 'S225_D42': 0.999999996 (-23.39912)
# R^2 (objective) value for Sample 'S226_D10': 0.999999996 (-31.57815)
# R^2 (objective) value for Sample 'S226_D23': 0.999999997 (-36.34789)
# R^2 (objective) value for Sample 'S226_D42': 0.999999997 (-31.70891)
# R^2 (objective) value for Sample 'S227_D10': 0.999999996 (-36.22160)
# R^2 (objective) value for Sample 'S227_D23': 0.999999996 (-21.35380)
# R^2 (objective) value for Sample 'S227_D42': 0.999999997 (-21.11756)
# R^2 (objective) value for Sample 'S228_D10': 0.999999997 (-23.79424)
# R^2 (objective) value for Sample 'S228_D23': 0.999999997 (-14.96988)
# R^2 (objective) value for Sample 'S228_D42': 0.999999996 (-19.34327)
# R^2 (objective) value for Sample 'S229_D10': 0.999999997 (-46.74883)
# R^2 (objective) value for Sample 'S229_D23': 0.999999998 (-24.89960)
# R^2 (objective) value for Sample 'S229_D42': 0.999999996 (-19.06659)
# R^2 (objective) value for Sample 'S230_D10': 0.999999996 (-20.01105)
# R^2 (objective) value for Sample 'S230_D23': 0.999999996 (-19.36583)
# R^2 (objective) value for Sample 'S230_D42': 0.999999997 (-21.91616)
# R^2 (objective) value for Sample 'S231_D10': 0.999999998 (-30.73425)
# R^2 (objective) value for Sample 'S231_D23': 0.999999997 (-28.16244)
# R^2 (objective) value for Sample 'S231_D42': 0.999999997 (-26.66716)
# R^2 (objective) value for Sample 'S232_D10': 0.999999996 (-19.07555)
# R^2 (objective) value for Sample 'S232_D23': 0.999999997 (-17.88101)
# R^2 (objective) value for Sample 'S232_D42': 0.999999998 (-21.05567)
# R^2 (objective) value for Sample 'S233_D10': 0.999999997 (-15.77955)
# R^2 (objective) value for Sample 'S233_D23': 0.999999997 (-14.47642)
# R^2 (objective) value for Sample 'S233_D42': 0.999999994 (-11.10642)
# ...
# R^2 (objective) value for Sample 'S542_D10': 0.999999996 (-13.18547)
# R^2 (objective) value for Sample 'S542_D23': 0.999999995 (-31.99601)
# R^2 (objective) value for Sample 'S542_D42': 0.999999996 (-11.29131)
# R^2 (objective) value for Sample 'S543_D10': 0.999999997 (-20.34833)
# R^2 (objective) value for Sample 'S543_D23': 0.999999996 (-43.90005)
# R^2 (objective) value for Sample 'S543_D42': 0.999999997 (-16.75110)
# R^2 (objective) value for Sample 'S544_D10': 0.999999996 (-17.34978)
# R^2 (objective) value for Sample 'S544_D23': 0.999999997 (-17.97104)
# R^2 (objective) value for Sample 'S544_D42': 0.999999997 (-13.76224)
# R^2 (objective) value for Sample 'S545_D10': 0.999999996 (-11.32843)
# R^2 (objective) value for Sample 'S545_D23': 0.999999997 (-12.89046)
# R^2 (objective) value for Sample 'S545_D42': 0.999999996 (-14.20814)
# R^2 (objective) value for Sample 'S546_D10': 0.999999995 (-15.46996)
# R^2 (objective) value for Sample 'S546_D23': 0.999999996 (-13.64928)
# R^2 (objective) value for Sample 'S546_D42': 0.999999996 (-18.51987)
# R^2 (objective) value for Sample 'S547_D10': 0.999999996 (-23.16262)
# R^2 (objective) value for Sample 'S547_D23': 0.999999996 (-22.22394)
# R^2 (objective) value for Sample 'S547_D42': 0.999999997 (-18.20029)
# R^2 (objective) value for Sample 'S548_D10': 0.999999996 (-10.47005)
# R^2 (objective) value for Sample 'S548_D23': 0.999999996 (-12.94512)
# R^2 (objective) value for Sample 'S548_D42': 0.999999996 (-12.69093)
# R^2 (objective) value for Sample 'S549_D10': 0.999999995 (-40.13780)
# R^2 (objective) value for Sample 'S549_D23': 0.999999996 (-17.60861)
# R^2 (objective) value for Sample 'S549_D42': 0.999999995 (-17.41407)
# R^2 (objective) value for Sample 'S550_D10': 0.999999996 (-15.07998)
# R^2 (objective) value for Sample 'S550_D23': 0.999999996 (-13.81146)
# R^2 (objective) value for Sample 'S550_D42': 0.999999996 (-9.58563)
# R^2 (objective) value for Sample 'S551_D10': 0.999999997 (-10.99485)
# R^2 (objective) value for Sample 'S551_D23': 0.999999996 (-15.27695)
# R^2 (objective) value for Sample 'S551_D42': 0.999999996 (-13.50905)
# R^2 (objective) value for Sample 'S552_D10': 0.999999996 (-13.45062)
# R^2 (objective) value for Sample 'S552_D23': 0.999999996 (-12.21119)
# R^2 (objective) value for Sample 'S552_D42': 0.999999996 (-12.97891)
# R^2 (objective) value for Sample 'S553_D10': 0.999999996 (-14.17024)
# R^2 (objective) value for Sample 'S553_D23': 0.999999995 (-14.84392)
# R^2 (objective) value for Sample 'S553_D42': 0.999999996 (-16.20669)
# R^2 (objective) value for Sample 'S554_D10': 0.999999996 (-15.40756)
# R^2 (objective) value for Sample 'S554_D23': 0.999999996 (-13.86787)
# R^2 (objective) value for Sample 'S554_D42': 0.999999996 (-13.77685)
# R^2 (objective) value for Sample 'S555_D10': 0.999999996 (-10.74922)
# R^2 (objective) value for Sample 'S555_D23': 0.999999995 (-49.90156)
# R^2 (objective) value for Sample 'S555_D42': 0.999999996 (-12.75123)
# R^2 (objective) value for Sample 'S556_D10': 0.999999996 (-14.71184)
# R^2 (objective) value for Sample 'S556_D23': 0.999999996 (-15.91669)
# R^2 (objective) value for Sample 'S556_D42': 0.999999995 (-16.01579)
# R^2 (objective) value for Sample 'S557_D10': 0.999999996 (-13.77791)
# R^2 (objective) value for Sample 'S557_D23': 0.999999996 (-16.76241)
# R^2 (objective) value for Sample 'S557_D42': 0.999999996 (-16.68943)
# R^2 (objective) value for Sample 'S558_D10': 0.999999996 (-16.40522)
# R^2 (objective) value for Sample 'S558_D23': 0.999999995 (-17.42629)
# R^2 (objective) value for Sample 'S558_D42': 0.999999996 (-19.24649)
# R^2 (objective) value for Sample 'S559_D10': 0.999999996 (-10.53533)
# R^2 (objective) value for Sample 'S559_D23': 0.999999996 (-10.68132)
# R^2 (objective) value for Sample 'S559_D42': 0.999999996 (-11.34281)
# R^2 (objective) value for Sample 'S560_D10': 0.999999996 (-11.95436)
# R^2 (objective) value for Sample 'S560_D23': 0.999999996 (-10.76388)
# R^2 (objective) value for Sample 'S560_D42': 0.999999995 (-9.44194)
# R^2 (objective) value for Sample 'S561_D10': 0.999999996 (-13.48307)
# R^2 (objective) value for Sample 'S561_D23': 0.999999996 (-13.50546)
# R^2 (objective) value for Sample 'S561_D42': 0.999999996 (-14.34858)
# R^2 (objective) value for Sample 'S562_D10': 0.999999996 (-17.16008)
# R^2 (objective) value for Sample 'S562_D23': 0.999999996 (-16.49479)
# R^2 (objective) value for Sample 'S562_D42': 0.999999996 (-15.25101)
# R^2 (objective) value for Sample 'S563_D10': 0.999999996 (-15.40287)
# R^2 (objective) value for Sample 'S563_D23': 0.999999995 (-37.38238)
# R^2 (objective) value for Sample 'S563_D42': 0.999999997 (-15.85522)
# R^2 (objective) value for Sample 'S564_D10': 0.999999997 (-20.55463)
# R^2 (objective) value for Sample 'S564_D23': 0.999999997 (-20.46295)
# R^2 (objective) value for Sample 'S564_D42': 0.999999995 (-17.94974)
# R^2 (objective) value for Sample 'S565_D10': 0.999999996 (-17.88828)
# R^2 (objective) value for Sample 'S565_D23': 0.999999996 (-17.57877)
# R^2 (objective) value for Sample 'S565_D42': 0.999999996 (-16.96199)
# R^2 (objective) value for Sample 'S566_D10': 0.999999996 (-16.61533)
# R^2 (objective) value for Sample 'S566_D23': 0.999999997 (-14.42614)
# R^2 (objective) value for Sample 'S566_D42': 0.999999996 (-18.75059)
# R^2 (objective) value for Sample 'S567_D10': 0.999999996 (-15.45867)
# R^2 (objective) value for Sample 'S567_D23': 0.999999997 (-14.97836)
# R^2 (objective) value for Sample 'S567_D42': 0.999999996 (-14.22281)
# R^2 (objective) value for Sample 'S568_D10': 0.999999996 (-17.02815)
# R^2 (objective) value for Sample 'S568_D23': 0.999999997 (-10.81910)
# R^2 (objective) value for Sample 'S568_D42': 0.999999997 (-30.77841)
# R^2 (objective) value for Sample 'S569_D10': 0.999999997 (-11.76366)
# R^2 (objective) value for Sample 'S569_D23': 0.999999995 (-35.74602)
# R^2 (objective) value for Sample 'S569_D42': 0.999999996 (-14.73979)
# R^2 (objective) value for Sample 'S570_D10': 0.999999996 (-19.02836)
# R^2 (objective) value for Sample 'S570_D23': 0.999999996 (-19.73855)
# R^2 (objective) value for Sample 'S570_D42': 0.999999996 (-15.11433)
# R^2 (objective) value for Sample 'S571_D10': 0.999999996 (-15.60402)
# R^2 (objective) value for Sample 'S571_D23': 0.999999997 (-17.22650)
# R^2 (objective) value for Sample 'S571_D42': 0.999999997 (-15.56432)
# R^2 (objective) value for Sample 'S572_D10': 0.999999996 (-18.61819)
# R^2 (objective) value for Sample 'S572_D23': 0.999999996 (-23.84723)
# R^2 (objective) value for Sample 'S572_D42': 0.999999996 (-19.87325)
# R^2 (objective) value for Sample 'S573_D10': 0.999999996 (-21.88400)
# R^2 (objective) value for Sample 'S573_D23': 0.999999996 (-17.71534)
# R^2 (objective) value for Sample 'S573_D42': 0.999999996 (-20.32670)
# R^2 (objective) value for Sample 'S574_D10': 0.999999996 (-25.53526)
# R^2 (objective) value for Sample 'S574_D23': 0.999999996 (-25.85739)
# R^2 (objective) value for Sample 'S574_D42': 0.999999997 (-26.33099)
# R^2 (objective) value for Sample 'S575_D10': 0.999999996 (-21.52696)
# R^2 (objective) value for Sample 'S575_D23': 0.999999996 (-24.73615)
# R^2 (objective) value for Sample 'S575_D42': 0.999999996 (-18.27013)
# R^2 (objective) value for Sample 'S576_D10': 0.999999996 (-13.14349)
# R^2 (objective) value for Sample 'S576_D23': 0.999999997 (-17.62805)
# R^2 (objective) value for Sample 'S576_D42': 0.999999996 (-17.39434)
# R^2 (objective) value for Sample 'S577_D10': 0.999999996 (-21.51689)
# R^2 (objective) value for Sample 'S577_D23': 0.999999996 (-19.42658)
# R^2 (objective) value for Sample 'S577_D42': 0.999999996 (-25.91939)
# R^2 (objective) value for Sample 'S578_D10': 0.999999996 (-20.97865)
# R^2 (objective) value for Sample 'S578_D23': 0.999999996 (-19.79733)
# R^2 (objective) value for Sample 'S578_D42': 0.999999995 (-26.90862)
# R^2 (objective) value for Sample 'S579_D10': 0.999999996 (-14.58822)
# R^2 (objective) value for Sample 'S579_D23': 0.999999996 (-17.48223)
# R^2 (objective) value for Sample 'S579_D42': 0.999999996 (-14.19472)
# R^2 (objective) value for Sample 'S580_D10': 0.999999996 (-14.09941)
# R^2 (objective) value for Sample 'S580_D23': 0.999999996 (-13.47639)
# R^2 (objective) value for Sample 'S580_D42': 0.999999996 (-16.99496)
# R^2 (objective) value for Sample 'S581_D10': 0.999999996 (-19.71121)
# R^2 (objective) value for Sample 'S581_D23': 0.999999996 (-18.59750)
# R^2 (objective) value for Sample 'S581_D42': 0.999999996 (-19.06603)
# R^2 (objective) value for Sample 'S582_D10': 0.999999996 (-28.27981)
# R^2 (objective) value for Sample 'S582_D23': 0.999999995 (-28.43126)
# R^2 (objective) value for Sample 'S582_D42': 0.999999996 (-29.92623)
# R^2 (objective) value for Sample 'S583_D10': 0.999999997 (-18.32261)
# R^2 (objective) value for Sample 'S583_D23': 0.999999996 (-16.68998)
# R^2 (objective) value for Sample 'S583_D42': 0.999999996 (-13.53889)
# R^2 (objective) value for Sample 'S584_D10': 0.999999996 (-22.14957)
# R^2 (objective) value for Sample 'S584_D23': 0.999999996 (-29.83132)
# R^2 (objective) value for Sample 'S584_D42': 0.999999996 (-24.85992)
# R^2 (objective) value for Sample 'S585_D10': 0.999999996 (-17.36334)
# R^2 (objective) value for Sample 'S585_D23': 0.999999996 (-16.58072)
# R^2 (objective) value for Sample 'S585_D42': 0.999999997 (-16.40935)
# R^2 (objective) value for Sample 'S586_D10': 0.999999996 (-25.44460)
# R^2 (objective) value for Sample 'S586_D23': 0.999999996 (-19.90546)
# R^2 (objective) value for Sample 'S586_D42': 0.999999996 (-21.28608)
# R^2 (objective) value for Sample 'S587_D10': 0.999999996 (-13.04590)
# R^2 (objective) value for Sample 'S587_D23': 0.999999996 (-17.10109)
# R^2 (objective) value for Sample 'S587_D42': 0.999999996 (-13.97571)
# R^2 (objective) value for Sample 'S588_D10': 0.999999996 (-18.26244)
# R^2 (objective) value for Sample 'S588_D23': 0.999999996 (-14.70811)
# R^2 (objective) value for Sample 'S588_D42': 0.999999997 (-19.08311)
# R^2 (objective) value for Sample 'S589_D10': 0.999999996 (-19.99333)
# R^2 (objective) value for Sample 'S589_D23': 0.999999996 (-21.32944)
# R^2 (objective) value for Sample 'S589_D42': 0.999999996 (-25.37142)
# R^2 (objective) value for Sample 'S590_D10': 0.999999996 (-10.30464)
# R^2 (objective) value for Sample 'S590_D23': 0.999999996 (-28.28840)
# R^2 (objective) value for Sample 'S590_D42': 0.999999997 (-15.62760)
# R^2 (objective) value for Sample 'S591_D10': 0.999999996 (-16.34202)
# R^2 (objective) value for Sample 'S591_D23': 0.999999996 (-17.77645)
# R^2 (objective) value for Sample 'S591_D42': 0.999999996 (-18.21281)
# R^2 (objective) value for Sample 'S592_D10': 0.999999996 (-21.36588)
# R^2 (objective) value for Sample 'S592_D23': 0.999999996 (-22.81041)
# R^2 (objective) value for Sample 'S592_D42': 0.999999996 (-19.49957)
# R^2 (objective) value for Sample 'S593_D10': 0.999999995 (-21.45081)
# R^2 (objective) value for Sample 'S593_D23': 0.999999996 (-17.38131)
# R^2 (objective) value for Sample 'S593_D42': 0.999999995 (-17.75838)
# R^2 (objective) value for Sample 'S594_D10': 0.999999996 (-11.78421)
# R^2 (objective) value for Sample 'S594_D23': 0.999999996 (-13.37748)
# R^2 (objective) value for Sample 'S594_D42': 0.999999996 (-10.47183)
# R^2 (objective) value for Sample 'S595_D10': 0.999999996 (-17.09308)
# R^2 (objective) value for Sample 'S595_D23': 0.999999995 (-32.57610)
# R^2 (objective) value for Sample 'S595_D42': 0.999999996 (-12.76579)
# R^2 (objective) value for Sample 'S596_D10': 0.999999995 (-33.61069)
# R^2 (objective) value for Sample 'S596_D23': 0.999999996 (-13.05667)
# R^2 (objective) value for Sample 'S596_D42': 0.999999995 (-38.11094)
# R^2 (objective) value for Sample 'S597_D10': 0.999999996 (-11.68033)
# R^2 (objective) value for Sample 'S597_D23': 0.999999997 (-14.64341)
# R^2 (objective) value for Sample 'S597_D42': 0.999999997 (-12.71788)
# R^2 (objective) value for Sample 'S598_D10': 0.999999996 (-16.20352)
# R^2 (objective) value for Sample 'S598_D23': 0.999999996 (-15.16561)
# R^2 (objective) value for Sample 'S598_D42': 0.999999996 (-17.76569)
# R^2 (objective) value for Sample 'S599_D10': 0.999999996 (-36.52579)
# R^2 (objective) value for Sample 'S599_D23': 0.999999996 (-13.35860)
# R^2 (objective) value for Sample 'S599_D42': 0.999999996 (-39.34789)
# R^2 (objective) value for Sample 'S600_D10': 0.999999996 (-12.56437)
# R^2 (objective) value for Sample 'S600_D23': 0.999999996 (-37.90931)
# R^2 (objective) value for Sample 'S600_D42': 0.999999996 (-12.13937)
# R^2 (objective) value for Sample 'S601_D10': 0.999999995 (-36.69140)
# R^2 (objective) value for Sample 'S601_D23': 0.999999997 (-10.79792)
# R^2 (objective) value for Sample 'S601_D42': 0.999999996 (-18.76747)
# R^2 (objective) value for Sample 'S602_D10': 0.999999996 (-16.06257)
# R^2 (objective) value for Sample 'S602_D23': 0.999999996 (-21.39768)
# R^2 (objective) value for Sample 'S602_D42': 0.999999997 (-19.57531)
# R^2 (objective) value for Sample 'S603_D10': 0.999999996 (-17.90941)
# R^2 (objective) value for Sample 'S603_D23': 0.999999996 (-17.41106)
# R^2 (objective) value for Sample 'S603_D42': 0.999999996 (-18.22168)
# R^2 (objective) value for Sample 'S604_D10': 0.999999996 (-18.26648)
# R^2 (objective) value for Sample 'S604_D23': 0.999999995 (-30.06614)
# R^2 (objective) value for Sample 'S604_D42': 0.999999996 (-12.03645)
# R^2 (objective) value for Sample 'S605_D10': 0.999999996 (-18.99052)
# R^2 (objective) value for Sample 'S605_D23': 0.999999996 (-21.25180)
# R^2 (objective) value for Sample 'S605_D42': 0.999999996 (-20.04973)
# R^2 (objective) value for Sample 'S606_D10': 0.999999996 (-35.09495)
# R^2 (objective) value for Sample 'S606_D23': 0.999999996 (-16.82320)
# R^2 (objective) value for Sample 'S606_D42': 0.999999996 (-26.47487)
# R^2 (objective) value for Sample 'S607_D10': 0.999999997 (-13.65450)
# R^2 (objective) value for Sample 'S607_D23': 0.999999996 (-18.19627)
# R^2 (objective) value for Sample 'S607_D42': 0.999999996 (-11.00403)
# R^2 (objective) value for Sample 'S608_D10': 0.999999996 (-18.16473)
# R^2 (objective) value for Sample 'S608_D23': 0.999999996 (-16.90031)
# R^2 (objective) value for Sample 'S608_D42': 0.999999997 (-12.20923)
# R^2 (objective) value for Sample 'S609_D10': 0.999999996 (-28.68513)
# R^2 (objective) value for Sample 'S609_D23': 0.999999996 (-13.24391)
# R^2 (objective) value for Sample 'S609_D42': 0.999999997 (-10.80616)
# R^2 (objective) value for Sample 'S610_D10': 0.999999996 (-13.30054)
# R^2 (objective) value for Sample 'S610_D23': 0.999999995 (-31.36279)
# R^2 (objective) value for Sample 'S610_D42': 0.999999996 (-21.42865)
# R^2 (objective) value for Sample 'S611_D10': 0.999999996 (-19.11732)
# R^2 (objective) value for Sample 'S611_D23': 0.999999996 (-17.85199)
# R^2 (objective) value for Sample 'S611_D42': 0.999999996 (-10.69627)
# R^2 (objective) value for Sample 'S612_D10': 0.999999996 (-29.60771)
# R^2 (objective) value for Sample 'S612_D23': 0.999999996 (-16.43865)
# R^2 (objective) value for Sample 'S612_D42': 0.999999996 (-15.70925)
# R^2 (objective) value for Sample 'S613_D10': 0.999999996 (-19.90894)
# R^2 (objective) value for Sample 'S613_D23': 0.999999996 (-21.26948)
# R^2 (objective) value for Sample 'S613_D42': 0.999999996 (-14.79176)
# R^2 (objective) value for Sample 'S614_D10': 0.999999996 (-17.63499)
# R^2 (objective) value for Sample 'S614_D23': 0.999999996 (-24.24975)
# R^2 (objective) value for Sample 'S614_D42': 0.999999996 (-22.95597)
# R^2 (objective) value for Sample 'S615_D10': 0.999999996 (-18.68069)
# R^2 (objective) value for Sample 'S615_D23': 0.999999996 (-21.49466)
# R^2 (objective) value for Sample 'S615_D42': 0.999999996 (-17.96609)
# R^2 (objective) value for Sample 'S616_D10': 0.999999996 (-14.00282)
# R^2 (objective) value for Sample 'S616_D23': 0.999999997 (-19.01402)
# R^2 (objective) value for Sample 'S616_D42': 0.999999996 (-18.37344)
# R^2 (objective) value for Sample 'Mean_D10': 0.999999996 (-5512.45527)
# R^2 (objective) value for Sample 'Median_D10': 0.999999996 (-19.21975)
# R^2 (objective) value for Sample 'Mean_D23': 0.999999996 (-5656.77403)
# R^2 (objective) value for Sample 'Median_D23': 0.999999996 (-19.85911)
# R^2 (objective) value for Sample 'Mean_D42': 0.999999996 (-3490.71406)
# R^2 (objective) value for Sample 'Median_D42': 0.999999996 (-19.05531)
# Number of QP solutions: 1854

# %% [markdown]
# ### Plot fitting for the mean and median samples

# %%
samples_to_plot = np.array(
    [
        # Best for 1 or 3 columns
        [x for x in operation_ids if "Mean" in x],
        [x for x in operation_ids if "Median" in x],
    ]
)

r2_text_loc = "lower right"

length = 4
nrows, ncols = samples_to_plot.shape
fig, axes = plt.subplots(
    nrows=nrows,
    ncols=ncols,
    figsize=(length * ncols, length * nrows),
    sharex=True,
    sharey=True,
)
sns.despine(fig)

for idx, (sample_id, ax) in enumerate(zip(samples_to_plot.flatten(), axes.flatten())):
    df_qp_sol, r2, objective_value = qp_solutions_dict[sample_id]
    xlabel, ylabel = df_qp_sol.columns

    ticks = np.geomspace(1e-6, 1e6, 5)
    perfect_fit_line = ax.plot(
        [0, ticks[-1]],
        [0, ticks[-1]],
        linestyle=":",
        color="black",
        linewidth=1,
        alpha=1,
    )

    df_zeros = df_qp_sol[(df_qp_sol.apply(lambda x: np.isclose(x, 0))).any(axis=1)]
    df_perfect = df_qp_sol[
        np.isclose(
            abs(df_qp_sol["Measured Proteome"] - df_qp_sol["Best-Fitted Proteome"]), 0
        )
    ]
    df_perfect = df_perfect[~df_perfect.index.isin(df_zeros.index)]

    df_altered = df_qp_sol[
        ~np.isclose(
            abs(df_qp_sol["Measured Proteome"] - df_qp_sol["Best-Fitted Proteome"]), 0
        )
    ]
    df_altered = df_altered[~df_altered.index.isin(df_zeros.index)]
    df_always_zero = df_zeros[(df_zeros == 0).all(axis=1)]
    df_zeros = df_zeros[~df_zeros.index.isin(df_always_zero.index)]
    df_from_zeros = df_zeros[np.isclose(df_zeros["Measured Proteome"], 0)]
    df_to_zeros = df_zeros[np.isclose(df_zeros["Best-Fitted Proteome"], 0)]

    handles = [
        ax.scatter(
            data=df_perfect.replace(0, ticks[0]),
            x=xlabel,
            y=ylabel,
            color="xkcd:blue",
            alpha=0.5,
            edgecolors="black",
            linewidths=1,
        ),
        ax.scatter(
            data=df_altered.replace(0, ticks[0]),
            x=xlabel,
            y=ylabel,
            color="xkcd:yellow",
            alpha=0.5,
            edgecolors="black",
            linewidths=1,
        ),
        ax.scatter(
            data=df_from_zeros.replace(0, ticks[0]),
            x=xlabel,
            y=ylabel,
            color="xkcd:green",
            alpha=0.5,
            edgecolors="black",
            linewidths=1,
        ),
        ax.scatter(
            data=df_to_zeros.replace(0, ticks[0]),
            x=xlabel,
            y=ylabel,
            color="xkcd:red",
            alpha=0.5,
            edgecolors="black",
            linewidths=1,
        ),
        ax.scatter(
            data=df_always_zero.replace(0, ticks[0]),
            x=xlabel,
            y=ylabel,
            color="xkcd:black",
            alpha=0.5,
            edgecolors="black",
            linewidths=1,
        ),
    ]
    labels = [
        f"Perfect fit",
        f"Adjusted expression",
        f"Unexpressed to expressed",
        f"Expressed to unexpressed",
        f"Never expressed",
    ]

    donor, day = sample_id.split("_")
    if not ("Mean" == donor or "Median" == donor):
        donor = donor.replace("S", "; Donor ")
    day = day.replace("D", "Day ")
    fancy_sample_id = " ".join((day, donor))

    ax.set_xscale("log")
    ax.set_yscale("log")

    fontdict = {"size": "xx-large"}
    if idx == len(samples_to_plot.flatten()) - np.ceil(ncols / 2):
        ax.set_xlabel(xlabel, fontdict=fontdict)
    fig.legend(
        handles=handles,
        labels=labels,
        loc="lower center",
        ncols=len(labels),
        frameon=False,
        fontsize="large",
        markerscale=2,
        bbox_to_anchor=(0.5, -0.05),
    )
    if idx % ncols == 0:
        ax.set_ylabel(ylabel, fontdict=fontdict)

    ax.set_xticks(ticks)
    ax.set_yticks(ticks)

    ax.xaxis.set_tick_params(labelsize="x-large")
    ax.yaxis.set_tick_params(labelsize="x-large")

    r2_format = " = {:.4f}"
    if r2_text_loc == "lower right":
        ax.text(
            0.95,
            0.1,
            r"$R^{2}$" + r2_format.format(r2) + ("\n{}".format(fancy_sample_id)),
            transform=ax.transAxes,
            color="black",
            fontsize="large",
            ha="right",
        )
    elif r2_text_loc == "upper left":
        ax.text(
            0.05,
            0.9,
            ("{}\n".format(fancy_sample_id)) + r"$R^{2}$" + r2_format.format(r2),
            transform=ax.transAxes,
            color="black",
            fontsize="large",
            ha="left",
        )
    else:
        pass
fig.tight_layout()
if save_figures:
    fig.savefig(
        f"{results_path}/QPfitting_{model_id}.{imagetype}",
        transparent=transparent,
        format=imagetype,
    )

# %% [markdown]
# ### Determine best value for slack variables

# %%
list_of_pcmodels = []
verbose = True
objective_rxns = ["NaKt"]

df_relaxation_filename = results_path / f"SlackPercentDeterminationData_{model_id}.tsv"

slack_min = 1e-5  # Slack %
slack_max = 1.5
if run_computations:
    for sample_id in operation_ids:
        df_qp_sol, r2, objective_value = qp_solutions_dict[sample_id]
        # Create a copy of the model
        pcmodel_sample = pcmodel.copy()
        pcmodel_sample.id = f"{pcmodel.id}_{sample_id}"
        for protdl in pcmodel_sample.reactions.query(
            lambda x: isinstance(x, ProteinDilution)
        ):
            if protdl.id in df_qp_sol.index:
                prot_bound = df_qp_sol.loc[protdl.id]["Best-Fitted Proteome"]
            else:
                prot_bound = 0
            protdl.bounds = (float(prot_bound), float(prot_bound))
        # Add the relaxation budget with slack = 0 first
        add_relaxation_budget(pcmodel_sample, 0, verbose)
        list_of_pcmodels += [pcmodel_sample]

    solutions = {
        pcmodel_sample.id: {
            "model": [],
            "slack": [],
            "objective": [],
            "relaxation": [],
            "_".join(objective_rxns): [],
        }
        for pcmodel_sample in list_of_pcmodels
    }
    slack_min = 1e-5
    slack_max = 1.5
    for slack_value in np.geomspace(slack_min, slack_max, 251):
        print(f"Updating slack variable to {100 * slack_value:.4f}%.")
        for pcmodel_sample in list_of_pcmodels:
            update_slack_value(pcmodel_sample, slack_value, verbose=False)
            relaxation_demand = pcmodel_sample.reactions.get_by_id(
                f"PBDL_relaxation_budget"
            )
            pcmodel_sample.objective = (
                sum(
                    [
                        r.flux_expression
                        for r in pcmodel_sample.reactions.get_by_any(objective_rxns)
                    ]
                )
                - relaxation_demand.flux_expression
            )
            pcmodel_sample.objective_direction = "max"
            sol = pcmodel_sample.optimize()
            obj_value = sol.objective_value
            if not obj_value or np.isnan(obj_value):
                continue
            else:
                demand = relaxation_demand.flux
                budget = relaxation_demand.upper_bound
            solutions[pcmodel_sample.id]["model"].append(pcmodel_sample.id)
            solutions[pcmodel_sample.id]["slack"].append(slack_value)
            solutions[pcmodel_sample.id]["objective"].append(obj_value)
            solutions[pcmodel_sample.id]["_".join(objective_rxns)].append(
                obj_value + demand
            )
            solutions[pcmodel_sample.id]["relaxation"].append(demand / budget)
    solutions = {
        pcmodel_sample: pd.DataFrame.from_dict(sol)
        for pcmodel_sample, sol in solutions.items()
    }

    df_relaxation = pd.concat(list(solutions.values()), axis=0)
    df_relaxation.to_csv(
        # f"{results_path}/SlackPercentDeterminationData_{model_id}.tsv",
        df_relaxation_filename,
        sep="\t",
        index=False,
    )
else:
    df_relaxation = pd.read_csv(
        df_relaxation_filename, sep="\t"
    )
    solutions = {
        mid: df_relaxation[df_relaxation["model"] == mid].drop("model", axis=1)
        for mid in df_relaxation["model"].unique()
    }
df_relaxation
# Out:
# Relaxation budget added to RBC3P_PC_Mean_D10, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC3P_PC_Median_D10, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC3P_PC_Mean_D23, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC3P_PC_Median_D23, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC3P_PC_Mean_D42, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC3P_PC_Median_D42, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Updating slack variable to 0.0010%.
# Updating slack variable to 0.0010%.
# d:\Anaconda3\envs\RBC-GEM-akey7\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Updating slack variable to 0.0011%.
# Updating slack variable to 0.0012%.
# Updating slack variable to 0.0012%.
# Updating slack variable to 0.0013%.
# Updating slack variable to 0.0013%.
# Updating slack variable to 0.0014%.
# Updating slack variable to 0.0015%.
# Updating slack variable to 0.0015%.
# Updating slack variable to 0.0016%.
# Updating slack variable to 0.0017%.
# Updating slack variable to 0.0018%.
# Updating slack variable to 0.0019%.
# Updating slack variable to 0.0019%.
# Updating slack variable to 0.0020%.
# Updating slack variable to 0.0021%.
# Updating slack variable to 0.0022%.
# Updating slack variable to 0.0024%.
# Updating slack variable to 0.0025%.
# Updating slack variable to 0.0026%.
# Updating slack variable to 0.0027%.
# Updating slack variable to 0.0029%.
# Updating slack variable to 0.0030%.
# Updating slack variable to 0.0031%.
# Updating slack variable to 0.0033%.
# Updating slack variable to 0.0035%.
# Updating slack variable to 0.0036%.
# Updating slack variable to 0.0038%.
# Updating slack variable to 0.0040%.
# Updating slack variable to 0.0042%.
# Updating slack variable to 0.0044%.
# Updating slack variable to 0.0046%.
# Updating slack variable to 0.0048%.
# Updating slack variable to 0.0051%.
# Updating slack variable to 0.0053%.
# Updating slack variable to 0.0056%.
# Updating slack variable to 0.0058%.
# Updating slack variable to 0.0061%.
# Updating slack variable to 0.0064%.
# Updating slack variable to 0.0067%.
# Updating slack variable to 0.0071%.
# Updating slack variable to 0.0074%.
# Updating slack variable to 0.0078%.
# Updating slack variable to 0.0081%.
# Updating slack variable to 0.0085%.
# Updating slack variable to 0.0090%.
# Updating slack variable to 0.0094%.
# Updating slack variable to 0.0099%.
# Updating slack variable to 0.0103%.
# Updating slack variable to 0.0108%.
# Updating slack variable to 0.0114%.
# Updating slack variable to 0.0119%.
# Updating slack variable to 0.0125%.
# Updating slack variable to 0.0131%.
# Updating slack variable to 0.0138%.
# Updating slack variable to 0.0144%.
# Updating slack variable to 0.0151%.
# Updating slack variable to 0.0159%.
# Updating slack variable to 0.0167%.
# Updating slack variable to 0.0175%.
# Updating slack variable to 0.0183%.
# Updating slack variable to 0.0192%.
# Updating slack variable to 0.0202%.
# Updating slack variable to 0.0211%.
# Updating slack variable to 0.0222%.
# Updating slack variable to 0.0233%.
# Updating slack variable to 0.0244%.
# Updating slack variable to 0.0256%.
# Updating slack variable to 0.0268%.
# Updating slack variable to 0.0281%.
# Updating slack variable to 0.0295%.
# Updating slack variable to 0.0310%.
# Updating slack variable to 0.0325%.
# Updating slack variable to 0.0341%.
# Updating slack variable to 0.0357%.
# Updating slack variable to 0.0375%.
# Updating slack variable to 0.0393%.
# Updating slack variable to 0.0412%.
# Updating slack variable to 0.0432%.
# Updating slack variable to 0.0453%.
# Updating slack variable to 0.0475%.
# Updating slack variable to 0.0499%.
# Updating slack variable to 0.0523%.
# Updating slack variable to 0.0548%.
# Updating slack variable to 0.0575%.
# Updating slack variable to 0.0603%.
# Updating slack variable to 0.0633%.
# Updating slack variable to 0.0664%.
# Updating slack variable to 0.0696%.
# Updating slack variable to 0.0730%.
# Updating slack variable to 0.0766%.
# Updating slack variable to 0.0803%.
# Updating slack variable to 0.0842%.
# Updating slack variable to 0.0884%.
# Updating slack variable to 0.0927%.
# Updating slack variable to 0.0972%.
# Updating slack variable to 0.1019%.
# Updating slack variable to 0.1069%.
# Updating slack variable to 0.1121%.
# Updating slack variable to 0.1176%.
# Updating slack variable to 0.1234%.
# Updating slack variable to 0.1294%.
# Updating slack variable to 0.1357%.
# Updating slack variable to 0.1423%.
# Updating slack variable to 0.1493%.
# Updating slack variable to 0.1566%.
# Updating slack variable to 0.1642%.
# Updating slack variable to 0.1722%.
# Updating slack variable to 0.1806%.
# Updating slack variable to 0.1894%.
# Updating slack variable to 0.1987%.
# Updating slack variable to 0.2084%.
# Updating slack variable to 0.2186%.
# Updating slack variable to 0.2292%.
# Updating slack variable to 0.2404%.
# Updating slack variable to 0.2522%.
# Updating slack variable to 0.2645%.
# Updating slack variable to 0.2774%.
# Updating slack variable to 0.2910%.
# Updating slack variable to 0.3052%.
# Updating slack variable to 0.3201%.
# Updating slack variable to 0.3357%.
# Updating slack variable to 0.3521%.
# Updating slack variable to 0.3693%.
# Updating slack variable to 0.3873%.
# Updating slack variable to 0.4062%.
# Updating slack variable to 0.4260%.
# Updating slack variable to 0.4468%.
# Updating slack variable to 0.4687%.
# Updating slack variable to 0.4915%.
# Updating slack variable to 0.5156%.
# Updating slack variable to 0.5407%.
# Updating slack variable to 0.5671%.
# Updating slack variable to 0.5948%.
# Updating slack variable to 0.6239%.
# Updating slack variable to 0.6543%.
# Updating slack variable to 0.6863%.
# Updating slack variable to 0.7198%.
# Updating slack variable to 0.7549%.
# Updating slack variable to 0.7918%.
# Updating slack variable to 0.8305%.
# Updating slack variable to 0.8710%.
# Updating slack variable to 0.9135%.
# Updating slack variable to 0.9581%.
# Updating slack variable to 1.0049%.
# Updating slack variable to 1.0540%.
# Updating slack variable to 1.1055%.
# Updating slack variable to 1.1594%.
# Updating slack variable to 1.2160%.
# Updating slack variable to 1.2754%.
# Updating slack variable to 1.3377%.
# Updating slack variable to 1.4030%.
# Updating slack variable to 1.4715%.
# Updating slack variable to 1.5434%.
# Updating slack variable to 1.6187%.
# Updating slack variable to 1.6978%.
# Updating slack variable to 1.7807%.
# Updating slack variable to 1.8676%.
# Updating slack variable to 1.9588%.
# Updating slack variable to 2.0545%.
# Updating slack variable to 2.1548%.
# Updating slack variable to 2.2600%.
# Updating slack variable to 2.3703%.
# Updating slack variable to 2.4861%.
# Updating slack variable to 2.6075%.
# Updating slack variable to 2.7348%.
# Updating slack variable to 2.8683%.
# Updating slack variable to 3.0084%.
# Updating slack variable to 3.1553%.
# Updating slack variable to 3.3093%.
# Updating slack variable to 3.4709%.
# Updating slack variable to 3.6404%.
# Updating slack variable to 3.8182%.
# Updating slack variable to 4.0046%.
# Updating slack variable to 4.2001%.
# Updating slack variable to 4.4052%.
# Updating slack variable to 4.6203%.
# Updating slack variable to 4.8459%.
# Updating slack variable to 5.0825%.
# Updating slack variable to 5.3307%.
# Updating slack variable to 5.5910%.
# Updating slack variable to 5.8640%.
# Updating slack variable to 6.1503%.
# Updating slack variable to 6.4506%.
# Updating slack variable to 6.7656%.
# Updating slack variable to 7.0960%.
# Updating slack variable to 7.4425%.
# Updating slack variable to 7.8059%.
# Updating slack variable to 8.1870%.
# Updating slack variable to 8.5868%.
# Updating slack variable to 9.0060%.
# Updating slack variable to 9.4458%.
# Updating slack variable to 9.9070%.
# Updating slack variable to 10.3907%.
# Updating slack variable to 10.8981%.
# Updating slack variable to 11.4302%.
# Updating slack variable to 11.9884%.
# Updating slack variable to 12.5737%.
# Updating slack variable to 13.1877%.
# Updating slack variable to 13.8316%.
# Updating slack variable to 14.5070%.
# Updating slack variable to 15.2153%.
# Updating slack variable to 15.9583%.
# Updating slack variable to 16.7375%.
# Updating slack variable to 17.5548%.
# Updating slack variable to 18.4119%.
# Updating slack variable to 19.3109%.
# Updating slack variable to 20.2539%.
# Updating slack variable to 21.2428%.
# Updating slack variable to 22.2801%.
# Updating slack variable to 23.3680%.
# Updating slack variable to 24.5090%.
# Updating slack variable to 25.7057%.
# Updating slack variable to 26.9609%.
# Updating slack variable to 28.2773%.
# Updating slack variable to 29.6581%.
# Updating slack variable to 31.1062%.
# Updating slack variable to 32.6251%.
# Updating slack variable to 34.2181%.
# Updating slack variable to 35.8889%.
# Updating slack variable to 37.6413%.
# Updating slack variable to 39.4793%.
# Updating slack variable to 41.4070%.
# Updating slack variable to 43.4288%.
# Updating slack variable to 45.5493%.
# Updating slack variable to 47.7734%.
# Updating slack variable to 50.1061%.
# Updating slack variable to 52.5527%.
# Updating slack variable to 55.1188%.
# Updating slack variable to 57.8101%.
# Updating slack variable to 60.6329%.
# Updating slack variable to 63.5935%.
# Updating slack variable to 66.6987%.
# Updating slack variable to 69.9554%.
# Updating slack variable to 73.3712%.
# Updating slack variable to 76.9538%.
# Updating slack variable to 80.7113%.
# Updating slack variable to 84.6523%.
# Updating slack variable to 88.7857%.
# Updating slack variable to 93.1210%.
# Updating slack variable to 97.6679%.
# Updating slack variable to 102.4369%.
# Updating slack variable to 107.4387%.
# Updating slack variable to 112.6847%.
# Updating slack variable to 118.1869%.
# Updating slack variable to 123.9578%.
# Updating slack variable to 130.0104%.
# Updating slack variable to 136.3586%.
# Updating slack variable to 143.0167%.
# Updating slack variable to 150.0000%.
#                    model     slack  objective  relaxation      NaKt
# 0      RBC3P_PC_Mean_D10  0.004062  -0.014193    0.021188  0.068217
# 1      RBC3P_PC_Mean_D10  0.004260  -0.014047    0.020166  0.068217
# 2      RBC3P_PC_Mean_D10  0.004468  -0.013948    0.019204  0.068217
# 3      RBC3P_PC_Mean_D10  0.004687  -0.013840    0.018286  0.068217
# 4      RBC3P_PC_Mean_D10  0.004915  -0.013722    0.017409  0.068217
# ..                   ...       ...        ...         ...       ...
# 119  RBC3P_PC_Median_D42  1.239578   0.013828    0.000047  0.069666
# 120  RBC3P_PC_Median_D42  1.300104   0.013828    0.000045  0.069666
# 121  RBC3P_PC_Median_D42  1.363586   0.013828    0.000043  0.069666
# 122  RBC3P_PC_Median_D42  1.430167   0.013828    0.000041  0.069666
# 123  RBC3P_PC_Median_D42  1.500000   0.013828    0.000039  0.069666
#
# [747 rows x 5 columns]

# %%
fig, axes = plt.subplots(
    3, 1, figsize=(4, 10), sharex=True, gridspec_kw=dict(hspace=0.05)
)
axes = axes.flatten()

# ax3d = fig.add_subplot(2, 2, 4, projection="3d")
sns.despine(fig)

handles = []
labels = []
chosen_slack_var = 0.03
colors = {
    "D10": "xkcd:green",
    "D23": "xkcd:gold",
    "D42": "xkcd:red",
}
linestyles = {
    "Mean": "-",
    "Median": "-.",
}
use_percents = True
for pcmodel_sample in list(solutions):
    donor, day = str(pcmodel_sample).split("_")[-2:]
    linestyle = linestyles.get(donor, ":")
    color = colors.get(day, "xkcd:light blue")
    if not ("Mean" == donor or "Median" == donor):
        donor = donor.replace("S", "; Donor ")
    day = day.replace("D", "Day ")
    fancy_sample_id = " ".join((day, donor))

    labels.append(fancy_sample_id)
    s_values = solutions[str(pcmodel_sample)]["slack"].values
    r_values = solutions[str(pcmodel_sample)]["relaxation"].values * (
        100 if use_percents else 1
    )
    o_values = solutions[str(pcmodel_sample)]["objective"].values
    rxn_values = solutions[str(pcmodel_sample)]["_".join(objective_rxns)].values

    zorder = 1
    lw = 2
    axes[0].plot(
        s_values,
        r_values,
        label=str(pcmodel_sample),
        color=color,
        linestyle=linestyle,
        linewidth=lw,
        zorder=zorder,
    )
    axes[1].plot(
        s_values,
        o_values,
        label=str(pcmodel_sample),
        color=color,
        linestyle=linestyle,
        linewidth=lw,
        zorder=zorder,
    )
    axes[2].plot(
        s_values,
        rxn_values,
        label=str(pcmodel_sample),
        color=color,
        linestyle=linestyle,
        linewidth=lw,
        zorder=zorder,
    )

    # index = list(s_values).index(s_values[s_values >= chosen_slack_var][0])
    # spt = s_values[index]
    # rpt = r_values[index]
    # opt = o_values[index]
    # rxnpt = rxn_values[index]
    # c = "black"
    # ls = ""
    # marker = "o"
    # markersize = 8
    # axes[0].plot(spt, rpt, color=c, linestyle=ls, marker=marker, markersize=markersize)
    # axes[1].plot(spt, opt, color=c, linestyle=ls, marker=marker, markersize=markersize)
    # axes[2].plot(spt, rxnpt, color=c, linestyle=ls, marker=marker, markersize=markersize)
    # ax3d.plot(spt, rpt, opt, color=c, linestyle=ls, marker=marker, markersize=markersize)
    # print(f"Elbow point for {pcmodel_sample}: ({spt:.5f}, {rpt:.5f}, {opt:.5f})")
fontdict = {"size": "x-large"}
axes[-1].set_xlabel(r"Slack variable $s$", fontdict=fontdict)

i = 0
zorder = 2
alpha = 0.7
limit_pad_sclar = 1.2
ymin, ymax = (-0.001 * (100 if use_percents else 1), max(r_values) * limit_pad_sclar)
smin = s_values[list(o_values).index(o_values[o_values <= 0][0])]
axes[i].vlines(chosen_slack_var, ymin=ymin, ymax=ymax, color="black", linestyle=":")
axes[i].vlines(
    smin, ymin=ymin, ymax=ymax, color="black", linestyle="-", zorder=zorder, alpha=alpha
)
axes[i].vlines(
    1, ymin=ymin, ymax=ymax, color="black", linestyle="-", zorder=zorder, alpha=alpha
)
axes[i].set_xlim(smin / 2, slack_max)
axes[i].set_ylim(ymin, ymax)
axes[i].set_xscale("log")
axes[i].annotate(
    rf"$s = {chosen_slack_var}$",
    xy=(chosen_slack_var, 0),
    xycoords="data",
    xytext=(5, 0),
    textcoords="offset points",
    ha="left",
    fontsize=fontdict["size"],
)
axes[i].annotate(
    rf"$s > 0$",
    xy=(smin, ymax),
    xycoords="data",
    xytext=(10, 5),
    textcoords="offset points",
    ha="center",
    fontsize=fontdict["size"],
)
axes[i].annotate(
    rf"$s \leq 1$",
    xy=(1, ymax),
    xycoords="data",
    xytext=(10, 5),
    textcoords="offset points",
    ha="center",
    fontsize=fontdict["size"],
)
axes[i].fill_between((smin / 2, smin), ymin, ymax, color="xkcd:light grey")
axes[i].annotate(
    "Infeasible",
    xy=(smin, (ymax + ymin) / 2),
    xycoords="data",
    rotation=90,
    xytext=(-10, 0),
    textcoords="offset points",
    va="center",
    ha="right",
    fontsize=fontdict["size"],
)


i += 1
ymin, ymax = (min(o_values) * limit_pad_sclar, max(o_values) * limit_pad_sclar)
axes[i].vlines(chosen_slack_var, ymin=ymin, ymax=ymax, color="black", linestyle=":")
axes[i].vlines(
    smin, ymin=ymin, ymax=ymax, color="black", linestyle="-", zorder=zorder, alpha=alpha
)
axes[i].vlines(
    1, ymin=ymin, ymax=ymax, color="black", linestyle="-", zorder=zorder, alpha=alpha
)
axes[i].set_xlim(smin / 2, slack_max)
axes[i].set_ylim(ymin, ymax)
axes[i].set_xscale("log")
# axes[i].annotate(rf'$s = {chosen_slack_var}$', xy=(chosen_slack_var, 0), xycoords='data', xytext=(5, 0), textcoords='offset points',  ha="left", fontsize=fontdict["size"])
# axes[i].annotate(rf'$s > 0$', xy=(smin, ymax), xycoords='data', xytext=(10, 5), textcoords='offset points', ha="center", fontsize=fontdict["size"])
# axes[i].annotate(rf'$s \leq 1$', xy=(1, ymax), xycoords='data', xytext=(10, 5), textcoords='offset points', ha="center", fontsize=fontdict["size"])
axes[i].fill_between((smin / 2, smin), ymin, ymax, color="xkcd:light grey")
axes[i].annotate(
    "Infeasible",
    xy=(smin, (ymax + ymin) / 2),
    xycoords="data",
    rotation=90,
    xytext=(-10, 0),
    textcoords="offset points",
    va="center",
    ha="right",
    fontsize=fontdict["size"],
)

i += 1

ymin, ymax = (0, max(rxn_values) * limit_pad_sclar)
axes[i].vlines(chosen_slack_var, ymin=ymin, ymax=ymax, color="black", linestyle=":")
axes[i].vlines(
    smin, ymin=ymin, ymax=ymax, color="black", linestyle="-", zorder=zorder, alpha=alpha
)
axes[i].vlines(
    1, ymin=ymin, ymax=ymax, color="black", linestyle="-", zorder=zorder, alpha=alpha
)
axes[i].set_xlim(smin / 2, slack_max)
axes[i].set_ylim(ymin, ymax)
axes[i].set_xscale("log")
# axes[i].annotate(rf'$s = {chosen_slack_var}$', xy=(chosen_slack_var, 0), xycoords='data', xytext=(5, 0), textcoords='offset points',  ha="left", fontsize=fontdict["size"])
# axes[i].annotate(rf'$s > 0$', xy=(smin, ymax), xycoords='data', xytext=(10, 5), textcoords='offset points', ha="center", fontsize=fontdict["size"])
# axes[i].annotate(rf'$s \leq 1$', xy=(1, ymax), xycoords='data', xytext=(10, 5), textcoords='offset points', ha="center", fontsize=fontdict["size"])
axes[i].fill_between((smin / 2, smin), ymin, ymax, color="xkcd:light grey")
axes[i].annotate(
    "Infeasible",
    xy=(smin, (ymax + ymin) / 2),
    xycoords="data",
    rotation=90,
    xytext=(-10, 0),
    textcoords="offset points",
    va="center",
    ha="right",
    fontsize=fontdict["size"],
)

handles, labels = axes[2].get_legend_handles_labels()
handles_labels = dict(zip(labels, handles))
handles_labels = {
    k: handles_labels[k] for k in sorted(handles_labels, key=get_time_from_id)
}
handles, labels = (list(handles_labels.values()), list(handles_labels.keys()))
labels = [
    "Day " + " ".join(l.replace(f"{pcmodel.id}_", "").split("_")[::-1])[1:]
    for l in labels
]
axes[2].legend(
    handles=handles,
    labels=labels,
    ncols=1,
    frameon=False,
    loc="upper center",
    fontsize="large",
    bbox_to_anchor=(0.6, 0.7),
)


axes[0].set_ylabel("Relaxation budget used (%)", fontdict=fontdict)
axes[1].set_ylabel("Objective value", fontdict=fontdict)
axes[2].set_ylabel("NaKt (mmol/gDW/hr)", fontdict=fontdict)

fig.align_labels()
if save_figures:
    fig.savefig(
        f"{results_path}/SlackPercentDetermination_{model_id}.{imagetype}",
        transparent=transparent,
        format=imagetype,
    )

# %% [markdown]
# ### Formulate models from QP solutions

# %%
list_of_relaxed_models = []
slack_value = chosen_slack_var  # Slack %
verbose = True

# In our experience, SBML/XML loads faster, but will take up to 4x more space uncompressed as compared to JSON
ftypes = {
    "xml"
    # "json",
}

model_values = {}
dataset_models_dirpath.mkdir(exist_ok=True, parents=True)
ftypes = set([ftypes]) if isinstance(ftypes, str) else set(ftypes)
for sample_id, (df_qp_sol, r2, objective_value) in qp_solutions_dict.items():
    # Create a copy of the model
    sample_id = f"{pcmodel.id}_{sample_id}"
    filenames = [
        Path(f"{dataset_models_dirpath}/{sample_id}.{ftype}") for ftype in ftypes
    ]
    if all([filename.exists() for filename in filenames]):
        print(f"Model already created for {sample_id}")
        continue
    pcmodel_sample = pcmodel.copy()
    pcmodel_sample.id = sample_id
    for protdl in pcmodel_sample.reactions.query(
        lambda x: isinstance(x, ProteinDilution)
    ):
        if protdl.id in df_qp_sol.index:
            prot_bound = df_qp_sol.loc[protdl.id]["Best-Fitted Proteome"]
        else:
            prot_bound = 0
        protdl.bounds = (float(prot_bound), float(prot_bound))
    # Add the relaxation budget
    add_relaxation_budget(pcmodel_sample, slack_value, verbose)
    # # Store model for later use
    # list_of_relaxed_models += [pcmodel_sample]
    for filename in filenames:
        # Might as well overwrite all files, especially if model needed to be regenerated anyways
        write_cobra_model(
            pcmodel_sample,
            filename=filename,
        )
# Out:
# Model already created for RBC3P_PC_S1_D10
# Model already created for RBC3P_PC_S1_D23
# Model already created for RBC3P_PC_S1_D42
# Model already created for RBC3P_PC_S2_D10
# Model already created for RBC3P_PC_S2_D23
# Model already created for RBC3P_PC_S2_D42
# Model already created for RBC3P_PC_S3_D10
# Model already created for RBC3P_PC_S3_D23
# Model already created for RBC3P_PC_S3_D42
# Model already created for RBC3P_PC_S4_D10
# Model already created for RBC3P_PC_S4_D23
# Model already created for RBC3P_PC_S4_D42
# Model already created for RBC3P_PC_S5_D10
# Model already created for RBC3P_PC_S5_D23
# Model already created for RBC3P_PC_S5_D42
# Model already created for RBC3P_PC_S6_D10
# Model already created for RBC3P_PC_S6_D23
# Model already created for RBC3P_PC_S6_D42
# Model already created for RBC3P_PC_S7_D10
# Model already created for RBC3P_PC_S7_D23
# Model already created for RBC3P_PC_S7_D42
# Model already created for RBC3P_PC_S8_D10
# Model already created for RBC3P_PC_S8_D23
# Model already created for RBC3P_PC_S8_D42
# Model already created for RBC3P_PC_S9_D10
# Model already created for RBC3P_PC_S9_D23
# Model already created for RBC3P_PC_S9_D42
# Model already created for RBC3P_PC_S10_D10
# Model already created for RBC3P_PC_S10_D23
# Model already created for RBC3P_PC_S10_D42
# Model already created for RBC3P_PC_S11_D10
# Model already created for RBC3P_PC_S11_D23
# Model already created for RBC3P_PC_S11_D42
# Model already created for RBC3P_PC_S12_D10
# Model already created for RBC3P_PC_S12_D23
# Model already created for RBC3P_PC_S12_D42
# Model already created for RBC3P_PC_S13_D10
# Model already created for RBC3P_PC_S13_D23
# Model already created for RBC3P_PC_S13_D42
# Model already created for RBC3P_PC_S14_D10
# Model already created for RBC3P_PC_S14_D23
# Model already created for RBC3P_PC_S14_D42
# Model already created for RBC3P_PC_S15_D10
# Model already created for RBC3P_PC_S15_D23
# Model already created for RBC3P_PC_S15_D42
# Model already created for RBC3P_PC_S16_D10
# Model already created for RBC3P_PC_S16_D23
# Model already created for RBC3P_PC_S16_D42
# Model already created for RBC3P_PC_S17_D10
# Model already created for RBC3P_PC_S17_D23
# Model already created for RBC3P_PC_S17_D42
# Model already created for RBC3P_PC_S18_D10
# Model already created for RBC3P_PC_S18_D23
# Model already created for RBC3P_PC_S18_D42
# Model already created for RBC3P_PC_S19_D10
# Model already created for RBC3P_PC_S19_D23
# Model already created for RBC3P_PC_S19_D42
# Model already created for RBC3P_PC_S20_D10
# Model already created for RBC3P_PC_S20_D23
# Model already created for RBC3P_PC_S20_D42
# Model already created for RBC3P_PC_S21_D10
# Model already created for RBC3P_PC_S21_D23
# Model already created for RBC3P_PC_S21_D42
# Model already created for RBC3P_PC_S22_D10
# Model already created for RBC3P_PC_S22_D23
# Model already created for RBC3P_PC_S22_D42
# Model already created for RBC3P_PC_S23_D10
# Model already created for RBC3P_PC_S23_D23
# Model already created for RBC3P_PC_S23_D42
# Model already created for RBC3P_PC_S24_D10
# Model already created for RBC3P_PC_S24_D23
# Model already created for RBC3P_PC_S24_D42
# Model already created for RBC3P_PC_S25_D10
# Model already created for RBC3P_PC_S25_D23
# Model already created for RBC3P_PC_S25_D42
# Model already created for RBC3P_PC_S26_D10
# Model already created for RBC3P_PC_S26_D23
# Model already created for RBC3P_PC_S26_D42
# Model already created for RBC3P_PC_S27_D10
# Model already created for RBC3P_PC_S27_D23
# Model already created for RBC3P_PC_S27_D42
# Model already created for RBC3P_PC_S28_D10
# Model already created for RBC3P_PC_S28_D23
# Model already created for RBC3P_PC_S28_D42
# Model already created for RBC3P_PC_S29_D10
# Model already created for RBC3P_PC_S29_D23
# Model already created for RBC3P_PC_S29_D42
# Model already created for RBC3P_PC_S30_D10
# Model already created for RBC3P_PC_S30_D23
# Model already created for RBC3P_PC_S30_D42
# Model already created for RBC3P_PC_S31_D10
# Model already created for RBC3P_PC_S31_D23
# Model already created for RBC3P_PC_S31_D42
# Model already created for RBC3P_PC_S32_D10
# Model already created for RBC3P_PC_S32_D23
# Model already created for RBC3P_PC_S32_D42
# Model already created for RBC3P_PC_S33_D10
# Model already created for RBC3P_PC_S33_D23
# Model already created for RBC3P_PC_S33_D42
# Model already created for RBC3P_PC_S34_D10
# Model already created for RBC3P_PC_S34_D23
# Model already created for RBC3P_PC_S34_D42
# Model already created for RBC3P_PC_S35_D10
# Model already created for RBC3P_PC_S35_D23
# Model already created for RBC3P_PC_S35_D42
# Model already created for RBC3P_PC_S36_D10
# Model already created for RBC3P_PC_S36_D23
# Model already created for RBC3P_PC_S36_D42
# Model already created for RBC3P_PC_S37_D10
# Model already created for RBC3P_PC_S37_D23
# Model already created for RBC3P_PC_S37_D42
# Model already created for RBC3P_PC_S38_D10
# Model already created for RBC3P_PC_S38_D23
# Model already created for RBC3P_PC_S38_D42
# Model already created for RBC3P_PC_S39_D10
# Model already created for RBC3P_PC_S39_D23
# Model already created for RBC3P_PC_S39_D42
# Model already created for RBC3P_PC_S40_D10
# Model already created for RBC3P_PC_S40_D23
# Model already created for RBC3P_PC_S40_D42
# Model already created for RBC3P_PC_S41_D10
# Model already created for RBC3P_PC_S41_D23
# Model already created for RBC3P_PC_S41_D42
# Model already created for RBC3P_PC_S42_D10
# Model already created for RBC3P_PC_S42_D23
# Model already created for RBC3P_PC_S42_D42
# Model already created for RBC3P_PC_S43_D10
# Model already created for RBC3P_PC_S43_D23
# Model already created for RBC3P_PC_S43_D42
# Model already created for RBC3P_PC_S44_D10
# Model already created for RBC3P_PC_S44_D23
# Model already created for RBC3P_PC_S44_D42
# Model already created for RBC3P_PC_S45_D10
# Model already created for RBC3P_PC_S45_D23
# Model already created for RBC3P_PC_S45_D42
# Model already created for RBC3P_PC_S46_D10
# Model already created for RBC3P_PC_S46_D23
# Model already created for RBC3P_PC_S46_D42
# Model already created for RBC3P_PC_S47_D10
# Model already created for RBC3P_PC_S47_D23
# Model already created for RBC3P_PC_S47_D42
# Model already created for RBC3P_PC_S48_D10
# Model already created for RBC3P_PC_S48_D23
# Model already created for RBC3P_PC_S48_D42
# Model already created for RBC3P_PC_S49_D10
# Model already created for RBC3P_PC_S49_D23
# Model already created for RBC3P_PC_S49_D42
# Model already created for RBC3P_PC_S50_D10
# Model already created for RBC3P_PC_S50_D23
# Model already created for RBC3P_PC_S50_D42
# Model already created for RBC3P_PC_S51_D10
# Model already created for RBC3P_PC_S51_D23
# Model already created for RBC3P_PC_S51_D42
# Model already created for RBC3P_PC_S52_D10
# Model already created for RBC3P_PC_S52_D23
# Model already created for RBC3P_PC_S52_D42
# Model already created for RBC3P_PC_S53_D10
# Model already created for RBC3P_PC_S53_D23
# Model already created for RBC3P_PC_S53_D42
# Model already created for RBC3P_PC_S54_D10
# Model already created for RBC3P_PC_S54_D23
# Model already created for RBC3P_PC_S54_D42
# Model already created for RBC3P_PC_S55_D10
# Model already created for RBC3P_PC_S55_D23
# Model already created for RBC3P_PC_S55_D42
# Model already created for RBC3P_PC_S56_D10
# Model already created for RBC3P_PC_S56_D23
# Model already created for RBC3P_PC_S56_D42
# Model already created for RBC3P_PC_S57_D10
# Model already created for RBC3P_PC_S57_D23
# Model already created for RBC3P_PC_S57_D42
# Model already created for RBC3P_PC_S58_D10
# Model already created for RBC3P_PC_S58_D23
# Model already created for RBC3P_PC_S58_D42
# Model already created for RBC3P_PC_S59_D10
# Model already created for RBC3P_PC_S59_D23
# Model already created for RBC3P_PC_S59_D42
# Model already created for RBC3P_PC_S60_D10
# Model already created for RBC3P_PC_S60_D23
# Model already created for RBC3P_PC_S60_D42
# Model already created for RBC3P_PC_S61_D10
# Model already created for RBC3P_PC_S61_D23
# Model already created for RBC3P_PC_S61_D42
# Model already created for RBC3P_PC_S62_D10
# Model already created for RBC3P_PC_S62_D23
# Model already created for RBC3P_PC_S62_D42
# Model already created for RBC3P_PC_S63_D10
# Model already created for RBC3P_PC_S63_D23
# Model already created for RBC3P_PC_S63_D42
# Model already created for RBC3P_PC_S64_D10
# Model already created for RBC3P_PC_S64_D23
# Model already created for RBC3P_PC_S64_D42
# Model already created for RBC3P_PC_S65_D10
# Model already created for RBC3P_PC_S65_D23
# Model already created for RBC3P_PC_S65_D42
# Model already created for RBC3P_PC_S66_D10
# Model already created for RBC3P_PC_S66_D23
# Model already created for RBC3P_PC_S66_D42
# Model already created for RBC3P_PC_S67_D10
# Model already created for RBC3P_PC_S67_D23
# Model already created for RBC3P_PC_S67_D42
# Model already created for RBC3P_PC_S68_D10
# Model already created for RBC3P_PC_S68_D23
# Model already created for RBC3P_PC_S68_D42
# Model already created for RBC3P_PC_S69_D10
# Model already created for RBC3P_PC_S69_D23
# Model already created for RBC3P_PC_S69_D42
# Model already created for RBC3P_PC_S70_D10
# Model already created for RBC3P_PC_S70_D23
# Model already created for RBC3P_PC_S70_D42
# Model already created for RBC3P_PC_S71_D10
# Model already created for RBC3P_PC_S71_D23
# Model already created for RBC3P_PC_S71_D42
# Model already created for RBC3P_PC_S72_D10
# Model already created for RBC3P_PC_S72_D23
# Model already created for RBC3P_PC_S72_D42
# Model already created for RBC3P_PC_S73_D10
# Model already created for RBC3P_PC_S73_D23
# Model already created for RBC3P_PC_S73_D42
# Model already created for RBC3P_PC_S74_D10
# Model already created for RBC3P_PC_S74_D23
# Model already created for RBC3P_PC_S74_D42
# Model already created for RBC3P_PC_S75_D10
# Model already created for RBC3P_PC_S75_D23
# Model already created for RBC3P_PC_S75_D42
# Model already created for RBC3P_PC_S76_D10
# Model already created for RBC3P_PC_S76_D23
# Model already created for RBC3P_PC_S76_D42
# Model already created for RBC3P_PC_S77_D10
# Model already created for RBC3P_PC_S77_D23
# Model already created for RBC3P_PC_S77_D42
# Model already created for RBC3P_PC_S78_D10
# Model already created for RBC3P_PC_S78_D23
# Model already created for RBC3P_PC_S78_D42
# Model already created for RBC3P_PC_S79_D10
# Model already created for RBC3P_PC_S79_D23
# Model already created for RBC3P_PC_S79_D42
# Model already created for RBC3P_PC_S80_D10
# Model already created for RBC3P_PC_S80_D23
# Model already created for RBC3P_PC_S80_D42
# Model already created for RBC3P_PC_S81_D10
# Model already created for RBC3P_PC_S81_D23
# Model already created for RBC3P_PC_S81_D42
# Model already created for RBC3P_PC_S82_D10
# Model already created for RBC3P_PC_S82_D23
# Model already created for RBC3P_PC_S82_D42
# Model already created for RBC3P_PC_S83_D10
# Model already created for RBC3P_PC_S83_D23
# Model already created for RBC3P_PC_S83_D42
# Model already created for RBC3P_PC_S84_D10
# Model already created for RBC3P_PC_S84_D23
# Model already created for RBC3P_PC_S84_D42
# Model already created for RBC3P_PC_S85_D10
# Model already created for RBC3P_PC_S85_D23
# Model already created for RBC3P_PC_S85_D42
# Model already created for RBC3P_PC_S86_D10
# Model already created for RBC3P_PC_S86_D23
# Model already created for RBC3P_PC_S86_D42
# Model already created for RBC3P_PC_S87_D10
# Model already created for RBC3P_PC_S87_D23
# Model already created for RBC3P_PC_S87_D42
# Model already created for RBC3P_PC_S88_D10
# Model already created for RBC3P_PC_S88_D23
# Model already created for RBC3P_PC_S88_D42
# Model already created for RBC3P_PC_S89_D10
# Model already created for RBC3P_PC_S89_D23
# Model already created for RBC3P_PC_S89_D42
# Model already created for RBC3P_PC_S90_D10
# Model already created for RBC3P_PC_S90_D23
# Model already created for RBC3P_PC_S90_D42
# Model already created for RBC3P_PC_S91_D10
# Model already created for RBC3P_PC_S91_D23
# Model already created for RBC3P_PC_S91_D42
# Model already created for RBC3P_PC_S92_D10
# Model already created for RBC3P_PC_S92_D23
# Model already created for RBC3P_PC_S92_D42
# Model already created for RBC3P_PC_S93_D10
# Model already created for RBC3P_PC_S93_D23
# Model already created for RBC3P_PC_S93_D42
# Model already created for RBC3P_PC_S94_D10
# Model already created for RBC3P_PC_S94_D23
# Model already created for RBC3P_PC_S94_D42
# Model already created for RBC3P_PC_S95_D10
# Model already created for RBC3P_PC_S95_D23
# Model already created for RBC3P_PC_S95_D42
# Model already created for RBC3P_PC_S96_D10
# Model already created for RBC3P_PC_S96_D23
# Model already created for RBC3P_PC_S96_D42
# Model already created for RBC3P_PC_S97_D10
# Model already created for RBC3P_PC_S97_D23
# Model already created for RBC3P_PC_S97_D42
# Model already created for RBC3P_PC_S98_D10
# Model already created for RBC3P_PC_S98_D23
# Model already created for RBC3P_PC_S98_D42
# Model already created for RBC3P_PC_S99_D10
# Model already created for RBC3P_PC_S99_D23
# Model already created for RBC3P_PC_S99_D42
# Model already created for RBC3P_PC_S100_D10
# Model already created for RBC3P_PC_S100_D23
# Model already created for RBC3P_PC_S100_D42
# Model already created for RBC3P_PC_S101_D10
# Model already created for RBC3P_PC_S101_D23
# Model already created for RBC3P_PC_S101_D42
# Model already created for RBC3P_PC_S102_D10
# Model already created for RBC3P_PC_S102_D23
# Model already created for RBC3P_PC_S102_D42
# Model already created for RBC3P_PC_S103_D10
# Model already created for RBC3P_PC_S103_D23
# Model already created for RBC3P_PC_S103_D42
# Model already created for RBC3P_PC_S104_D10
# Model already created for RBC3P_PC_S104_D23
# Model already created for RBC3P_PC_S104_D42
# Model already created for RBC3P_PC_S105_D10
# Model already created for RBC3P_PC_S105_D23
# Model already created for RBC3P_PC_S105_D42
# Model already created for RBC3P_PC_S106_D10
# Model already created for RBC3P_PC_S106_D23
# Model already created for RBC3P_PC_S106_D42
# Model already created for RBC3P_PC_S107_D10
# Model already created for RBC3P_PC_S107_D23
# Model already created for RBC3P_PC_S107_D42
# Model already created for RBC3P_PC_S108_D10
# Model already created for RBC3P_PC_S108_D23
# Model already created for RBC3P_PC_S108_D42
# Model already created for RBC3P_PC_S109_D10
# Model already created for RBC3P_PC_S109_D23
# Model already created for RBC3P_PC_S109_D42
# Model already created for RBC3P_PC_S110_D10
# Model already created for RBC3P_PC_S110_D23
# Model already created for RBC3P_PC_S110_D42
# Model already created for RBC3P_PC_S111_D10
# Model already created for RBC3P_PC_S111_D23
# Model already created for RBC3P_PC_S111_D42
# Model already created for RBC3P_PC_S112_D10
# Model already created for RBC3P_PC_S112_D23
# Model already created for RBC3P_PC_S112_D42
# Model already created for RBC3P_PC_S113_D10
# Model already created for RBC3P_PC_S113_D23
# Model already created for RBC3P_PC_S113_D42
# Model already created for RBC3P_PC_S114_D10
# Model already created for RBC3P_PC_S114_D23
# Model already created for RBC3P_PC_S114_D42
# Model already created for RBC3P_PC_S115_D10
# Model already created for RBC3P_PC_S115_D23
# Model already created for RBC3P_PC_S115_D42
# Model already created for RBC3P_PC_S116_D10
# Model already created for RBC3P_PC_S116_D23
# Model already created for RBC3P_PC_S116_D42
# Model already created for RBC3P_PC_S117_D10
# Model already created for RBC3P_PC_S117_D23
# Model already created for RBC3P_PC_S117_D42
# Model already created for RBC3P_PC_S118_D10
# Model already created for RBC3P_PC_S118_D23
# Model already created for RBC3P_PC_S118_D42
# Model already created for RBC3P_PC_S119_D10
# Model already created for RBC3P_PC_S119_D23
# Model already created for RBC3P_PC_S119_D42
# Model already created for RBC3P_PC_S120_D10
# Model already created for RBC3P_PC_S120_D23
# Model already created for RBC3P_PC_S120_D42
# Model already created for RBC3P_PC_S121_D10
# Model already created for RBC3P_PC_S121_D23
# Model already created for RBC3P_PC_S121_D42
# Model already created for RBC3P_PC_S122_D10
# Model already created for RBC3P_PC_S122_D23
# Model already created for RBC3P_PC_S122_D42
# Model already created for RBC3P_PC_S123_D10
# Model already created for RBC3P_PC_S123_D23
# Model already created for RBC3P_PC_S123_D42
# Model already created for RBC3P_PC_S124_D10
# Model already created for RBC3P_PC_S124_D23
# Model already created for RBC3P_PC_S124_D42
# Model already created for RBC3P_PC_S125_D10
# Model already created for RBC3P_PC_S125_D23
# Model already created for RBC3P_PC_S125_D42
# Model already created for RBC3P_PC_S126_D10
# Model already created for RBC3P_PC_S126_D23
# Model already created for RBC3P_PC_S126_D42
# Model already created for RBC3P_PC_S127_D10
# Model already created for RBC3P_PC_S127_D23
# Model already created for RBC3P_PC_S127_D42
# Model already created for RBC3P_PC_S128_D10
# Model already created for RBC3P_PC_S128_D23
# Model already created for RBC3P_PC_S128_D42
# Model already created for RBC3P_PC_S129_D10
# Model already created for RBC3P_PC_S129_D23
# Model already created for RBC3P_PC_S129_D42
# Model already created for RBC3P_PC_S130_D10
# Model already created for RBC3P_PC_S130_D23
# Model already created for RBC3P_PC_S130_D42
# Model already created for RBC3P_PC_S131_D10
# Model already created for RBC3P_PC_S131_D23
# Model already created for RBC3P_PC_S131_D42
# Model already created for RBC3P_PC_S132_D10
# Model already created for RBC3P_PC_S132_D23
# Model already created for RBC3P_PC_S132_D42
# Model already created for RBC3P_PC_S133_D10
# Model already created for RBC3P_PC_S133_D23
# Model already created for RBC3P_PC_S133_D42
# Model already created for RBC3P_PC_S134_D10
# Model already created for RBC3P_PC_S134_D23
# Model already created for RBC3P_PC_S134_D42
# Model already created for RBC3P_PC_S135_D10
# Model already created for RBC3P_PC_S135_D23
# Model already created for RBC3P_PC_S135_D42
# Model already created for RBC3P_PC_S136_D10
# Model already created for RBC3P_PC_S136_D23
# Model already created for RBC3P_PC_S136_D42
# Model already created for RBC3P_PC_S137_D10
# Model already created for RBC3P_PC_S137_D23
# Model already created for RBC3P_PC_S137_D42
# Model already created for RBC3P_PC_S138_D10
# Model already created for RBC3P_PC_S138_D23
# Model already created for RBC3P_PC_S138_D42
# Model already created for RBC3P_PC_S139_D10
# Model already created for RBC3P_PC_S139_D23
# Model already created for RBC3P_PC_S139_D42
# Model already created for RBC3P_PC_S140_D10
# Model already created for RBC3P_PC_S140_D23
# Model already created for RBC3P_PC_S140_D42
# Model already created for RBC3P_PC_S141_D10
# Model already created for RBC3P_PC_S141_D23
# Model already created for RBC3P_PC_S141_D42
# Model already created for RBC3P_PC_S142_D10
# Model already created for RBC3P_PC_S142_D23
# Model already created for RBC3P_PC_S142_D42
# Model already created for RBC3P_PC_S143_D10
# Model already created for RBC3P_PC_S143_D23
# Model already created for RBC3P_PC_S143_D42
# Model already created for RBC3P_PC_S144_D10
# Model already created for RBC3P_PC_S144_D23
# Model already created for RBC3P_PC_S144_D42
# Model already created for RBC3P_PC_S145_D10
# Model already created for RBC3P_PC_S145_D23
# Model already created for RBC3P_PC_S145_D42
# Model already created for RBC3P_PC_S146_D10
# Model already created for RBC3P_PC_S146_D23
# Model already created for RBC3P_PC_S146_D42
# Model already created for RBC3P_PC_S147_D10
# Model already created for RBC3P_PC_S147_D23
# Model already created for RBC3P_PC_S147_D42
# Model already created for RBC3P_PC_S148_D10
# Model already created for RBC3P_PC_S148_D23
# Model already created for RBC3P_PC_S148_D42
# Model already created for RBC3P_PC_S149_D10
# Model already created for RBC3P_PC_S149_D23
# Model already created for RBC3P_PC_S149_D42
# Model already created for RBC3P_PC_S150_D10
# Model already created for RBC3P_PC_S150_D23
# Model already created for RBC3P_PC_S150_D42
# Model already created for RBC3P_PC_S151_D10
# Model already created for RBC3P_PC_S151_D23
# Model already created for RBC3P_PC_S151_D42
# Model already created for RBC3P_PC_S152_D10
# Model already created for RBC3P_PC_S152_D23
# Model already created for RBC3P_PC_S152_D42
# Model already created for RBC3P_PC_S153_D10
# Model already created for RBC3P_PC_S153_D23
# Model already created for RBC3P_PC_S153_D42
# Model already created for RBC3P_PC_S154_D10
# Model already created for RBC3P_PC_S154_D23
# Model already created for RBC3P_PC_S154_D42
# Model already created for RBC3P_PC_S155_D10
# Model already created for RBC3P_PC_S155_D23
# Model already created for RBC3P_PC_S155_D42
# Model already created for RBC3P_PC_S156_D10
# Model already created for RBC3P_PC_S156_D23
# Model already created for RBC3P_PC_S156_D42
# Model already created for RBC3P_PC_S157_D10
# Model already created for RBC3P_PC_S157_D23
# Model already created for RBC3P_PC_S157_D42
# Model already created for RBC3P_PC_S158_D10
# Model already created for RBC3P_PC_S158_D23
# Model already created for RBC3P_PC_S158_D42
# Model already created for RBC3P_PC_S159_D10
# Model already created for RBC3P_PC_S159_D23
# Model already created for RBC3P_PC_S159_D42
# Model already created for RBC3P_PC_S160_D10
# Model already created for RBC3P_PC_S160_D23
# Model already created for RBC3P_PC_S160_D42
# Model already created for RBC3P_PC_S161_D10
# Model already created for RBC3P_PC_S161_D23
# Model already created for RBC3P_PC_S161_D42
# Model already created for RBC3P_PC_S162_D10
# Model already created for RBC3P_PC_S162_D23
# Model already created for RBC3P_PC_S162_D42
# Model already created for RBC3P_PC_S163_D10
# Model already created for RBC3P_PC_S163_D23
# Model already created for RBC3P_PC_S163_D42
# Model already created for RBC3P_PC_S164_D10
# Model already created for RBC3P_PC_S164_D23
# Model already created for RBC3P_PC_S164_D42
# Model already created for RBC3P_PC_S165_D10
# Model already created for RBC3P_PC_S165_D23
# Model already created for RBC3P_PC_S165_D42
# Model already created for RBC3P_PC_S166_D10
# Model already created for RBC3P_PC_S166_D23
# Model already created for RBC3P_PC_S166_D42
# Model already created for RBC3P_PC_S167_D10
# Model already created for RBC3P_PC_S167_D23
# Model already created for RBC3P_PC_S167_D42
# Model already created for RBC3P_PC_S168_D10
# Model already created for RBC3P_PC_S168_D23
# Model already created for RBC3P_PC_S168_D42
# Model already created for RBC3P_PC_S169_D10
# Model already created for RBC3P_PC_S169_D23
# Model already created for RBC3P_PC_S169_D42
# Model already created for RBC3P_PC_S170_D10
# Model already created for RBC3P_PC_S170_D23
# Model already created for RBC3P_PC_S170_D42
# Model already created for RBC3P_PC_S171_D10
# Model already created for RBC3P_PC_S171_D23
# Model already created for RBC3P_PC_S171_D42
# Model already created for RBC3P_PC_S172_D10
# Model already created for RBC3P_PC_S172_D23
# Model already created for RBC3P_PC_S172_D42
# Model already created for RBC3P_PC_S173_D10
# Model already created for RBC3P_PC_S173_D23
# Model already created for RBC3P_PC_S173_D42
# Model already created for RBC3P_PC_S174_D10
# Model already created for RBC3P_PC_S174_D23
# Model already created for RBC3P_PC_S174_D42
# Model already created for RBC3P_PC_S175_D10
# Model already created for RBC3P_PC_S175_D23
# Model already created for RBC3P_PC_S175_D42
# Model already created for RBC3P_PC_S176_D10
# Model already created for RBC3P_PC_S176_D23
# Model already created for RBC3P_PC_S176_D42
# Model already created for RBC3P_PC_S177_D10
# Model already created for RBC3P_PC_S177_D23
# Model already created for RBC3P_PC_S177_D42
# Model already created for RBC3P_PC_S178_D10
# Model already created for RBC3P_PC_S178_D23
# Model already created for RBC3P_PC_S178_D42
# Model already created for RBC3P_PC_S179_D10
# Model already created for RBC3P_PC_S179_D23
# Model already created for RBC3P_PC_S179_D42
# Model already created for RBC3P_PC_S180_D10
# Model already created for RBC3P_PC_S180_D23
# Model already created for RBC3P_PC_S180_D42
# Model already created for RBC3P_PC_S181_D10
# Model already created for RBC3P_PC_S181_D23
# Model already created for RBC3P_PC_S181_D42
# Model already created for RBC3P_PC_S182_D10
# Model already created for RBC3P_PC_S182_D23
# Model already created for RBC3P_PC_S182_D42
# Model already created for RBC3P_PC_S183_D10
# Model already created for RBC3P_PC_S183_D23
# Model already created for RBC3P_PC_S183_D42
# Model already created for RBC3P_PC_S184_D10
# Model already created for RBC3P_PC_S184_D23
# Model already created for RBC3P_PC_S184_D42
# Model already created for RBC3P_PC_S185_D10
# Model already created for RBC3P_PC_S185_D23
# Model already created for RBC3P_PC_S185_D42
# Model already created for RBC3P_PC_S186_D10
# Model already created for RBC3P_PC_S186_D23
# Model already created for RBC3P_PC_S186_D42
# Model already created for RBC3P_PC_S187_D10
# Model already created for RBC3P_PC_S187_D23
# Model already created for RBC3P_PC_S187_D42
# Model already created for RBC3P_PC_S188_D10
# Model already created for RBC3P_PC_S188_D23
# Model already created for RBC3P_PC_S188_D42
# Model already created for RBC3P_PC_S189_D10
# Model already created for RBC3P_PC_S189_D23
# Model already created for RBC3P_PC_S189_D42
# Model already created for RBC3P_PC_S190_D10
# Model already created for RBC3P_PC_S190_D23
# Model already created for RBC3P_PC_S190_D42
# Model already created for RBC3P_PC_S191_D10
# Model already created for RBC3P_PC_S191_D23
# Model already created for RBC3P_PC_S191_D42
# Model already created for RBC3P_PC_S192_D10
# Model already created for RBC3P_PC_S192_D23
# Model already created for RBC3P_PC_S192_D42
# Model already created for RBC3P_PC_S193_D10
# Model already created for RBC3P_PC_S193_D23
# Model already created for RBC3P_PC_S193_D42
# Model already created for RBC3P_PC_S194_D10
# Model already created for RBC3P_PC_S194_D23
# Model already created for RBC3P_PC_S194_D42
# Model already created for RBC3P_PC_S195_D10
# Model already created for RBC3P_PC_S195_D23
# Model already created for RBC3P_PC_S195_D42
# Model already created for RBC3P_PC_S196_D10
# Model already created for RBC3P_PC_S196_D23
# Model already created for RBC3P_PC_S196_D42
# Model already created for RBC3P_PC_S197_D10
# Model already created for RBC3P_PC_S197_D23
# Model already created for RBC3P_PC_S197_D42
# Model already created for RBC3P_PC_S198_D10
# Model already created for RBC3P_PC_S198_D23
# Model already created for RBC3P_PC_S198_D42
# Model already created for RBC3P_PC_S199_D10
# Model already created for RBC3P_PC_S199_D23
# Model already created for RBC3P_PC_S199_D42
# Model already created for RBC3P_PC_S200_D10
# Model already created for RBC3P_PC_S200_D23
# Model already created for RBC3P_PC_S200_D42
# Model already created for RBC3P_PC_S201_D10
# Model already created for RBC3P_PC_S201_D23
# Model already created for RBC3P_PC_S201_D42
# Model already created for RBC3P_PC_S202_D10
# Model already created for RBC3P_PC_S202_D23
# Model already created for RBC3P_PC_S202_D42
# Model already created for RBC3P_PC_S203_D10
# Model already created for RBC3P_PC_S203_D23
# Model already created for RBC3P_PC_S203_D42
# Model already created for RBC3P_PC_S204_D10
# Model already created for RBC3P_PC_S204_D23
# Model already created for RBC3P_PC_S204_D42
# Model already created for RBC3P_PC_S205_D10
# Model already created for RBC3P_PC_S205_D23
# Model already created for RBC3P_PC_S205_D42
# Model already created for RBC3P_PC_S206_D10
# Model already created for RBC3P_PC_S206_D23
# Model already created for RBC3P_PC_S206_D42
# Model already created for RBC3P_PC_S207_D10
# Model already created for RBC3P_PC_S207_D23
# Model already created for RBC3P_PC_S207_D42
# Model already created for RBC3P_PC_S208_D10
# Model already created for RBC3P_PC_S208_D23
# Model already created for RBC3P_PC_S208_D42
# Model already created for RBC3P_PC_S209_D10
# Model already created for RBC3P_PC_S209_D23
# Model already created for RBC3P_PC_S209_D42
# Model already created for RBC3P_PC_S210_D10
# Model already created for RBC3P_PC_S210_D23
# Model already created for RBC3P_PC_S210_D42
# Model already created for RBC3P_PC_S211_D10
# Model already created for RBC3P_PC_S211_D23
# Model already created for RBC3P_PC_S211_D42
# Model already created for RBC3P_PC_S212_D10
# Model already created for RBC3P_PC_S212_D23
# Model already created for RBC3P_PC_S212_D42
# Model already created for RBC3P_PC_S213_D10
# Model already created for RBC3P_PC_S213_D23
# Model already created for RBC3P_PC_S213_D42
# Model already created for RBC3P_PC_S214_D10
# Model already created for RBC3P_PC_S214_D23
# Model already created for RBC3P_PC_S214_D42
# Model already created for RBC3P_PC_S215_D10
# Model already created for RBC3P_PC_S215_D23
# Model already created for RBC3P_PC_S215_D42
# Model already created for RBC3P_PC_S216_D10
# Model already created for RBC3P_PC_S216_D23
# Model already created for RBC3P_PC_S216_D42
# Model already created for RBC3P_PC_S217_D10
# Model already created for RBC3P_PC_S217_D23
# Model already created for RBC3P_PC_S217_D42
# Model already created for RBC3P_PC_S218_D10
# Model already created for RBC3P_PC_S218_D23
# Model already created for RBC3P_PC_S218_D42
# Model already created for RBC3P_PC_S219_D10
# Model already created for RBC3P_PC_S219_D23
# Model already created for RBC3P_PC_S219_D42
# Model already created for RBC3P_PC_S220_D10
# Model already created for RBC3P_PC_S220_D23
# Model already created for RBC3P_PC_S220_D42
# Model already created for RBC3P_PC_S221_D10
# Model already created for RBC3P_PC_S221_D23
# Model already created for RBC3P_PC_S221_D42
# Model already created for RBC3P_PC_S222_D10
# Model already created for RBC3P_PC_S222_D23
# Model already created for RBC3P_PC_S222_D42
# Model already created for RBC3P_PC_S223_D10
# Model already created for RBC3P_PC_S223_D23
# Model already created for RBC3P_PC_S223_D42
# Model already created for RBC3P_PC_S224_D10
# Model already created for RBC3P_PC_S224_D23
# Model already created for RBC3P_PC_S224_D42
# Model already created for RBC3P_PC_S225_D10
# Model already created for RBC3P_PC_S225_D23
# Model already created for RBC3P_PC_S225_D42
# Model already created for RBC3P_PC_S226_D10
# Model already created for RBC3P_PC_S226_D23
# Model already created for RBC3P_PC_S226_D42
# Model already created for RBC3P_PC_S227_D10
# Model already created for RBC3P_PC_S227_D23
# Model already created for RBC3P_PC_S227_D42
# Model already created for RBC3P_PC_S228_D10
# Model already created for RBC3P_PC_S228_D23
# Model already created for RBC3P_PC_S228_D42
# Model already created for RBC3P_PC_S229_D10
# Model already created for RBC3P_PC_S229_D23
# Model already created for RBC3P_PC_S229_D42
# Model already created for RBC3P_PC_S230_D10
# Model already created for RBC3P_PC_S230_D23
# Model already created for RBC3P_PC_S230_D42
# Model already created for RBC3P_PC_S231_D10
# Model already created for RBC3P_PC_S231_D23
# Model already created for RBC3P_PC_S231_D42
# Model already created for RBC3P_PC_S232_D10
# Model already created for RBC3P_PC_S232_D23
# Model already created for RBC3P_PC_S232_D42
# Model already created for RBC3P_PC_S233_D10
# Model already created for RBC3P_PC_S233_D23
# Model already created for RBC3P_PC_S233_D42
# Model already created for RBC3P_PC_S234_D10
# Model already created for RBC3P_PC_S234_D23
# Model already created for RBC3P_PC_S234_D42
# Model already created for RBC3P_PC_S235_D10
# Model already created for RBC3P_PC_S235_D23
# Model already created for RBC3P_PC_S235_D42
# Model already created for RBC3P_PC_S236_D10
# Model already created for RBC3P_PC_S236_D23
# Model already created for RBC3P_PC_S236_D42
# Model already created for RBC3P_PC_S237_D10
# Model already created for RBC3P_PC_S237_D23
# Model already created for RBC3P_PC_S237_D42
# Model already created for RBC3P_PC_S238_D10
# Model already created for RBC3P_PC_S238_D23
# Model already created for RBC3P_PC_S238_D42
# Model already created for RBC3P_PC_S239_D10
# Model already created for RBC3P_PC_S239_D23
# Model already created for RBC3P_PC_S239_D42
# Model already created for RBC3P_PC_S240_D10
# Model already created for RBC3P_PC_S240_D23
# Model already created for RBC3P_PC_S240_D42
# Model already created for RBC3P_PC_S241_D10
# Model already created for RBC3P_PC_S241_D23
# Model already created for RBC3P_PC_S241_D42
# Model already created for RBC3P_PC_S242_D10
# Model already created for RBC3P_PC_S242_D23
# Model already created for RBC3P_PC_S242_D42
# Model already created for RBC3P_PC_S243_D10
# Model already created for RBC3P_PC_S243_D23
# Model already created for RBC3P_PC_S243_D42
# Model already created for RBC3P_PC_S244_D10
# Model already created for RBC3P_PC_S244_D23
# Model already created for RBC3P_PC_S244_D42
# Model already created for RBC3P_PC_S245_D10
# Model already created for RBC3P_PC_S245_D23
# Model already created for RBC3P_PC_S245_D42
# Model already created for RBC3P_PC_S246_D10
# Model already created for RBC3P_PC_S246_D23
# Model already created for RBC3P_PC_S246_D42
# Model already created for RBC3P_PC_S247_D10
# Model already created for RBC3P_PC_S247_D23
# Model already created for RBC3P_PC_S247_D42
# Model already created for RBC3P_PC_S248_D10
# Model already created for RBC3P_PC_S248_D23
# Model already created for RBC3P_PC_S248_D42
# Model already created for RBC3P_PC_S249_D10
# Model already created for RBC3P_PC_S249_D23
# Model already created for RBC3P_PC_S249_D42
# Model already created for RBC3P_PC_S250_D10
# Model already created for RBC3P_PC_S250_D23
# Model already created for RBC3P_PC_S250_D42
# Model already created for RBC3P_PC_S251_D10
# Model already created for RBC3P_PC_S251_D23
# Model already created for RBC3P_PC_S251_D42
# Model already created for RBC3P_PC_S252_D10
# Model already created for RBC3P_PC_S252_D23
# Model already created for RBC3P_PC_S252_D42
# Model already created for RBC3P_PC_S253_D10
# Model already created for RBC3P_PC_S253_D23
# Model already created for RBC3P_PC_S253_D42
# Model already created for RBC3P_PC_S254_D10
# Model already created for RBC3P_PC_S254_D23
# Model already created for RBC3P_PC_S254_D42
# Model already created for RBC3P_PC_S255_D10
# Model already created for RBC3P_PC_S255_D23
# Model already created for RBC3P_PC_S255_D42
# Model already created for RBC3P_PC_S256_D10
# Model already created for RBC3P_PC_S256_D23
# Model already created for RBC3P_PC_S256_D42
# Model already created for RBC3P_PC_S257_D10
# Model already created for RBC3P_PC_S257_D23
# Model already created for RBC3P_PC_S257_D42
# Model already created for RBC3P_PC_S258_D10
# Model already created for RBC3P_PC_S258_D23
# Model already created for RBC3P_PC_S258_D42
# Model already created for RBC3P_PC_S259_D10
# Model already created for RBC3P_PC_S259_D23
# Model already created for RBC3P_PC_S259_D42
# Model already created for RBC3P_PC_S260_D10
# Model already created for RBC3P_PC_S260_D23
# Model already created for RBC3P_PC_S260_D42
# Model already created for RBC3P_PC_S261_D10
# Model already created for RBC3P_PC_S261_D23
# Model already created for RBC3P_PC_S261_D42
# Model already created for RBC3P_PC_S262_D10
# Model already created for RBC3P_PC_S262_D23
# Model already created for RBC3P_PC_S262_D42
# Model already created for RBC3P_PC_S263_D10
# Model already created for RBC3P_PC_S263_D23
# Model already created for RBC3P_PC_S263_D42
# Model already created for RBC3P_PC_S264_D10
# Model already created for RBC3P_PC_S264_D23
# Model already created for RBC3P_PC_S264_D42
# Model already created for RBC3P_PC_S265_D10
# Model already created for RBC3P_PC_S265_D23
# Model already created for RBC3P_PC_S265_D42
# Model already created for RBC3P_PC_S266_D10
# Model already created for RBC3P_PC_S266_D23
# Model already created for RBC3P_PC_S266_D42
# Model already created for RBC3P_PC_S267_D10
# Model already created for RBC3P_PC_S267_D23
# Model already created for RBC3P_PC_S267_D42
# Model already created for RBC3P_PC_S268_D10
# Model already created for RBC3P_PC_S268_D23
# Model already created for RBC3P_PC_S268_D42
# Model already created for RBC3P_PC_S269_D10
# Model already created for RBC3P_PC_S269_D23
# Model already created for RBC3P_PC_S269_D42
# Model already created for RBC3P_PC_S270_D10
# Model already created for RBC3P_PC_S270_D23
# Model already created for RBC3P_PC_S270_D42
# Model already created for RBC3P_PC_S271_D10
# Model already created for RBC3P_PC_S271_D23
# Model already created for RBC3P_PC_S271_D42
# Model already created for RBC3P_PC_S272_D10
# Model already created for RBC3P_PC_S272_D23
# Model already created for RBC3P_PC_S272_D42
# Model already created for RBC3P_PC_S273_D10
# Model already created for RBC3P_PC_S273_D23
# Model already created for RBC3P_PC_S273_D42
# Model already created for RBC3P_PC_S274_D10
# Model already created for RBC3P_PC_S274_D23
# Model already created for RBC3P_PC_S274_D42
# Model already created for RBC3P_PC_S275_D10
# Model already created for RBC3P_PC_S275_D23
# Model already created for RBC3P_PC_S275_D42
# Model already created for RBC3P_PC_S276_D10
# Model already created for RBC3P_PC_S276_D23
# Model already created for RBC3P_PC_S276_D42
# Model already created for RBC3P_PC_S277_D10
# Model already created for RBC3P_PC_S277_D23
# Model already created for RBC3P_PC_S277_D42
# Model already created for RBC3P_PC_S278_D10
# Model already created for RBC3P_PC_S278_D23
# Model already created for RBC3P_PC_S278_D42
# Model already created for RBC3P_PC_S279_D10
# Model already created for RBC3P_PC_S279_D23
# Model already created for RBC3P_PC_S279_D42
# Model already created for RBC3P_PC_S280_D10
# Model already created for RBC3P_PC_S280_D23
# Model already created for RBC3P_PC_S280_D42
# Model already created for RBC3P_PC_S281_D10
# Model already created for RBC3P_PC_S281_D23
# Model already created for RBC3P_PC_S281_D42
# Model already created for RBC3P_PC_S282_D10
# Model already created for RBC3P_PC_S282_D23
# Model already created for RBC3P_PC_S282_D42
# Model already created for RBC3P_PC_S283_D10
# Model already created for RBC3P_PC_S283_D23
# Model already created for RBC3P_PC_S283_D42
# Model already created for RBC3P_PC_S284_D10
# Model already created for RBC3P_PC_S284_D23
# Model already created for RBC3P_PC_S284_D42
# Model already created for RBC3P_PC_S285_D10
# Model already created for RBC3P_PC_S285_D23
# Model already created for RBC3P_PC_S285_D42
# Model already created for RBC3P_PC_S286_D10
# Model already created for RBC3P_PC_S286_D23
# Model already created for RBC3P_PC_S286_D42
# Model already created for RBC3P_PC_S287_D10
# Model already created for RBC3P_PC_S287_D23
# Model already created for RBC3P_PC_S287_D42
# Model already created for RBC3P_PC_S288_D10
# Model already created for RBC3P_PC_S288_D23
# Model already created for RBC3P_PC_S288_D42
# Model already created for RBC3P_PC_S289_D10
# Model already created for RBC3P_PC_S289_D23
# Model already created for RBC3P_PC_S289_D42
# Model already created for RBC3P_PC_S290_D10
# Model already created for RBC3P_PC_S290_D23
# Model already created for RBC3P_PC_S290_D42
# Model already created for RBC3P_PC_S291_D10
# Model already created for RBC3P_PC_S291_D23
# Model already created for RBC3P_PC_S291_D42
# Model already created for RBC3P_PC_S292_D10
# Model already created for RBC3P_PC_S292_D23
# Model already created for RBC3P_PC_S292_D42
# Model already created for RBC3P_PC_S293_D10
# Model already created for RBC3P_PC_S293_D23
# Model already created for RBC3P_PC_S293_D42
# Model already created for RBC3P_PC_S294_D10
# Model already created for RBC3P_PC_S294_D23
# Model already created for RBC3P_PC_S294_D42
# Model already created for RBC3P_PC_S295_D10
# Model already created for RBC3P_PC_S295_D23
# Model already created for RBC3P_PC_S295_D42
# Model already created for RBC3P_PC_S296_D10
# Model already created for RBC3P_PC_S296_D23
# Model already created for RBC3P_PC_S296_D42
# Model already created for RBC3P_PC_S297_D10
# Model already created for RBC3P_PC_S297_D23
# Model already created for RBC3P_PC_S297_D42
# Model already created for RBC3P_PC_S298_D10
# Model already created for RBC3P_PC_S298_D23
# Model already created for RBC3P_PC_S298_D42
# Model already created for RBC3P_PC_S299_D10
# Model already created for RBC3P_PC_S299_D23
# Model already created for RBC3P_PC_S299_D42
# Model already created for RBC3P_PC_S300_D10
# Model already created for RBC3P_PC_S300_D23
# Model already created for RBC3P_PC_S300_D42
# Model already created for RBC3P_PC_S301_D10
# Model already created for RBC3P_PC_S301_D23
# Model already created for RBC3P_PC_S301_D42
# Model already created for RBC3P_PC_S302_D10
# Model already created for RBC3P_PC_S302_D23
# Model already created for RBC3P_PC_S302_D42
# Model already created for RBC3P_PC_S303_D10
# Model already created for RBC3P_PC_S303_D23
# Model already created for RBC3P_PC_S303_D42
# Model already created for RBC3P_PC_S304_D10
# Model already created for RBC3P_PC_S304_D23
# Model already created for RBC3P_PC_S304_D42
# Model already created for RBC3P_PC_S305_D10
# Model already created for RBC3P_PC_S305_D23
# Model already created for RBC3P_PC_S305_D42
# Model already created for RBC3P_PC_S306_D10
# Model already created for RBC3P_PC_S306_D23
# Model already created for RBC3P_PC_S306_D42
# Model already created for RBC3P_PC_S307_D10
# Model already created for RBC3P_PC_S307_D23
# Model already created for RBC3P_PC_S307_D42
# Model already created for RBC3P_PC_S308_D10
# Model already created for RBC3P_PC_S308_D23
# Model already created for RBC3P_PC_S308_D42
# Model already created for RBC3P_PC_S309_D10
# Model already created for RBC3P_PC_S309_D23
# Model already created for RBC3P_PC_S309_D42
# Model already created for RBC3P_PC_S310_D10
# Model already created for RBC3P_PC_S310_D23
# Model already created for RBC3P_PC_S310_D42
# Model already created for RBC3P_PC_S311_D10
# Model already created for RBC3P_PC_S311_D23
# Model already created for RBC3P_PC_S311_D42
# Model already created for RBC3P_PC_S312_D10
# Model already created for RBC3P_PC_S312_D23
# Model already created for RBC3P_PC_S312_D42
# Model already created for RBC3P_PC_S313_D10
# Model already created for RBC3P_PC_S313_D23
# Model already created for RBC3P_PC_S313_D42
# Model already created for RBC3P_PC_S314_D10
# Model already created for RBC3P_PC_S314_D23
# Model already created for RBC3P_PC_S314_D42
# Model already created for RBC3P_PC_S315_D10
# Model already created for RBC3P_PC_S315_D23
# Model already created for RBC3P_PC_S315_D42
# Model already created for RBC3P_PC_S316_D10
# Model already created for RBC3P_PC_S316_D23
# Model already created for RBC3P_PC_S316_D42
# Model already created for RBC3P_PC_S317_D10
# Model already created for RBC3P_PC_S317_D23
# Model already created for RBC3P_PC_S317_D42
# Model already created for RBC3P_PC_S318_D10
# Model already created for RBC3P_PC_S318_D23
# Model already created for RBC3P_PC_S318_D42
# Model already created for RBC3P_PC_S319_D10
# Model already created for RBC3P_PC_S319_D23
# Model already created for RBC3P_PC_S319_D42
# Model already created for RBC3P_PC_S320_D10
# Model already created for RBC3P_PC_S320_D23
# Model already created for RBC3P_PC_S320_D42
# Model already created for RBC3P_PC_S321_D10
# Model already created for RBC3P_PC_S321_D23
# Model already created for RBC3P_PC_S321_D42
# Model already created for RBC3P_PC_S322_D10
# Model already created for RBC3P_PC_S322_D23
# Model already created for RBC3P_PC_S322_D42
# Model already created for RBC3P_PC_S323_D10
# Model already created for RBC3P_PC_S323_D23
# Model already created for RBC3P_PC_S323_D42
# Model already created for RBC3P_PC_S324_D10
# Model already created for RBC3P_PC_S324_D23
# Model already created for RBC3P_PC_S324_D42
# Model already created for RBC3P_PC_S325_D10
# Model already created for RBC3P_PC_S325_D23
# Model already created for RBC3P_PC_S325_D42
# Model already created for RBC3P_PC_S326_D10
# Model already created for RBC3P_PC_S326_D23
# Model already created for RBC3P_PC_S326_D42
# Model already created for RBC3P_PC_S327_D10
# Model already created for RBC3P_PC_S327_D23
# Model already created for RBC3P_PC_S327_D42
# Model already created for RBC3P_PC_S328_D10
# Model already created for RBC3P_PC_S328_D23
# Model already created for RBC3P_PC_S328_D42
# Model already created for RBC3P_PC_S329_D10
# Model already created for RBC3P_PC_S329_D23
# Model already created for RBC3P_PC_S329_D42
# Model already created for RBC3P_PC_S330_D10
# Model already created for RBC3P_PC_S330_D23
# Model already created for RBC3P_PC_S330_D42
# Model already created for RBC3P_PC_S331_D10
# Model already created for RBC3P_PC_S331_D23
# Model already created for RBC3P_PC_S331_D42
# Model already created for RBC3P_PC_S332_D10
# Model already created for RBC3P_PC_S332_D23
# Model already created for RBC3P_PC_S332_D42
# Model already created for RBC3P_PC_S333_D10
# Model already created for RBC3P_PC_S333_D23
# Model already created for RBC3P_PC_S333_D42
# Model already created for RBC3P_PC_S334_D10
# Model already created for RBC3P_PC_S334_D23
# Model already created for RBC3P_PC_S334_D42
# Model already created for RBC3P_PC_S335_D10
# Model already created for RBC3P_PC_S335_D23
# Model already created for RBC3P_PC_S335_D42
# Model already created for RBC3P_PC_S336_D10
# Model already created for RBC3P_PC_S336_D23
# Model already created for RBC3P_PC_S336_D42
# Model already created for RBC3P_PC_S337_D10
# Model already created for RBC3P_PC_S337_D23
# Model already created for RBC3P_PC_S337_D42
# Model already created for RBC3P_PC_S338_D10
# Model already created for RBC3P_PC_S338_D23
# Model already created for RBC3P_PC_S338_D42
# Model already created for RBC3P_PC_S339_D10
# Model already created for RBC3P_PC_S339_D23
# Model already created for RBC3P_PC_S339_D42
# Model already created for RBC3P_PC_S340_D10
# Model already created for RBC3P_PC_S340_D23
# Model already created for RBC3P_PC_S340_D42
# Model already created for RBC3P_PC_S341_D10
# Model already created for RBC3P_PC_S341_D23
# Model already created for RBC3P_PC_S341_D42
# Model already created for RBC3P_PC_S342_D10
# Model already created for RBC3P_PC_S342_D23
# Model already created for RBC3P_PC_S342_D42
# Model already created for RBC3P_PC_S343_D10
# Model already created for RBC3P_PC_S343_D23
# Model already created for RBC3P_PC_S343_D42
# Model already created for RBC3P_PC_S344_D10
# Model already created for RBC3P_PC_S344_D23
# Model already created for RBC3P_PC_S344_D42
# Model already created for RBC3P_PC_S345_D10
# Model already created for RBC3P_PC_S345_D23
# Model already created for RBC3P_PC_S345_D42
# Model already created for RBC3P_PC_S346_D10
# Model already created for RBC3P_PC_S346_D23
# Model already created for RBC3P_PC_S346_D42
# Model already created for RBC3P_PC_S347_D10
# Model already created for RBC3P_PC_S347_D23
# Model already created for RBC3P_PC_S347_D42
# Model already created for RBC3P_PC_S348_D10
# Model already created for RBC3P_PC_S348_D23
# Model already created for RBC3P_PC_S348_D42
# Model already created for RBC3P_PC_S349_D10
# Model already created for RBC3P_PC_S349_D23
# Model already created for RBC3P_PC_S349_D42
# Model already created for RBC3P_PC_S350_D10
# Model already created for RBC3P_PC_S350_D23
# Model already created for RBC3P_PC_S350_D42
# Model already created for RBC3P_PC_S351_D10
# Model already created for RBC3P_PC_S351_D23
# Model already created for RBC3P_PC_S351_D42
# Model already created for RBC3P_PC_S352_D10
# Model already created for RBC3P_PC_S352_D23
# Model already created for RBC3P_PC_S352_D42
# Model already created for RBC3P_PC_S353_D10
# Model already created for RBC3P_PC_S353_D23
# Model already created for RBC3P_PC_S353_D42
# Model already created for RBC3P_PC_S354_D10
# Model already created for RBC3P_PC_S354_D23
# Model already created for RBC3P_PC_S354_D42
# Model already created for RBC3P_PC_S355_D10
# Model already created for RBC3P_PC_S355_D23
# Model already created for RBC3P_PC_S355_D42
# Model already created for RBC3P_PC_S356_D10
# Model already created for RBC3P_PC_S356_D23
# Model already created for RBC3P_PC_S356_D42
# Model already created for RBC3P_PC_S357_D10
# Model already created for RBC3P_PC_S357_D23
# Model already created for RBC3P_PC_S357_D42
# Model already created for RBC3P_PC_S358_D10
# Model already created for RBC3P_PC_S358_D23
# Model already created for RBC3P_PC_S358_D42
# Model already created for RBC3P_PC_S359_D10
# Model already created for RBC3P_PC_S359_D23
# Model already created for RBC3P_PC_S359_D42
# Model already created for RBC3P_PC_S360_D10
# Model already created for RBC3P_PC_S360_D23
# Model already created for RBC3P_PC_S360_D42
# Model already created for RBC3P_PC_S361_D10
# Model already created for RBC3P_PC_S361_D23
# Model already created for RBC3P_PC_S361_D42
# Model already created for RBC3P_PC_S362_D10
# Model already created for RBC3P_PC_S362_D23
# Model already created for RBC3P_PC_S362_D42
# Model already created for RBC3P_PC_S363_D10
# Model already created for RBC3P_PC_S363_D23
# Model already created for RBC3P_PC_S363_D42
# Model already created for RBC3P_PC_S364_D10
# Model already created for RBC3P_PC_S364_D23
# Model already created for RBC3P_PC_S364_D42
# Model already created for RBC3P_PC_S365_D10
# Model already created for RBC3P_PC_S365_D23
# Model already created for RBC3P_PC_S365_D42
# Model already created for RBC3P_PC_S366_D10
# Model already created for RBC3P_PC_S366_D23
# Model already created for RBC3P_PC_S366_D42
# ...
# Model already created for RBC3P_PC_S498_D10
# Model already created for RBC3P_PC_S498_D23
# Model already created for RBC3P_PC_S498_D42
# Model already created for RBC3P_PC_S499_D10
# Model already created for RBC3P_PC_S499_D23
# Model already created for RBC3P_PC_S499_D42
# Model already created for RBC3P_PC_S500_D10
# Model already created for RBC3P_PC_S500_D23
# Model already created for RBC3P_PC_S500_D42
# Model already created for RBC3P_PC_S501_D10
# Model already created for RBC3P_PC_S501_D23
# Model already created for RBC3P_PC_S501_D42
# Model already created for RBC3P_PC_S502_D10
# Model already created for RBC3P_PC_S502_D23
# Model already created for RBC3P_PC_S502_D42
# Model already created for RBC3P_PC_S503_D10
# Model already created for RBC3P_PC_S503_D23
# Model already created for RBC3P_PC_S503_D42
# Model already created for RBC3P_PC_S504_D10
# Model already created for RBC3P_PC_S504_D23
# Model already created for RBC3P_PC_S504_D42
# Model already created for RBC3P_PC_S505_D10
# Model already created for RBC3P_PC_S505_D23
# Model already created for RBC3P_PC_S505_D42
# Model already created for RBC3P_PC_S506_D10
# Model already created for RBC3P_PC_S506_D23
# Model already created for RBC3P_PC_S506_D42
# Model already created for RBC3P_PC_S507_D10
# Model already created for RBC3P_PC_S507_D23
# Model already created for RBC3P_PC_S507_D42
# Model already created for RBC3P_PC_S508_D10
# Model already created for RBC3P_PC_S508_D23
# Model already created for RBC3P_PC_S508_D42
# Model already created for RBC3P_PC_S509_D10
# Model already created for RBC3P_PC_S509_D23
# Model already created for RBC3P_PC_S509_D42
# Model already created for RBC3P_PC_S510_D10
# Model already created for RBC3P_PC_S510_D23
# Model already created for RBC3P_PC_S510_D42
# Model already created for RBC3P_PC_S511_D10
# Model already created for RBC3P_PC_S511_D23
# Model already created for RBC3P_PC_S511_D42
# Model already created for RBC3P_PC_S512_D10
# Model already created for RBC3P_PC_S512_D23
# Model already created for RBC3P_PC_S512_D42
# Model already created for RBC3P_PC_S513_D10
# Model already created for RBC3P_PC_S513_D23
# Model already created for RBC3P_PC_S513_D42
# Model already created for RBC3P_PC_S514_D10
# Model already created for RBC3P_PC_S514_D23
# Model already created for RBC3P_PC_S514_D42
# Model already created for RBC3P_PC_S515_D10
# Model already created for RBC3P_PC_S515_D23
# Model already created for RBC3P_PC_S515_D42
# Model already created for RBC3P_PC_S516_D10
# Model already created for RBC3P_PC_S516_D23
# Model already created for RBC3P_PC_S516_D42
# Model already created for RBC3P_PC_S517_D10
# Model already created for RBC3P_PC_S517_D23
# Model already created for RBC3P_PC_S517_D42
# Model already created for RBC3P_PC_S518_D10
# Model already created for RBC3P_PC_S518_D23
# Model already created for RBC3P_PC_S518_D42
# Model already created for RBC3P_PC_S519_D10
# Model already created for RBC3P_PC_S519_D23
# Model already created for RBC3P_PC_S519_D42
# Model already created for RBC3P_PC_S520_D10
# Model already created for RBC3P_PC_S520_D23
# Model already created for RBC3P_PC_S520_D42
# Model already created for RBC3P_PC_S521_D10
# Model already created for RBC3P_PC_S521_D23
# Model already created for RBC3P_PC_S521_D42
# Model already created for RBC3P_PC_S522_D10
# Model already created for RBC3P_PC_S522_D23
# Model already created for RBC3P_PC_S522_D42
# Model already created for RBC3P_PC_S523_D10
# Model already created for RBC3P_PC_S523_D23
# Model already created for RBC3P_PC_S523_D42
# Model already created for RBC3P_PC_S524_D10
# Model already created for RBC3P_PC_S524_D23
# Model already created for RBC3P_PC_S524_D42
# Model already created for RBC3P_PC_S525_D10
# Model already created for RBC3P_PC_S525_D23
# Model already created for RBC3P_PC_S525_D42
# Model already created for RBC3P_PC_S526_D10
# Model already created for RBC3P_PC_S526_D23
# Model already created for RBC3P_PC_S526_D42
# Model already created for RBC3P_PC_S527_D10
# Model already created for RBC3P_PC_S527_D23
# Model already created for RBC3P_PC_S527_D42
# Model already created for RBC3P_PC_S528_D10
# Model already created for RBC3P_PC_S528_D23
# Model already created for RBC3P_PC_S528_D42
# Model already created for RBC3P_PC_S529_D10
# Model already created for RBC3P_PC_S529_D23
# Model already created for RBC3P_PC_S529_D42
# Model already created for RBC3P_PC_S530_D10
# Model already created for RBC3P_PC_S530_D23
# Model already created for RBC3P_PC_S530_D42
# Model already created for RBC3P_PC_S531_D10
# Model already created for RBC3P_PC_S531_D23
# Model already created for RBC3P_PC_S531_D42
# Model already created for RBC3P_PC_S532_D10
# Model already created for RBC3P_PC_S532_D23
# Model already created for RBC3P_PC_S532_D42
# Model already created for RBC3P_PC_S533_D10
# Model already created for RBC3P_PC_S533_D23
# Model already created for RBC3P_PC_S533_D42
# Model already created for RBC3P_PC_S534_D10
# Model already created for RBC3P_PC_S534_D23
# Model already created for RBC3P_PC_S534_D42
# Model already created for RBC3P_PC_S535_D10
# Model already created for RBC3P_PC_S535_D23
# Model already created for RBC3P_PC_S535_D42
# Model already created for RBC3P_PC_S536_D10
# Model already created for RBC3P_PC_S536_D23
# Model already created for RBC3P_PC_S536_D42
# Model already created for RBC3P_PC_S537_D10
# Model already created for RBC3P_PC_S537_D23
# Model already created for RBC3P_PC_S537_D42
# Model already created for RBC3P_PC_S538_D10
# Model already created for RBC3P_PC_S538_D23
# Model already created for RBC3P_PC_S538_D42
# Model already created for RBC3P_PC_S539_D10
# Model already created for RBC3P_PC_S539_D23
# Model already created for RBC3P_PC_S539_D42
# Model already created for RBC3P_PC_S540_D10
# Model already created for RBC3P_PC_S540_D23
# Model already created for RBC3P_PC_S540_D42
# Model already created for RBC3P_PC_S541_D10
# Model already created for RBC3P_PC_S541_D23
# Model already created for RBC3P_PC_S541_D42
# Model already created for RBC3P_PC_S542_D10
# Model already created for RBC3P_PC_S542_D23
# Model already created for RBC3P_PC_S542_D42
# Model already created for RBC3P_PC_S543_D10
# Model already created for RBC3P_PC_S543_D23
# Model already created for RBC3P_PC_S543_D42
# Model already created for RBC3P_PC_S544_D10
# Model already created for RBC3P_PC_S544_D23
# Model already created for RBC3P_PC_S544_D42
# Model already created for RBC3P_PC_S545_D10
# Model already created for RBC3P_PC_S545_D23
# Model already created for RBC3P_PC_S545_D42
# Model already created for RBC3P_PC_S546_D10
# Model already created for RBC3P_PC_S546_D23
# Model already created for RBC3P_PC_S546_D42
# Model already created for RBC3P_PC_S547_D10
# Model already created for RBC3P_PC_S547_D23
# Model already created for RBC3P_PC_S547_D42
# Model already created for RBC3P_PC_S548_D10
# Model already created for RBC3P_PC_S548_D23
# Model already created for RBC3P_PC_S548_D42
# Model already created for RBC3P_PC_S549_D10
# Model already created for RBC3P_PC_S549_D23
# Model already created for RBC3P_PC_S549_D42
# Model already created for RBC3P_PC_S550_D10
# Model already created for RBC3P_PC_S550_D23
# Model already created for RBC3P_PC_S550_D42
# Model already created for RBC3P_PC_S551_D10
# Model already created for RBC3P_PC_S551_D23
# Model already created for RBC3P_PC_S551_D42
# Model already created for RBC3P_PC_S552_D10
# Model already created for RBC3P_PC_S552_D23
# Model already created for RBC3P_PC_S552_D42
# Model already created for RBC3P_PC_S553_D10
# Model already created for RBC3P_PC_S553_D23
# Model already created for RBC3P_PC_S553_D42
# Model already created for RBC3P_PC_S554_D10
# Model already created for RBC3P_PC_S554_D23
# Model already created for RBC3P_PC_S554_D42
# Model already created for RBC3P_PC_S555_D10
# Model already created for RBC3P_PC_S555_D23
# Model already created for RBC3P_PC_S555_D42
# Model already created for RBC3P_PC_S556_D10
# Model already created for RBC3P_PC_S556_D23
# Model already created for RBC3P_PC_S556_D42
# Model already created for RBC3P_PC_S557_D10
# Model already created for RBC3P_PC_S557_D23
# Model already created for RBC3P_PC_S557_D42
# Model already created for RBC3P_PC_S558_D10
# Model already created for RBC3P_PC_S558_D23
# Model already created for RBC3P_PC_S558_D42
# Model already created for RBC3P_PC_S559_D10
# Model already created for RBC3P_PC_S559_D23
# Model already created for RBC3P_PC_S559_D42
# Model already created for RBC3P_PC_S560_D10
# Model already created for RBC3P_PC_S560_D23
# Model already created for RBC3P_PC_S560_D42
# Model already created for RBC3P_PC_S561_D10
# Model already created for RBC3P_PC_S561_D23
# Model already created for RBC3P_PC_S561_D42
# Model already created for RBC3P_PC_S562_D10
# Model already created for RBC3P_PC_S562_D23
# Model already created for RBC3P_PC_S562_D42
# Model already created for RBC3P_PC_S563_D10
# Model already created for RBC3P_PC_S563_D23
# Model already created for RBC3P_PC_S563_D42
# Model already created for RBC3P_PC_S564_D10
# Model already created for RBC3P_PC_S564_D23
# Model already created for RBC3P_PC_S564_D42
# Model already created for RBC3P_PC_S565_D10
# Model already created for RBC3P_PC_S565_D23
# Model already created for RBC3P_PC_S565_D42
# Model already created for RBC3P_PC_S566_D10
# Model already created for RBC3P_PC_S566_D23
# Model already created for RBC3P_PC_S566_D42
# Model already created for RBC3P_PC_S567_D10
# Model already created for RBC3P_PC_S567_D23
# Model already created for RBC3P_PC_S567_D42
# Model already created for RBC3P_PC_S568_D10
# Model already created for RBC3P_PC_S568_D23
# Model already created for RBC3P_PC_S568_D42
# Model already created for RBC3P_PC_S569_D10
# Model already created for RBC3P_PC_S569_D23
# Model already created for RBC3P_PC_S569_D42
# Model already created for RBC3P_PC_S570_D10
# Model already created for RBC3P_PC_S570_D23
# Model already created for RBC3P_PC_S570_D42
# Model already created for RBC3P_PC_S571_D10
# Model already created for RBC3P_PC_S571_D23
# Model already created for RBC3P_PC_S571_D42
# Model already created for RBC3P_PC_S572_D10
# Model already created for RBC3P_PC_S572_D23
# Model already created for RBC3P_PC_S572_D42
# Model already created for RBC3P_PC_S573_D10
# Model already created for RBC3P_PC_S573_D23
# Model already created for RBC3P_PC_S573_D42
# Model already created for RBC3P_PC_S574_D10
# Model already created for RBC3P_PC_S574_D23
# Model already created for RBC3P_PC_S574_D42
# Model already created for RBC3P_PC_S575_D10
# Model already created for RBC3P_PC_S575_D23
# Model already created for RBC3P_PC_S575_D42
# Model already created for RBC3P_PC_S576_D10
# Model already created for RBC3P_PC_S576_D23
# Model already created for RBC3P_PC_S576_D42
# Model already created for RBC3P_PC_S577_D10
# Model already created for RBC3P_PC_S577_D23
# Model already created for RBC3P_PC_S577_D42
# Model already created for RBC3P_PC_S578_D10
# Model already created for RBC3P_PC_S578_D23
# Model already created for RBC3P_PC_S578_D42
# Model already created for RBC3P_PC_S579_D10
# Model already created for RBC3P_PC_S579_D23
# Model already created for RBC3P_PC_S579_D42
# Model already created for RBC3P_PC_S580_D10
# Model already created for RBC3P_PC_S580_D23
# Model already created for RBC3P_PC_S580_D42
# Model already created for RBC3P_PC_S581_D10
# Model already created for RBC3P_PC_S581_D23
# Model already created for RBC3P_PC_S581_D42
# Model already created for RBC3P_PC_S582_D10
# Model already created for RBC3P_PC_S582_D23
# Model already created for RBC3P_PC_S582_D42
# Model already created for RBC3P_PC_S583_D10
# Model already created for RBC3P_PC_S583_D23
# Model already created for RBC3P_PC_S583_D42
# Model already created for RBC3P_PC_S584_D10
# Model already created for RBC3P_PC_S584_D23
# Model already created for RBC3P_PC_S584_D42
# Model already created for RBC3P_PC_S585_D10
# Model already created for RBC3P_PC_S585_D23
# Model already created for RBC3P_PC_S585_D42
# Model already created for RBC3P_PC_S586_D10
# Model already created for RBC3P_PC_S586_D23
# Model already created for RBC3P_PC_S586_D42
# Model already created for RBC3P_PC_S587_D10
# Model already created for RBC3P_PC_S587_D23
# Model already created for RBC3P_PC_S587_D42
# Model already created for RBC3P_PC_S588_D10
# Model already created for RBC3P_PC_S588_D23
# Model already created for RBC3P_PC_S588_D42
# Model already created for RBC3P_PC_S589_D10
# Model already created for RBC3P_PC_S589_D23
# Model already created for RBC3P_PC_S589_D42
# Model already created for RBC3P_PC_S590_D10
# Model already created for RBC3P_PC_S590_D23
# Model already created for RBC3P_PC_S590_D42
# Model already created for RBC3P_PC_S591_D10
# Model already created for RBC3P_PC_S591_D23
# Model already created for RBC3P_PC_S591_D42
# Model already created for RBC3P_PC_S592_D10
# Model already created for RBC3P_PC_S592_D23
# Model already created for RBC3P_PC_S592_D42
# Model already created for RBC3P_PC_S593_D10
# Model already created for RBC3P_PC_S593_D23
# Model already created for RBC3P_PC_S593_D42
# Model already created for RBC3P_PC_S594_D10
# Model already created for RBC3P_PC_S594_D23
# Model already created for RBC3P_PC_S594_D42
# Model already created for RBC3P_PC_S595_D10
# Model already created for RBC3P_PC_S595_D23
# Model already created for RBC3P_PC_S595_D42
# Model already created for RBC3P_PC_S596_D10
# Model already created for RBC3P_PC_S596_D23
# Model already created for RBC3P_PC_S596_D42
# Model already created for RBC3P_PC_S597_D10
# Model already created for RBC3P_PC_S597_D23
# Model already created for RBC3P_PC_S597_D42
# Model already created for RBC3P_PC_S598_D10
# Model already created for RBC3P_PC_S598_D23
# Model already created for RBC3P_PC_S598_D42
# Model already created for RBC3P_PC_S599_D10
# Model already created for RBC3P_PC_S599_D23
# Model already created for RBC3P_PC_S599_D42
# Model already created for RBC3P_PC_S600_D10
# Model already created for RBC3P_PC_S600_D23
# Model already created for RBC3P_PC_S600_D42
# Model already created for RBC3P_PC_S601_D10
# Model already created for RBC3P_PC_S601_D23
# Model already created for RBC3P_PC_S601_D42
# Model already created for RBC3P_PC_S602_D10
# Model already created for RBC3P_PC_S602_D23
# Model already created for RBC3P_PC_S602_D42
# Model already created for RBC3P_PC_S603_D10
# Model already created for RBC3P_PC_S603_D23
# Model already created for RBC3P_PC_S603_D42
# Model already created for RBC3P_PC_S604_D10
# Model already created for RBC3P_PC_S604_D23
# Model already created for RBC3P_PC_S604_D42
# Model already created for RBC3P_PC_S605_D10
# Model already created for RBC3P_PC_S605_D23
# Model already created for RBC3P_PC_S605_D42
# Model already created for RBC3P_PC_S606_D10
# Model already created for RBC3P_PC_S606_D23
# Model already created for RBC3P_PC_S606_D42
# Model already created for RBC3P_PC_S607_D10
# Model already created for RBC3P_PC_S607_D23
# Model already created for RBC3P_PC_S607_D42
# Model already created for RBC3P_PC_S608_D10
# Model already created for RBC3P_PC_S608_D23
# Model already created for RBC3P_PC_S608_D42
# Model already created for RBC3P_PC_S609_D10
# Model already created for RBC3P_PC_S609_D23
# Model already created for RBC3P_PC_S609_D42
# Model already created for RBC3P_PC_S610_D10
# Model already created for RBC3P_PC_S610_D23
# Model already created for RBC3P_PC_S610_D42
# Model already created for RBC3P_PC_S611_D10
# Model already created for RBC3P_PC_S611_D23
# Model already created for RBC3P_PC_S611_D42
# Model already created for RBC3P_PC_S612_D10
# Model already created for RBC3P_PC_S612_D23
# Model already created for RBC3P_PC_S612_D42
# Model already created for RBC3P_PC_S613_D10
# Model already created for RBC3P_PC_S613_D23
# Model already created for RBC3P_PC_S613_D42
# Model already created for RBC3P_PC_S614_D10
# Model already created for RBC3P_PC_S614_D23
# Model already created for RBC3P_PC_S614_D42
# Model already created for RBC3P_PC_S615_D10
# Model already created for RBC3P_PC_S615_D23
# Model already created for RBC3P_PC_S615_D42
# Model already created for RBC3P_PC_S616_D10
# Model already created for RBC3P_PC_S616_D23
# Model already created for RBC3P_PC_S616_D42
# Model already created for RBC3P_PC_Mean_D10
# Model already created for RBC3P_PC_Median_D10
# Model already created for RBC3P_PC_Mean_D23
# Model already created for RBC3P_PC_Median_D23
# Model already created for RBC3P_PC_Mean_D42
# Model already created for RBC3P_PC_Median_D42
